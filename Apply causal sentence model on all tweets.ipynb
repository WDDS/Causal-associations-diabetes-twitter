# %% [markdown]
# ### The trained causal sentence model (binary classifier) will be applied on all diabetes related tweets to determine only tweets containing causal information

# %%
import pandas as pd
import numpy as np
import spacy 
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, matthews_corrcoef
from transformers import BertForSequenceClassification, AutoTokenizer, Trainer, TrainingArguments
from transformers import AdamW, get_linear_schedule_with_warmup
from tqdm import tqdm, trange
import random
import os
import torch.nn.functional as F
import torch
from torch.nn import CrossEntropyLoss
import torch.nn as nn
from torch.utils.data import DataLoader, DataLoader
import transformers
from tqdm import tqdm, trange
#from google.colab import drive, files
import io
import sys
from utils import *
from torch.nn.parallel import DistributedDataParallel
import torch.multiprocessing as mp
import torch.distributed as dist

diabetes_keywords = [
"glucose", "#glucose","blood glucose", "#bloodglucose",
"insulin", "#insulin", "insulin pump", "#insulinpump",
"diabetes", "#diabetes", "t1d", "#t1d", "#type1diabetes",
"#type1", "t2d", "#t2d", "#type2diabetes", "#type2",
"#bloodsugar", "#dsma", "#bgnow", "#wearenotwaiting",
"#insulin4all", "dblog", "#dblog", "diyps", "#diyps",
"hba1c", "#hba1c", "#cgm", "#freestylelibre",
"diabetic", "#diabetic", "#gbdoc", "finger prick",
"#fingerprick", "#gestational", "gestational diabetes",
"#gdm", "freestyle libre", "#changingdiabetes",
"continuous glucose monitoring", "#continuousglucosemonitoring",
"#thisisdiabetes", "#lifewithdiabetes", "#stopdiabetes",
"#diabetesadvocate", "#diabadass", "#diabetesawareness",
"#diabeticproblems", "#diaversary", "#justdiabeticthings",
"#diabetestest", "#t1dlookslikeme", "#t2dlookslikeme",
"#duckfiabetes", "#kissmyassdiabetes", "#GBDoc",
"#changingdiabetes", "freestyle libre", "#freestylelibre",
"#cgm"
]

# Transform labels + encodings into Pytorch DataSet object (including __len__, __getitem__)
class TweetDataSet(torch.utils.data.Dataset):
    def __init__(self, text, tokenizer):
        self.text = text
        self.tokenizer = tokenizer

    def __getitem__(self, idx):
        inputs = self.tokenizer(self.text, padding=True, truncation=True, return_token_type_ids=True)
        ids = inputs["input_ids"]
        mask = inputs["attention_mask"]
        token_type_ids = inputs["token_type_ids"]
        return {
                "input_ids" : torch.tensor(ids[idx], dtype=torch.long)
              , "attention_mask" : torch.tensor(mask[idx], dtype=torch.long)
              , "token_type_ids" : torch.tensor(token_type_ids[idx], dtype=torch.long)
        }      

    def __len__(self):
        return len(self.text)


def compute_metrics(pred, labels):
    precision, recall, f1, _ = precision_recall_fscore_support(labels, pred, average='weighted')
    acc = accuracy_score(labels, pred)
    return {
        'accuracy': acc,
        'f1': f1,
        'precision': precision,
        'recall': recall
    }



class CausalityBERT(torch.nn.Module):
    """ Model Bert"""
    def __init__(self):
        super(CausalityBERT, self).__init__()
        self.num_labels = 2
        self.bert = transformers.BertModel.from_pretrained("vinai/bertweet-base")
        self.dropout = torch.nn.Dropout(0.3)
        self.linear1 = torch.nn.Linear(768, 256)
        self.linear2 = torch.nn.Linear(256, self.num_labels)
        self.softmax = torch.nn.Softmax(-1)
        
    def forward(self, input_ids, attention_mask, token_type_ids):
        _, output_1 = self.bert(input_ids, attention_mask = attention_mask, token_type_ids=token_type_ids, return_dict=False) # if output 1 is our cls token        
        output_2 = self.dropout(output_1)
        output_3 = self.linear1(output_2)  
        output_4 = self.dropout(output_3)
        output_5 = self.linear2(output_4)
        # cross entory will take care of the logits - we don't need if we are usign cross entropy for loss function 
        # if doing yourself - use nll loss and logSoftmax 
#         logit = self.softmax(output_5)
        return output_5



    
softmax = torch.nn.Softmax(-1)
    
#################### MODEL PARAMETERS #####################

#device = torch.device('cuda:7' if torch.cuda.is_available() else 'cpu')

bert_model = "vinai/bertweet-base"
data_path = "/Users/adrianahne/PhD/Data/matching-tweets_diab_noRT-noDupl_20210128_personal_noJokes_withFullText_emotional.parquet" 
causal_model = "./model_causal-sentences/model_4_finetuned-8-epochs-lr_1e-05.pth"
save_path = "causalSentences.csv"

# VIVEK: Choose a large batchSize. The batchSize will be splitted over the numer of GPUs
# if 8 GPUs and batch_size 32 => each GPU executes 4 tweets
batch_size = 2048
#world_size = 8 # N GPUs

# %%
tokenizer = AutoTokenizer.from_pretrained(bert_model)

model = CausalityBERT()
model.load_state_dict(torch.load(causal_model, map_location='cpu'))
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# You are using a model of type roberta to instantiate a model of type bert. This is not supported for all configurations of models and can yield errors.
# Some weights of the model checkpoint at vinai/bertweet-base were not used when initializing BertModel: ['roberta.embeddings.word_embeddings.weight', 'roberta.encoder.layer.6.attention.output.LayerNorm.bias', 'roberta.encoder.layer.8.attention.self.value.bias', 'roberta.encoder.layer.5.attention.self.query.weight', 'roberta.encoder.layer.3.attention.output.dense.bias', 'lm_head.bias', 'roberta.encoder.layer.1.attention.self.value.weight', 'roberta.encoder.layer.6.attention.output.LayerNorm.weight', 'roberta.encoder.layer.3.intermediate.dense.bias', 'roberta.encoder.layer.4.output.dense.weight', 'roberta.encoder.layer.8.intermediate.dense.bias', 'roberta.encoder.layer.6.output.LayerNorm.bias', 'roberta.encoder.layer.9.attention.output.dense.weight', 'roberta.encoder.layer.9.attention.self.key.weight', 'roberta.encoder.layer.8.attention.self.key.bias', 'roberta.encoder.layer.4.attention.self.query.weight', 'roberta.encoder.layer.4.output.LayerNorm.weight', 'roberta.encoder.layer.6.intermediate.dense.bias', 'roberta.encoder.layer.1.intermediate.dense.weight', 'roberta.pooler.dense.weight', 'roberta.encoder.layer.3.attention.self.value.weight', 'roberta.encoder.layer.1.attention.self.key.weight', 'roberta.encoder.layer.2.attention.output.dense.bias', 'roberta.encoder.layer.6.output.dense.bias', 'roberta.encoder.layer.0.output.dense.bias', 'roberta.encoder.layer.11.attention.self.key.weight', 'roberta.encoder.layer.8.output.LayerNorm.bias', 'roberta.encoder.layer.7.output.dense.bias', 'roberta.encoder.layer.2.attention.output.LayerNorm.weight', 'roberta.encoder.layer.7.output.LayerNorm.bias', 'roberta.embeddings.LayerNorm.weight', 'roberta.encoder.layer.1.attention.self.key.bias', 'roberta.encoder.layer.6.attention.self.key.bias', 'roberta.encoder.layer.5.intermediate.dense.weight', 'roberta.encoder.layer.11.output.dense.bias', 'roberta.encoder.layer.2.intermediate.dense.bias', 'roberta.encoder.layer.6.attention.self.query.bias', 'roberta.encoder.layer.11.attention.self.key.bias', 'roberta.encoder.layer.5.output.LayerNorm.bias', 'roberta.encoder.layer.0.intermediate.dense.weight', 'roberta.encoder.layer.4.attention.self.value.weight', 'roberta.encoder.layer.10.output.dense.bias', 'roberta.encoder.layer.4.attention.output.LayerNorm.weight', 'roberta.encoder.layer.8.attention.output.LayerNorm.bias', 'roberta.encoder.layer.1.output.dense.weight', 'lm_head.layer_norm.bias', 'roberta.encoder.layer.5.output.dense.bias', 'roberta.encoder.layer.4.intermediate.dense.bias', 'roberta.encoder.layer.11.attention.self.query.bias', 'roberta.encoder.layer.11.attention.output.dense.weight', 'roberta.encoder.layer.8.attention.self.query.weight', 'roberta.encoder.layer.11.output.dense.weight', 'roberta.encoder.layer.7.attention.output.LayerNorm.weight', 'roberta.encoder.layer.8.output.dense.weight', 'roberta.encoder.layer.10.output.dense.weight', 'roberta.encoder.layer.0.attention.self.key.weight', 'roberta.encoder.layer.5.attention.self.key.bias', 'lm_head.decoder.weight', 'roberta.encoder.layer.4.output.dense.bias', 'roberta.encoder.layer.7.attention.self.key.weight', 'roberta.encoder.layer.6.attention.self.query.weight', 'roberta.encoder.layer.9.output.LayerNorm.bias', 'roberta.encoder.layer.5.attention.self.value.bias', 'roberta.encoder.layer.2.output.dense.weight', 'roberta.encoder.layer.9.intermediate.dense.weight', 'roberta.encoder.layer.10.attention.self.value.bias', 'roberta.encoder.layer.0.attention.self.value.weight', 'roberta.encoder.layer.1.intermediate.dense.bias', 'roberta.encoder.layer.1.attention.output.LayerNorm.bias', 'roberta.encoder.layer.2.attention.self.value.weight', 'roberta.encoder.layer.2.intermediate.dense.weight', 'roberta.encoder.layer.10.attention.output.dense.weight', 'roberta.encoder.layer.5.attention.self.key.weight', 'roberta.encoder.layer.2.output.LayerNorm.weight', 'roberta.encoder.layer.0.attention.self.key.bias', 'roberta.pooler.dense.bias', 'roberta.encoder.layer.9.attention.output.LayerNorm.weight', 'roberta.en ...
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertModel were not initialized from the model checkpoint at vinai/bertweet-base and are newly initialized: ['encoder.layer.7.attention.self.query.bias', 'encoder.layer.0.intermediate.dense.bias', 'encoder.layer.4.intermediate.dense.weight', 'encoder.layer.5.attention.self.query.bias', 'encoder.layer.6.intermediate.dense.bias', 'encoder.layer.3.attention.self.value.weight', 'encoder.layer.0.output.LayerNorm.bias', 'encoder.layer.6.output.dense.bias', 'encoder.layer.10.attention.output.dense.bias', 'encoder.layer.11.output.LayerNorm.bias', 'encoder.layer.6.attention.self.query.bias', 'encoder.layer.8.attention.output.dense.bias', 'encoder.layer.4.intermediate.dense.bias', 'encoder.layer.7.attention.self.query.weight', 'encoder.layer.9.intermediate.dense.bias', 'encoder.layer.3.intermediate.dense.bias', 'encoder.layer.6.attention.output.LayerNorm.weight', 'encoder.layer.9.attention.output.LayerNorm.bias', 'encoder.layer.3.attention.self.value.bias', 'encoder.layer.5.intermediate.dense.bias', 'encoder.layer.5.output.dense.weight', 'encoder.layer.0.attention.self.query.weight', 'encoder.layer.6.intermediate.dense.weight', 'encoder.layer.8.output.dense.bias', 'encoder.layer.5.attention.output.dense.weight', 'encoder.layer.1.attention.self.query.bias', 'encoder.layer.2.attention.self.query.bias', 'encoder.layer.9.output.dense.weight', 'encoder.layer.0.attention.output.LayerNorm.weight', 'encoder.layer.7.intermediate.dense.bias', 'encoder.layer.11.output.LayerNorm.weight', 'encoder.layer.8.attention.self.key.bias', 'encoder.layer.0.output.LayerNorm.weight', 'encoder.layer.4.output.LayerNorm.weight', 'encoder.layer.5.attention.output.LayerNorm.weight', 'encoder.layer.7.attention.self.value.bias', 'encoder.layer.8.attention.output.dense.weight', 'encoder.layer.2.output.LayerNorm.bias', 'encoder.layer.10.intermediate.dense.weight', 'encoder.layer.3.attention.self.key.weight', 'encoder.layer.9.attention.output.dense.weight', 'encoder.layer.0.attention.output.LayerNorm.bias', 'encoder.layer.0.attention.output.dense.bias', 'encoder.layer.9.attention.self.query.bias', 'encoder.layer.11.attention.self.value.bias', 'encoder.layer.5.attention.self.value.bias', 'encoder.layer.11.attention.output.dense.bias', 'encoder.layer.0.attention.output.dense.weight', 'encoder.layer.5.attention.output.dense.bias', 'encoder.layer.0.intermediate.dense.weight', 'encoder.layer.7.attention.self.key.weight', 'encoder.layer.8.attention.self.query.weight', 'encoder.layer.9.intermediate.dense.weight', 'encoder.layer.5.output.LayerNorm.bias', 'encoder.layer.6.attention.self.query.weight', 'encoder.layer.4.output.dense.weight', 'encoder.layer.9.attention.self.query.weight', 'encoder.layer.4.attention.output.LayerNorm.weight', 'encoder.layer.7.output.dense.weight', 'encoder.layer.0.attention.self.value.weight', 'encoder.layer.5.attention.self.query.weight', 'encoder.layer.0.output.dense.bias', 'embeddings.LayerNorm.weight', 'encoder.layer.3.output.dense.bias', 'encoder.layer.4.attention.self.key.bias', 'pooler.dense.weight', 'encoder.layer.5.attention.self.key.weight', 'encoder.layer.2.intermediate.dense.bias', 'encoder.layer.2.intermediate.dense.weight', 'encoder.layer.2.attention.self.value.bias', 'encoder.layer.2.attention.self.value.weight', 'encoder.layer.11.output.dense.weight', 'encoder.layer.7.attention.output.LayerNorm.weight', 'encoder.layer.8.attention.self.query.bias', 'encoder.layer.1.attention.self.key.bias', 'encoder.layer.1.attention.self.value.weight', 'encoder.layer.0.output.dense.weight', 'encoder.layer.4.attention.self.query.bias', 'encoder.layer.4.attention.self.query.weight', 'encoder.layer.9.attention.self.key.bias', 'encoder.layer.5.intermediate.dense.weight', 'encoder.layer.9.output.dense.bias', 'encoder.layer.4.output.LayerNorm.bias', 'encoder.layer.8.attention.output.LayerNorm.weight', 'encoder.layer.2.attention.output.dense.weight', 'encoder.layer.7.output.LayerNorm.weight', 'encoder.layer.1.attention.self.key.weight', 'encod ...
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# <All keys matched successfully>

# %%
# load data
data = pd.read_parquet(data_path)#.sample(n=100, random_state=33)
print("Total count:", data.shape[0])
data.head()
# Out:
# Total count: 562013
#                     id                      created_at lang  \
# 0   862697033131597824  Thu May 11 15:52:55 +0000 2017   en
# 2   862733663443615744  Thu May 11 18:18:28 +0000 2017   en
# 5   862832546945675264  Fri May 12 00:51:24 +0000 2017   en
# 14  863308516198678529  Sat May 13 08:22:44 +0000 2017   en
# 15  863399191497904130  Sat May 13 14:23:03 +0000 2017   en
#
#                                                  text             user_name  \
# 0   Hypo in the Boticelli rooms at the @UffiziGall...       Samantha Morris
# 2   Life &amp; diabetes in a jar altogether! 😍  I'...        Hasan Abughosh
# 5   It's always worrying as a diabetic when your f...  ­­­Mitth'raw'nuruodo
# 14  Wut about iam my own mum people? They gift tan...                  Saad
# 15  If you have type 1 diabetes , you don't deserv...  NastyNana-demonation
#
#    user_screen_name  user_followers_count  user_friends_count  \
# 0     TheBorgiaBuIl                 624.0               570.0
# 2        H_Abughosh                2420.0              1455.0
# 5         MattWWeir                 257.0               177.0
# 14          msaadkb                1050.0               567.0
# 15      LandauCamar                 134.0               219.0
#
#                   user_location  \
# 0          Southampton, England
# 2   Hashemite Kingdom of Jordan
# 5                          None
# 14                   SC:msaadkb
# 15                     New York
#
#                                      user_description  ...  \
# 0   Tattooed Renaissance historian and author. Aut...  ...
# 2   Marketing Manager of Easy Jordan | Startup & T...  ...
# 5   So please forgive what I have done. No, you ca...  ...
# 14  you'll will never know what i am really trying...  ...
# 15  I am WOMAN , I'm NEW YORK & Jewish PROUD. Wife...  ...
#
#    retweeted_user_friends_count retweeted_user_location  \
# 0                          None                    None
# 2                          None                    None
# 5                          None                    None
# 14                         None                    None
# 15                         None                    None
#
#    retweeted_user_description retweeted_place_full_name retweeted_text  \
# 0                        None                      None           None
# 2                        None                      None           None
# 5                        None                      None           None
# 14                       None                      None           None
# 15                       None                      None           None
#
#      Project posted_month                                     tweet_URL_USER  \
# 0   Diabetes       201705  Hypo in the Boticelli rooms at the USER and on...
# 2   Diabetes       201705  Life &amp; diabetes in a jar altogether! 😍  I'...
# 5   Diabetes       201705  It's always worrying as a diabetic when your f...
# 14  Diabetes       201705  Wut about iam my own mum people? They gift tan...
# 15  Diabetes       201705  If you have type 1 diabetes , you don't deserv...
#
#                                             full_text emotion
# 0   Hypo in the Boticelli rooms at the @UffiziGall...    True
# 2   Life &amp; diabetes in a jar altogether! 😍\n\n...    True
# 5   It's always worrying as a diabetic when your f...    True
# 14  Wut about "iam my own mum" people? They gift t...    True
# 15  If you have type 1 diabetes , you don't deserv...    True
#
# [5 rows x 24 columns]

# %%
####### SPLIT TWEETS INTO SENTENCES ######################

TweetsSplit = data["full_text"].map(lambda full_text: split_into_sentences(normalizeTweet(full_text)))
print(TweetsSplit.shape[0])

sentences = TweetsSplit.explode()
print("tweets to sentences:", sentences.shape[0])

print(sentences[20:40].values)
# Out:
# Error: token: M.Phil.B.Ed
# ['@USER', 'I', 'lost', 'my', 'teaching', 'job', ',', 'due', 'to', 'lockdown', 'I', 'could', 'not', 'go', 'any', 'job', ',', 'as', 'a', 'diabetic', 'need', 'money', 'for', 'my', 'food', 'and', 'medicine', 'kindly', 'help', 'mam', ',', 'instead', 'of', 'that', 'I', "'m", 'ready', 'to', 'sell', 'my', 'M', '.', 'A', ',', 'M.Phil.B.Ed', '.', ',', 'certificates', ',', 'according', 'to', 'your', 'wish', 'fix', 'price', '.']
# Error: token: smoked.drank.drugs.never
# ['@USER', '@USER', '@USER', '@USER', 'I', 'never', 'get', 'the', 'flu', 'HTTPURL', 'diabetic', 'but', 'I', 'never', 'really', 'get', 'sick.infact', 'I', 'really', "can't", 'remember', 'in', 'my', 'adult', 'life', 'wen', 'I', "'ve", 'really', 'gotten', 'sick', '.', 'I', "'ve", 'never', 'ever', 'smoked.drank.drugs.never', '&', 'I', "'m", 'a', 'musician', '&', 'thank', 'god', 'never', 'got', 'caught', 'in', 'that', 'trap', '.']
# Error: token: SSE.WRD.SER.ADRA
# ['R', '/', 'Sir', ',', 'Will', 'retire', 'on', '30.4', '.', '20', '.', 'Suffering', 'from', 'chronic', 'diabetic', 'and', 'BP', ',', 'I', 'was', 'under', 'treatment', 'by', 'the', 'pvt', '.', 'Doctor', 'from', '11.02', '.', '20', 'to23', '.', '02.20', ',', 'Other', "'s", 'PMC', 'commuted', ',', '.', 'My', 'PMC', '/', 'LAP', '/', 'CL', 'regretted.Huge', 'losing.Pls', 'see', '.', 'Thanks', 'n', 'Regards', '.', 'T', 'K', 'HALDAR', '.', 'SSE.WRD.SER.ADRA', '(', 'DPRMS', ')', '.']
# Error: token: .kisongochi@gmail.com
# ['@USER', '@USER', '@USER', 'I', 'am', 'desperate', 'for', 'help', '.', 'I', 'need', 'my', 'insulin', 'to', 'bring', 'my', 'blood', 'sugar', 'back', 'down', '.', 'It', "'s", '$', '217', '.', 'That', "'s", 'all', 'I', 'need', '.', 'I', "'m", 'not', 'asking', 'for', 'a', 'windfall', ',', 'just', 'a', 'little', 'help', ',', 'please', '.', 'My', 'PayPal', 'is', 'victor.wambwa', '.kisongochi@gmail.com', 'Thanks', 'in', 'advance', ':beating_heart:', ':folded_hands:', ':folded_hands:', ':beating_heart:']
# Error: token: danni.mordell@gmail.com
# ['@USER', '@USER', 'I', 'lost', 'count', 'on', 'how', 'many', 'times', 'I', "'ve", 'tweeted', 'and', 'retweeted', '.', 'My', 'mom', 'who', 'is', 'diabetic', 'needs', 'her', 'insulin', 'and', 'has', "n't", 'had', 'a', 'meal', 'in', 'days', '.', 'I', "'m", 'really', 'still', 'short', 'on', 'food', 'ane', 'remainder', 'of', 'rent', '.', 'Pleaseeeee', 'see', 'my', 'cry', 'for', 'help', '.', 'PayPal', 'danni.mordell@gmail.com']
# Error: token: .kisongochi@gmail.com
# ['@USER', '@USER', '@USER', 'I', 'am', 'desperate', 'for', 'help', '.', 'I', 'need', 'my', 'insulin', 'to', 'bring', 'my', 'blood', 'sugar', 'back', 'down', '.', 'It', "'s", '$', '217', '.', 'That', "'s", 'all', 'I', 'need', '.', 'I', "'m", 'not', 'asking', 'for', 'a', 'windfall', ',', 'just', 'a', 'little', 'help', ',', 'please', '.', 'My', 'PayPal', 'is', 'victor.wambwa', '.kisongochi@gmail.com', 'Thanks', 'in', 'advance', ':beating_heart:', ':folded_hands:', ':folded_hands:', ':beating_heart:']
# Error: token: vihenda.h@yahoo.com
# ['I', 'am', 'desperate', 'for', 'help', '.', 'I', 'need', 'my', 'insulin', 'to', 'bring', 'my', 'blood', 'sugar', 'back', 'down', '.', 'It', "'s", '$', '300', '.', ':beating_heart:', ':folded_hands:', ':folded_hands:', ':beating_heart:', 'and', 'am', 'currently', 'out', 'of', 'work', 'if', 'anybody', 'could', 'spare', 'anything', 'for', 'a', 'meal', 'and', 'of', 'buying', 'my', 'insulin', 'it', 'would', 'be', 'appreciated', '.', 'PayPal', ':', 'vihenda.h@yahoo.com', 'Thanks', ':folded_hands:', 'Help', 'boost', '.', ':red_heart:']
# Error: token: all.of.the.time
# ['I', 'clearly', 'remember', 'all', 'of', 'the', 'T1D', 'early', 'warning', 'signs', '—', 'he', 'was', 'so', 'thirsty', '—', 'all.of.the.time', '.', 'had', 'to', 'pee', 'so', 'much', 'I', 'was', 'actually', 'reprimanding', 'him', '—', 'thinking', 'he', 'was', "n't", 'telling', 'the', 'truth', 'losing', 'weight', 'drastically', 'feeling', 'sick', '.', 'Be', 'awkward', '—', 'easy', 'check', 'at', 'PCP']
# Error: token: I.B.prophen
# ['@USER', 'Definitely', 'need', 'to', 'be', 'seen', 'that', "'s", 'a', 'sign', 'of', 'a', 'few', 'things', ':', 'Blood', 'clot', ',', 'diabetes', ',', 'kidney', 'failure', '...', 'and', 'much', 'more', 'rely', 'bad', 'shit', '!', 'Elevate', 'ya', 'feet', 'take', 'some', 'I.B.prophen', 'it', "'s", 'an', 'anti', 'inflammatory', 'and', 'call', 'a', 'doctor', 'A', '.', 'S', '.', 'A', '.', 'P', '.', '#medadvice']
# Error: token: danni.mordell@gmail.com
# ['@USER', 'Sorry', 'to', 'spam', 'u', '.', 'I', 'lost', 'count', 'on', 'how', 'many', 'times', 'I', "'ve", 'tweeted', 'and', 'retweeted', '.', 'My', 'mom', 'who', 'is', 'diabetic', 'needs', 'her', 'insulin', 'and', 'has', "n't", 'had', 'a', 'meal', 'in', 'days', '.', 'I', "'m", 'really', 'still', 'short', 'on', 'food', 'ane', 'remainder', 'of', 'rent', '.', 'Pleaseeeee', 'see', 'my', 'cry', 'for', 'help', '.', 'PayPal', 'danni.mordell@gmail.com']
# Error: token: vihenda.h@yahoo.com
# ['I', 'am', 'desperate', 'for', 'help', '.', 'I', 'need', 'my', 'insulin', 'to', 'bring', 'my', 'blood', 'sugar', 'back', 'down', '.', 'It', "'s", '$', '300', 'That', "'s", 'all', 'I', 'need', '.', 'I', "'m", 'not', 'asking', 'for', 'a', 'windfall', ',', 'just', 'a', 'little', 'help', ',', 'please', '.', 'My', 'PayPal', 'is', 'vihenda.h@yahoo.com', 'Thanks', 'in', 'advance', ':beating_heart:', ':folded_hands:', ':folded_hands:', ':beating_heart:']
# Error: token: 2.3.managed
# ['Had', 'a', 'awful', 'diabetic', 'hypo', 'earlier', 'with', 'blood', 'sugars', 'at', '2.3.managed', 'to', 'get', 'them', 'back', 'up', ',', 'but', 'just', 'checked', 'it', 'now', '&', 'its', '21.4', "can't", 'win.Just', 'hope', 'i', 'wake', 'up', 'in', 'the', 'morning', '.', '#T1D', '#Insulin', '#Hypoglycemia', '&', 'now', '#Hyperglycemia', '#']
# Error: token: 75yrs.old.and
# ['@USER', 'My', 'mom', 'needs', 'money', 'for', 'her', 'daily', 'maintenance', 'med', '.', 'She', 'has', 'a', 'diabetes', '&', '75yrs.old.and', 'most', 'of', 'the', 'time', 'she', 'admitted', 'to', 'the', 'hospital', '.']
# Error: token: .kisongochi@gmail.com
# ['@USER', '@USER', 'I', 'am', 'desperate', 'for', 'help', '.', 'I', 'need', 'my', 'insulin', 'to', 'bring', 'my', 'blood', 'sugar', 'back', 'down', '.', 'It', "'s", '$', '217', '.', 'That', "'s", 'all', 'I', 'need', '.', 'I', "'m", 'not', 'asking', 'for', 'a', 'windfall', ',', 'just', 'a', 'little', 'help', ',', 'please', '.', 'My', 'PayPal', 'is', 'victor.wambwa', '.kisongochi@gmail.com', 'Thanks', 'in', 'advance', ':beating_heart:', ':folded_hands:', ':folded_hands:', ':beating_heart:']
# Error: token: .kisongochi@gmail.com
# ['#SettlerSaturday', 'I', 'am', 'desperate', 'for', 'help', '.', 'I', 'need', 'my', 'insulin', 'to', 'bring', 'my', 'blood', 'sugar', 'back', 'down', '.', 'It', "'s", '$', '217', '.', 'That', "'s", 'all', 'I', 'need', '.', 'I', "'m", 'not', 'asking', 'for', 'a', 'windfall', ',', 'just', 'a', 'little', 'help', ',', 'please', '.', 'My', 'PayPal', 'is', 'victor.wambwa', '.kisongochi@gmail.com', 'Thanks', 'in', 'advance', ':folded_hands:', ':beating_heart:', 'HTTPURL']
# Error: token: .kisongochi@gmail.com
# ['@USER', 'I', 'am', 'desperate', 'for', 'help', '.', 'I', 'need', 'my', 'insulin', 'to', 'bring', 'my', 'blood', 'sugar', 'back', 'down', '.', 'It', "'s", '$', '217', '.', 'That', "'s", 'all', 'I', 'need', '.', 'I', "'m", 'not', 'asking', 'for', 'a', 'windfall', ',', 'just', 'a', 'little', 'help', ',', 'please', '.', 'My', 'PayPal', 'is', 'victor.wambwa', '.kisongochi@gmail.com', 'Thanks', 'in', 'advance', ':beating_heart:', ':folded_hands:', ':folded_hands:', ':beating_heart:']
# Error: token: .kisongochi@gmail.com
# ['Good', 'Morning', '!', 'I', 'am', 'desperate', 'for', 'help', '.', 'I', 'need', 'my', 'insulin', 'to', 'bring', 'my', 'blood', 'sugar', 'back', 'down', '.', 'It', "'s", '$', '217', '.', 'That', "'s", 'all', 'I', 'need', '.', 'I', "'m", 'not', 'asking', 'for', 'a', 'windfall', ',', 'just', 'a', 'little', 'help', ',', 'please', '.', 'My', 'PayPal', 'is', 'victor.wambwa', '.kisongochi@gmail.com', 'Thanks', 'in', 'advance', ':beating_heart:', ':folded_hands:', ':folded_hands:', ':beating_heart:', '#SaturdayMorning']
# Error: token: .kisongochi@gmail.com
# ['@USER', 'Good', 'Morning', '!', 'I', 'am', 'desperate', 'for', 'help', '.', 'I', 'need', 'my', 'insulin', 'to', 'bring', 'my', 'blood', 'sugar', 'back', 'down', '.', 'It', "'s", '$', '217', '.', 'That', "'s", 'all', 'I', 'need', '.', 'I', "'m", 'not', 'asking', 'for', 'a', 'windfall', ',', 'just', 'a', 'little', 'help', ',', 'please', '.', 'My', 'PayPal', 'is', 'victor.wambwa', '.kisongochi@gmail.com', 'Thanks', 'in', 'advance', ':beating_heart:', ':folded_hands:', ':folded_hands:', ':beating_heart:']
# Error: token: stella.waithaka99@gmail.com
# ['@USER', '@USER', '@USER', 'I', 'am', 'desperate', 'for', 'help', '.', 'I', 'need', 'my', 'insulin', 'to', 'bring', 'my', 'blood', 'sugar', 'back', 'down', '.', 'It', "'s", '$', '217', '.', 'That', "'s", 'all', 'I', 'need', '.', 'I', "'m", 'not', 'asking', 'for', 'a', 'windfall', ',', 'just', 'a', 'little', 'help', ',', 'please', '.', 'My', 'PayPal', 'is', 'stella.waithaka99@gmail.com', 'Thanks', 'in', 'advance', ':beating_heart:', ':folded_hands:', ':folded_hands:', ':beating_heart:']
# Error: token: y.o.daughter
# ['@USER', '@USER', 'I', "'m", '🇨', '🇦', 'ian', 'with', '50', 'y.o.daughter', 'T1D', '41', 'yrs', '.', 'I', 'worried', 'about', 'her', 'having', 'good', 'control', 'when', 'young', 'but', 'never', 'worried', 'about', 'cost', '.', 'She', 'now', 'has', 'a', 'state', 'of', 'the', 'art', 'pump', '&', 'even', 'as', 'a', 'single', 'parent', 'of', '2', 'teens', ',', 'in', 'average', 'job', '&', 'without', 'support', 'from', 'ex', ',', 'insulin', '&', 'supplies', 'are', 'within', 'her', 'means', '.']
# Error: token: diabetes.cancer.they
# ['@USER', '@USER', 'There', 'is', 'still', 'young', 'kids', 'with', 'compromised', 'immunity', 'and', 'diabetes.cancer.they', 'can', 'not', 'catch', 'cornovirus', '19', '.', 'He', 'being', 'a', 'tard', 'and', 'hurting', 'more', 'then', 'his', 'own', 'state', 'doing', 'this', '.']
# Error: token: slim.co.za
# ['Just', 'look', 'at', 'these', 'amazing', 'results', 'in', 'only', '3months', ',', 'no', 'diet', ',', 'no', 'exercise', 'just', 'from', '1', 'cup', 'a', 'day', '.', ':hot_beverage:', ':tropical_drink:', ':hot_beverage:', 'Diabetic', 'and', 'Vegan', 'Friendly', 'You', 'can', 'also', 'DO', 'it', '!', '!', 'Let', 'me', 'know', 'if', 'I', 'can', 'help', 'you', ':inbox_tray:', ':e-mail:', 'info', '@USER', 'slim.co.za', 'HTTPURL', 'HTTPURL']
# Error: token: gilbaluseno@yahoo.co.uk
# ['@USER', 'I', "'m", 'sick', 'from', '20th', 'in', 'hospital', 'suffering', 'from', 'diabetic', 'of', 'high', 'sugar', 'levels', ',', 'liloba80@gmail.com', 'or', 'gilbaluseno@yahoo.co.uk', 'or', 'glusenoliloba@gmail.com', ',', '+', '2547128362', '25']
# Error: token: 4.more.weeks
# ['Getting', 'put', 'on', 'short', 'acting', 'insulin', 'too', '.', 'Been', 'trying', 'to', 'eat', 'less', 'carbs', 'and', 'now', 'I', 'got', 'ketones', 'going', 'on', '.', 'So', 'I', 'eat', 'the', 'carbs', 'I', 'should', 'and', 'I', 'shoot', 'right', 'up', '(', 'I', 'now', 'understand', 'the', 'diabetes', 'rage', 'my', 'dad', 'talked', 'about', 'now', ')', '4.more.weeks', '.']
# Error: token: 2.1.When
# ['Had', 'awful', 'diabetic', 'hypo', 'today', '.', 'blood', 'sugars', 'dropped', '2.1.When', 'you', 'ask', 'loved', 'ones', 'if', 'they', 'understood', 'a', 'Type', '1', 'diabetic', 'in', 'a', 'hypo', '&', 'what', 'to', 'do', ',', 'They', 'have', "n't", 'a', 'clue', ',', 'If', 'that', 'was', 'my', 'kids', 'i', "'d", 'want', 'to', 'learn', 'everything', 'to', 'help', 'them', '.', '#T1D', 'Makes', 'you', 'realize', 'who', 'actually', 'care', '.', '#Ignorance', ':thinking_face:', ':face_with_rolling_eyes:']
# Error: token: .kisongochi@gmail.com
# ['@USER', 'I', 'am', 'desperate', 'for', 'help', '.', 'I', 'need', 'my', 'insulin', 'to', 'bring', 'my', 'blood', 'sugar', 'back', 'down', '.', 'It', "'s", '$', '217', '.', 'That', "'s", 'all', 'I', 'need', '.', 'I', "'m", 'not', 'asking', 'for', 'a', 'windfall', ',', 'just', 'a', 'little', 'help', ',', 'please', '.', 'My', 'PayPal', 'is', 'victor.wambwa', '.kisongochi@gmail.com', 'Thanks', 'in', 'advance', ':beating_heart:', ':folded_hands:', ':folded_hands:', ':beating_heart:']
# Error: token: A.K.Gupta
# ['We', 'are', 'old', 'parents', ',', 'alone', 'and', 'diabetic', 'patients', 'waiting', 'for', 'their', 'son', 'to', 'return', 'home', 'for', 'the', 'last', '1.5', 'months', 'We', 'are', 'mailing', 'by', 'losing', 'from', 'everywhere', 'Kindly', 'release', 'him', 'the', 'E', 'pass', 'Name', 'Vivek', 'Gupta', 'S', '/', 'o', 'A.K.Gupta', 'Mobile', '9540563173', 'vehicle', 'No', '.', 'RJ14AC1306Mail', 'Id', 'vivek5080.05@gmail.com']
# Error: token: vivek5080.05@gmail.com
# ['We', 'are', 'old', 'parents', ',', 'alone', 'and', 'diabetic', 'patients', 'waiting', 'for', 'their', 'son', 'to', 'return', 'home', 'for', 'the', 'last', '1.5', 'months', 'We', 'are', 'mailing', 'by', 'losing', 'from', 'everywhere', 'Kindly', 'release', 'him', 'the', 'E', 'pass', 'Name', 'Vivek', 'Gupta', 'S', '/', 'o', 'A.K.Gupta', 'Mobile', '9540563173', 'vehicle', 'No', '.', 'RJ14AC1306Mail', 'Id', 'vivek5080.05@gmail.com']
# Error: token: 5.8.Never
# ['Something', 'i', "'m", 'so', 'proud', 'of', 'today', 'the', 'first', 'time', 'in', 'ages', '.', 'I', 'was', 'nervous', 'about', 'up', 'dosing', 'my', 'insulin', '&', 'worried', 'if', 'my', 'blood', 'i', 'went', 'in', 'to', 'a', 'diabetic', 'hypo.But', 'Today', 'all', 'day', 'my', 'blood', 'sugars', 'have', 'been', '6.3', '&', 'tonight', 'before', 'my', 'supper', 'it', 'was', '5.8.Never', 'thought', 'i', "'d", 'do', 'it', ',', 'but', 'so', 'pleased', 'x']
# Error: token: ...diabetic/carb
# ['Being', 'vegan', 'is', 'fine', 'and', 'all', 'if', 'you', 'can', 'afford', 'it', 'and', 'are', "n't", '...diabetic/carb', 'averse', 'To', 'shame', 'people', 'for', 'eating', 'meat', '/', 'animal', 'byproducts', '...', 'man', 'stfu', 'lmao', "y'all", 'vegans', 'tend', 'to', 'be', '"', 'progressive', '"', 'so', 'lemme', 'put', 'it', 'in', 'words', 'you', 'can', 'understand', ':', 'Judging', 'omnivores', 'is', '"', 'classist', '"', 'and', '"', 'ableist', '"']
# Error: token: .kisongochi@gmail.com
# ['@USER', '@USER', '@USER', 'I', 'am', 'desperate', 'for', 'help', '.', 'I', 'need', 'my', 'insulin', 'to', 'bring', 'my', 'blood', 'sugar', 'back', 'down', '.', 'It', "'s", '$', '217', '.', 'That', "'s", 'all', 'I', 'need', '.', 'I', "'m", 'not', 'asking', 'for', 'a', 'windfall', ',', 'just', 'a', 'little', 'help', ',', 'please', '.', 'My', 'PayPal', 'is', 'victor.wambwa', '.kisongochi@gmail.com', 'Thanks', 'in', 'advance', ':beating_heart:', ':folded_hands:', ':folded_hands:', ':beating_heart:']
# Error: token: 7.4.Trev
# ['I', "'m", 'hopeless', 'managing', 'type', '2', 'diabetes', ',', 'so', 'I', 'got', 'Trev', 'to', 'do', 'it', 'for', 'me', '&', 'it', "'s", '7.4.Trev', 'told', 'me', 'I', "'d", 'feel', 'crook', '&', 'he', "'s", 'right', '.', 'I', "'m", 'eating', 'in', '5mins', '&', 'I', "'ll", 'check', 'it', 'approx', '30', 'mins', ':thumbs_up:', ':thumbs_up:', 'Ian']
# Error: token: .kisongochi@gmail.com
# ['@USER', '@USER', 'I', 'am', 'desperate', 'for', 'help', '.', 'I', 'need', 'my', 'insulin', 'to', 'bring', 'my', 'blood', 'sugar', 'back', 'down', '.', 'It', "'s", '$', '217', '.', 'That', "'s", 'all', 'I', 'need', '.', 'I', "'m", 'not', 'asking', 'for', 'a', 'windfall', ',', 'just', 'a', 'little', 'help', ',', 'please', '.', 'My', 'PayPal', 'is', 'victor.wambwa', '.kisongochi@gmail.com', 'Thanks', 'in', 'advance', ':beating_heart:', ':folded_hands:', ':folded_hands:', ':beating_heart:']
# Error: token: .kisongochi@gmail.com
# ['@USER', '@USER', '@USER', 'I', 'am', 'desperate', 'for', 'help', '.', 'I', 'need', 'my', 'insulin', 'to', 'bring', 'my', 'blood', 'sugar', 'back', 'down', '.', 'It', "'s", '$', '217', '.', 'That', "'s", 'all', 'I', 'need', '.', 'I', "'m", 'not', 'asking', 'for', 'a', 'windfall', ',', 'just', 'a', 'little', 'help', ',', 'please', '.', 'My', 'PayPal', 'is', 'victor.wambwa', '.kisongochi@gmail.com', 'Thanks', 'in', 'advance', ':beating_heart:', ':folded_hands:', ':folded_hands:', ':beating_heart:']
# Error: token: .kisongochi@gmail.com
# ['#CNNTownHall', 'I', 'am', 'desperate', 'for', 'help', '.', 'I', 'need', 'my', 'insulin', 'to', 'bring', 'my', 'blood', 'sugar', 'back', 'down', '.', 'It', "'s", '$', '217', '.', 'That', "'s", 'all', 'I', 'need', '.', 'I', "'m", 'not', 'asking', 'for', 'a', 'windfall', ',', 'just', 'a', 'little', 'help', ',', 'please', '.', 'My', 'PayPal', 'is', 'victor.wambwa', '.kisongochi@gmail.com', 'Thanks', 'in', 'advance', ':folded_hands:', ':beating_heart:', 'HTTPURL']
# Error: token: though.Enjoy.Happy
# ['@USER', 'I', 'was', 'kidding', '.', 'I', 'used', 'to', 'enjoy', 'them.But', 'I', 'have', 'diabetes', 'HTTPURL', 'worries', 'though.Enjoy.Happy', 'Sunday', '!']
# Error: token: aaronschaper.sps@gmail.com
# ['@USER', '@USER', 'Cashapp', '$', 'AaronSchaper', 'Paypal', 'aaronschaper.sps@gmail.com', 'Any', 'help', 'will', 'be', 'great', 'need', 'insulin', 'bad', '.']
# Error: token: fam..paypal.me/zazu12
# ['@USER', 'Thank', 'you', 'Jo', '..', 'hes', 'doing', 'ok', '..', 'but', 'tomorrow', 'is', '7', 'weeks', 'and', 'time', 'for', 'a', 'new', 'bottle', 'of', 'insulin', '..', 'I', "'m", 'sinking', ',', 'well', 'sunk', '..', 'it', "'s", 'taking', 'a', 'high', 'toll', 'on', 'me', 'and', 'my', 'fam..paypal.me/zazu12', '$', 'DawnFratus', '..', 'I', 'hope', 'all', 'is', 'well', 'w', '/', 'you', 'and', 'yours']
# Error: token: .kisongochi@gmail.com
# ['@USER', '@USER', '@USER', 'I', 'am', 'desperate', 'for', 'help', '.', 'I', 'need', 'my', 'insulin', 'to', 'bring', 'my', 'blood', 'sugar', 'back', 'down', '.', 'It', "'s", '$', '217', '.', 'That', "'s", 'all', 'I', 'need', '.', 'I', "'m", 'not', 'asking', 'for', 'a', 'windfall', ',', 'just', 'a', 'little', 'help', ',', 'please', '.', 'My', 'PayPal', 'is', 'victor.wambwa', '.kisongochi@gmail.com', 'Thanks', 'in', 'advance', ':beating_heart:', ':folded_hands:', ':folded_hands:', ':beating_heart:']
# Error: token: .kisongochi@gmail.com
# ['@USER', '@USER', '@USER', 'I', 'am', 'desperate', 'for', 'help', '.', 'I', 'need', 'my', 'insulin', 'to', 'bring', 'my', 'blood', 'sugar', 'back', 'down', '.', 'It', "'s", '$', '217', '.', 'That', "'s", 'all', 'I', 'need', '.', 'I', "'m", 'not', 'asking', 'for', 'a', 'windfall', ',', 'just', 'a', 'little', 'help', ',', 'please', '.', 'My', 'PayPal', 'is', 'victor.wambwa', '.kisongochi@gmail.com', 'Thanks', 'in', 'advance', ':beating_heart:', ':folded_hands:', ':folded_hands:', ':beating_heart:']
# Error: token: .kisongochi@gmail.com
# ['@USER', 'am', 'desperate', 'for', 'help', '.', 'I', 'need', 'my', 'insulin', 'to', 'bring', 'my', 'blood', 'sugar', 'back', 'down', '.', 'It', "'s", '$', '217', '.', 'That', "'s", 'all', 'I', 'need', '.', 'I', "'m", 'not', 'asking', 'for', 'a', 'windfall', ',', 'just', 'a', 'little', 'help', ',', 'please', '.', 'My', 'PayPal', 'is', 'victor.wambwa', '.kisongochi@gmail.com', 'Thanks', 'in', 'advance', ':beating_heart:', ':folded_hands:', ':folded_hands:', ':beating_heart:']
# Error: token: U.S.moneymakers.Stop
# ['My', 'husband', ',', 'a', 'diabetic', ',', 'says', 'price', 'of', 'insulin', 'is', 'going', 'up.The', 'pharma', 'companies', 'are', 'biggest', 'U.S.moneymakers.Stop', 'getting', 'RICH', 'off', 'the', 'sick', '!']
# Error: token: .kisongochi@gmail.com
# ['@USER', '@USER', '@USER', '@USER', 'I', 'am', 'desperate', 'for', 'help', '.', 'I', 'need', 'my', 'insulin', 'to', 'bring', 'my', 'blood', 'sugar', 'back', 'down', '.', 'It', "'s", '$', '217', '.', 'That', "'s", 'all', 'I', 'need', '.', 'I', "'m", 'not', 'asking', 'for', 'a', 'windfall', ',', 'just', 'a', 'little', 'help', ',', 'please', '.', 'My', 'PayPal', 'is', 'victor.wambwa', '.kisongochi@gmail.com', 'Thanks', 'in', 'advance', ':beating_heart:', ':folded_hands:', ':folded_hands:', ':beating_heart:']
# Error: token: no.0006085037.pls
# ['@USER', 'afternoon', 'sir', '..', 'I', 'have', 'a', 'mum', 'by', 'the', 'name', 'shoetan', 'bukola', 'who', 'is', 'suffering', 'from', 'cataract', ',', 'diabetes', 'and', 'hypertension', '..', 'She', 'needs', 'to', 'urgently', 'carry', 'out', 'her', 'operation', 'in', 'coming', 'weeks', '.', 'name', ':', 'shoetan', 'bukola', 'Phone', ':', '08084217599', 'Bank', ':', 'Union', 'bank', 'accnt', 'no.0006085037.pls', 'help', 'sir']
# Error: token: put.of.hours
# ['Middle', 'of', 'the', 'night', 'trip', 'to', 'put.of.hours', 'is', 'absolutely', 'no', 'what', 'ur', 'wanting', 'in', 'this', 'weather', ':loudly_crying_face:', 'fucking', 'hate', 'being', 'diabetic', '.']
# Error: token: directhoming@chiltern.cats.org.uk
# ['to', 'adopt', 'Casper', 'is', 'struggling', 'to', 'find', 'a', 'new', 'home', '.', 'He', 'is', '7', 'years', 'old', ',', 'talkative', 'and', 'friendly', '.', 'He', 'is', 'diabetic', 'but', 'it', 'is', 'not', 'complicated', 'to', 'give', 'treatment', ',', 'it', 'is', 'not', 'difficult', 'for', 'an', 'owner', 'to', 'take', 'care', 'of', 'it', '.', 'Please', 'send', 'an', 'e', 'mail', 'directhoming@chiltern.cats.org.uk', 'for', '#catsoftwitter']
# Error: token: 65..diabetic/newly
# ['I', "can't", 'even', 'celebrate', 'this', 'match', '.', 'My', 'Uncle', 'is', '65..diabetic/newly', 'diagnosed', 'hypertensive', ',', 'with', 'every', 'Watford', 'attack', 'my', 'heart', 'beats', 'faster', 'on', 'his', 'behalf', '.', 'Man', 'is', 'a', 'passionate', 'Chelsea', 'fan', ',', 'just', 'glum', 'in', 'his', 'chair', '.', 'Conte', 'why', '?', '?', '?']
# Error: token: me.2.The
# ['I', 'find', 'it', 'Pretty', 'sad', 'that', 'us', 'Upstate', 'NY', 'Cancer', ',', 'Diabetic', ',', 'Patient', "'s", 'Have', 'to', 'Fund', 'a', 'extra', 'phone', 'line', 'just', 'to', 'be', 'able', 'to', 'dial', '911', 'because', 'in', '2018', 'Our', 'Government', 'Up', 'here', '&', 'Cell', 'Carriers', 'Worry', 'more', 'about', 'Numbers', 'then', 'they', 'do', '1.the', 'average', 'working', 'Joe', 'like', 'me.2.The', 'Vets', 'that', 'served']
# Error: token: sashahooper@mail.usf.edu
# ['Shadow', '10', 'yrs', 'been', 'w', '/', 'family', 'since', 'kittenhood', '.', 'Ft', 'Walton', 'Beach', ',', 'Fl', 'diabetic', '.', 'Shadow', "'s", 'people', 'work', 'too', 'much', 'to', 'give', 'care', 'he', 'needs', 'friendly', 'most', 'of', 'time', 'can', 'be', 'feisty.Currently', 'indoor', 'outdoor', 'cat', 'been', 'staying', 'inside', 'more', 'lately', '.', 'Shadow', 'loves', 'to', 'talk', '.', 'sashahooper@mail.usf.edu', '.', ':folded_hands:', ':paw_prints:', ':crying_cat:', 'HTTPURL']
# Error: token: .kisongochi@gmail.com
# ['@USER', 'I', 'am', 'desperate', 'for', 'help', '.', 'I', 'need', 'my', 'insulin', 'to', 'bring', 'my', 'blood', 'sugar', 'back', 'down', '.', 'It', "'s", '$', '217', '.', 'That', "'s", 'all', 'I', 'need', '.', 'I', "'m", 'not', 'asking', 'for', 'a', 'windfall', ',', 'just', 'a', 'little', 'help', ',', 'please', '.', 'My', 'PayPal', 'is', 'victor.wambwa', '.kisongochi@gmail.com', 'Thanks', 'in', 'advance', ':beating_heart:', ':folded_hands:', ':folded_hands:', ':beating_heart:']
# Error: token: aaronschaper.sps@gmail.com
# ['@USER', 'with', 'the', 'murder', 'of', 'my', 'friend', 'no', 'insulin', 'or', 'food', 'any', 'help', 'would', 'be', 'amazing', 'right', 'now', '.', 'The', 'stress', 'and', 'no', 'insulin', 'and', 'no', 'food', 'is', 'making', 'me', 'real', 'sick', '.', 'Please', 'any', 'help', 'at', 'all', '.', 'Paypal', 'aaronschaper.sps@gmail.com', 'Will', 'even', 'pay', 'it', 'back', '.']
# Error: token: D.L.Hughley
# ['@USER', '@USER', 'D.L.Hughley', 'said', 'it', 'best', ':', "'", 'White', 'people', 'would', 'rather', 'lose', 'their', 'feet', 'to', 'diabetes', 'than', 'use', 'the', 'health', 'care', 'provided', 'by', 'black', 'man', '.', '"']
# Error: token: J.W.Wakefields
# ['Had', 'a', 'great', 'day', 'at', 'Dark', 'City', 'yesterday', 'but', 'today', 'Im', 'a', 'broken', 'man', 'awaiting', 'type', '2', 'diabetes', '.', 'Shout', 'out', 'to', 'J.W.Wakefields', 'The', 'Man', 'with', 'the', 'Golden', 'Churro', ',', 'that', 'was', 'quite', 'delicous', '#darkcity', '#northernmonk']
# Error: token: .kisongochi@gmail.com
# ['@USER', '@USER', '@USER', 'I', 'am', 'desperate', 'for', 'help', '.', 'I', 'need', 'my', 'insulin', 'to', 'bring', 'my', 'blood', 'sugar', 'back', 'down', '.', 'It', "'s", '$', '217', '.', 'That', "'s", 'all', 'I', 'need', '.', 'I', "'m", 'not', 'asking', 'for', 'a', 'windfall', ',', 'just', 'a', 'little', 'help', ',', 'please', '.', 'My', 'PayPal', 'is', 'victor.wambwa', '.kisongochi@gmail.com', 'Thanks', 'in', 'advance', ':beating_heart:', ':folded_hands:', ':folded_hands:', ':beating_heart:']
# Error: token: kavai.peter@gmail.com
# ['@USER', 'Dear', 'Indian', 'embassy', '@USER', 'I', 'am', 'suffering', 'from', 'high', 'diabetic', 'and', 'high', 'blood', 'pressure', '.', 'I', 'beg', 'you', 'To', 'help', 'me', 'to', 'go', 'trichy', 'flight', 'on', '21', 'June', '2020', '.', 'My', 'registered', 'mobile', 'no', '.', '05708300', '86', 'My', 'passport', 'no', '.', 'K8972507', 'My', 'mail', 'id', ':', 'kavai.peter@gmail.com']
# Error: token: .kisongochi@gmail.com
# ['@USER', '@USER', 'I', 'am', 'desperate', 'for', 'help', '.', 'I', 'need', 'my', 'insulin', 'to', 'bring', 'my', 'blood', 'sugar', 'back', 'down', '.', 'It', "'s", '$', '217', '.', 'That', "'s", 'all', 'I', 'need', '.', 'I', "'m", 'not', 'asking', 'for', 'a', 'windfall', ',', 'just', 'a', 'little', 'help', ',', 'please', '.', 'My', 'PayPal', 'is', 'victor.wambwa', '.kisongochi@gmail.com', 'Thanks', 'in', 'advance', ':beating_heart:', ':folded_hands:', ':folded_hands:', ':beating_heart:']
# Error: token: michaelkerry@hotmail.co.uk
# ['@USER', '@USER', 'Hi', 'I', "'m", 'the', 'mother', 'of', 'Gemma', 'Kerry', ',', 'she', 'is', 'type', '1', 'diabetic', 'it', 'is', 'a', 'long', 'term', 'condition', '.', 'I', 'have', 'applied', 'to', 'make', 'a', 'wish', '.', 'And', 'she', 'has', 'not', 'yet', 'been', 'accepted', '.', 'I', 'know', 'she', 'would', 'love', 'to', 'meet', 'you', '.', 'She', 'has', 'tickets', 'to', 'the', 'Leeds', 'show', 'michaelkerry@hotmail.co.uk']
# Error: token: claire.kearns@live.co.uk
# ['Contact', 'claire.kearns@live.co.uk', '.', 'I', 'only', 'would', 'need', '10', 'mins', 'of', 'your', 'time', 'for', 'a', 'phone', 'recording', '&', 'it', 'would', 'be', 'much', 'appreciated', '!', '#T1D', '#eddmt1']
# Error: token: into.a.needle
# ['I', 'just', 'walked', 'into.a.needle', ',', 'it', 'was', 'atleast', '1cm', 'into', 'my', 'foot', '...', 'my', 'moms', 'reaction', '(', 'fyi', 'she', 'has', 'diabetes', 'and', 'wounds', 'on', 'diabetic', 'feets', 'heal.very', 'badly', ')', ':', 'you', 'see', 'theats', 'why', 'its', 'bad', 'for', 'diabetic', '.', 'me', ':', '?', '?', '?', '¡', '¡', '¡', '¿', '¿', '¿', '!', '!', '?', '?', 'Well', 'thanks.for', 'the', 'cooncern', '...']
# Error: token: .kisongochi@gmail.com
# ['@USER', 'Good', 'Morning', '!', 'I', 'am', 'desperate', 'for', 'help', '.', 'I', 'need', 'my', 'insulin', 'to', 'bring', 'my', 'blood', 'sugar', 'back', 'down', '.', 'It', "'s", '$', '217', '.', 'That', "'s", 'all', 'I', 'need', '.', 'I', "'m", 'not', 'asking', 'for', 'a', 'windfall', ',', 'just', 'a', 'little', 'help', ',', 'please', '.', 'My', 'PayPal', 'is', 'victor.wambwa', '.kisongochi@gmail.com', 'Thanks', 'in', 'advance', ':beating_heart:', ':folded_hands:', ':folded_hands:', ':beating_heart:']
# Error: token: 6.3/113.5
# ['Bloodsugar', 'was', '6.3/113.5', 'gonna', 'take', 'insulin', 'before', 'breakfast', '.', 'Having', 'scrambeled', 'eggs', 'and', 'bacon', 'for', 'breakfast', ':)', 'lets', 'hope', 'my', 'bloodsugar', 'stays', 'good', 'all', 'day', ':)', 'keep', 'you', 'posted', '#dailybloodsugars', 'HTTPURL']
# Error: token: .kisongochi@gmail.com
# ['@USER', '@USER', '@USER', 'I', 'am', 'desperate', 'for', 'help', '.', 'I', 'need', 'my', 'insulin', 'to', 'bring', 'my', 'blood', 'sugar', 'back', 'down', '.', 'It', "'s", '$', '217', '.', 'That', "'s", 'all', 'I', 'need', '.', 'I', "'m", 'not', 'asking', 'for', 'a', 'windfall', ',', 'just', 'a', 'little', 'help', ',', 'please', '.', 'My', 'PayPal', 'is', 'victor.wambwa', '.kisongochi@gmail.com', 'Thanks', 'in', 'advance', ':beating_heart:', ':folded_hands:', ':folded_hands:', ':beating_heart:']
# Error: token: .kisongochi@gmail.com
# ['@USER', '@USER', '@USER', '@USER', 'I', 'am', 'desperate', 'for', 'help', '.', 'I', 'need', 'my', 'insulin', 'to', 'bring', 'my', 'blood', 'sugar', 'back', 'down', '.', 'It', "'s", '$', '217', '.', 'That', "'s", 'all', 'I', 'need', '.', 'I', "'m", 'not', 'asking', 'for', 'a', 'windfall', ',', 'just', 'a', 'little', 'help', ',', 'please', '.', 'My', 'PayPal', 'is', 'victor.wambwa', '.kisongochi@gmail.com', 'Thanks', 'in', 'advance', ':beating_heart:', ':folded_hands:', ':folded_hands:', ':beating_heart:']
# Error: token: danni.mordell@gmail.com
# ['@USER', '@USER', 'I', 'lost', 'count', 'on', 'how', 'many', 'times', 'I', "'ve", 'tweeted', 'and', 'retweeted', '.', 'My', 'mom', 'who', 'is', 'diabetic', 'needs', 'her', 'insulin', 'and', 'has', "n't", 'had', 'a', 'meal', 'in', 'days', '.', 'I', "'m", 'really', 'still', 'short', 'on', 'food', 'ane', 'remainder', 'of', 'rent', '.', 'Pleaseeeee', 'see', 'my', 'cry', 'for', 'help', '.', 'PayPal', 'danni.mordell@gmail.com']
# Error: token: rosarodriguezortiz@yahoo.com.mx
# ['@USER', 'Hi', 'I', '´', 've', 'seen', 'a', 'video', ',', 'wich', 'a', 'chip', 'regenerate', 'all', 'cell', 'of', 'any', 'illness', '.', 'I', 'have', 'diabetes', '.', 'and', 'a', 'renal', 'damage', '3', '°', 'grade', '...', 'If', 'you', 'need', 'some', 'people', 'to', 'investigate', 'this', 'chip', ',', 'I', '¨', 'm', 'dissponible', '.', 'I', '´', 'm', '66', 'years', 'old', 'woman', 'My', 'mail', 'is', 'rosarodriguezortiz@yahoo.com.mx', '.', 'Live', 'in', 'México', '.']
# Error: token: b.c.will
# ['@USER', '@USER', '@USER', '@USER', 'I', 'have', 'a', 'good', 'diet', 'it', 'was', 'my', 'life', 'and', 'for', 'a', 'bad', 'day', 'I', 'b.c.will', 'get', 'diabetes']
# Error: token: U.P.but
# ['@USER', 'can', 'u', 'help', 'us', ':folded_hands:', 'we', 'are', 'senior', 'citizens', 'and', 'both', 'of', 'them', 'are', 'diabetic', 'patients', '.', 'Need', 'pass', 'to', 'travel', 'from', 'Noida', 'to', 'Jaipur', 'for', 'my', 'son', '.', 'we', 'are', 'alone', 'last', '45', '+', 'days', '.', 'hamare', 'bete', 'ko', 'permission', 'de', 'do', '.', 'also', 'registered', 'online', 'rajasthan', 'and', 'U.P.but', 'data', 'deleted']
# Error: token: this...mika/marina/queen
# ['(', '(', 'as', 'if', 'anyones', 'anticipating', 'lmao', ')', ')', 'the', 'good', 'news', 'is', '...', 'i', 'alrd', 'planned', 'more', 'of', 'that', 'glucose', 'guardian', 'minv', ':eyes:', 'and', '!', '!', 'i', 'have', 'this...mika/marina/queen', 'art', '(', 'book', '?', '?', ')', 'that', 'i', 'did', 'for', 'uni', 'exhibition', 'n', 'im', 'gonna', 'share', 'it', 'soon', 'heres', 'a', 'sneak', 'peek', 'HTTPURL']
# Error: token: rising.moon.midwife
# ['No', 'gestational', 'diabetes', 'for', 'me', ':folded_hands:', ':medium-light_skin_tone:', ':smiling_face_with_open_hands:', 'Thankful', 'I', 'chose', 'a', 'care', 'provider', 'risingmoonmidwifery', 'rising.moon.midwife', 'who', 'allowed', 'me', '(', 'and', 'preferred', ')', 'I', 'eat', 'a', '50g', 'carb', 'breakfast', 'for', 'my', 'test', 'rather', 'than', 'drink', 'the', 'juice', '!', ':face_vomiting:', '10', '...', 'HTTPURL']
# Error: token: holistically...dietician/podiatrist
# ['@USER', '@USER', 'I', 'am', 'particularly', 'lucky', 'though', 'with', 'my', 'diabetic', 'consultant', 'at', 'a', 'different', 'hospital', 'in', 'Newport', 'Gwent', '.', 'She', 'is', 'amazing', '&', 'theyve', 'employed', 'type', '1', 'DSN', 'too', '.', 'My', 'control', "'s", 'never', 'been', 'better', 'because', 'they', 'do', "n't", 'judge', 'they', 'work', 'holistically...dietician/podiatrist', 'etc', '.', 'I', 'love', 'them', 'all', ':blue_heart:']
# Error: token: traceyanne@live.com.au
# ['@USER', 'My', 'mum', 'is', 'sick', 'and', 'disabled', 'and', 'im', 'her', 'sole', 'carer', '.', 'ive', 'been', 'cut', 'from', 'work', ',', 'cant', 'afford', 'her', 'insulin', 'and', 'medical', 'supplies', 'on', 'my', 'own', 'now', '.', 'Any', 'help', 'would', 'be', 'amazing', '.', 'Paypal', 'is', 'traceyanne@live.com.au']
# Error: token: .kisongochi@gmail.com
# ['@USER', 'I', 'am', 'desperate', 'for', 'help', '.', 'I', 'need', 'my', 'insulin', 'to', 'bring', 'my', 'blood', 'sugar', 'back', 'down', '.', 'It', "'s", '$', '217', '.', 'That', "'s", 'all', 'I', 'need', '.', 'I', "'m", 'not', 'asking', 'for', 'a', 'windfall', ',', 'just', 'a', 'little', 'help', ',', 'please', '.', 'My', 'PayPal', 'is', 'victor.wambwa', '.kisongochi@gmail.com', 'Thanks', 'in', 'advance', ':beating_heart:', ':folded_hands:', ':folded_hands:', ':beating_heart:']
# Error: token: kavai.peter@gmail.com
# ['Dear', 'Indian', 'embassy', '@USER', 'I', 'am', 'suffering', 'from', 'high', 'diabetic', 'and', 'high', 'blood', 'pressure', '.', 'I', 'beg', 'you', 'to', 'go', 'trichy', 'flight', 'on', '21', 'June', '2020', '.', 'My', 'registered', 'mobile', 'no', '.', '05708300', '86', 'My', 'passport', 'no', '.', 'K8972507', 'My', 'mail', 'id', ':', 'kavai.peter@gmail.com']
# Error: token: .kisongochi@gmail.com
# ['@USER', 'Good', 'Morning', '!', 'I', 'am', 'desperate', 'for', 'help', '.', 'I', 'need', 'my', 'insulin', 'to', 'bring', 'my', 'blood', 'sugar', 'back', 'down', '.', 'It', "'s", '$', '217', '.', 'That', "'s", 'all', 'I', 'need', '.', 'I', "'m", 'not', 'asking', 'for', 'a', 'windfall', ',', 'just', 'a', 'little', 'help', ',', 'please', '.', 'My', 'PayPal', 'is', 'victor.wambwa', '.kisongochi@gmail.com', 'Thanks', 'in', 'advance', ':beating_heart:', ':folded_hands:', ':folded_hands:', ':beating_heart:']
# Error: token: S.A.She
# ['@USER', 'My', 'mom', 'had', 'to', 'send', 'her', 'prescriptions', 'to', 'S.A.She', 'suffers', 'from', 'b', '.', 'p', '.', 'and', 'diabetes', '.', 'Sadly', 'she', 'did', "n't", 'have', 'a', 'meds', 'for', 'sometime', 'she', 'fell', 'and', 'broke', 'her', 'leg.frankly', 'speaking', 'its', 'not', 'easy', 'to', 'get', 'her', 'meds', 'now', 'in', 'Zim.pharmacies', 'demand', 'Us', 'dollars', 'of', 'which', 'u', "can't", 'easily', 'access', '.']
# Error: token: c.h.robinson
# ['Another', 'year', 'in', 'the', 'books', 'doing', 'the', '#T1D', 'walk', 'at', '@USER', 'with', 'my', 'family', '.', 'I', 'am', 'beyond', 'blessed', 'to', 'be', 'able', 'to', 'participate', 'with', 'my', 'mom', ',', 'melzy', '1975', 'and', 'her', 'company', ',', 'c.h.robinson', 'Worldwide', '.', 'They', 'are', 'an', 'amazing', '...', 'HTTPURL']
# Error: token: .kisongochi@gmail.com
# ['@USER', 'I', 'am', 'desperate', 'for', 'help', '.', 'I', 'need', 'my', 'insulin', 'to', 'bring', 'my', 'blood', 'sugar', 'back', 'down', '.', 'It', "'s", '$', '217', '.', 'That', "'s", 'all', 'I', 'need', '.', 'I', "'m", 'not', 'asking', 'for', 'a', 'windfall', ',', 'just', 'a', 'little', 'help', ',', 'please', '.', 'My', 'PayPal', 'is', 'victor.wambwa', '.kisongochi@gmail.com', 'Thanks', 'in', 'advance', ':beating_heart:', ':folded_hands:', ':folded_hands:', ':beating_heart:']
# Error: token: .kisongochi@gmail.com
# ['@USER', '@USER', 'I', 'am', 'desperate', 'for', 'help', '.', 'I', 'need', 'my', 'insulin', 'to', 'bring', 'my', 'blood', 'sugar', 'back', 'down', '.', 'It', "'s", '$', '217', '.', 'That', "'s", 'all', 'I', 'need', '.', 'I', "'m", 'not', 'asking', 'for', 'a', 'windfall', ',', 'just', 'a', 'little', 'help', ',', 'please', '.', 'My', 'PayPal', 'is', 'victor.wambwa', '.kisongochi@gmail.com', 'Thanks', 'in', 'advance', ':beating_heart:', ':folded_hands:', ':folded_hands:', ':beating_heart:']
# Error: token: .kisongochi@gmail.com
# ['@USER', 'Good', 'Morning', '!', 'I', 'am', 'desperate', 'for', 'help', '.', 'I', 'need', 'my', 'insulin', 'to', 'bring', 'my', 'blood', 'sugar', 'back', 'down', '.', 'It', "'s", '$', '217', '.', 'That', "'s", 'all', 'I', 'need', '.', 'I', "'m", 'not', 'asking', 'for', 'a', 'windfall', ',', 'just', 'a', 'little', 'help', ',', 'please', '.', 'My', 'PayPal', 'is', 'victor.wambwa', '.kisongochi@gmail.com', 'Thanks', 'in', 'advance', ':beating_heart:', ':folded_hands:', ':folded_hands:', ':beating_heart:']
# Error: token: stella.waithaka99@gmail.com
# ['@USER', '@USER', '@USER', '@USER', '@USER', 'I', 'am', 'desperate', 'for', 'help', '.', 'I', 'need', 'my', 'insulin', 'to', 'bring', 'my', 'blood', 'sugar', 'back', 'down', '.', 'It', "'s", '$', '217', '.', 'That', "'s", 'all', 'I', 'need', '.', 'I', "'m", 'not', 'asking', 'for', 'a', 'windfall', ',', 'just', 'a', 'little', 'help', ',', 'please', '.', 'My', 'PayPal', 'is', 'stella.waithaka99@gmail.com', 'Thanks', 'in', 'advance', ':beating_heart:', ':folded_hands:', ':folded_hands:', ':beating_heart:']
# Error: token: legs.pl.pray
# ['Kindly', 'pray', 'for', 'me', '.', 'I', 'am', 'suffering', 'from', 'diabetes', 'and', 'joint', 'pain', 'weakness', 'in', 'legs.pl.pray', 'for', 'Mrs', 'Ori', '~', 'HTTPURL', '#pray', '#prayer', 'HTTPURL']
# Error: token: .kisongochi@gmail.com
# ['@USER', '@USER', 'Good', 'Morning', '!', 'I', 'am', 'desperate', 'for', 'help', '.', 'I', 'need', 'my', 'insulin', 'to', 'bring', 'my', 'blood', 'sugar', 'back', 'down', '.', 'It', "'s", '$', '217', '.', 'That', "'s", 'all', 'I', 'need', '.', 'I', "'m", 'not', 'asking', 'for', 'a', 'windfall', ',', 'just', 'a', 'little', 'help', ',', 'please', '.', 'My', 'PayPal', 'is', 'victor.wambwa', '.kisongochi@gmail.com', 'Thanks', 'in', 'advance', ':beating_heart:', ':folded_hands:', ':folded_hands:', ':beating_heart:']
# Error: token: ...Biden/Harris
# ['@USER', 'Rock', 'solid', '.', 'I', 'did', "n't", 'realize', 'he', 'had', 'such', 'a', 'great', 'plan', '.', 'My', 'wife', 'is', 'a', 'type', '1', 'diabetic', 'and', 'will', 'benefit', 'greatly', '.', 'Guess', 'I', 'will', 'have', 'to', 'change', 'my', 'vote', 'to', 'him', '..', 'Sadly', ',', 'some', 'people', 'will', 'think', 'that', '..', 'NOT', 'ME', '!', '...Biden/Harris', '2020', '!']
# Error: token: All.The.Time
# ['@USER', '@USER', 'Tonight', 'my', 'T1D', 'daughter', 'was', 'at', 'your', 'show', ',', 'right', 'before', 'you', 'spoke', 'about', 'your', 'son', 'having', 'diabetes', 'I', 'had', 'texted', 'her', 'to', 'give', 'correction', '..', 'she', 'was', 'frustrated', 'with', 'having', 'to', 'deal', 'with', 'diabetes', 'All.The.Time', '...', 'thanks', 'for', 'your', 'message', '!', '!', 'Mia', '(', 'in', 'the', 'middle', ')', '#lifeofT1D', 'HTTPURL']
# Error: token: abcnews.go.com/Health/type
# ['As', 'a', 'mom', 'of', 'a', 'type', 'one', 'diabetic', 'teen', 'who', 'needs', 'to', 'socialize', 'some', ',', 'this', 'artical', 'is', 'terrifying', ',', 'but', 'not', 'surprising', '.', 'whhttps', ':/', '/', 'abcnews.go.com/Health/type', 'diabetics', 'high', 'risk', 'severe', 'illness', 'related', 'coronavirus', '/', 'story', '?', 'id', '=', '7115338', '2', '.']
# Error: token: stella.waithaka99@gmail.com
# ['@USER', 'am', 'desperate', 'for', 'help', '.', 'I', 'need', 'my', 'insulin', 'to', 'bring', 'my', 'blood', 'sugar', 'back', 'down', '.', 'It', "'s", '$', '217', '.', 'That', "'s", 'all', 'I', 'need', '.', 'I', "'m", 'not', 'asking', 'for', 'a', 'windfall', ',', 'just', 'a', 'little', 'help', ',', 'please', '.', 'My', 'PayPal', 'is', 'stella.waithaka99@gmail.com', 'Thanks', 'in', 'advance', ':beating_heart:', ':folded_hands:', ':folded_hands:', ':beating_heart:']
# Error: token: .kisongochi@gmail.com
# ['@USER', 'I', 'am', 'desperate', 'for', 'help', '.', 'I', 'need', 'my', 'insulin', 'to', 'bring', 'my', 'blood', 'sugar', 'back', 'down', '.', 'It', "'s", '$', '217', '.', 'That', "'s", 'all', 'I', 'need', '.', 'I', "'m", 'not', 'asking', 'for', 'a', 'windfall', ',', 'just', 'a', 'little', 'help', ',', 'please', '.', 'My', 'PayPal', 'is', 'victor.wambwa', '.kisongochi@gmail.com', 'Thanks', 'in', 'advance', ':beating_heart:', ':folded_hands:', ':folded_hands:', ':beating_heart:']
# Error: token: A.N.Other
# ['@USER', 'Do', "n't", 'be', 'surprised', ',', 'it', 'is', 'the', 'same', 'for', 'many', 'things', '.', 'Typically', ',', 'people', 'do', "n't", 'understand', 'cancer', ',', 'diabetes', ',', 'heart', 'disease', 'any', 'better', '.', 'Best', 'to', 'keep', 'human', 'foibles', 'in', 'perspective', '.', 'MS', 'is', "n't", 'anything', 'special', 'to', 'most', 'people', '.', 'Just', 'A.N.Other', 'illness', '.']
# Error: token: a.m..
# ['Diabetes', 'doctor', 'in', 'the', 'a.m..', 'I', 'wonder', 'who', 'I', 'can', 'talk', 'into', 'going', 'with', 'me', '.', 'Lol', 'I', 'never', 'be', 'wanting', 'to', 'go', 'alone', ':astonished_face:']
# Error: token: Joesephine.McClard@hotmail.com
# ['I', "'m", 'in', 'REAL', 'TROUBLE', 'I', "can't", 'afford', 'insulin', '!', '!', '!', 'PLEASE', 'HELP', '!', '!', '!', 'PayPal', 'Joesephine.McClard@hotmail.com', 'Cash', 'App', '$', 'HardluckJoesephine', 'Venmo', '@USER', 'Joesephine', 'McClard']
# Error: token: schick.sara@yahoo.com
# ['@USER', 'I', 'have', 'two', 'Autistic', 'boys', ',', 'a', 'father', 'I', 'take', 'care', 'of', 'who', 'has', 'UC', 'and', 'diabetes', '...', 'And', 'I', 'have', 'COPD', '.', 'my', 'disabled', 'veteran', 'husband', 'is', 'quarantined', 'in', 'another', 'state', '..', 'my', 'family', 'we', 'are', 'on', 'our', 'own', '.', 'Any', 'help', 'so', 'I', 'can', 'feed', 'my', 'crew', 'is', 'greatly', 'appreciated', '.', 'schick.sara@yahoo.com', 'is', 'my', 'PayPal']
# Error: token: .kisongochi@gmail.com
# ['@USER', '@USER', 'Good', 'Morning', '!', 'I', 'am', 'desperate', 'for', 'help', '.', 'I', 'need', 'my', 'insulin', 'to', 'bring', 'my', 'blood', 'sugar', 'back', 'down', '.', 'It', "'s", '$', '217', '.', 'That', "'s", 'all', 'I', 'need', '.', 'I', "'m", 'not', 'asking', 'for', 'a', 'windfall', ',', 'just', 'a', 'little', 'help', ',', 'please', '.', 'My', 'PayPal', 'is', 'victor.wambwa', '.kisongochi@gmail.com', 'Thanks', 'in', 'advance', ':beating_heart:', ':folded_hands:', ':folded_hands:', ':beating_heart:']
# Error: token: o.k.with
# ['@USER', 'Fair', 'enough', '.', 'Im', 'o.k.with', 'either', '.', 'Im', 'also', '#asthmatic', '.', '&', '#arthritic', 'Im', 'actually', 'ok', 'with', '#diabetic', ',', 'tho', 'I', 'understand', 'not', 'all', 'are', '.', '#adsadea2017']
# Error: token: .kisongochi@gmail.com
# ['@USER', '@USER', 'I', 'am', 'desperate', 'for', 'help', '.', 'I', 'need', 'my', 'insulin', 'to', 'bring', 'my', 'blood', 'sugar', 'back', 'down', '.', 'It', "'s", '$', '217', '.', 'That', "'s", 'all', 'I', 'need', '.', 'I', "'m", 'not', 'asking', 'for', 'a', 'windfall', ',', 'just', 'a', 'little', 'help', ',', 'please', '.', 'My', 'PayPal', 'is', 'victor.wambwa', '.kisongochi@gmail.com', 'Thanks', 'in', 'advance', ':beating_heart:', ':folded_hands:', ':folded_hands:', ':beating_heart:']
# Error: token: ovo.victor95@gmail.com
# ['I', 'am', 'desperate', 'for', 'help', '.', 'I', 'need', 'my', 'insulin', 'to', 'bring', 'my', 'blood', 'sugar', 'back', 'down', '.', 'It', "'s", '$', '317', '.', 'That', "'s", 'all', 'I', 'need', '.', 'I', "'m", 'not', 'asking', 'for', 'a', 'windfall', ',', 'just', 'a', 'little', 'help', ',', 'please', '.', 'My', 'PayPal', 'is', 'ovo.victor95@gmail.com', 'Thanks', 'in', 'advance', '#BoostPleaseRT']
# Error: token: .kisongochi@gmail.com
# ['@USER', 'I', 'am', 'desperate', 'for', 'help', '.', 'I', 'need', 'my', 'insulin', 'to', 'bring', 'my', 'blood', 'sugar', 'back', 'down', '.', 'It', "'s", '$', '217', '.', 'That', "'s", 'all', 'I', 'need', '.', 'I', "'m", 'not', 'asking', 'for', 'a', 'windfall', ',', 'just', 'a', 'little', 'help', ',', 'please', '.', 'My', 'PayPal', 'is', 'victor.wambwa', '.kisongochi@gmail.com', 'Thanks', 'in', 'advance', ':folded_hands:', ':beating_heart:', 'HTTPURL']
# Error: token: danni.mordell@gmail.com
# ['I', 'lost', 'count', 'on', 'how', 'many', 'times', 'I', "'ve", 'tweeted', 'and', 'retweeted', '.', 'My', 'mom', 'who', 'is', 'diabetic', 'needs', 'her', 'insulin', 'and', 'has', "n't", 'had', 'a', 'meal', 'in', 'days', '.', 'I', "'m", 'really', 'still', 'short', 'on', 'food', 'ane', 'remainder', 'of', 'rent', '.', 'Pleaseeeee', 'see', 'my', 'cry', 'for', 'help', '.', 'PayPal', 'danni.mordell@gmail.com']
# Error: token: stella.waithaka99@gmail.com
# ['@USER', '@USER', '@USER', '@USER', '@USER', 'I', 'am', 'desperate', 'for', 'help', '.', 'I', 'need', 'my', 'insulin', 'to', 'bring', 'my', 'blood', 'sugar', 'back', 'down', '.', 'It', "'s", '$', '217', '.', 'That', "'s", 'all', 'I', 'need', '.', 'I', "'m", 'not', 'asking', 'for', 'a', 'windfall', ',', 'just', 'a', 'little', 'help', ',', 'please', '.', 'My', 'PayPal', 'is', 'stella.waithaka99@gmail.com', 'Thanks', 'in', 'advance', ':beating_heart:', ':folded_hands:', ':folded_hands:', ':beating_heart:']
# Error: token: Urb.Caguas.Norte
# ['@USER', 'How', 'can', 'I', 'contact', 'PREPA', 'I', 'live', 'in', 'Urb.Caguas.Norte', 'street', 'Caracas', 'with', 'a', 'patient', 'l', 'kidney', 'failure', 'diabetes', 'neuropathic', 'pain', 'AEE', 'doensnt', 'prioritize', 'my', 'street', 'even', 'though', 'I', 'have', 'reported', 'several', 'Times', 'my', 'street', 'all', 'post', 'are', 'intact', 'and', 'subestation', '3901', 'is', 'working', 'help', 'us']
# Error: token: 636.949.7484
# ['More', 'than', '25', 'million', 'Americans', 'have', 'diabetes', ',', 'but', 'millions', 'more', 'do', "n't", 'know', 'they', 'have', 'it', '&', 'receive', 'no', 'beneficial', 'care', '.', 'The', '@USER', 'Health', 'Services', 'clinic', 'has', 'free', 'blood', 'draws', 'on', 'Thursdays', 'in', 'March', 'to', 'help', 'you', 'track', 'blood', 'sugar', 'levels', 'and', 'get', 'help', '.', 'Call', '636.949.7484', '.', 'HTTPURL']
# Error: token: pract.Drs.are
# ['@USER', 'Am', 'I', 'right', 'that', 'my1or2things', 'were', 'the', 'death', 'bid', '?', 'The', 'insulin', 'coma', 'therapyORdeep', 'sleep', 'theory', '.', '+', 'young', 'pract.Drs.are', 'ignor', '.', 'It', '?', 'HTTPURL']
# Error: token: No.They.Don
# ['@USER', '@USER', 'I', 'did', "n't", 'catch', 'diabetes', '.', 'I', 'was', 'born', 'with', 'a', 'genetic', 'defect', 'that', 'caused', 'an', 'autoimmune', 'reaction', 'that', 'destroyed', 'my', 'islet', 'cells', 'by', 'the', 'age', 'of', '17', '.', 'You', 'can', 'fuck', 'right', 'off', 'with', 'that', 'stupid', '"', 'markets', 'solve', 'all', 'our', 'problems', '"', 'crap', '.', 'No.They.Don', "'", 't', '.']
# Error: token: danni.mordell@gmail.com
# ['Please', '.', 'I', "'ve", 'been', 'trying', 'for', '5', 'days', '.', 'My', 'mom', 'is', 'disabled', 'and', 'diabetic', 'who', 'needs', 'ger', 'insulin', '.', 'Im', 'short', 'on', 'rent', 'and', 'food', '.', 'This', 'is', 'my', 'last', 'try', '.', 'For', 'some', 'reason', 'im', 'going', 'unnoticed', ',', 'but', 'glad', 'you', "'re", 'helping', 'others', 'in', 'worse', 'situations', '.', 'PayPal', 'danni.mordell@gmail.com']
# Error: token: U.S.ofA
# ['If', 'it', "'s", 'a', 'fair', 'price', 'for', 'other', 'countries', ',', 'it', "'s", 'a', 'fair', 'price', 'in', 'the', 'U.S.ofA', '.', 'Discovering', 'insulin', 'could', 'have', 'made', 'Banting', 'very', 'rich', ',', 'but', 'he', 'decided', 'to', 'give', 'the', 'patent', 'away', 'for', 'free', '.', 'He', 'wanted', 'insulin', 'to', 'be', 'available', 'to', 'everyone', ',', 'not', 'held', 'out', 'of', 'reach', 'at', 'exorbitant', 'prices', '.']
# Error: token: .kisongochi@gmail.com
# ['@USER', '@USER', '@USER', 'Good', 'Morning', '!', 'I', 'am', 'desperate', 'for', 'help', '.', 'I', 'need', 'my', 'insulin', 'to', 'bring', 'my', 'blood', 'sugar', 'back', 'down', '.', 'It', "'s", '$', '217', '.', 'That', "'s", 'all', 'I', 'need', '.', 'I', "'m", 'not', 'asking', 'for', 'a', 'windfall', ',', 'just', 'a', 'little', 'help', ',', 'please', '.', 'My', 'PayPal', 'is', 'victor.wambwa', '.kisongochi@gmail.com', 'Thanks', 'in', 'advance', ':beating_heart:', ':folded_hands:', ':folded_hands:', ':beating_heart:']
# Error: token: .kisongochi@gmail.com
# ...
# Error: token: stella.waithaka99@gmail.com
# ['@USER', '@USER', '@USER', 'I', 'am', 'desperate', 'for', 'help', '.', 'I', 'need', 'my', 'insulin', 'to', 'bring', 'my', 'blood', 'sugar', 'back', 'down', '.', 'It', "'s", '$', '217', '.', 'That', "'s", 'all', 'I', 'need', '.', 'I', "'m", 'not', 'asking', 'for', 'a', 'windfall', ',', 'just', 'a', 'little', 'help', ',', 'please', '.', 'My', 'PayPal', 'is', 'stella.waithaka99@gmail.com', 'Thanks', 'in', 'advance', ':beating_heart:', ':folded_hands:', ':folded_hands:', ':beating_heart:']
# Error: token: 2.9.Only
# ['@USER', 'The', 'govnt', 'declare', 'the', 'control', 'of', 'virus', 'will', 'end', 'in', '2.14', ',', 'my', 'insulin', 'will', 'use', 'up', 'at', '2.9.Only', '5', 'days', 'I', 'can', 'hold', 'HTTPURL', 'not', 'a', 'problem', 'for', 'me.But', 'still', 'thanks', 'for', 'your', 'care', '.']
# Error: token: year...mar/apr...oct/nov...both
# ['@USER', 'I', 'have', 'diabetes', 'and', 'congestive', 'heart', 'failure', '...', 'have', 'a', 'defibrillator', '..', 'been', 'sick', '2', "'", 's', 'last', 'year...mar/apr...oct/nov...both', 'times', 'out', 'of', 'work', '4', '5', 'weeks', 'recovery', '...', 'this', 'lab', 'created', 'virus', 'attacks', 'your', 'lungs', '...', 'tires', 'you', 'out', 'and', 'drowns', 'you', '...', 'creators', 'knew', 'exactly', 'what', 'it', 'would', 'do']
# Error: token: .kisongochi@gmail.com
# ['@USER', '@USER', '@USER', 'Good', 'Morning', '!', 'I', 'am', 'desperate', 'for', 'help', '.', 'I', 'need', 'my', 'insulin', 'to', 'bring', 'my', 'blood', 'sugar', 'back', 'down', '.', 'It', "'s", '$', '217', '.', 'That', "'s", 'all', 'I', 'need', '.', 'I', "'m", 'not', 'asking', 'for', 'a', 'windfall', ',', 'just', 'a', 'little', 'help', ',', 'please', '.', 'My', 'PayPal', 'is', 'victor.wambwa', '.kisongochi@gmail.com', 'Thanks', 'in', 'advance', ':beating_heart:', ':folded_hands:', ':folded_hands:', ':beating_heart:']
# Error: token: .kisongochi@gmail.com
# ['@USER', 'Good', 'afternoon', '!', 'I', 'am', 'desperate', 'for', 'help', '.', 'I', 'need', 'my', 'insulin', 'to', 'bring', 'my', 'blood', 'sugar', 'back', 'down', '.', 'It', "'s", '$', '217', '.', 'That', "'s", 'all', 'I', 'need', '.', 'I', "'m", 'not', 'asking', 'for', 'a', 'windfall', ',', 'just', 'a', 'little', 'help', ',', 'please', '.', 'My', 'PayPal', 'is', 'victor.wambwa', '.kisongochi@gmail.com', 'Thanks', 'in', 'advance', ':beating_heart:', ':folded_hands:', ':folded_hands:', ':beating_heart:']
# Error: token: agay.kagang@aol.com
# ['Hello', 'sorry', 'to', 'bother', ':waving_hand:', 'but', 'I', "'m", 'hoping', 'Is', 'there', 'anyone', 'could', 'help', 'us', 'out', '?', ':folded_hands:', 'my', 'aunt', 'need', 'some', 'help', 'for', 'her', 'insulin', 'treatment', 'because', 'she', 'has', 'Diabetes', 'and', 'it', "'s", 'getting', 'worse', ':disappointed_face:', ':pensive_face:', '.', 'Any', 'help', 'means', 'a', 'lot', '.', 'Hoping', 'for', 'your', 'kind', 'and', 'understanding', ':revolving_hearts:', ':folded_hands:', 'PayPal', 'agay.kagang@aol.com', 'HTTPURL']
# Error: token: .kisongochi@gmail.com
# ['@USER', 'I', 'am', 'desperate', 'for', 'help', '.', 'I', 'need', 'my', 'insulin', 'to', 'bring', 'my', 'blood', 'sugar', 'back', 'down', '.', 'It', "'s", '$', '217', '.', 'That', "'s", 'all', 'I', 'need', '.', 'I', "'m", 'not', 'asking', 'for', 'a', 'windfall', ',', 'just', 'a', 'little', 'help', ',', 'please', '.', 'My', 'PayPal', 'is', 'victor.wambwa', '.kisongochi@gmail.com', 'Thanks', 'in', 'advance', ':beating_heart:', ':folded_hands:', ':folded_hands:', ':beating_heart:']
# Error: token: i.e.insulin
# ['@USER', 'But', 'u', 'can', 'not', 'abruptly', 'stop', 'it', 'causes', 'side', 'effects.Your', 'body', 'need', 'sugar', 'i.e.insulin', 'so', 'keep', 'taking', 'it', 'but', 'controllably', 'so', 'then', 'ur', 'body', 'will', 'get', 'used', 'to', 'minimal', 'but', 'balanced', 'intake', 'of', 'sugar.If', 'your', 'blood', 'can', 'control', 'it', 'u', 'r', 'good', 'to', 'go', 'girl']
# Error: token: stella.waithaka99@gmail.com
# ['@USER', '@USER', 'I', 'am', 'desperate', 'for', 'help', '.', 'I', 'need', 'my', 'insulin', 'to', 'bring', 'my', 'blood', 'sugar', 'back', 'down', '.', 'It', "'s", '$', '217', '.', 'That', "'s", 'all', 'I', 'need', '.', 'I', "'m", 'not', 'asking', 'for', 'a', 'windfall', ',', 'just', 'a', 'little', 'help', ',', 'please', '.', 'My', 'PayPal', 'is', 'stella.waithaka99@gmail.com', 'Thanks', 'in', 'advance', ':beating_heart:', ':folded_hands:', ':folded_hands:', ':beating_heart:']
# Error: token: P.s.he
# ['Just', 'got', 'home', 'from', 'a', '73', 'hour', 'shift', ',', 'had', 'a', 'nap', 'then', 'woke', 'up', 'to', 'my', 'boyfriend', 'having', 'a', 'diabetic', 'seizure', 'and', 'a', 'hypo', '!', 'Scariest', 'thing', 'in', 'the', 'world', '.', 'If', 'you', 'experience', 'seizures', 'I', 'hope', 'you', "'re", 'okay', 'and', 'take', 'some', 'time', 'out', 'for', 'yourself', '.', 'It', 'looks', 'exhausting', 'and', 'terrifying', '.', 'P.s.he', "'", 's', 'good', 'now']
# Error: token: jejune.Chemicals.Hense
# ['I', 'agent', 'had', 'a', 'cold', 'or', 'flu', 'in', 'decades', '.', 'I', 'am', 'not', 'turning', 'blue', '.', 'I', 'was', 'exposed', 'to', 'bad', 'stuff', 'at', 'camp', 'jejune.Chemicals.Hense', 'I', 'have', 'diabetes', '.']
# Error: token: a.m...
# ['Just', 'finished', '@USER', "'", 's', 'incredible', 'book', '.', 'If', 'I', 'understood', 'it', 'correctly', 'he', "'s", 'saying', 'that', 'insulin', 'is', 'super', 'awesome', 'and', 'I', 'should', 'consume', 'as', 'much', 'sugar', 'as', 'possible', 'so', 'my', 'pancreas', 'makes', 'a', 'ton', 'of', 'it', '.', 'Score', '!', '!', 'I', 'believe', 'Krispy', 'Kreme', 'is', 'open', 'at', '1', 'a.m...']
# Error: token: .kisongochi@gmail.com
# ['@USER', '@USER', 'Good', 'afternoon', '!', 'I', 'am', 'desperate', 'for', 'help', '.', 'I', 'need', 'my', 'insulin', 'to', 'bring', 'my', 'blood', 'sugar', 'back', 'down', '.', 'It', "'s", '$', '217', '.', 'That', "'s", 'all', 'I', 'need', '.', 'I', "'m", 'not', 'asking', 'for', 'a', 'windfall', ',', 'just', 'a', 'little', 'help', ',', 'please', '.', 'My', 'PayPal', 'is', 'victor.wambwa', '.kisongochi@gmail.com', 'Thanks', 'in', 'advance', ':beating_heart:', ':folded_hands:', ':folded_hands:', ':beating_heart:']
# Error: token: 5.4.Plz
# ['Plz', 'Bro', 'I', 'beg', 'u', 'to', 'pray', 'for', 'my', 'husband', 'Romeo', 'Dsouza', 'he', 'is', 'suffering', 'from', 'diabetes', 'and', 'chronic', 'kidney', 'disease.his', 'creatinine', 'levels', 'which', 'has', 'to', 'be1', ',', 'is', '5.4.Plz', 'pray', 'for', 'it', 'to', 'come', 'down.For', 'God', 'nothing', 'is', 'impossible.Medical', 'science', 'can', 'fail', '~', 'HTTPURL', '#pray', '#prayer', 'HTTPURL']
# Error: token: now11.9.needs
# ['@USER', '@USER', 'I', 'was', 'admitted', 'on', '20th', ',', 'August', ',', '2018', ',', 'suffering', 'from', 'diabetic', 'of', 'high', 'sugar', 'levels', 'then', '38.7', ',', 'now11.9.needs', 'money', 'for', 'upkeep', 'welfare', '&', 'house', 'rent', '+', 'hospital', 'bills']
# Error: token: danni.mordell@gmail.com
# ['@USER', '@USER', 'I', 'lost', 'count', 'on', 'how', 'many', 'times', 'I', "'ve", 'tweeted', 'and', 'retweeted', '.', 'My', 'mom', 'who', 'is', 'diabetic', 'needs', 'her', 'insulin', 'and', 'has', "n't", 'had', 'a', 'meal', 'in', 'days', '.', 'I', "'m", 'really', 'still', 'short', 'on', 'food', 'ane', 'remainder', 'of', 'rent', '.', 'Pleaseeeee', 'see', 'my', 'cry', 'for', 'help', '.', 'PayPal', 'danni.mordell@gmail.com', 'Quote', 'Tweet']
# Error: token: d.n.and
# ['@USER', 'So', 'glad', 'I', 'ignored', 'the', 'd.n.and', 'followed', 'the', 'diabetes', '.', 'co.UK', 'site', 'and', 'forum', '(', 'diawara', ')', '...', 'I', 'accidently', 'got', 'on', 'the', 'blue', 'forum', 'and', 'coudnt', 'believe', 'their', 'advice', '...', 'why', "can't", 'they', 'admit', 'theyre', 'wrong', '...', 'it', "'s", 'progressive', 'if', 'you', 'follow', 'their', 'advice', '..']
# Error: token: Dr.Hustler.if
# ['I', 'understand', 'if', '@USER', 'decide', ',', 'that', 'he', 'wo', "n't", 'vie', '4', 'president', ',', 'all', 'this', 'endless', 'political', 'diabetes', 'that', 'we', "'re", 'seeing', '2day', 'will', 'STOP.All', 'this', 'political', 'rhythm', 'is', 'danced', 'in', 'the', 'tune', 'of', 'Dr.Hustler.if', 'he', 'happens', '2', 'say', 'No', '!', 'I', 'tell', 'U', 'even', '@USER', 'will', 'b', 'asleep', 'at', 'a', 'time', 'like', 'now']
# Error: token: m.facebook.com/story.php?story_fbid=2043993635924063&id=100009403392187
# ['So', 'sad', ',', 'yet', 'another', 'childs', 'life', 'taken', 'by', '#T1D', ':crying_face:', '.', 'Read', 'a', 'mother', "'s", 'story', 'and', 'the', 'signs', 'of', 'T1https', ':/', '/', 'm.facebook.com/story.php?story_fbid=2043993635924063&id=100009403392187']
# Error: token: bld.pressure.The
# ['Unfortunately', ',', 'the', 'people', 'who', 'live', 'there', 'tend', 'to', 'be', 'a', 'bit', 'unhealthy', '.', 'Type', '2', 'diabetes', ',', 'obesity', 'and', 'high', 'bld.pressure.The', 'morbidity', 'would', 'be', 'high', '.', 'Interestingly', 'tho', ',', 'it', "'s", 'a', 'warm', 'area', '.', 'Its', 'frequently', 'said', 'that', 'viruses', 'go', 'away', 'when', 'it', "'s", 'warm', '.', 'But', 'then', ',', '#COVID19', 'is', 'not', 'a', 'normal', 'virus']
# Error: token: .kisongochi@gmail.com
# ['@USER', '@USER', 'I', 'am', 'desperate', 'for', 'help', '.', 'I', 'need', 'my', 'insulin', 'to', 'bring', 'my', 'blood', 'sugar', 'back', 'down', '.', 'It', "'s", '$', '217', '.', 'That', "'s", 'all', 'I', 'need', '.', 'I', "'m", 'not', 'asking', 'for', 'a', 'windfall', ',', 'just', 'a', 'little', 'help', ',', 'please', '.', 'My', 'PayPal', 'is', 'victor.wambwa', '.kisongochi@gmail.com', 'Thanks', 'in', 'advance', ':beating_heart:', ':folded_hands:', ':folded_hands:', ':beating_heart:']
# Error: token: 500.EA.Time
# ['@USER', 'SO', 'GLAD', 'to', 'hear', 'about', 'Cost', 'of', 'Meds', 'ESPECIALLY', 'INSULIN', '!', 'My', 'husband', 'had', 'to', 'pay', '>', '$', '500.EA.Time', 'he', 'got', 'Insulin', '..', '&', 'He', 'had', 'to', 'REFILL', 'at', 'least', '2x', 'monthly', '!', 'We', 'could', 'Only', 'pay', 'for', 'it', 'by', 'letting', 'EVERYTHING', 'else', 'go', '!', 'He', 'was', 'a', 'very', 'high', 'Dose', 'Insulin', 'Dependent.He', 'passed', '10/2017', '.', 'w', '/', 'Cancer']
# Error: token: CUT.OUT.THE.SUGAR
# ['CUT.OUT.THE.SUGAR', '.', 'I', 'know', 'devil', 'is', 'trying', 'to', 'test', 'you', 'but', 'us', 'people', 'with', 'pcos', 'are', 'prone', 'to', 'getting', 'diabetes', 'bc', 'we', "can't", 'process', 'sugar', 'the', 'way', 'people', 'without', 'this', '„', 'disease', '“', 'can', '.', 'The', 'sugar', 'also', 'increase', 'the', 'chances', 'of', 'acne', ',', 'ovarian', 'cancer', 'and', 'uterine', 'cancer']
# Error: token: Joesephine.McClard@hotmail.com
# ['I', "'m", 'still', 'short', '$', '150', 'I', 'need', 'insulin', 'badly', ',', 'I', "'m", 'starting', 'to', 'get', 'very', 'sick', '.', 'PayPal', 'Joesephine.McClard@hotmail.com', 'Cash', 'App', '$', 'HardluckJoesephine', 'Please', 'help', '.', 'Thank', 'you', '!', 'HTTPURL']
# Error: token: Test.Of.Strength
# ['I', 'bought', 'this', 'the', 'day', 'before', 'I', 'found', 'out', 'about', 'the', 'diabetes', '.', 'It', 'is', 'genuinely', 'torturing', 'me', '.', 'I', 'dreamed', 'about', 'it', 'the', 'other', 'day', '@USER', 'singing', 'the', 'Oompa', 'Loompa', 'song', 'to', 'me', 'and', 'everything', '.', 'Have', "n't", 'given', 'in', 'yet', '.', 'Test.Of.Strength', 'HTTPURL']
# Error: token: .kisongochi@gmail.com
# ['@USER', 'Good', 'Morning', '!', 'I', 'am', 'desperate', 'for', 'help', '.', 'I', 'need', 'my', 'insulin', 'to', 'bring', 'my', 'blood', 'sugar', 'back', 'down', '.', 'It', "'s", '$', '217', '.', 'That', "'s", 'all', 'I', 'need', '.', 'I', "'m", 'not', 'asking', 'for', 'a', 'windfall', ',', 'just', 'a', 'little', 'help', ',', 'please', '.', 'My', 'PayPal', 'is', 'victor.wambwa', '.kisongochi@gmail.com', 'Thanks', 'in', 'advance', ':beating_heart:', ':folded_hands:', ':folded_hands:', ':beating_heart:']
# Error: token: etc.3.never
# ['ppl', 'in', 'the', 'replies', 'have', 'never1.lived', 'in', 'poverty', '2.had', 'a', 'disorder', 'changing', 'ur', 'metabolism', '/', 'response', 'to', 'insulin', '/', 'etc.3.never', 'had', 'life', 'keep', 'them', 'from', 'being', 'active', 'whether', 'that', 'be', 'mental', 'illness', ',', 'chronic', 'pain', ',', 'etc4.been', 'raised', 'by', 'a', 'family', 'that', 'did', "n't", 'educate', 'you', 'abt', 'nutrition']
# Error: token: e.g.last
# ['America', "'s", 'in', 'a', 'sick', 'ward', ',', 'result', 'of', 'extreme', 'sedentary', 'habits', ',', 'insulin', 'galore', 'and', 'bad', 'sleep', 'hygiene', '.', 'Sick', 'in', 'chair', 'snares', 'and', 'seat', 'snags', '.', 'We', "'re", 'ruined', '.', 'Metabolism', 'bankruptcy', 'in', 'generation', 'at', 'helm', 'that', "can't", 'talk', 'about', 'real', 'problems', 'e.g.last', 'night', "'s", '‘', 'debate', "'", '.', '@USER', 'and', 'Diehl', '.']
# Error: token: No.4509638031.kindly
# ['@USER', 'Sir', ',', 'we', 'both', 'couple', 'are', 'senior', 'citizen', 'suffering', 'from', 'diabetes', '(', 'insulin', 'dependent', ')', 'with', 'high', 'blood', 'pressure', 'but', 'we', "'re", 'alloted', 'upper', 'berth', 'in', '2', 'cabins', 'in', 'a', '/', 'c', '1', 'st', 'class', 'in', 'train', 'no', '.', '12431', 'on', '21/12/19', 'vide', 'PNR', 'No.4509638031.kindly', 'arrange', 'me', 'at', 'least', '1', 'lower', 'berth']
# Error: token: So.much.sugar
# ['I', "'m", 'seeing', 'these', 'Tweets', 'about', 'Frosted', 'Flakes', 'with', 'bananas', '.', 'As', 'a', 'type', '1', 'diabetic', ',', 'I', "'m", 'doing', 'the', 'carb', 'counting', 'in', 'my', 'head', ',', 'and', 'I', "'m", 'terrified', '.', 'So.much.sugar', '...', 'bon', 'appetit', '.', 'But', 'Frosted', 'Flakes', 'are', 'good', '.', 'I', 'just', "can't", 'have', 'them', 'much', '.', ':slightly_smiling_face:', ':two_hearts:', ':bowl_with_spoon:', 'HTTPURL']
# Error: token: GO.FOR.IT
# ['@USER', 'Well', ',', 'there', "'s", 'a', 'very', 'good', 'chance', 'you', "'ll", 'die', 'if', 'you', 'take', 'insulin', 'without', 'being', 'diagnosed', 'with', 'Diabetes', '...', 'soooooo', '...', 'there', "'s", 'THAT', ',', 'but', 'hey', '!', 'Since', 'ye', 'all', 'do', "n't", '“', 'believe', '”', 'in', 'science', 'I', 'say', '...', 'GO.FOR.IT', 'stable', 'genius', '!', ':thumbs_up:', 'HTTPURL']
# Error: token: U.S.price
# ['Insulin', 'has', 'NOT', 'gone', 'down', 'in', 'price', '.', 'I', 'get', 'mine', 'in', 'Canada', 'cause', 'I', 'can', 'not', 'afford', 'U.S.price', '.', 'Once', 'again', 'drumpf', 'lied', 'big', 'surprise', '.']
# 562013
# tweets to sentences: 1580990
# ['No need to medicine contenue .'
#  '@USER " That does n\'t mean we should take care of the person who sits at home , eats poorly and gets diabetes .'
#  '" Mick Mulvaney .' 'Republican .'
#  '@USER Dear lord that rack is sepeeated by type 1 and type 2 diabetes .'
#  'Stay away my friend .'
#  '@USER i have kids and i want to spend time with them desperately .'
#  'i have some diabetes amputations but i need help could u please :revolving_hearts:'
#  '@USER @USER @USER Why should everybody have to pay 40 million with diabetes because they made poor health choices ?'
#  'He goes into this story about how he beat diabetes and lost 36lbs from being " on the vinegar "'
#  '@USER 2 quit my job & wrk fulltime takin care of my mom with Rheumatoid Arthritis & Diabetes !'
#  "Ca n't do that with my job !" "I 'm all she has & I :red_heart: ️her"
#  "@USER Having to cut back on carbs , my eye exam found evidence of diabetes damage and I 'm between insurance so no proper doctor yet :unamused_face:"
#  'Now I need a whole bottle of wine , the gentleman just told me that his wife has a bad case of diabetes and has had a double leg amputation :loudly_crying_face: :loudly_crying_face:'
#  "@USER ilysm :red_heart: and I 'm so glad I get to meet you soon !"
#  'You have helped me through my type 1 diabetes by always making me smile and laugh'
#  'Went to the eye doctor today and I still have 20/20 vision and no damage to my eyes from my type 1 diabetes !'
#  '!' 'God is good , all the time !']

# %%
######### Exclude questions and sentences with less than 5 words 
# and sentences without diabetes related keyword #################


trainingData = sentences[sentences.str.split(" ").str.len() > 5] # keep only sentence with more than 3 tokens
trainingData = trainingData[~trainingData.str.endswith("?")]
trainingData = trainingData[trainingData.str.contains("|".join(diabetes_keywords))]

print("N sentences with > 5 words & no question & all with diabetes keyword:", trainingData.shape)

text = trainingData.values.tolist()
# Out:
# N sentences with > 5 words & no question & all with diabetes keyword: (482583,)

# %%
dd = pd.DataFrame({"text":text})
dd["tokenized"] = dd.text.str.split(" ")
for i, row in dd[20:40].iterrows():
    print(row["text"])
    print(row["tokenized"])
    print()
# Out:
# @USER Dear Noelia , Im one of the mewgulf 's victim that lead me to sudden heart attack and diabetic by watching too much of their sweetness .
# ['@USER', 'Dear', 'Noelia', ',', 'Im', 'one', 'of', 'the', 'mewgulf', "'s", 'victim', 'that', 'lead', 'me', 'to', 'sudden', 'heart', 'attack', 'and', 'diabetic', 'by', 'watching', 'too', 'much', 'of', 'their', 'sweetness', '.']
#
# suggest me a best way to cure fast #IndiaGateSweetTalk @USER My father suffering from diabetes !
# ['suggest', 'me', 'a', 'best', 'way', 'to', 'cure', 'fast', '#IndiaGateSweetTalk', '@USER', 'My', 'father', 'suffering', 'from', 'diabetes', '!']
#
# Yeah catch my ass in Canada once I 'm off parent 's insurance bc I definitely canNOT afford insulin on my own .
# ['Yeah', 'catch', 'my', 'ass', 'in', 'Canada', 'once', 'I', "'m", 'off', 'parent', "'s", 'insurance', 'bc', 'I', 'definitely', 'canNOT', 'afford', 'insulin', 'on', 'my', 'own', '.']
#
# @USER @USER She 'll love it until they decide insulin is too expensive to provide to certain people ...
# ['@USER', '@USER', 'She', "'ll", 'love', 'it', 'until', 'they', 'decide', 'insulin', 'is', 'too', 'expensive', 'to', 'provide', 'to', 'certain', 'people', '...']
#
# @USER :pensive_face: :pensive_face: :pensive_face: sugar and glucose is the same thing
# ['@USER', ':pensive_face:', ':pensive_face:', ':pensive_face:', 'sugar', 'and', 'glucose', 'is', 'the', 'same', 'thing']
#
# I walked into a pharmacy with no prescription and got insulin for 30 bucks .
# ['I', 'walked', 'into', 'a', 'pharmacy', 'with', 'no', 'prescription', 'and', 'got', 'insulin', 'for', '30', 'bucks', '.']
#
# @USER :face_with_tears_of_joy: :weary_face: his insulin levels must be protected at all costs
# ['@USER', ':face_with_tears_of_joy:', ':weary_face:', 'his', 'insulin', 'levels', 'must', 'be', 'protected', 'at', 'all', 'costs']
#
# @USER @USER You 're talking to a guy who beat diabetes FYI ...
# ['@USER', '@USER', 'You', "'re", 'talking', 'to', 'a', 'guy', 'who', 'beat', 'diabetes', 'FYI', '...']
#
# Pneumonia , diabetes , etc .
# ['Pneumonia', ',', 'diabetes', ',', 'etc', '.']
#
# Trump allowing the cost of insulin to not be so overpriced that people who rely on it literally die because they 're poor is n't him being a good president or working for the people it 's literally a man doing less than the absolute bare minimum job of keeping his constituents alive
# ['Trump', 'allowing', 'the', 'cost', 'of', 'insulin', 'to', 'not', 'be', 'so', 'overpriced', 'that', 'people', 'who', 'rely', 'on', 'it', 'literally', 'die', 'because', 'they', "'re", 'poor', 'is', "n't", 'him', 'being', 'a', 'good', 'president', 'or', 'working', 'for', 'the', 'people', 'it', "'s", 'literally', 'a', 'man', 'doing', 'less', 'than', 'the', 'absolute', 'bare', 'minimum', 'job', 'of', 'keeping', 'his', 'constituents', 'alive']
#
# like my dad I love mcdonald and i 'll die of diabetes at 30 HTTPURL
# ['like', 'my', 'dad', 'I', 'love', 'mcdonald', 'and', 'i', "'ll", 'die', 'of', 'diabetes', 'at', '30', 'HTTPURL']
#
# Hey @USER thanks for giving my insulin dependent mother the run around on her pump parts .
# ['Hey', '@USER', 'thanks', 'for', 'giving', 'my', 'insulin', 'dependent', 'mother', 'the', 'run', 'around', 'on', 'her', 'pump', 'parts', '.']
#
# I 'm sure it 's not a huge deal she 's been without her insulin pump for a week .
# ['I', "'m", 'sure', 'it', "'s", 'not', 'a', 'huge', 'deal', 'she', "'s", 'been', 'without', 'her', 'insulin', 'pump', 'for', 'a', 'week', '.']
#
# i saw my diabetes doc on thurs and we changed some ratios , i have n't seen myself in so good of a range since i was hospitalized in february :loudly_crying_face: :sparkling_heart: we 're finally back in business boys and girls !
# ['i', 'saw', 'my', 'diabetes', 'doc', 'on', 'thurs', 'and', 'we', 'changed', 'some', 'ratios', ',', 'i', 'have', "n't", 'seen', 'myself', 'in', 'so', 'good', 'of', 'a', 'range', 'since', 'i', 'was', 'hospitalized', 'in', 'february', ':loudly_crying_face:', ':sparkling_heart:', 'we', "'re", 'finally', 'back', 'in', 'business', 'boys', 'and', 'girls', '!']
#
# @USER I am a disabled person who has n't been able to leave the house , I am an insulin diabetic , with a severe back injury we do n't have any food banks , I 'm down to top ramen and running so low on everything else , fruits and veggies , juice boxes , any help with be a Godsend , God Bless
# ['@USER', 'I', 'am', 'a', 'disabled', 'person', 'who', 'has', "n't", 'been', 'able', 'to', 'leave', 'the', 'house', ',', 'I', 'am', 'an', 'insulin', 'diabetic', ',', 'with', 'a', 'severe', 'back', 'injury', 'we', 'do', "n't", 'have', 'any', 'food', 'banks', ',', 'I', "'m", 'down', 'to', 'top', 'ramen', 'and', 'running', 'so', 'low', 'on', 'everything', 'else', ',', 'fruits', 'and', 'veggies', ',', 'juice', 'boxes', ',', 'any', 'help', 'with', 'be', 'a', 'Godsend', ',', 'God', 'Bless']
#
# @USER In the diabetes space , both have been used interchangeably for as long as I can remember .
# ['@USER', 'In', 'the', 'diabetes', 'space', ',', 'both', 'have', 'been', 'used', 'interchangeably', 'for', 'as', 'long', 'as', 'I', 'can', 'remember', '.']
#
# @USER I successfully corrected an insulin pump issue and as a result feel physically much better than I have in a while .
# ['@USER', 'I', 'successfully', 'corrected', 'an', 'insulin', 'pump', 'issue', 'and', 'as', 'a', 'result', 'feel', 'physically', 'much', 'better', 'than', 'I', 'have', 'in', 'a', 'while', '.']
#
# @USER My employer provided health care { spouse } will force me to switch insulin from the one that works best & gives me the best quality of life to another .
# ['@USER', 'My', 'employer', 'provided', 'health', 'care', '{', 'spouse', '}', 'will', 'force', 'me', 'to', 'switch', 'insulin', 'from', 'the', 'one', 'that', 'works', 'best', '&', 'gives', 'me', 'the', 'best', 'quality', 'of', 'life', 'to', 'another', '.']
#
# I 'll still have insulin but my A1c will go up & I will feel worse .
# ['I', "'ll", 'still', 'have', 'insulin', 'but', 'my', 'A1c', 'will', 'go', 'up', '&', 'I', 'will', 'feel', 'worse', '.']
#
# @USER Next stop get a tetanus jab , it wo n't do your 1/3 of a heart and diabetes any good to be that close to the great unwashed let alone the Lyme disease !
# ['@USER', 'Next', 'stop', 'get', 'a', 'tetanus', 'jab', ',', 'it', 'wo', "n't", 'do', 'your', '1/3', 'of', 'a', 'heart', 'and', 'diabetes', 'any', 'good', 'to', 'be', 'that', 'close', 'to', 'the', 'great', 'unwashed', 'let', 'alone', 'the', 'Lyme', 'disease', '!']

# %%
test_dataset = TweetDataSet(text, tokenizer)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
# Define Trainer and predict

# set inference arguments
training_args = TrainingArguments(
    output_dir='./results',          # output directory
#    per_device_train_batch_size=64,  # batch size per device during training
    per_device_eval_batch_size=batch_size,   # batch size for evaluation
    logging_dir='./logs',            # directory for storing logs
    seed=0,
#    local_rank = rank
)

# we only use Trainer for inference
trainer = Trainer(model=model, args=training_args)
print("build trainer on device:", training_args.device, "with n gpus:", training_args.n_gpu)

logits = trainer.predict(test_dataset)
# Out:
# build trainer on device: cpu with n gpus: 0
#     <div>
#
#       <progress value='28' max='28' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [28/28 03:28]
#     </div>

# %%
predictions = torch.argmax(torch.Tensor(logits.predictions),dim=1).flatten()
probas = torch.softmax(torch.Tensor(logits.predictions), dim = -1)[...,-1:].to('cpu').numpy().squeeze()

# %%
probas = pd.Series(probas)
predictions = pd.Series(predictions)

# %%
probas.head()
# Out:
# 0    0.414361
# 1    0.704896
# 2    0.718448
# 3    0.623301
# 4    0.588045
# dtype: float32

# %%
predictions.head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    1
# dtype: int64

# %%
causalDF = pd.DataFrame({"text":text, "causal_predictions": predictions, "proba":probas})
# causalDF = causalDF[causalDF["causal_predictions"] == 1]
print("causal sentences:", causalDF.shape[0])
causalDF.head()
# Out:
# causal sentences: 867
#                                                 text  causal_predictions  \
# 0  Why did the doctor say they has type 2 diabete...                   0
# 1  When my kid ' s struggling for her insulin for...                   1
# 2  @USER Thanks man , she ' s got this bad flu bu...                   1
# 3  If we can't laugh a little about the ups and d...                   1
# 4  That ' s the premise behind a new dark comedy ...                   1
#
#       proba
# 0  0.414361
# 1  0.704896
# 2  0.718448
# 3  0.623301
# 4  0.588045

# %%
causalDF.to_csv(save_path, sep=";")

# %% [markdown]
# ### Sort subset of tweets by their prediction probabilities and print some examples

# %%
#causalDF = causalDF[0:100].sort_values(by=["proba"], ascending=[False])
#causalDF.head()

# %%
#for i, row in causalDF.iterrows():
#    print(row["text"], row["proba"])
#    print()

# %%
sent = pd.read_csv("/home/adrian/Downloads/causal_sentences_predictions_part_0.csv")
for i, row in sent[0:20].iterrows():
    print()
    print(row["text"])
    print(row["causal_predictions"])
# Out:
# Hypo in the Boticelli rooms at the @USER and one of the staff members offered me a sweet cause he knew my pain #type1diabetes
# 1
#
# Life & diabetes in a jar altogether !
# 0
#
# It 's always worrying as a diabetic when your foot starts to hurt .
# 0
#
# Mmm I love bacon and hardly any carbs for breakfast :raising_hands: :light_skin_tone: :smiling_face_with_sunglasses: #breakfastoftheday #diabetes #diabetic ...
# 1
#
# * frantically applies for jobs so that i can afford to take care of my diabetic cat *
# 0
#
# I 'm type 1 diabetic not caused by eating poorly , I 'm 150 lbs wet .
# 0
#
# @USER " That does n't mean we should take care of the person who sits at home , eats poorly and gets diabetes .
# 1
#
# @USER Dear lord that rack is sepeeated by type 1 and type 2 diabetes .
# 1
#
# i have some diabetes amputations but i need help could u please :revolving_hearts:
# 0
#
# He goes into this story about how he beat diabetes and lost 36lbs from being " on the vinegar "
# 1
#
# @USER Having to cut back on carbs , my eye exam found evidence of diabetes damage and I 'm between insurance so no proper doctor yet :unamused_face:
# 1
#
# Now I need a whole bottle of wine , the gentleman just told me that his wife has a bad case of diabetes and has had a double leg amputation :loudly_crying_face: :loudly_crying_face:
# 1
#
# You have helped me through my type 1 diabetes by always making me smile and laugh
# 0
#
# Went to the eye doctor today and I still have 20/20 vision and no damage to my eyes from my type 1 diabetes !
# 1
#
# En Vogue thank you ever so much for singing the National Athem at my charity event to KO diabetes Love you ladies
# 1
#
# He said " oh , you can go at least an hour w / out insulin before getting sick .
# 1
#
# @USER the thing to remember is you breath in co2 + sugar + energy and breathe out o2 + glucose + nitrogen .
# 1
#
# @USER I have diabetes too and am really shocked by this .
# 0
#
# @USER Sugar licking lips might produce insulin inside you so I dont think that 's a good idea .
# 1
#
# There 's a cure for diabetes too .
# 0

# %%
causes = pd.read_csv("/home/adrian/Downloads/cause_effect_predictions_part_0.csv")
causes.head()
"""
for i, row in causes[0:20].iterrows():
    print()
    print(row["text"])
    print(row["causal_predictions"])"""
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-17-0fb127520f9c> in <module>
# ----> 1 causes = pd.read_csv("/home/adrian/Downloads/cause_effect_predictions_part_0.csv")
#       2 causes.head()
#       3 """
#       4 for i, row in causes[0:20].iterrows():
#       5     print()
#
# ~/miniconda3/envs/pytorch/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# --> 610     return _read(filepath_or_buffer, kwds)
#     611
#     612
#
# ~/miniconda3/envs/pytorch/lib/python3.8/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     466
#     467     with parser:
# --> 468         return parser.read(nrows)
#     469
#     470
#
# ~/miniconda3/envs/pytorch/lib/python3.8/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1055     def read(self, nrows=None):
#    1056         nrows = validate_integer("nrows", nrows)
# -> 1057         index, columns, col_dict = self._engine.read(nrows)
#    1058
#    1059         if index is None:
#
# ~/miniconda3/envs/pytorch/lib/python3.8/site-packages/pandas/io/parsers.py in read(self, nrows)
#    2059     def read(self, nrows=None):
#    2060         try:
# -> 2061             data = self._reader.read(nrows)
#    2062         except StopIteration:
#    2063             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 47 fields in line 4, saw 49

# %% [markdown]
# ### Check predictions of causal sentence classifier

# %%
dataPath = "data/Causality_tweets_data.xlsx"
data = pd.read_excel(dataPath, sheet_name="round4").sample(n=1000)
print(data["Causal association"].value_counts())
data.head()
# Out:
# 0.0    861
# 1.0    139
# Name: Causal association, dtype: int64
#       Unnamed: 0                                           sentence Intent  \
# 648        134.0  @USER @USER while this is very funny , insulin...    NaN
# 810       2628.0                diabetic retinopathy in both eyes .    NaN
# 1546      2785.0  sitting at a fundraiser listening to kids with...    NaN
# 399        925.0  Maybe everyshow can also have a character scen...   joke
# 1197      3521.0               I think I may have type 2 diabetes .    NaN
#
#           Cause                  Effect  Causal association  Unnamed: 6
# 648   diabetics  need private insurance                 1.0    0.868545
# 810         NaN                     NaN                 0.0    0.036845
# 1546        NaN                     NaN                 0.0    0.222685
# 399         NaN                     NaN                 0.0    0.805460
# 1197        NaN                     NaN                 0.0    0.094678

# %%
trainingData = data[data["sentence"].str.split(" ").str.len() > 5] # keep only sentence with more than 3 tokens
trainingData = trainingData[~trainingData["sentence"].str.endswith("?")]
print(trainingData.shape)
text = trainingData["sentence"].values.tolist()

test_dataset = TweetDataSet(text, tokenizer)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
# Out:
# (954, 7)

# %%
# set inference arguments
training_args = TrainingArguments(
    output_dir='./results',          # output directory
#    per_device_train_batch_size=64,  # batch size per device during training
    per_device_eval_batch_size=10,   # batch size for evaluation
    logging_dir='./logs',            # directory for storing logs
    seed=0,
#    local_rank = rank
)

# we only use Trainer for inference
trainer = Trainer(model=model, args=training_args)
print("build trainer on device:", training_args.device, "with n gpus:", training_args.n_gpu)

logits = trainer.predict(test_dataset)
# Out:
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).
# ***** Running Prediction *****
#   Num examples = 954
#   Batch size = 10
# build trainer on device: cpu with n gpus: 0
#     <div>
#
#       <progress value='96' max='96' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [96/96 04:54]
#     </div>

# %%
predictions = torch.argmax(torch.Tensor(logits.predictions),dim=1).flatten()
probas = torch.softmax(torch.Tensor(logits.predictions), dim = -1)[...,-1:].to('cpu').numpy().squeeze()

probas = pd.Series(probas)
predictions = pd.Series(predictions)
print(predictions.shape)
# Out:
# (954,)

# %%
print(len(text))
print(len(predictions))
print(len(probas))
print(len(trainingData["Causal association"]))
print(trainingData["Causal association"].shape)
# Out:
# 954
# 954
# 954
# 954
# (954,)

# %%
causalDF = pd.DataFrame({"text":text, "causal_predictions": predictions, "proba":probas, "real":trainingData["Causal association"].values.tolist()})
causalDF['causal_predictions'] = causalDF['causal_predictions'].astype(int)
causalDF['real'] = causalDF['real'].astype(int)
for i,row in causalDF.iterrows():
    print(row["text"])
    print("true:", row["real"], "pred:", row["proba"])
    print()
# Out:
# @USER @USER while this is very funny , insulin is actually not covered by our public health care and diabetics like myself still need private insurance
# true: 1 pred: 0.6497282981872559
#
# diabetic retinopathy in both eyes .
# true: 0 pred: 0.2772119641304016
#
# sitting at a fundraiser listening to kids with juvenile diabetes basically beg for funding .
# true: 0 pred: 0.43385839462280273
#
# Maybe everyshow can also have a character scene dedicated to glucose alerts so that #type1diabetes can ruin every last thing : rolling_on_the_floor_laughing :
# true: 0 pred: 0.6416450142860413
#
# I think I may have type 2 diabetes .
# true: 0 pred: 0.3295542895793915
#
# That ' s why it ' s complications of covid 19 as it killed them because of the virus , it ' s like saying someone with cancer getting shot and dying should n't be labeled as being shot as a
# true: 0 pred: 0.729767382144928
#
# And napapabayaan ko sya ever since .
# true: 0 pred: 0.33289599418640137
#
# @USER Low carb is perfect for my diabetes but not for loosing too much weight : frowning_face : I was n't over weight to begin with ( mody diabetic )
# true: 1 pred: 0.6796983480453491
#
# :d og_face : : two_hearts : Kenley has Type 1 diabetes , and she says pup play beats pricking her finger ( doctors agree , too ) !
# true: 1 pred: 0.6487112045288086
#
# My elderly , diabetic mother in law is upstairs with a terrible cough , waiting for the results from her #COVID test .
# true: 0 pred: 0.618962287902832
#
# so lets all drink coca cola & pretend thats better ) LOL !
# true: 0 pred: 0.3070634603500366
#
# Idk why everyone made it out to be the most disgusting thing ever .
# true: 0 pred: 0.35506877303123474
#
# @USER : smiling_face_with_horns : : face_with_tears_of_joy : : sign_of_the_horns : Damn diabetic .
# true: 0 pred: 0.46340683102607727
#
# Also , sitting is the new smoking !
# true: 0 pred: 0.2737191617488861
#
# @USER @USER : red_heart : this !
# true: 0 pred: 0.1797269731760025
#
# Now all cards are off the table .
# true: 0 pred: 0.21005411446094513
#
# At first I thought he was talking about my tattoo and then realized I was wearing my CGM ( continuous glucose monitor ) on my arm and told him
# true: 0 pred: 0.6512057781219482
#
# Lower your carbs with diabetes ...
# true: 0 pred: 0.20454610884189606
#
# I desperately need hernia repair and weight loss surgeries .
# true: 0 pred: 0.32083380222320557
#
# A very low carb diet gives the better A1c ' s for T1D ' s and T2D ' s .
# true: 1 pred: 0.6284722089767456
#
# Things said in our house : " That ' s just diabetes on a plate .
# true: 0 pred: 0.4737517833709717
#
# Retail price = $ 1,949 .
# true: 0 pred: 0.16241461038589478
#
# if you want to mock trump how about point out that we have people dying from rationing their insulin while pharmaceutical company and insurance execs make astronomical profits .
# true: 1 pred: 0.6921637654304504
#
# I ate half a pizza yesterday and still lost weight .
# true: 0 pred: 0.29098251461982727
#
# He lost his best friend & I would like Cooper to have hope .
# true: 0 pred: 0.40964168310165405
#
# " I never used to eat breakfast or lunch and now I do " HTTPURL
# true: 0 pred: 0.401782751083374
#
# I ' m jealous , I can't have candy cos I ' m diabetic !
# true: 1 pred: 0.5199621319770813
#
# @USER @USER @USER My nephew is diabetic and I ' m really worried for him
# true: 0 pred: 0.44111111760139465
#
# The suspense is killing me .
# true: 0 pred: 0.14111781120300293
#
# @USER any news on flights as due to fly st 19:10 from MCO with my type 1 diabetic daughter and just need to know something as I am a nervous wreck what are the chances of getting home
# true: 0 pred: 0.7019965052604675
#
# @USER If you have a working pancreas , tell it thanks .
# true: 0 pred: 0.37773603200912476
#
# Busy week so just WENT TO PiCK IT UP TODAY but hold on mam , There has been a COST INCREASE NOW 467 .
# true: 0 pred: 0.6163957715034485
#
# So this probably is n't that important to anyone , but I saw @USER in a diabetes magazine and I just realized him and I have the same insulin pump , so it ' s pretty cool tbh .
# true: 0 pred: 0.740225076675415
#
# My mom was DX as LADA in Dec .
# true: 0 pred: 0.26606765389442444
#
# I can make your bones stronger !
# true: 0 pred: 0.1673019379377365
#
# #cgm #diabeticlife #type2diabetes #typetwodiabetic #mylifewithdiabetes HTTPURL
# true: 1 pred: 0.5896400809288025
#
# Hitoribocchi No Marumaruseikatsu almost gave me diabetes .
# true: 0 pred: 0.4557391405105591
#
# Type 1 diabetic with us who had limited insulin and I ' ve been DM ing since this morning !
# true: 0 pred: 0.5644105076789856
#
# They bonded over diabetes : face_with_tears_of_joy :
# true: 0 pred: 0.24904009699821472
#
# When I tried to control my high a1c as a borderline diabetic & it did n't work with the typical wholegrain low fat diet , i did n't just accept that info ...
# true: 1 pred: 0.6788340210914612
#
# A bra who got transferred from St Boniface ate pure Glucose powder from the Chemistry lab , the whole class was whyling and we were so sure he was gonna die , he did n't , One week later all the Glucose containers went missing : face_with_tears_of_joy : : face_with_tears_of_joy : : face_with_tears_of_joy :
# true: 0 pred: 0.7104297280311584
#
# No need to attack Dorit for not knowing difference between type 1 and type 2 diabetes !
# true: 0 pred: 0.5701135396957397
#
# This win is all thanks for local advocates .
# true: 0 pred: 0.21513788402080536
#
# If you ' re ready to cure my diabetes .. of course yes .. I like @USER ' s chocolate ...
# true: 0 pred: 0.6332275867462158
#
# @USER For example : My first week giving 459 too much insulin .
# true: 0 pred: 0.36586993932724
#
# And if I have a #cgm , an #insulinpump and #technology in my life , everything is easier and better , I ' m happier and my family lives safer !
# true: 1 pred: 0.7198777794837952
#
# The chaotic industry behind the insulin I need to live HTTPURL
# true: 0 pred: 0.3575904071331024
#
# I am 59 ys / o I am a woman I have type 1 diabetes and hypothyroid and my medications even with medical insurance , are #Extreme .
# true: 1 pred: 0.6833955645561218
#
# Just a reminder : Walmart insulin is not the answer to the insulin pricing crisis .
# true: 0 pred: 0.4255865514278412
#
# wise words from trump today “ i dont has insulin , should i be ”
# true: 0 pred: 0.4760400354862213
#
# Almost shit my underwear this morning passing my morning meds .
# true: 0 pred: 0.25786420702934265
#
# Mixing that and myo inositol helps with my pcos symptons / insulin resistance
# true: 0 pred: 0.501828134059906
#
# I really hope one day someone finds a cure for diabetes .
# true: 0 pred: 0.3225039541721344
#
# My Mermaidy Tail ( tale ) .
# true: 0 pred: 0.19911803305149078
#
# @USER Dear President Biden , since I lost 2 of my sons from diabetes I have not prayed .
# true: 1 pred: 0.5231852531433105
#
# Hopefully manalo coz I ' m badly need it for my diabetes .
# true: 0 pred: 0.42380785942077637
#
# It ' s soul destroying , let alone having the ability to rampage & destroy the human body :p ensive_face : This may be a bit of a medical & boring read , but bear with ...
# true: 0 pred: 0.7018094062805176
#
# I spent most my time in the @USER room in the hospital using their consoles at the time .
# true: 0 pred: 0.5858791470527649
#
# The last thing you want is a disgruntled pancreas .
# true: 0 pred: 0.3736821413040161
#
# ) and disgraced President * And many of his enablers will still be relatively young with decades of shame and embarrassment that they will get to account for without him .
# true: 0 pred: 0.6447543501853943
#
# @USER Because #Harvey has destroyed the insulin supply for many people .
# true: 0 pred: 0.2929897904396057
#
# they have assured us that with the correct care he should be safe and hopefully wake up over the next few days
# true: 0 pred: 0.6948995590209961
#
# @USER @USER @USER @USER It ' s accepted that I have to be on some medication for my diabetes for the rest of my life .
# true: 1 pred: 0.6519922614097595
#
# I really needed to study today , but here I am forgetting my insulin and ruin the whole day :) ) ) Being chronically ill and being stressed does not really work that well together
# true: 1 pred: 0.6801108121871948
#
# 2 ) Our family foots the bill for something that SHOULD be covered but is n't .
# true: 0 pred: 0.5258310437202454
#
# @USER Glucose if I recall my chemistry , well I raise you C8H10N4O2 !
# true: 0 pred: 0.6175892949104309
#
# @USER @USER I am a diabetic home healthcare liaison .
# true: 0 pred: 0.24732273817062378
#
# Only a person living with T1D would understand .
# true: 0 pred: 0.29621824622154236
#
# The day when they first tried it on a ward of dying patients and they all miraculously started improving would be an amazing scene to recreate .
# true: 0 pred: 0.6279487609863281
#
# @USER @USER * reminds me that I need to re learn dosing on the old school insulins just in case , esp given current insulin climate *
# true: 0 pred: 0.6761961579322815
#
# My #CGM sensor in my arm is itching like crazy ( it ' s almost time to change it so I bet the skin is irritated ) and I just want to rip it outttt
# true: 1 pred: 0.7027215361595154
#
# If they did n't get covid , they would still be alive .
# true: 0 pred: 0.30396637320518494
#
# Either ways this sort of attack serves no use in any case .
# true: 0 pred: 0.33326441049575806
#
# I flew the W in my own way .
# true: 0 pred: 0.26056429743766785
#
# A good friend ' s dad is in the hospital on a respirator .
# true: 0 pred: 0.5094751119613647
#
# Define ‘ 5 mins away from diabetes ' ...
# true: 0 pred: 0.2960226237773895
#
# It ' s not something you take unless things are serious af .
# true: 0 pred: 0.33202266693115234
#
# I ' m happy that woman w diabetic son evacuated w her 2 cars but she seems bragadocious amongst the struggles of others @USER #harvey
# true: 0 pred: 0.7272043824195862
#
# My answer for #egg #sugar #shot #Vegan #Diabetic #TTotal well 1 out of three ain't bad !
# true: 0 pred: 0.6149338483810425
#
# He is under going Dialysis twice a week .
# true: 0 pred: 0.282624214887619
#
# @USER @USER @USER @USER hey at least he said co pay and has had other tweets about insulin that make sense
# true: 0 pred: 0.5657475590705872
#
# Ughhh , I literally ate healthy that whole entire week too !
# true: 0 pred: 0.38701480627059937
#
# Gotta do something about my weight and the shit I eat , gonna end up with diabetes
# true: 1 pred: 0.5419042706489563
#
# I live in Seattle and have diabetes and severe asthma .
# true: 0 pred: 0.38136425614356995
#
# @USER Very disheartening that this has happened , my elderly grandma who suffers from both diabetes and RA was scheduled to be vaccinated tomorrow afternoon and my father ( a diabetic ) was also scheduled .
# true: 1 pred: 0.7038134336471558
#
# I do n't even wanna think kungenzeka ntoni if my mom caught COVID 19 .
# true: 0 pred: 0.5498460531234741
#
# Now I ' ll never eat salads again .
# true: 0 pred: 0.22117818892002106
#
# @USER @USER My son was like that when he was young too .
# true: 0 pred: 0.3572646975517273
#
# @USER I am a medical professional on the front lines .
# true: 0 pred: 0.25749972462654114
#
# @USER @USER Asparagus pee is nasty !
# true: 0 pred: 0.20785893499851227
#
# @USER @USER it literally breaks down into glucose in your mouth
# true: 0 pred: 0.34075140953063965
#
# @USER Mind your cavities , Justin .
# true: 0 pred: 0.18286292254924774
#
# @USER With this insulin pump I am not afraid of anything !
# true: 0 pred: 0.2950828969478607
#
# I ' m more concerned about my weight but food is life so fuck it .
# true: 0 pred: 0.44849392771720886
#
# @USER so if your aunt died in Somalia because she did not have insulin .
# true: 1 pred: 0.41950950026512146
#
# He was given Hydroxycholroquine and zinc .
# true: 0 pred: 0.36733293533325195
#
# @USER @USER I ' ve got to be honest A , this question was all for you haha #gbdoc
# true: 0 pred: 0.5630010962486267
#
# i see diabetes and a couple of visits to the dentist , wby HTTPURL
# true: 0 pred: 0.4487245976924896
#
# @USER No thanks : face_with_rolling_eyes : : broken_heart : I do n't want to get diabetes : hand_with_fingers_splayed : : egg : : mouth : : egg :
# true: 0 pred: 0.6656944751739502
#
# He did n't say they gave him medication .
# true: 0 pred: 0.2571813464164734
#
# Man Diabetes is so annoying the mf mosquitoes of diseases smh :p erson_facepalming : : medium dark_skin_tone : ‍ : male_sign :
# true: 0 pred: 0.6232221126556396
#
# @USER He buys the irresistible ice cream .
# true: 0 pred: 0.18211831152439117
#
# Now I want a baby .
# true: 0 pred: 0.15965108573436737
#
# We had to keep an eye on her damn blood sugar because she ' s a diabetic and insists on getting shit faced still : woozy_face :
# true: 1 pred: 0.6940488815307617
#
# I was able to reverse my “ pre ” diabetic diagnosis and lower my blood pressure by losing weight and changing my eating habits !
# true: 1 pred: 0.6583485007286072
#
# Im diabetic but thats what insulin ' s for !
# true: 0 pred: 0.35345354676246643
#
# Here they are now age 15 & 10 and healthy thankfully !
# true: 0 pred: 0.3269626200199127
#
# My daughter is on 3 different insulin ' s to control her diabetes .
# true: 0 pred: 0.40618687868118286
#
# @USER Really sorry to hear this .
# true: 0 pred: 0.16125372052192688
#
# @USER Oh , it ' s fine .
# true: 0 pred: 0.21161146461963654
#
# I used #blueblood and #bloodsugar From @USER cosmetics .
# true: 0 pred: 0.34596017003059387
#
# @USER @USER David , wake up !
# true: 0 pred: 0.17520876228809357
#
# I only have 2 daily injections , before breakfast and before my evening meal .
# true: 0 pred: 0.42376381158828735
#
# @USER i drink a lot of water and jump around or walk or just any type of activity if i dont have insulin around me
# true: 1 pred: 0.5761153101921082
#
# Just told some in a groot voice that .. I'M DIABETIC .. Weird that they ran off and did n't want to ask anymore ridiculous questions : winking_face_with_tongue :
# true: 0 pred: 0.7456207275390625
#
# I never had a problem with pre existing conditions prior to ACA .
# true: 0 pred: 0.34234750270843506
#
# Really looking forward to my @USER pack , really hard to find things to drink as a diabetic so this ' ll be a neat try .
# true: 1 pred: 0.6565637588500977
#
# I feel a diabetic episode coming on .
# true: 0 pred: 0.27257198095321655
#
# But go ahead and get your feelngs hurt because of a tweet .
# true: 0 pred: 0.3850535452365875
#
# Do n't panic until that is ruled out .
# true: 0 pred: 0.24918581545352936
#
# Once I asked my uncle : apko b diabetes hai He replied , yes my child do n't u know " trend me hai " : face_with_tongue :
# true: 0 pred: 0.6385550498962402
#
# @USER @USER @USER you get diabetes from consuming too much sugar , do n't think vegans do that .
# true: 1 pred: 0.5611923933029175
#
# Walmart sells insulin 1000 units for 25 bucks .
# true: 0 pred: 0.24735255539417267
#
# hell im still big lol : face_with_tears_of_joy :
# true: 0 pred: 0.26551833748817444
#
# : syringe : : lipstick : : red_heart : : smiling_face_with_heart eyes : @USER HTTPURL
# true: 0 pred: 0.49135562777519226
#
# HTTPURL my gf ' s brother is currently facing eviction .
# true: 0 pred: 0.3011455535888672
#
# I ' ll let you know if I decide to try it .
# true: 0 pred: 0.3411865830421448
#
# Thank you , Tea Fairy , for this 1 gallon of classic milk tea and for the free korean skin care product ~ : smiling_face_with_hearts : HTTPURL
# true: 0 pred: 0.6496607065200806
#
# My wife mocks me for being as precautious as I am , and it was a 3 day fight to convince my HR that I should n't come to the office *
# true: 0 pred: 0.6709460616111755
#
# No medical insurance right now due to the Divorce and my Wife being a cunt .
# true: 0 pred: 0.45788925886154175
#
# Waited 3 days for test results .
# true: 0 pred: 0.14284050464630127
#
# You ' re buying makeup people not insulin , you ' ll be fine .
# true: 0 pred: 0.37907469272613525
#
# @USER @USER You ' re so right .
# true: 0 pred: 0.19329996407032013
#
# I pray my family gets better 3 deaths in 2 weeks and just found out my dad has diabetes : loudly_crying_face : : folded_hands : : medium dark_skin_tone : just praying everyday until things get better
# true: 0 pred: 0.6981817483901978
#
# I was fascinated by the large number of designs .
# true: 0 pred: 0.2716083228588104
#
# @USER I and my partner are type 2 diabetic and I ' m thankful for Smuckers sugar free jams and jelly and especially orange marmalade .
# true: 0 pred: 0.6755335330963135
#
# @USER @USER my ' helpful ' friends bought me a diabetic Easter egg :( #gbdoc
# true: 0 pred: 0.4927421510219574
#
# I have to take my braces out and brush my teeth after every time I eat and jamie has to do his insulin every time he eats , we ' re a right pair : rolling_on_the_floor_laughing :
# true: 1 pred: 0.6899610161781311
#
# A bottle has around 3 time the amount of insulin than a pen .
# true: 0 pred: 0.34442877769470215
#
# @USER @USER I keep telling myself she ' s not so tired anymore .
# true: 0 pred: 0.3797149658203125
#
# I went to get my insulin .
# true: 0 pred: 0.21849091351032257
#
# They would block you for making references to your diabetes :p erson_shrugging : ‍ : male_sign :
# true: 0 pred: 0.5853601098060608
#
# The cost is so high .
# true: 0 pred: 0.14534814655780792
#
# @USER @USER @USER My partner has diabetes , high blood pressure & asthma .
# true: 0 pred: 0.34163665771484375
#
# @USER @USER When I was diagnosed at 11 , my t1d auntie gave me a bag full of very tasty sugar free snacks and it was very reassuring to me , because I felt like I could n't eat anything good ever again and that bag made me realise that I still could :)
# true: 1 pred: 0.7220380902290344
#
# He was found clinically dead three times that I know of .
# true: 0 pred: 0.35178181529045105
#
# We dont have money and now we are bak to the hous .
# true: 0 pred: 0.40462926030158997
#
# I want to keep my child from Diabetes , HPB , weak heart , leukemia , MS , or any other impairment .
# true: 0 pred: 0.6502169966697693
#
# Vet heard he is eating @USER Zero Mature cat food and taking no meds , and was VERY impressed !
# true: 0 pred: 0.4779147803783417
#
# Diabetes , sleep Apnea , Hypertension , and worse
# true: 0 pred: 0.2538068890571594
#
# T cells are the mystery immunity a lot of world has even without the vaccine .
# true: 0 pred: 0.3981524407863617
#
# Might be first article I ' ve read where they deny that being lazy causes Type 2
# true: 1 pred: 0.5222206115722656
#
# Now i ' m kicking myself in the ass .
# true: 0 pred: 0.3488203287124634
#
# @USER Having a healthy amount of glucose in your blood .
# true: 0 pred: 0.3526032567024231
#
# I ' m convinced it ' s from a vaccine .
# true: 0 pred: 0.30352672934532166
#
# @USER This is why I ' m afraid to tell people I have diabetes because they assume it ' s “ my fault ”
# true: 1 pred: 0.657660186290741
#
# : grinning_face_with_sweat : : face_with_tears_of_joy : : smiling_face_with_smiling_eyes : .
# true: 0 pred: 0.4084004759788513
#
# I am that diabetic who HATES needles and just had my blood taken : face_vomiting : : face_vomiting : : face_vomiting :
# true: 1 pred: 0.6628091931343079
#
# Probably out biting the heads off chocolate rabbits !
# true: 0 pred: 0.29233062267303467
#
# @USER Please explain how Biden sets the price of insulin .
# true: 0 pred: 0.2413923293352127
#
# My handsome husband Brian was dx with #T1D nearly 32 yrs ago .
# true: 0 pred: 0.3959088623523712
#
# Harder for me to recognize lows in the cold too #dsma
# true: 0 pred: 0.3766705393791199
#
# if u ever wonder why diabetes is such a prominent thing in malaysia just look at what everyone is selling rn
# true: 0 pred: 0.6514983177185059
#
# That ' s all the diabetes ” : face_with_tears_of_joy : : face_with_tears_of_joy :
# true: 0 pred: 0.4902847409248352
#
# Also , if you love cats and have n't seen this video , it will make your heart grow 3 sizes :) HTTPURL HTTPURL
# true: 0 pred: 0.5999062657356262
#
# My hubs was Type 1 diabetic for 53 years .
# true: 0 pred: 0.2949126660823822
#
# @USER @USER I had to stop this video midway coz it was giving me diabetes ..
# true: 0 pred: 0.4188179671764374
#
# @USER I could use it to buy the insulin I need , I ' m $ 180 from my goal of $ 250 , I ' ve had $ 45 donated and I won a $ 25 giveaway .
# true: 0 pred: 0.696725606918335
#
# ” Like yup and you gave your child diabetes without consent :p erson_shrugging : : light_skin_tone : ‍ : female_sign :
# true: 0 pred: 0.6066134572029114
#
# Or am I confusing bisexuality with diabetes again
# true: 0 pred: 0.3109973669052124
#
# Please do n't be a douche and leave them for someone in need .
# true: 0 pred: 0.4602058529853821
#
# Yea , diabetes and obesity is what the fuck is going on
# true: 0 pred: 0.3616901934146881
#
# It is because of an operation .
# true: 0 pred: 0.12506000697612762
#
# The Mom ' s nickname " Dear " is weird #BasketballWives
# true: 0 pred: 0.455024778842926
#
# It does n't have gold flecks in it .
# true: 0 pred: 0.27479246258735657
#
# Also I have work hard for the body I now have and I ' m not risking it for something as foolish as ice cream for breakfast .. unless it ' s cheat day !
# true: 0 pred: 0.6969041228294373
#
# Yep , breaking the pen boxes sucks because each pen is not individually wrapped
# true: 0 pred: 0.4371924102306366
#
# She ' s looking to cut 1 cell phone , the tv services and the home phone .
# true: 0 pred: 0.48263034224510193
#
# I have 10ferals , they ' re healthy
# true: 0 pred: 0.3635389506816864
#
# Do n't shit run in our family but alcoholism , big bodies and diabetes :p erson_facepalming : : medium_skin_tone : ‍ : female_sign :
# true: 0 pred: 0.6600019335746765
#
# @USER I love big babies .
# true: 0 pred: 0.12254976481199265
#
# She was abandoned and we found her skeletal and drinking mud .
# true: 0 pred: 0.33760687708854675
#
# He may ‘ ve had a heart glitch or TIA .
# true: 0 pred: 0.31338557600975037
#
# @USER Sorry to here that elka my dad also has fatty liver disease and type 2 diabetes i have to constantly get on him about listening to his doc and checking his blood sugar numbers
# true: 1 pred: 0.736088752746582
#
# Pretty good for virus because it kills the host in large quantities .
# true: 0 pred: 0.3655344843864441
#
# a white kid died today from diabetes ...
# true: 1 pred: 0.30137529969215393
#
# Was hoping maybe something can be done .
# true: 0 pred: 0.2329890877008438
#
# @USER She ' s diabetic so she gets super itchy spots on her back where we inject her insulin so she ' d appreciate it if you itched those too
# true: 1 pred: 0.7059090733528137
#
# This year paa if Sarknatives no get Diabetes we no get again .
# true: 0 pred: 0.45284613966941833
#
# @USER I was vegetarian eating eggs and dairy until type 1 diabetes in 1995 ...
# true: 0 pred: 0.44806694984436035
#
# I ' ve been sick multiple times because of pricing .
# true: 1 pred: 0.25941336154937744
#
# Please help me with rent and insulin !
# true: 0 pred: 0.23427270352840424
#
# tell that to diabetics dying from rationing insulin , you pig fucker .
# true: 1 pred: 0.4208129942417145
#
# " I am here , do n't be afraid " These words have so much power that a weak person has a kind of glucose given in the body to pick up any challenge .
# true: 0 pred: 0.7318726181983948
#
# Right , think I ' m going to try and get some sleep .
# true: 0 pred: 0.4934323728084564
#
# If they did n't have that , I ' d be in a hospital
# true: 0 pred: 0.5142155289649963
#
# my diabetic body will not be able to take another flu virus .
# true: 0 pred: 0.3798528015613556
#
# @USER I often get from drs and nurses when admitted to hospital : " wow you ' ve been Diabetic for a long time , tbh you know more about it than I do " like wow cool thanks for that , you ' re the one in controll right now : neutral_face :
# true: 0 pred: 0.7318819165229797
#
# @USER I ' d rather die of a sodium related heart attack than a diabetes related seizure .
# true: 1 pred: 0.511307418346405
#
# My GrandFATHER , A diabetic , remarried in his 70s .
# true: 0 pred: 0.38874080777168274
#
# @USER @USER Looks like the line for free pancakes at IHOP or the line for free diabetes tests .
# true: 0 pred: 0.5305284857749939
#
# @USER Because I just can't leave anything incomplete , re finger stick : " One important goal of diabetes treatment is to keep the blood glucose levels near the normal range of 70 to 120 mg / dl before meals and under 140 mg / dl at two hours after eating .
# true: 1 pred: 0.7266028523445129
#
# @USER I honestly keep forgetting that they make them for more than just insulin already .
# true: 0 pred: 0.4243248403072357
#
# @USER @USER Hormones mainly insulin being spiked causes weight gain ...
# true: 1 pred: 0.32391566038131714
#
# But I still freak out : face_with_medical_mask : : folded_hands : : medium light_skin_tone :
# true: 0 pred: 0.5508481860160828
#
# @USER yeah i mean more diet as in what you eat everyday more than ' going on a diet ' if that makes sense .
# true: 0 pred: 0.7040356993675232
#
# The ignorance of people when it comes to diabetes annoys me .
# true: 0 pred: 0.30199792981147766
#
# It ' s never been easy_the ride is still rough .
# true: 0 pred: 0.34107983112335205
#
# know youve come back to a small town when i ' m on my way to my pdsn ' s house to pick up insulin : see no evil_monkey :
# true: 0 pred: 0.7127475738525391
#
# Do n't let this condition douse your child ' s dreams and aspirations .
# true: 0 pred: 0.42578375339508057
#
# I have been saying this since day 1 .
# true: 0 pred: 0.22773326933383942
#
# This is the diabetic diet there ' s apple juice , orange juice , and diced fruit ( which I did n't order ) total 33g of sugar Weetbix which I do n't eat Tea which I do n't drink #hospitalfood @USER @USER HTTPURL
# true: 0 pred: 0.6897361278533936
#
# Then take bloods and the answer will be a few hours
# true: 0 pred: 0.3558183014392853
#
# Put off my 3 hour glucose test but now I ' m here .
# true: 0 pred: 0.4566238224506378
#
# @USER I spent seven years of my life dedicated to diabetes .
# true: 0 pred: 0.31487372517585754
#
# thinking how fucked up it is that such a thing is necessary in the so called greatest nation on earth .
# true: 0 pred: 0.6186515092849731
#
# @USER My insulin ratio went from 1 unit per 3 carbs to 1 unit per 2 carbs for like a month , plus I moved my basal from morning to night because my BG was going up 100 + points overnight .
# true: 1 pred: 0.711085319519043
#
# i do n't need some diabetic who does n't know she ' s acting erratic who does n't know time dillation or that blue light effects the brain just like sugar and releases dopamine you ' re so hopped up on t .
# true: 0 pred: 0.7346022129058838
#
# Are u crasi I wanna move the aids diabetes siphilis type beat pollution going in my lungs is the main reason and congestion charges mf why are you charging me for driving MY OWN CAR
# true: 0 pred: 0.7262499332427979
#
# I ' ve never even thought of going off humalog partially because insurance but also it ' s never been brought up by my endo .
# true: 1 pred: 0.5947502255439758
#
# It was n't at the hospital ( only people with issues go there here ) , it was in a community centre , and I was invited by letter .
# true: 0 pred: 0.6220570802688599
#
# I ' m getting diabetes by hearing the song .
# true: 0 pred: 0.3514828681945801
#
# @USER Well , can't say nothing about diabetes , but my opinion is Alzheimer ' s is environment ...
# true: 0 pred: 0.6096786856651306
#
# Read about a Type 2 diabetic who caught #COVIDー19 .
# true: 0 pred: 0.28661274909973145
#
# @USER : face_with_tears_of_joy : maybe my Twitter takes should be tied to a glucose level device .. 125ml and below I can't tweet .
# true: 0 pred: 0.6443350315093994
#
# Not to mention I spent my lunch hour calling around for insulin .
# true: 0 pred: 0.3193496763706207
#
# Explanation thread : my brother is a type 1 diabetic .
# true: 0 pred: 0.3875170648097992
#
# My insulin pen has increased $ 24 to % 100 .
# true: 0 pred: 0.28886061906814575
#
# Blood Pressure and Diabetes no longer hindrance for Blood Donors Since my late teens I have been a regular blood donor and over the years have donated blood to known people , and to strangers , dozens of times .
# true: 0 pred: 0.7140058279037476
#
# @USER watching the episode seeing PK ' s glucose level is freaking me out .
# true: 0 pred: 0.4910375773906708
#
# Bread and pasta rice etc make me ill .
# true: 0 pred: 0.21986931562423706
#
# : unamused_face : < — my shocked face .
# true: 0 pred: 0.3459221124649048
#
# @USER That we will have to pay for with medicine cost go up 2000 % that ' s exact amount on insulin that was during Obama / Biden reign of terror .
# true: 0 pred: 0.6733958125114441
#
# @USER Add , Corbyn , Abbot , Mike Dean and Diabetes and you ain't far wrong .
# true: 0 pred: 0.4642181098461151
#
# Playing around with this Glucose screening , I ' m starved : weary_face :
# true: 0 pred: 0.49529969692230225
#
# @USER @USER My hairdresser ' s husband is an extremely brittle diabetic .
# true: 0 pred: 0.3691307306289673
#
# Some much needed time with my Trap Bro @USER Bout to turn it up a notch !
# true: 0 pred: 0.4596307873725891
#
# So much confusion amongst public about difference between T1 and T2 diabetes .
# true: 0 pred: 0.3687650263309479
#
# @USER tried your Pamana Peach tonight for the first time .
# true: 0 pred: 0.22016631066799164
#
# The glucose drink was not even as bad as people make it out to be : unamused_face : : face_with_tears_of_joy :
# true: 1 pred: 0.6268740296363831
#
# Wearing my insulin pump visibly WASNT working , so this is my next thought lol
# true: 0 pred: 0.5028817057609558
#
# @USER Stop assuming one thing works for everyone .
# true: 0 pred: 0.23068687319755554
#
# ; These twelve hour days are going to be the death of me .
# true: 0 pred: 0.332307904958725
#
# Watch bro create some fye fye with it : high_voltage : : hot_beverage : : artist_palette : #issaMasterPeace #Pottery #iWillPostFinishedCreationsLater HTTPURL
# true: 0 pred: 0.6756296157836914
#
# People are literally dying because they can't diabetes medicine .
# true: 1 pred: 0.2876914441585541
#
# If they catch it , dad wo n't survive .
# true: 0 pred: 0.31034696102142334
#
# @USER i know thats how i thought too !
# true: 0 pred: 0.2749647796154022
#
# I definitely got my flu shot today .
# true: 0 pred: 0.274405300617218
#
# Her coworker really had the audacity to ask her to turn it off the sound because it is annoying .
# true: 0 pred: 0.5096104145050049
#
# Had my glucose test today so hopefully that comes back good tomorrow .
# true: 0 pred: 0.4461020231246948
#
# @USER @USER My dad was diabetic and we had to hide all of the snacks in the house .
# true: 1 pred: 0.5795304179191589
#
# @USER I was born not producing insulin .
# true: 0 pred: 0.15855954587459564
#
# The Easter Bunny stopped at the dispensary before our house and he had severe munchies .
# true: 0 pred: 0.5154281854629517
#
# someday you ' ll figure it out .
# true: 0 pred: 0.23735924065113068
#
# M & M ' s hmmm bit controversial !
# true: 0 pred: 0.2801779508590698
#
# There is no reason for 15ml of insulin to cost this much .
# true: 0 pred: 0.3995228707790375
#
# I have been waiting to wear this dress for a long time , Twitter .
# true: 0 pred: 0.41079989075660706
#
# My nails are nicer but the callous point remains .
# true: 0 pred: 0.2540828585624695
#
# He is T1D and will run out of insulin and instead of going to a clinic he will just go into DKA ...
# true: 1 pred: 0.6428446769714355
#
# I have n't slept a full night through since my child was diagnosed .
# true: 0 pred: 0.3558763861656189
#
# And while that was an obvious hyperbole , I will say my cost has gone down by half just this year
# true: 0 pred: 0.6169828176498413
#
# @USER That can't be true .
# true: 0 pred: 0.16255201399326324
#
# If you or someone you now would be interested , please retweet and tag !
# true: 0 pred: 0.426230251789093
#
# Sven here determined giving Nightingale constant attention and she can't cure that diabetes he poured .
# true: 0 pred: 0.5454960465431213
#
# 5 Insulin pens costs 1800 to 2000 per month .
# true: 0 pred: 0.2940419614315033
#
# @USER I live with a bro , he has serious covid symptoms , he is also diabetic , I went to mbagathi for test , I was refad to Kenyata .
# true: 0 pred: 0.7109927535057068
#
# So many highs and lows today , I ' m definitely on the diabetic rollercoaster : roller_coaster : Hoping for a 7 mile run tomorrow as well : crossed_fingers : : light_skin_tone :
# true: 1 pred: 0.7146748900413513
#
# @USER That is some of the best diabetes reporting I have ever seen .
# true: 0 pred: 0.403627872467041
#
# @USER Like with insulin , on which there is just plain profit , since inventors gave it free to use , so zero R & D expenses , yet now costs a lot to buy .
# true: 1 pred: 0.7046757936477661
#
# American gets diabetes and will likely blame China .
# true: 0 pred: 0.26718834042549133
#
# It is completely awful and so frightening .
# true: 0 pred: 0.19505974650382996
#
# She should be given her insulin , it ' s not healthy to go without insulin when you ' re type 1 .
# true: 0 pred: 0.6212623119354248
#
# @USER Amala is pretty much a lump of carbs , converts to glucose ...
# true: 0 pred: 0.43549078702926636
#
# She is 8 she went blind last summer bc of diabetes n she has Cushings disease but she is still very happy
# true: 1 pred: 0.6492828130722046
#
# Can touch my toes atm .
# true: 0 pred: 0.1439789980649948
#
# @USER @USER Diabetic , so the mince pies are a no no .
# true: 0 pred: 0.33930182456970215
#
# Anything to make it easier to get it right .
# true: 0 pred: 0.24516870081424713
#
# @USER Seems like he has take social distancing seriously because of his diabetes
# true: 1 pred: 0.2951701581478119
#
# Ad : just sold my diabetic test strips here in Phoenix , AZ HTTPURL
# true: 0 pred: 0.4478602409362793
#
# Dont get me wrong being ok with who you are is amazing but .
# true: 0 pred: 0.4066261053085327
#
# @USER I ' ve been without insurance for a few months and Walmart has an alternative version of the insulin I use and it costs $ 25 a bottle .
# true: 0 pred: 0.6341395974159241
#
# Because I have no shame .. and self control whatsoever .
# true: 0 pred: 0.2647700607776642
#
# @USER @USER Tbh I get where you ' re coming from 100 % I have type 1 diabetes so I spent a lot of time chilling by myself too .
# true: 1 pred: 0.6883859634399414
#
# @USER @USER $ AsWill 8 I could use some help !
# true: 0 pred: 0.3154850900173187
#
# @USER Yes , saw something on that as well .
# true: 0 pred: 0.27450087666511536
#
# #Throwback : skier : First ski holiday wearing my insulin pump .
# true: 0 pred: 0.3032778799533844
#
# Lrt I ' ve been eating to maintain my glucose levels but noticed earlier today that I still have more food supplies than I normally do for a Wednesday and realized I have n't been eating or drinking my usual amount nor has Matt .
# true: 1 pred: 0.7572019696235657
#
# Truly the enemy of the people .
# true: 0 pred: 0.18953490257263184
#
# Considering the price of insulin actually is ...
# true: 0 pred: 0.22626760601997375
#
# @USER First Halloween in a new neighborhood , thought we would have trick or treaters .
# true: 0 pred: 0.4677502512931824
#
# My diabetes team are all amazing @USER I am well listened to , treated with respect and regarded as someone that knows their own health very well .
# true: 0 pred: 0.667489767074585
#
# :d oughnut : :d oughnut : :d oughnut : I need glucose .
# true: 0 pred: 0.45966875553131104
#
# And I ' m climbing the walls .
# true: 0 pred: 0.2721956670284271
#
# Both have had cataract surgery and are able to see again !
# true: 0 pred: 0.34238162636756897
#
# Looks like I better get the insulin ready .
# true: 0 pred: 0.23321686685085297
#
# I want grocery workers vaccinated first since they come into contact w / everybody & it ' s expensive to avoid them .
# true: 0 pred: 0.6524360775947571
#
# @USER @USER ( 2 ) They both past away from cancer and diabetes a year apart from one another when I was 11 , and these stories have helped momentarily distract me of life ' s certain realities back then and even now .
# true: 1 pred: 0.6885418891906738
#
# Did n't even think about checking my patients for political correctness : face_with_rolling_eyes :
# true: 0 pred: 0.4768125116825104
#
# Dinevelop ko ang diabetes because of my lifestyle before .
# true: 1 pred: 0.34959807991981506
#
# so why do n't all you ' he died of covid ' arseholes stop tainting his passing with your nonsense !
# true: 0 pred: 0.6205466985702515
#
# exactly $ 100 to split between insulin and food for 7 T_T
# true: 0 pred: 0.2973273992538452
#
# @USER @USER Found out tonight that the insurance my school district switched to considers my insulin a " specialty drug " and now instead of my $ 105 copay per fill , I ' ll be paying almost $ 600 per fill .
# true: 0 pred: 0.723688006401062
#
# @USER All is well my regular Diabetes follow up
# true: 0 pred: 0.28826460242271423
#
# The fact that insulin had yet to be made free is a big ol fuck you courtesy of big pharma
# true: 0 pred: 0.5596073865890503
#
# My diabetes is almost a teenager .
# true: 0 pred: 0.2243070751428604
#
# @USER It is literally a tax on groceries .
# true: 0 pred: 0.24751833081245422
#
# All you ' ve been doing the past decade is stating the obvious .
# true: 0 pred: 0.4288483262062073
#
# dear immune system , my pancreas did nothing wrong .
# true: 0 pred: 0.24010193347930908
#
# : heart_suit : Diabetes should be talked about .
# true: 0 pred: 0.3054276406764984
#
# I ' m happy with my fuel and insulin plan that resulted in this blood glucose trend during my 10 mile run this morning .
# true: 0 pred: 0.6929289698600769
#
# Thank goodness for #insulin and a #CGM #bakinglove #NDAM #diabetes #NationalDiabetesAwarenessMonth #insulin4all HTTPURL
# true: 0 pred: 0.676414430141449
#
# I ' ve slept with onions in my socks for years now , and I do n't have diabetes , so HTTPURL
# true: 0 pred: 0.6856643557548523
#
# 20 years with T1D today , and who knew what this last year would bring : red_heart : #gbdoc #diaversary HTTPURL
# true: 0 pred: 0.6376722455024719
#
# that means you hate black people more than you love your feet .
# true: 0 pred: 0.32788166403770447
#
# If you have Type 2 Diabetes and voted for Trump ...
# true: 0 pred: 0.3663727641105652
#
# Litter box was in t / FL room w / other cats .
# true: 0 pred: 0.3536992371082306
#
# About to drop this off to my fam nem .
# true: 0 pred: 0.32438915967941284
#
# I repair senior citizens homes for free so they can keep living in them .
# true: 0 pred: 0.48643550276756287
#
# Use a diabetic lancet to draw your blood a knife .
# true: 0 pred: 0.38274386525154114
#
# If you ' re not friends of , family of or a diabetic yourself .
# true: 0 pred: 0.46823132038116455
#
# Time to gather & check or verify accuracu then input this new data almost a new job .
# true: 0 pred: 0.5142250657081604
#
# ” Insulin costs her $ 36 .
# true: 0 pred: 0.251360684633255
#
# @USER @USER Just a video of diabetes .
# true: 0 pred: 0.22504346072673798
#
# Ignoring young people dying for rationing insulin and fathers committing suicide to avoid burdening famiy with medical debt .
# true: 1 pred: 0.6233119964599609
#
# @USER Sometimes , but the diabetic nurse from Del Monte says no , so doing my best to be a sensible 50 something : thumbs_up :
# true: 0 pred: 0.6400357484817505
#
# @USER I am very lucky .
# true: 0 pred: 0.1217370480298996
#
# we were so HAPPY to talk to each other that all we did was giggle ...
# true: 0 pred: 0.462830513715744
#
# I ' m worried I have gestational diabetes too : upside down_face :
# true: 1 pred: 0.5080094933509827
#
# I splurge once in a while though .
# true: 0 pred: 0.33643683791160583
#
# @USER Probably a syringe Full of insulin .
# true: 0 pred: 0.2433464527130127
#
# Today I picked up the scripts for my 8 wk re up , & he ' s given me * everything * on my acute list .
# true: 0 pred: 0.5894457101821899
#
# sincerely , a tired diabetic .
# true: 0 pred: 0.17887280881404877
#
# Oh , but she guaranteed the ability to buy overpriced policies with huge deductibles .
# true: 0 pred: 0.49640652537345886
#
# My sister 73 year old diabetic had coronavirus last month and recovered never went to the hospital but treated by her doctor
# true: 0 pred: 0.6321998834609985
#
# @USER the false smell of alcohol on breath can be diabetes .
# true: 0 pred: 0.2842486798763275
#
# @USER Wow did not know they had tariffs on our diabetes meds .
# true: 0 pred: 0.3132169246673584
#
# He is better and continuing to be .
# true: 0 pred: 0.1944202333688736
#
# Rather die while I ' m living than live while I ' m dead .
# true: 0 pred: 0.5403679013252258
#
# @USER I have n't seen the full thing but it got discredited with me when they said sugar does n't have a direct effect on diabetes
# true: 1 pred: 0.6674715280532837
#
# :p erson_standing : ‍ : female_sign : i cant stand it here
# true: 0 pred: 0.36570221185684204
#
# @USER I made a seasoned and marinated chicken with steamed veggies .
# true: 0 pred: 0.373955100774765
#
# @USER honestly economically I ' ve started reading more ABoringDystopia the price of insulin is shit and ive tried telling my mom
# true: 0 pred: 0.6786456108093262
#
# I ' m talking 1/4 of the cup is caramel .
# true: 0 pred: 0.32230421900749207
#
# He was discharged 2 days later .
# true: 0 pred: 0.20761831104755402
#
# I have to inject 5 times a day so know what she was on about .
# true: 0 pred: 0.42192792892456055
#
# @USER can you get something done about the price of insulin PLEASE !
# true: 0 pred: 0.356242835521698
#
# There ' s gotta be some protests for that or somethi
# true: 0 pred: 0.39850232005119324
#
# @USER Sorry I read that as “ insulin pen needles ” .
# true: 0 pred: 0.3524627983570099
#
# @USER I rcv ' d inpatient b / c I became diabetic after I was in MSKCC & they removed my pancreas completely .
# true: 1 pred: 0.6841897368431091
#
# @USER @USER Retired farmer but been through diagnosis and then walking it off ...
# true: 0 pred: 0.3413082957267761
#
# @USER Juvenile diabetes I do not think is linked to breast fed or not .
# true: 0 pred: 0.44745662808418274
#
# First hyperglycemia sickness in years .. diabetic life is hard sometimes .
# true: 0 pred: 0.42750677466392517
#
# Just waiting for my depression type 1 diabetes and a care to give like .. I seriously want to hide in shame right now .
# true: 1 pred: 0.6710104942321777
#
# Otherwise this EO is worth LESS than the orange buffoons signature .
# true: 0 pred: 0.31824854016304016
#
# 5 million have cardiovascular disease 70 million are obese #COVIDー19
# true: 0 pred: 0.26723551750183105
#
# " I have NEVER had so much fun checking my blood sugar !
# true: 0 pred: 0.39980173110961914
#
# The price of insulin is a human rights issue at this point .
# true: 0 pred: 0.33916741609573364
#
# @USER Still trying to convince my parents , one of whom is diabetic , that going into an airport to go visit my brother in a couple weeks is not a realistic plan .
# true: 0 pred: 0.7185487151145935
#
# the mother of 3 with diabetes who cuts your hair , your son ' s kindergarten teacher with asthma , your mom ' s dentist who gives seniors discounts , the Vietnam War veteran who bags your groceries ...
# true: 0 pred: 0.712600827217102
#
# Remember Aunty Margo who was on 5 injections of insulin per day and got off it all in 7 weeks .
# true: 0 pred: 0.5537062883377075
#
# He had developed type 2 diabetes after grandma died I took him forks over knives and he ' s plant based but then he had to go to the nursing home and they feed him crap he ' s gained weight does n't look so good and diabetes is back : broken_heart : it
# true: 1 pred: 0.7261302471160889
#
# I just need help with food and the co pay on my medication for this week :d isappointed_face : HTTPURL
# true: 0 pred: 0.612841784954071
#
# Suppose I * should * check my #bgnow really .
# true: 0 pred: 0.2898978888988495
#
# Diabetes damn near had my life 6 months ago .
# true: 0 pred: 0.26564285159111023
#
# me van a dar diabetes pero da igual SON MUY BONITOS
# true: 0 pred: 0.5370086431503296
#
# As you know , my brother is mentally handicapped , and a diabetic .
# true: 0 pred: 0.4044189155101776
#
# @USER " If you take insulin it has become unaffordable for you .
# true: 0 pred: 0.32621172070503235
#
# @USER @USER @USER I hope progress will be made real fast .
# true: 0 pred: 0.2804412841796875
#
# We are the most obese country and most diabetic .
# true: 0 pred: 0.28962525725364685
#
# Donie " well I ' ve had a few weird dates , The last date i was on she pulled out a diabetes test .
# true: 0 pred: 0.6632674932479858
#
#  twas great : sign_of_the_horns : : light_skin_tone :
# true: 0 pred: 0.27965933084487915
#
# :p ensive_face : The Tylenol Sinus is helping a little .
# true: 0 pred: 0.45566603541374207
#
# It ' s not their fault .
# true: 0 pred: 0.2093413770198822
#
# @USER Getting Diabetes just looking at it : confused_face :
# true: 0 pred: 0.2996889352798462
#
# Behind on bills so hoping it hits before stuff gets shut off .
# true: 0 pred: 0.27569931745529175
#
# I have n't been close to a human other than my wife in over a week .
# true: 0 pred: 0.5188643336296082
#
# He has done good NOTHING for us .
# true: 0 pred: 0.24093621969223022
#
# I was shocked , I was terrified , I was extremely confused by what was ...
# true: 0 pred: 0.420232892036438
#
# He was one lucky kid when you and the Arizona Coyotes sent him a bobble head of you and Orion , even though we lived in Ohio .
# true: 0 pred: 0.648320198059082
#
# @USER @USER @USER Marcus , I have had 5 heart attacks , an open heart quadruple bypass , diabetic ulcers on my feet and I am still here !
# true: 0 pred: 0.5972695350646973
#
# I can feel the cavities & diabetes no thanks HTTPURL
# true: 0 pred: 0.3008342683315277
#
# Bruh I need to finish this glucose test .
# true: 0 pred: 0.2940520644187927
#
# @USER YEAH she has hip dysplasia and diabetes which caused her blindness TT but she responds so sweetly to ppl cooing at her n i just , wanted to hold her all day WEH
# true: 1 pred: 0.729649543762207
#
# I am that diabetic who HATES needles and just had my blood taken : face_vomiting : : face_vomiting : : face_vomiting :
# true: 1 pred: 0.6628091931343079
#
# Most will need to keep total carbs < 20 gram for life “ green leafy veg , eggs , cheese , meat for remainder of life ” .
# true: 0 pred: 0.691565990447998
#
# I am also fighting with Diabetes since last many years and practising good life with some boring things like going for a walk and eating fruits etc .
# true: 1 pred: 0.6636888980865479
#
# I am the luckiest woman alive
# true: 0 pred: 0.1398412436246872
#
# Unless Beth Parker did that but then after nurse walked away , she grabbed more insulin from the bottle .
# true: 0 pred: 0.5835384130477905
#
# @USER Open up the markets and deregulate , Beto .
# true: 0 pred: 0.31791988015174866
#
# @USER I can cure your Ulcer I can cure your Diabetes I can cure you quick ejaculation problem I can cure your Diabetes I can cure your heart problems I can cure your chronic Disease !
# true: 0 pred: 0.6852600574493408
#
# : smiling_face_with_hearts : I ' ve been diabetic for nearly 30 years since 14 x : camera : Amanda ( 2/2 )
# true: 0 pred: 0.5951552391052246
#
# Everyone has also forgotten is Easter is coming a traditional family occasion .
# true: 0 pred: 0.35292303562164307
#
# after we were finished she said she didnt understand how I couldnt take care of myself : upside down_face : : water_pistol :
# true: 0 pred: 0.584800660610199
#
# @USER My son was insulin resistant at 16 and is diabetes free at 31 .
# true: 0 pred: 0.4058998227119446
#
# @USER @USER Donald Trump did nothing for the cost of insulin .
# true: 0 pred: 0.2281007319688797
#
# @USER I am ok on diet because I am a diabetic .
# true: 1 pred: 0.31923314929008484
#
# So I had a gastric bypass .
# true: 0 pred: 0.2744225561618805
#
# EJECTING WARP CORE IN 5 4 3 too late * coma *
# true: 0 pred: 0.34372657537460327
#
# @USER Insulin , glucose , lipids and some hormones
# true: 0 pred: 0.38430124521255493
#
# very careful with my diet and I ride my bike every night for 30 minutes ...
# true: 0 pred: 0.4823029935359955
#
# The evidence is all there .
# true: 0 pred: 0.17070917785167694
#
# My mother : I ' m positive when you get older you ' re going to get diabetes from what you eat .
# true: 1 pred: 0.6742027401924133
#
# “ You ' re fat and pale .
# true: 0 pred: 0.259355366230011
#
# She relied on emergency services being called by people around her .
# true: 0 pred: 0.3062022626399994
#
# I am an agoraphobic ( actual diagnosis ) person but even so with it being Ramadan & my birthday coming up the isolation is getting too me .
# true: 0 pred: 0.6472673416137695
#
# #HurricanceFlorenceI I have dropped a whopping 57 pounds and discovered my type 2 diabetes was gone .
# true: 1 pred: 0.6171877384185791
#
# @USER If you are n't IR and do n't have diabetes , then go for it .
# true: 0 pred: 0.4902997612953186
#
# @USER People do n't abuse diabetes or heart medicine .
# true: 0 pred: 0.265503466129303
#
# Does n't matter what I am in 10years dear , you are the glucose guardian here .
# true: 0 pred: 0.5269922018051147
#
# @USER @USER I am one of those people that has to share insulin with a family member .
# true: 0 pred: 0.4952058494091034
#
# Nooooooooo you do n't say : rolling_on_the_floor_laughing : : rolling_on_the_floor_laughing : ( not directed at Daniel )
# true: 0 pred: 0.48504722118377686
#
# " #rip #bkfinest #diabetic / #nofear = 11 .
# true: 0 pred: 0.40476807951927185
#
# ...
# true: 1 pred: 0.2819744348526001
#
# I ' m going to bed now , because , well , I like sleep and I ' ve got to water my garden tomorrow ...
# true: 0 pred: 0.696175217628479
#
# Same way they did my great grandma who still had to get her shit cut off .
# true: 0 pred: 0.4654376804828644
#
# Chocolates not going to keep her warm during the winter ...
# true: 0 pred: 0.3337244689464569
#
# @USER I do n't smoke disgusting habit and I do n't drink being diabetic and all its really bad for my health but with you in that sexy dress I would n't mind partaking you .
# true: 1 pred: 0.6990925669670105
#
# I , for one , feel pretty damn grateful for each new week .
# true: 0 pred: 0.4332110583782196
#
# in the hospital with a infected foot from diabetes
# true: 0 pred: 0.3043235242366791
#
# I have that too as well as me / fibro
# true: 0 pred: 0.35535991191864014
#
# Nna I see diabetes here HTTPURL
# true: 0 pred: 0.2628956735134125
#
# @USER If a patient is not taking insulin and the comes with high sugars and I then increase their normal dose I may give them a hypo .
# true: 1 pred: 0.6857398748397827
#
# Nothing you hear is ever true
# true: 0 pred: 0.17766790091991425
#
# No & No , I ' d prefer to get the virus than have frozen stem cells injected into my system .
# true: 0 pred: 0.6473710536956787
#
# Opened Venmo to see if by some miracle I ' d forgotten bout some $ $ sitting in there & saw this .
# true: 0 pred: 0.6339077949523926
#
# It ' s the 6th most expensive life support liquid medicine in the world .
# true: 0 pred: 0.45267924666404724
#
# It ' s been a hot minute since I ' ve posted anything food related .
# true: 0 pred: 0.4850880801677704
#
# I was told I could stop my diabetes meds in 6 months
# true: 0 pred: 0.3525639474391937
#
# Good job Easter is only once a year : winking_face :
# true: 0 pred: 0.38762593269348145
#
# Rental company was not helpful at all .
# true: 0 pred: 0.21113748848438263
#
# I ' m an emotional mess .
# true: 0 pred: 0.18245144188404083
#
# I keep unsubbing from these diabetes that are plaguing me .
# true: 0 pred: 0.3338019549846649
#
# I have had more than 10 mojor fractures , I have asthma since birth , diabetes , depression , yet I get up every day for my nation .
# true: 0 pred: 0.671155571937561
#
# @USER I ' m a diabetic , I ' m in an attempt risk ' group .
# true: 0 pred: 0.5521551370620728
#
# I do n't drink because I ' m diabetic , but I ' ve always been fascinated by beer cans because my father made me pick up cans on the parkway outside Poquito Bayou in Shalimar , FL for 1 mile when I was a young boy .
# true: 1 pred: 0.7099840044975281
#
# Glucose drink so nasty : loudly_crying_face :
# true: 0 pred: 0.3808576464653015
#
# In another ep I only saw part of : 3 !
# true: 0 pred: 0.2158799171447754
#
# @USER @USER may be not but nobody can afford them .
# true: 0 pred: 0.2816127836704254
#
# @USER Not that I can specifically remember but not sure I ' ve always had the best fun when I was n't prepared at times #GBdoc
# true: 0 pred: 0.6826770305633545
#
# It ' s 9:30 ain't he suppose ta take his insulin shot n put on his sleepers by now
# true: 0 pred: 0.5940167307853699
#
# Plus any neurodivergence that affects executive functioning .
# true: 0 pred: 0.293776273727417
#
# How many times I ' ve had pneumonia .
# true: 0 pred: 0.2849300503730774
#
# She diabetic and requires insulin so it ' s hitting her really hard
# true: 0 pred: 0.3724747598171234
#
# Thank you for representing type 1 !
# true: 0 pred: 0.1876632273197174
#
# You have got to be kidding .
# true: 0 pred: 0.18623086810112
#
# @USER I ' m approaching 46 yrs with T1D , and yes , it gets better .
# true: 0 pred: 0.4654831886291504
#
# We are trying to cure this disease .
# true: 0 pred: 0.2161681205034256
#
# @USER I ' m vegan because I have type 1 diabetes and do n't wanna have a heart attack .
# true: 1 pred: 0.62504643201828
#
# @USER " Just imagine how much insulin you could buy when your extended family all pools their checks together !
# true: 0 pred: 0.5236388444900513
#
# They sit WAY too long .
# true: 0 pred: 0.18755148351192474
#
# Day 4 of no lunchtime insulin : syringe :
# true: 0 pred: 0.20601457357406616
#
# If someone is describing themselves it ' s OK but do n't like it being used to describe me .
# true: 0 pred: 0.5501790046691895
#
# @USER I only wasted some time at two hour sessions on preventing diabetes .
# true: 0 pred: 0.42483779788017273
#
# I cringe every time that ad comes on because it ' s not self inflicted with them
# true: 0 pred: 0.5111433863639832
#
# It was cut on twice .
# true: 0 pred: 0.15322571992874146
#
# The fact that I can look at “ DKA ” and know it means diabetic ketoacidosis and actually know what that means is crazy to me : flushed_face : #futurenurse
# true: 0 pred: 0.7218806147575378
#
# @USER @USER Nah , it looks to me like cancer .
# true: 0 pred: 0.23557575047016144
#
# I have a friend with Type 1 diabetes , he wants to visit #pokemoncenterlondon and is wondering if he is eligible for a accessibility queue .
# true: 0 pred: 0.7141219973564148
#
# Regálame unas tenis de esas de diabético I ' m ur biggest fan man :p leading_face :
# true: 0 pred: 0.6301742792129517
#
# @USER You are a good dad , looking out for their best interest , saving them from cavities and diabetes ...
# true: 0 pred: 0.6071726083755493
#
# @USER My insulin pump doesnt allow me to calculate using 333g of carbohydrates , but with 225g , it tells me to give 18,5 units of insulin which it doesnt allow me to give in one sitting .
# true: 0 pred: 0.6582938432693481
#
# Shits expensive and i like to live : grinning_face_with_sweat : : grinning_face_with_sweat :
# true: 0 pred: 0.4803200960159302
#
# Our house is worthless , our pension worth less due to falling pound .
# true: 0 pred: 0.37275806069374084
#
# Three months since getting my Libre , and my HBA 1c is down from 70 to 56 !
# true: 1 pred: 0.5825958847999573
#
# nice way to fool world .. we know the quality of chinese products ...
# true: 0 pred: 0.351299911737442
#
# all the good intentions are there but the end result is never quite that you wanted .
# true: 0 pred: 0.45423391461372375
#
# and diabetes will do for the both of them soon .
# true: 0 pred: 0.3165951669216156
#
# Increases in insulin does n't mean that at all tho .
# true: 0 pred: 0.3059360980987549
#
# apple news feed several months after I ' ve read JUST ONE article about diabetes : HTTPURL
# true: 0 pred: 0.5576578974723816
#
# @USER I wish others could feel what daily diabetic life feels like to your body ...
# true: 0 pred: 0.42817145586013794
#
# @USER Am planning to take the next day off to recuperate !
# true: 0 pred: 0.3522006869316101
#
# @USER I kind of have but I ' m still troubled about what happened to be honest #gbdoc
# true: 0 pred: 0.568511426448822
#
# Apparently I ' m borderline Diabetic .
# true: 0 pred: 0.307172030210495
#
# If your can help me anything please help : yellow_heart : Cashapp $ EricFarrar 1 HTTPURL
# true: 0 pred: 0.5946342945098877
#
# @USER The tweet is mean , but letting poor people die of diabetes is ...
# true: 1 pred: 0.42850345373153687
#
# Can go from 95 to 115 or more by end of run .
# true: 0 pred: 0.35218125581741333
#
# : unamused_face : Stop with the false lows .
# true: 0 pred: 0.38044318556785583
#
# @USER i called the office everyday for two weeks telling them i am about to run out of insulin and they told me i need to be seen and i said okay , and they scheduled me for february and said they can not prescribe until i am seen .
# true: 0 pred: 0.6966169476509094
#
# This for a diabetes medication .
# true: 0 pred: 0.19257597625255585
#
# if its possible please send me back to my home country .
# true: 0 pred: 0.26096293330192566
#
# So today I asked her where they are bc I wanted some & she said " no te voy decir porque te va dar la diabetes y te va dar la azúcar "
# true: 0 pred: 0.7352227568626404
#
# @USER " That ' s a recipe for getting sugar high / and / diabetes ...
# true: 0 pred: 0.5008029937744141
#
# Got a touch of the shakes .
# true: 0 pred: 0.22467905282974243
#
# Due to my diabetes , I pretty much exist on salads .
# true: 1 pred: 0.35115286707878113
#
# if you are poor you have zero rights to law in America .
# true: 0 pred: 0.37036851048469543
#
# @USER $ 500 every two days aint enough sir .
# true: 0 pred: 0.2516051232814789
#
# @USER Got up , checked email , went to the gym , checked my blood sugar , gave some insulin , going to work shortly ...
# true: 0 pred: 0.669349730014801
#
# Italian drs have been prioritising those likely to
# true: 0 pred: 0.282182902097702
#
# @USER I can't do orange juice with my diabetes .
# true: 0 pred: 0.27127960324287415
#
# The way cholesterol and diabetes scares you guys so much as soon as you see a fat person call themselves beautiful , you ' d think you ' d have the same energy for alcoholism but every weekend its “ lemme drive the boat ” cant go out without drinking but fat people are your concern .
# true: 1 pred: 0.7344157099723816
#
# People die with out insulin .
# true: 0 pred: 0.1826709657907486
#
# @USER My Mom was a diabetic , so I get why she gave out pennies now ...
# true: 0 pred: 0.5356727242469788
#
# As a diabetic with arthritis and early signs of liver damage , I ' m terrified .
# true: 1 pred: 0.5207705497741699
#
# Big pharma ' s greed for the people ' s need is disgusting .
# true: 0 pred: 0.4187624454498291
#
# @USER You would have a diabetic coma .
# true: 0 pred: 0.21997952461242676
#
# The import of crap US employment practices & attitudes is widespread .
# true: 0 pred: 0.26230326294898987
#
# My Granny had Diabetes & got those pale , glazed , confused , sleepy symptoms whenever her blood sugar got too low .
# true: 1 pred: 0.6525909900665283
#
# We knew this day was coming so we said our goodbyes , cried , laughed and said all we needed to say .
# true: 0 pred: 0.6245332360267639
#
# I am type 1 diabetic , and my son has Aspergers .
# true: 0 pred: 0.40231388807296753
#
# @USER Sorry for the delayed response ...
# true: 0 pred: 0.18100596964359283
#
# I pay this vet for a preventative care plan and they were n't listening to me or paying attention to him and what they were prescribing him .
# true: 0 pred: 0.6409651041030884
#
# I ' m SO gonna die of malnutrition and diabetes one day .
# true: 1 pred: 0.422763466835022
#
# @USER Any chance we can get a reply .
# true: 0 pred: 0.241738423705101
#
# @USER @USER i had no diabetes or cholesterol medicines for a year .
# true: 0 pred: 0.31516727805137634
#
# Once they wake up and are with it ya just can't make em go
# true: 0 pred: 0.4022551476955414
#
# @USER @USER Sir my mother has diabetes and Asthama , she is using medicines past 4years referred by Dr .
# true: 1 pred: 0.6274115443229675
#
# i could n't even live on my own anymore , but God got that under control and blessed me with my own spot again : crossed_fingers : : medium_skin_tone : shout out to the man above : yellow_heart : HTTPURL
# true: 0 pred: 0.7208362817764282
#
# @USER Several of my family from 18 80 years old , including my partner of 33 years , rely on insulin .
# true: 0 pred: 0.5650143623352051
#
# @USER Whenever my GF tells people to lose weight ...
# true: 0 pred: 0.23234139382839203
#
# @USER It catches up to them in the end though .
# true: 0 pred: 0.32136771082878113
#
# Gave up after the second as I fell asleep with boredom .
# true: 0 pred: 0.2935125529766083
#
# For someone whose parents are dependant on medication due to being diabetic , I know the struggle of trying to find their medication at all times .
# true: 1 pred: 0.6783543825149536
#
# My blood sugars would shoot up
# true: 0 pred: 0.2249079793691635
#
# I hit Hendricks and Soda during the Cubs WS run !
# true: 0 pred: 0.3323076367378235
#
# @USER my mom ordered her insulin and it was shipped through you .
# true: 0 pred: 0.3072148263454437
#
# @USER Yep @USER had a struggle to track down insulin yesterday ( fifth pharmacy I think before anyone said they could even order it in at the moment ) .
# true: 1 pred: 0.6404776573181152
#
# @USER @USER @USER Sounds so sweet I almost got Diabetes reading it .
# true: 0 pred: 0.33874836564064026
#
# @USER OK now you definitely get a follow back just checked your profile type one diabetic I ' m a lifelong type one diabetic and you love Doctor Who oh hell it ' s go time
# true: 0 pred: 0.7244961261749268
#
# my nana told me last night a dr .
# true: 0 pred: 0.19835621118545532
#
# Eating high carb foods causes blood glucose spikes & damage my body .
# true: 1 pred: 0.3435346484184265
#
# they ' re bad because of the chronic diabetes you have
# true: 0 pred: 0.34517383575439453
#
# @USER To take insulin everytime I eat carbs and to make sure to go to bed with my sugar in the mid 100s with a light snack , they wanted to change
# true: 1 pred: 0.7007232308387756
#
# : clapping_hands : EVERY PREGNANCY IS A HEALTH RISK .
# true: 0 pred: 0.324930876493454
#
# If the heat impacts my diabetes I ' ll be off home .
# true: 0 pred: 0.3656129837036133
#
# I am praying for you .
# true: 0 pred: 0.1456921249628067
#
# @USER Your heart can beat out of your Body not connected to the lungs or anything as long as it has potassium an glucose
# true: 0 pred: 0.6048631072044373
#
# @USER I do n't even like taking insulin and I need it to survive so there ' s no way in hell I would like opioids
# true: 1 pred: 0.6479715704917908
#
# Sounds pretty awful with lots of medication including insulin in very short supply #diabetes HTTPURL
# true: 0 pred: 0.5163375735282898
#
# let me tell all the diabetics that they do n't need their insulin rq
# true: 0 pred: 0.5130496025085449
#
# Diabetes is like trying to dry your washing outside when it ' s snowing ...
# true: 0 pred: 0.4474087953567505
#
# Heck , when I was obese I had no problem with cardio at all .
# true: 0 pred: 0.43748682737350464
#
# Shaunie FINALLY got a storyline !
# true: 0 pred: 0.22921200096607208
#
# It ' s like twin telepathy , but less cool
# true: 0 pred: 0.3542649447917938
#
# I have all my #T1D supplies ready to go .
# true: 0 pred: 0.2959911525249481
#
# And it sure as hell did n't mean I was n't otherwise healthy .
# true: 0 pred: 0.3459913432598114
#
# Tell them they are feeding us toxins and show them the deaths !
# true: 0 pred: 0.4111465513706207
#
# I sent proof to my job and they still let me go .
# true: 0 pred: 0.286861389875412
#
# @USER I ' m pretty sure it ' s NOT her HbA 1c
# true: 0 pred: 0.49898549914360046
#
# @USER Haha those stupid white cartoon kids are going to die from diabetes .
# true: 1 pred: 0.38692256808280945
#
# Well we ' ve tried this and I can tell you from my insulin prices this is crap ...
# true: 0 pred: 0.5110172629356384
#
# Ok done Insulin secretion Ok done FBG Good A1C Good .
# true: 0 pred: 0.42310065031051636
#
# @USER Yeah , they ' ve said my glucose test came back high so I ' ve got to go in for diabetic checks and see how they ' re going to monitor it , but need growth scans as when you ' re diabetic baby grows quicker / bigger : face_blowing_a_kiss :
# true: 1 pred: 0.7584505677223206
#
# and a Type 1 Diabetic who is kept alive by insulin #Pharmacare : loudly_crying_face : : loudly_crying_face : : loudly_crying_face : #ThroneSpeech #T1D
# true: 1 pred: 0.722518265247345
#
# @USER There no tea even near that horrific drink !
# true: 0 pred: 0.2661782503128052
#
# first , rice causes diabetes .
# true: 1 pred: 0.16049492359161377
#
# Town is business as usual .
# true: 0 pred: 0.13375191390514374
#
# On plus side , if I got diabetes I ' ll get access to foot clinics , and free prescriptions , and flu shots .
# true: 1 pred: 0.6607317328453064
#
# Truthfully I have a hard time looking at these pictures of Drew , the morning I drove him to the ER .
# true: 0 pred: 0.6163235902786255
#
# that ' s like 900 / month and there are people DYING because they can't afford it , especially during all of the covid madness
# true: 1 pred: 0.617893636226654
#
# Diabetes runs in my family .
# true: 0 pred: 0.17721909284591675
#
# @USER Hillary says , " No one in America should die because they can't afford insulin .
# true: 1 pred: 0.46340659260749817
#
# The trans woman is a pre op brony .
# true: 0 pred: 0.29675763845443726
#
# Pupils like a damn bushbaby !
# true: 0 pred: 0.18535731732845306
#
# / hold your hand / You choose to be diabetic .
# true: 0 pred: 0.31556209921836853
#
# This is not ok , at all !
# true: 0 pred: 0.24695466458797455
#
# HTTPURL please donate whatever u can .
# true: 0 pred: 0.18796473741531372
#
# @USER It ' s hard because he does so little for himself .
# true: 0 pred: 0.3165132403373718
