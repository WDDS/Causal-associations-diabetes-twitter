# %% [markdown]
# #### Apply cause-effect model (named-entity recognition task) on all causal sentences

# %%
from transformers import AutoTokenizer, AutoModel
import pandas as pd
import os
import torch
from nltk.tokenize import TweetTokenizer
from emoji import demojize
import re
import glob
import joblib


bert_model = "vinai/bertweet-base" # "bert-large-uncased"; "roberta-large"


##### DATA TO LOAD ######
dataDir = "/home/adrian/workspace/causality/Causal-associations-diabetes-twitter/results_causal_sentences"
csv_files = glob.glob(os.path.join(dataDir, "*.csv"))

result_dir = "results_cause_effect_emotional_tweets"

# Always predicts batch_size many tweets and stores result in result_dir
batch_size =  10000 #65552 #1024   #512 # # 65552 #32776 #16388 #8194 #2048

cause_effect_model = joblib.load("./model_causal-sentences/bertEmbeddings_simpleCRF.pkl")

# %%
tokenizer = AutoTokenizer.from_pretrained(bert_model, padding = "max_length", truncation = True, max_length = 60, return_offsets_mapping=True )
model = AutoModel.from_pretrained(bert_model)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Some weights of the model checkpoint at vinai/bertweet-base were not used when initializing RobertaModel: ['lm_head.layer_norm.bias', 'lm_head.decoder.bias', 'lm_head.dense.bias', 'lm_head.decoder.weight', 'lm_head.bias', 'lm_head.layer_norm.weight', 'lm_head.dense.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
## load data

tuples = []
for file in csv_files:
    with open(file, "r") as f:
        lines = f.readlines()
        for i, line in enumerate(lines):
            if i == 0: # header
                if line.endswith("\n"):
                    line = line[:-2]
                header = line.split(",")[1:]
            else:
                index, ll = line.split(",", 1)
                ll, prob = ll.rsplit(",", 1)
                if prob.endswith("\n"):
                    prob = prob[:-2]
                text, pred = ll.rsplit(",", 1)
                if text.startswith('"') and text.endswith('"'):
                    text = text[1:-1]
                    #text = text[]
                    #print(text)

                tuples.append((text, pred, prob))

print("N tweets from file:", len(tuples))

df = pd.DataFrame(tuples, columns=["text", "pred", "proba"])
df.pred = pd.to_numeric(df.pred)
df.proba = pd.to_numeric(df.proba)
print(df.pred.value_counts())
df.head()
# Out:
# N tweets from file: 1024
# 1    564
# 0    460
# Name: pred, dtype: int64
#                                                 text  pred     proba
# 0  Hypo in the Boticelli rooms at the @USER and o...     1  0.660970
# 1              Life & diabetes in a jar altogether !     0  0.241259
# 2  It 's always worrying as a diabetic when your ...     0  0.355484
# 3  Mmm I love bacon and hardly any carbs for brea...     1  0.553529
# 4  * frantically applies for jobs so that i can a...     0  0.492331

# %%
########### take only causal sentences & tokenize ###########
df_causal = df[df["pred"] == 1].sample(n=100, random_state=0)  # SAMPLE ONLY FOR TESTING
df_causal["tokenized"] = df_causal["text"].map(lambda tweet: normalizeTweet(tweet).split(" "))
print("N causal sentences:", df_causal.shape[0])
df_causal.head()
# Out:
# N causal sentences: 100
#                                                   text  pred     proba  \
# 468  To help change the way the NHS treats #type2di...     1  0.685685
# 602  Okay but on the real , I almost lost my life T...     1  0.696993
# 388  @USER Mental Health , keep my diabetes in chec...     1  0.704010
# 607  I 'm a 58 yr old man , with diabetes and a str...     1  0.528210
# 767  Update ( since I made a surprising number of y...     1  0.579300
#
#                                              tokenized
# 468  [To, help, change, the, way, the, NHS, treats,...
# 602  [Okay, but, on, the, real, ,, I, almost, lost,...
# 388  [@USER, Mental, Health, ,, keep, my, diabetes,...
# 607  [I, ', m, a, 58, yr, old, man, ,, with, diabet...
# 767  [Update, (, since, I, made, a, surprising, num...

# %%
#df_causal.to_parquet("data/causal_emotional_sentences.parquet")

# %%
df_causal = pd.read_parquet("data/causal_emotional_sentences.parquet")
df_causal.shape
# Out:
# (281664, 4)

# %%
########################### Check if cuda available ############################
print("Cuda available: ", torch.cuda.is_available())
device = torch.device('cuda:1' if torch.cuda.is_available() else 'cpu')
print("Selected {} for this notebook".format(device))
# Out:
# Cuda available:  False
# Selected cpu for this notebook

# %%
################## GET BERT EMBEDDINGS + OTHER FEATURES ###############################""
def get_word_embeddings(sentence, sentence_tokenised):
    """ Get word embeddings for each word in sentence """
    ids = tokenizer.encode(sentence) 
    ids_tensor = torch.tensor(ids).unsqueeze(0) # Batch size: 1
    word_vectors = model(ids_tensor)[0].squeeze()
    
    word_embeddings_all = []
    for word in sentence_tokenised: # average word embeddings of sub-tokens 
        word_encoded = tokenizer.encode(word)
        word_encoded.remove(tokenizer.cls_token_id)
        word_encoded.remove(tokenizer.sep_token_id)
        
        try:
            word_indices = [ids.index(encoded_id) for encoded_id in word_encoded ] 
        except ValueError: 
            print("sentence:", sentence)
            print("tokenized:", sentence_tokenised)
            print("ids:", ids)
            print()
            print("word:", word)
            print("word_encoded:", word_encoded)
            #print("encoded_id:", encoded_id)
            print("\n\n")
        
        # average all sub_word vectors of word
        word_vector = torch.zeros((768))
        for sub_token_id in word_indices:
            word_vector += word_vectors[sub_token_id]
        word_vector /= len(word_indices)
        
        word_embeddings_all.append(word_vector)
        
    return word_embeddings_all

def word2features(word, i, wordembedding):

    features = {
        'word.lower()': word.lower(),
        'word.isupper()': word.isupper(),
        'word.isdigit()': word.isdigit(),
        'wordlength': len(word),
        'wordinitialcap': word[0].isupper(),
        'wordmixedcap': len([x for x in word[1:] if x.isupper()])>0,
        'wordallcap': len([x for x in word if x.isupper()])==len(word),
        'distfromsentbegin': i
    }

    # here you add 300 (fastText) / 768 (Bert) features (one for each vector component)
    for iv,value in enumerate(wordembedding):
        features['v{}'.format(iv)]=value
    
    return features



def sent2features(sentence, tokenized):
    word_vectors = get_word_embeddings(sentence, tokenized)
    return [word2features(tokenized[i], i, word_vectors[i]) for i in range(len(tokenized))]

X_train = [sent2features(sentence, tokenized) for sentence, tokenized in zip(df_causal.text.values.tolist(), df_causal.tokenized.values.tolist())]
print("X_train:", len(X_train), len(X_train[0]))

# %%
for i in range(0, df_causal.shape[0], batch_size):
    print(i)
    tweet_subset = df_causal[i:i+batch_size]
    X = [sent2features(sentence, tokenized) 
         for sentence, tokenized in zip(tweet_subset.text.values.tolist()
                                    , tweet_subset.tokenized.values.tolist())]
    
    predictions = cause_effect_model.predict(X)
    cause_effect_DF = pd.DataFrame({"text":tweet_subset.text,
                             "tokenized": tweet_subset.tokenized,
                             "predictions": predictions})
cause_effect_DF
# Out:
# 0
# sentence: @USER Mental Health , keep my diabetes in check , but also to meet some frankly awesome people along the way , and I love watching other runners achieve their goals , it 's very fulfilling .
# tokenized: ['@USER', 'Mental', 'Health', ',', 'keep', 'my', 'diabetes', 'in', 'check', ',', 'but', 'also', 'to', 'meet', 'some', 'frankly', 'awesome', 'people', 'along', 'the', 'way', ',', 'and', 'I', 'love', 'watching', 'other', 'runners', 'achieve', 'their', 'goals', ',', 'it', "'", 's', 'very', 'fulfilling', '.']
# ids: [0, 5, 13150, 1960, 7, 264, 23, 15015, 16, 560, 7, 42, 237, 9, 681, 109, 22362, 742, 83, 1041, 6, 154, 7, 13, 8, 71, 406, 185, 17034, 5708, 130, 2032, 7, 18, 20, 249, 29366, 4, 2]
#
# word: '
# word_encoded: [69]
#
#
#
# sentence: @USER Mental Health , keep my diabetes in check , but also to meet some frankly awesome people along the way , and I love watching other runners achieve their goals , it 's very fulfilling .
# tokenized: ['@USER', 'Mental', 'Health', ',', 'keep', 'my', 'diabetes', 'in', 'check', ',', 'but', 'also', 'to', 'meet', 'some', 'frankly', 'awesome', 'people', 'along', 'the', 'way', ',', 'and', 'I', 'love', 'watching', 'other', 'runners', 'achieve', 'their', 'goals', ',', 'it', "'", 's', 'very', 'fulfilling', '.']
# ids: [0, 5, 13150, 1960, 7, 264, 23, 15015, 16, 560, 7, 42, 237, 9, 681, 109, 22362, 742, 83, 1041, 6, 154, 7, 13, 8, 71, 406, 185, 17034, 5708, 130, 2032, 7, 18, 20, 249, 29366, 4, 2]
#
# word: s
# word_encoded: [256]
#
#
#
# sentence: I 'm a 58 yr old man , with diabetes and a strong family history of heart issues .
# tokenized: ['I', "'", 'm', 'a', '58', 'yr', 'old', 'man', ',', 'with', 'diabetes', 'and', 'a', 'strong', 'family', 'history', 'of', 'heart', 'issues', '.']
# ids: [0, 8, 40, 11, 4799, 2599, 289, 171, 7, 30, 15015, 13, 11, 1033, 383, 1128, 15, 398, 1494, 4, 2]
#
# word: '
# word_encoded: [69]
#
#
#
# sentence: I 'm a 58 yr old man , with diabetes and a strong family history of heart issues .
# tokenized: ['I', "'", 'm', 'a', '58', 'yr', 'old', 'man', ',', 'with', 'diabetes', 'and', 'a', 'strong', 'family', 'history', 'of', 'heart', 'issues', '.']
# ids: [0, 8, 40, 11, 4799, 2599, 289, 171, 7, 30, 15015, 13, 11, 1033, 383, 1128, 15, 398, 1494, 4, 2]
#
# word: m
# word_encoded: [504]
#
#
#
# sentence: @USER He 's had trouble since before Xmas , diabetic , ulcers that would n't heal and now weakness in both legs , they 've taken him to Jimmys so I 'll know more when he 's been assessed x
# tokenized: ['@USER', 'He', "'", 's', 'had', 'trouble', 'since', 'before', 'Xmas', ',', 'diabetic', ',', 'ulcers', 'that', 'would', "n't", 'heal', 'and', 'now', 'weakness', 'in', 'both', 'legs', ',', 'they', "'", 've', 'taken', 'him', 'to', 'Jimmys', 'so', 'I', "'", 'll', 'know', 'more', 'when', 'he', "'", 's', 'been', 'assessed', 'x']
# ids: [0, 5, 162, 20, 118, 2390, 324, 213, 8032, 7, 49488, 7, 2123, 32812, 25, 86, 29, 8532, 13, 77, 10656, 16, 425, 2368, 7, 59, 120, 1203, 124, 9, 611, 20192, 2010, 39, 8, 113, 68, 89, 64, 58, 20, 108, 57869, 314, 2]
#
# word: '
# word_encoded: [69]
#
#
#
# sentence: @USER He 's had trouble since before Xmas , diabetic , ulcers that would n't heal and now weakness in both legs , they 've taken him to Jimmys so I 'll know more when he 's been assessed x
# tokenized: ['@USER', 'He', "'", 's', 'had', 'trouble', 'since', 'before', 'Xmas', ',', 'diabetic', ',', 'ulcers', 'that', 'would', "n't", 'heal', 'and', 'now', 'weakness', 'in', 'both', 'legs', ',', 'they', "'", 've', 'taken', 'him', 'to', 'Jimmys', 'so', 'I', "'", 'll', 'know', 'more', 'when', 'he', "'", 's', 'been', 'assessed', 'x']
# ids: [0, 5, 162, 20, 118, 2390, 324, 213, 8032, 7, 49488, 7, 2123, 32812, 25, 86, 29, 8532, 13, 77, 10656, 16, 425, 2368, 7, 59, 120, 1203, 124, 9, 611, 20192, 2010, 39, 8, 113, 68, 89, 64, 58, 20, 108, 57869, 314, 2]
#
# word: s
# word_encoded: [256]
#
#
#
# sentence: @USER He 's had trouble since before Xmas , diabetic , ulcers that would n't heal and now weakness in both legs , they 've taken him to Jimmys so I 'll know more when he 's been assessed x
# tokenized: ['@USER', 'He', "'", 's', 'had', 'trouble', 'since', 'before', 'Xmas', ',', 'diabetic', ',', 'ulcers', 'that', 'would', "n't", 'heal', 'and', 'now', 'weakness', 'in', 'both', 'legs', ',', 'they', "'", 've', 'taken', 'him', 'to', 'Jimmys', 'so', 'I', "'", 'll', 'know', 'more', 'when', 'he', "'", 's', 'been', 'assessed', 'x']
# ids: [0, 5, 162, 20, 118, 2390, 324, 213, 8032, 7, 49488, 7, 2123, 32812, 25, 86, 29, 8532, 13, 77, 10656, 16, 425, 2368, 7, 59, 120, 1203, 124, 9, 611, 20192, 2010, 39, 8, 113, 68, 89, 64, 58, 20, 108, 57869, 314, 2]
#
# word: '
# word_encoded: [69]
#
#
#
# sentence: @USER He 's had trouble since before Xmas , diabetic , ulcers that would n't heal and now weakness in both legs , they 've taken him to Jimmys so I 'll know more when he 's been assessed x
# tokenized: ['@USER', 'He', "'", 's', 'had', 'trouble', 'since', 'before', 'Xmas', ',', 'diabetic', ',', 'ulcers', 'that', 'would', "n't", 'heal', 'and', 'now', 'weakness', 'in', 'both', 'legs', ',', 'they', "'", 've', 'taken', 'him', 'to', 'Jimmys', 'so', 'I', "'", 'll', 'know', 'more', 'when', 'he', "'", 's', 'been', 'assessed', 'x']
# ids: [0, 5, 162, 20, 118, 2390, 324, 213, 8032, 7, 49488, 7, 2123, 32812, 25, 86, 29, 8532, 13, 77, 10656, 16, 425, 2368, 7, 59, 120, 1203, 124, 9, 611, 20192, 2010, 39, 8, 113, 68, 89, 64, 58, 20, 108, 57869, 314, 2]
#
# word: ve
# word_encoded: [1988]
#
#
#
# sentence: @USER He 's had trouble since before Xmas , diabetic , ulcers that would n't heal and now weakness in both legs , they 've taken him to Jimmys so I 'll know more when he 's been assessed x
# tokenized: ['@USER', 'He', "'", 's', 'had', 'trouble', 'since', 'before', 'Xmas', ',', 'diabetic', ',', 'ulcers', 'that', 'would', "n't", 'heal', 'and', 'now', 'weakness', 'in', 'both', 'legs', ',', 'they', "'", 've', 'taken', 'him', 'to', 'Jimmys', 'so', 'I', "'", 'll', 'know', 'more', 'when', 'he', "'", 's', 'been', 'assessed', 'x']
# ids: [0, 5, 162, 20, 118, 2390, 324, 213, 8032, 7, 49488, 7, 2123, 32812, 25, 86, 29, 8532, 13, 77, 10656, 16, 425, 2368, 7, 59, 120, 1203, 124, 9, 611, 20192, 2010, 39, 8, 113, 68, 89, 64, 58, 20, 108, 57869, 314, 2]
#
# word: '
# word_encoded: [69]
#
#
#
# sentence: @USER He 's had trouble since before Xmas , diabetic , ulcers that would n't heal and now weakness in both legs , they 've taken him to Jimmys so I 'll know more when he 's been assessed x
# tokenized: ['@USER', 'He', "'", 's', 'had', 'trouble', 'since', 'before', 'Xmas', ',', 'diabetic', ',', 'ulcers', 'that', 'would', "n't", 'heal', 'and', 'now', 'weakness', 'in', 'both', 'legs', ',', 'they', "'", 've', 'taken', 'him', 'to', 'Jimmys', 'so', 'I', "'", 'll', 'know', 'more', 'when', 'he', "'", 's', 'been', 'assessed', 'x']
# ids: [0, 5, 162, 20, 118, 2390, 324, 213, 8032, 7, 49488, 7, 2123, 32812, 25, 86, 29, 8532, 13, 77, 10656, 16, 425, 2368, 7, 59, 120, 1203, 124, 9, 611, 20192, 2010, 39, 8, 113, 68, 89, 64, 58, 20, 108, 57869, 314, 2]
#
# word: ll
# word_encoded: [2597]
#
#
#
# sentence: @USER He 's had trouble since before Xmas , diabetic , ulcers that would n't heal and now weakness in both legs , they 've taken him to Jimmys so I 'll know more when he 's been assessed x
# tokenized: ['@USER', 'He', "'", 's', 'had', 'trouble', 'since', 'before', 'Xmas', ',', 'diabetic', ',', 'ulcers', 'that', 'would', "n't", 'heal', 'and', 'now', 'weakness', 'in', 'both', 'legs', ',', 'they', "'", 've', 'taken', 'him', 'to', 'Jimmys', 'so', 'I', "'", 'll', 'know', 'more', 'when', 'he', "'", 's', 'been', 'assessed', 'x']
# ids: [0, 5, 162, 20, 118, 2390, 324, 213, 8032, 7, 49488, 7, 2123, 32812, 25, 86, 29, 8532, 13, 77, 10656, 16, 425, 2368, 7, 59, 120, 1203, 124, 9, 611, 20192, 2010, 39, 8, 113, 68, 89, 64, 58, 20, 108, 57869, 314, 2]
#
# word: '
# word_encoded: [69]
#
#
#
# sentence: @USER He 's had trouble since before Xmas , diabetic , ulcers that would n't heal and now weakness in both legs , they 've taken him to Jimmys so I 'll know more when he 's been assessed x
# tokenized: ['@USER', 'He', "'", 's', 'had', 'trouble', 'since', 'before', 'Xmas', ',', 'diabetic', ',', 'ulcers', 'that', 'would', "n't", 'heal', 'and', 'now', 'weakness', 'in', 'both', 'legs', ',', 'they', "'", 've', 'taken', 'him', 'to', 'Jimmys', 'so', 'I', "'", 'll', 'know', 'more', 'when', 'he', "'", 's', 'been', 'assessed', 'x']
# ids: [0, 5, 162, 20, 118, 2390, 324, 213, 8032, 7, 49488, 7, 2123, 32812, 25, 86, 29, 8532, 13, 77, 10656, 16, 425, 2368, 7, 59, 120, 1203, 124, 9, 611, 20192, 2010, 39, 8, 113, 68, 89, 64, 58, 20, 108, 57869, 314, 2]
#
# word: s
# word_encoded: [256]
#
#
#
# sentence: @USER Ca n't really tell it 's all my success , diabetes for the first 10 kg and then Victoza for the next 10 definitely helped .
# tokenized: ['@USER', 'Ca', "n't", 'really', 'tell', 'it', "'", 's', 'all', 'my', 'success', ',', 'diabetes', 'for', 'the', 'first', '10', 'kg', 'and', 'then', 'Victoza', 'for', 'the', 'next', '10', 'definitely', 'helped', '.']
# ids: [0, 5, 522, 29, 116, 238, 18, 20, 48, 23, 1837, 7, 15015, 19, 6, 160, 251, 10856, 13, 133, 13622, 969, 3614, 19, 6, 217, 251, 1013, 2692, 4, 2]
#
# word: '
# word_encoded: [69]
#
#
#
# sentence: @USER Ca n't really tell it 's all my success , diabetes for the first 10 kg and then Victoza for the next 10 definitely helped .
# tokenized: ['@USER', 'Ca', "n't", 'really', 'tell', 'it', "'", 's', 'all', 'my', 'success', ',', 'diabetes', 'for', 'the', 'first', '10', 'kg', 'and', 'then', 'Victoza', 'for', 'the', 'next', '10', 'definitely', 'helped', '.']
# ids: [0, 5, 522, 29, 116, 238, 18, 20, 48, 23, 1837, 7, 15015, 19, 6, 160, 251, 10856, 13, 133, 13622, 969, 3614, 19, 6, 217, 251, 1013, 2692, 4, 2]
#
# word: s
# word_encoded: [256]
# sentence: Do they teach diabetes specialists in medical school that they 're professionally mandated to make all their patients feel like shit or
# tokenized: ['Do', 'they', 'teach', 'diabetes', 'specialists', 'in', 'medical', 'school', 'that', 'they', "'", 're', 'professionally', 'mandated', 'to', 'make', 'all', 'their', 'patients', 'feel', 'like', 'shit', 'or']
# ids: [0, 172, 59, 2592, 15015, 38263, 16, 3541, 230, 25, 59, 81, 30926, 54243, 9, 115, 48, 130, 5546, 174, 43, 145, 72, 2]
#
# word: '
# word_encoded: [69]
#
#
#
# sentence: Do they teach diabetes specialists in medical school that they 're professionally mandated to make all their patients feel like shit or
# tokenized: ['Do', 'they', 'teach', 'diabetes', 'specialists', 'in', 'medical', 'school', 'that', 'they', "'", 're', 'professionally', 'mandated', 'to', 'make', 'all', 'their', 'patients', 'feel', 'like', 'shit', 'or']
# ids: [0, 172, 59, 2592, 15015, 38263, 16, 3541, 230, 25, 59, 81, 30926, 54243, 9, 115, 48, 130, 5546, 174, 43, 145, 72, 2]
#
# word: re
# word_encoded: [1330]
#
#
#
# sentence: Every day talking shit about skinny girls :unamused_face: at least my health in good condition and I ain't got diabetes but w / e do ur ting HTTPURL
# tokenized: ['Every', 'day', 'talking', 'shit', 'about', 'skinny', 'girls', ':', 'unamused_face', ':', 'at', 'least', 'my', 'health', 'in', 'good', 'condition', 'and', 'I', "ain't", 'got', 'diabetes', 'but', 'w', '/', 'e', 'do', 'ur', 'ting', 'HTTPURL']
# ids: [0, 1077, 93, 401, 145, 62, 5160, 374, 596, 35, 538, 23, 1256, 16, 94, 5980, 13, 8, 413, 100, 15015, 42, 293, 75, 853, 32, 315, 1371, 10, 2]
#
# word: :
# word_encoded: [22]
#
#
#
# sentence: Every day talking shit about skinny girls :unamused_face: at least my health in good condition and I ain't got diabetes but w / e do ur ting HTTPURL
# tokenized: ['Every', 'day', 'talking', 'shit', 'about', 'skinny', 'girls', ':', 'unamused_face', ':', 'at', 'least', 'my', 'health', 'in', 'good', 'condition', 'and', 'I', "ain't", 'got', 'diabetes', 'but', 'w', '/', 'e', 'do', 'ur', 'ting', 'HTTPURL']
# ids: [0, 1077, 93, 401, 145, 62, 5160, 374, 596, 35, 538, 23, 1256, 16, 94, 5980, 13, 8, 413, 100, 15015, 42, 293, 75, 853, 32, 315, 1371, 10, 2]
#
# word: unamused_face
# word_encoded: [439, 15628, 6012, 524, 363]
#
#
#
# sentence: Every day talking shit about skinny girls :unamused_face: at least my health in good condition and I ain't got diabetes but w / e do ur ting HTTPURL
# tokenized: ['Every', 'day', 'talking', 'shit', 'about', 'skinny', 'girls', ':', 'unamused_face', ':', 'at', 'least', 'my', 'health', 'in', 'good', 'condition', 'and', 'I', "ain't", 'got', 'diabetes', 'but', 'w', '/', 'e', 'do', 'ur', 'ting', 'HTTPURL']
# ids: [0, 1077, 93, 401, 145, 62, 5160, 374, 596, 35, 538, 23, 1256, 16, 94, 5980, 13, 8, 413, 100, 15015, 42, 293, 75, 853, 32, 315, 1371, 10, 2]
#
# word: :
# word_encoded: [22]
#
#
#
# sentence: dare not lie down again or they will knock me out & I 'll feel like a diabetic so I drink a pot of coffee & head out to 2nd Cup , still tired .
# tokenized: ['dare', 'not', 'lie', 'down', 'again', 'or', 'they', 'will', 'knock', 'me', 'out', '&', 'I', "'", 'll', 'feel', 'like', 'a', 'diabetic', 'so', 'I', 'drink', 'a', 'pot', 'of', 'coffee', '&', 'head', 'out', 'to', '2nd', 'Cup', ',', 'still', 'tired', '.']
# ids: [0, 4144, 46, 932, 181, 206, 72, 59, 70, 4251, 27, 50, 55, 8, 113, 174, 43, 11, 49488, 39, 8, 1056, 11, 5343, 15, 1477, 55, 378, 50, 9, 1228, 1811, 7, 135, 757, 4, 2]
#
# word: '
# word_encoded: [69]
#
#
#
# sentence: dare not lie down again or they will knock me out & I 'll feel like a diabetic so I drink a pot of coffee & head out to 2nd Cup , still tired .
# tokenized: ['dare', 'not', 'lie', 'down', 'again', 'or', 'they', 'will', 'knock', 'me', 'out', '&', 'I', "'", 'll', 'feel', 'like', 'a', 'diabetic', 'so', 'I', 'drink', 'a', 'pot', 'of', 'coffee', '&', 'head', 'out', 'to', '2nd', 'Cup', ',', 'still', 'tired', '.']
# ids: [0, 4144, 46, 932, 181, 206, 72, 59, 70, 4251, 27, 50, 55, 8, 113, 174, 43, 11, 49488, 39, 8, 1056, 11, 5343, 15, 1477, 55, 378, 50, 9, 1228, 1811, 7, 135, 757, 4, 2]
#
# word: ll
# word_encoded: [2597]
#
#
#
# sentence: @USER Aww hun you really are having a day of it , I 've just been to my diabetes check and all is good levels are down , weight not too bad only fly is my thyroid is on the blink but not too bad at the mo , :smiling_face_with_halo:
# tokenized: ['@USER', 'Aww', 'hun', 'you', 'really', 'are', 'having', 'a', 'day', 'of', 'it', ',', 'I', "'", 've', 'just', 'been', 'to', 'my', 'diabetes', 'check', 'and', 'all', 'is', 'good', 'levels', 'are', 'down', ',', 'weight', 'not', 'too', 'bad', 'only', 'fly', 'is', 'my', 'thyroid', 'is', 'on', 'the', 'blink', 'but', 'not', 'too', 'bad', 'at', 'the', 'mo', ',', ':', 'smiling_face_with_halo', ':']
# ids: [0, 5, 5586, 6018, 14, 116, 41, 344, 11, 93, 15, 18, 7, 8, 120, 45, 108, 9, 23, 15015, 560, 13, 48, 17, 94, 4138, 41, 181, 7, 1916, 46, 111, 227, 121, 2039, 17, 23, 17300, 39651, 17, 24, 6, 15166, 42, 46, 111, 227, 35, 6, 2191, 7, 4894, 2]
#
# word: '
# word_encoded: [69]
#
#
#
# sentence: @USER Aww hun you really are having a day of it , I 've just been to my diabetes check and all is good levels are down , weight not too bad only fly is my thyroid is on the blink but not too bad at the mo , :smiling_face_with_halo:
# tokenized: ['@USER', 'Aww', 'hun', 'you', 'really', 'are', 'having', 'a', 'day', 'of', 'it', ',', 'I', "'", 've', 'just', 'been', 'to', 'my', 'diabetes', 'check', 'and', 'all', 'is', 'good', 'levels', 'are', 'down', ',', 'weight', 'not', 'too', 'bad', 'only', 'fly', 'is', 'my', 'thyroid', 'is', 'on', 'the', 'blink', 'but', 'not', 'too', 'bad', 'at', 'the', 'mo', ',', ':', 'smiling_face_with_halo', ':']
# ids: [0, 5, 5586, 6018, 14, 116, 41, 344, 11, 93, 15, 18, 7, 8, 120, 45, 108, 9, 23, 15015, 560, 13, 48, 17, 94, 4138, 41, 181, 7, 1916, 46, 111, 227, 121, 2039, 17, 23, 17300, 39651, 17, 24, 6, 15166, 42, 46, 111, 227, 35, 6, 2191, 7, 4894, 2]
#
# word: ve
# word_encoded: [1988]
#
#
#
# sentence: @USER Aww hun you really are having a day of it , I 've just been to my diabetes check and all is good levels are down , weight not too bad only fly is my thyroid is on the blink but not too bad at the mo , :smiling_face_with_halo:
# tokenized: ['@USER', 'Aww', 'hun', 'you', 'really', 'are', 'having', 'a', 'day', 'of', 'it', ',', 'I', "'", 've', 'just', 'been', 'to', 'my', 'diabetes', 'check', 'and', 'all', 'is', 'good', 'levels', 'are', 'down', ',', 'weight', 'not', 'too', 'bad', 'only', 'fly', 'is', 'my', 'thyroid', 'is', 'on', 'the', 'blink', 'but', 'not', 'too', 'bad', 'at', 'the', 'mo', ',', ':', 'smiling_face_with_halo', ':']
# ids: [0, 5, 5586, 6018, 14, 116, 41, 344, 11, 93, 15, 18, 7, 8, 120, 45, 108, 9, 23, 15015, 560, 13, 48, 17, 94, 4138, 41, 181, 7, 1916, 46, 111, 227, 121, 2039, 17, 23, 17300, 39651, 17, 24, 6, 15166, 42, 46, 111, 227, 35, 6, 2191, 7, 4894, 2]
#
# word: :
# word_encoded: [22]
#
#
#
# sentence: @USER Aww hun you really are having a day of it , I 've just been to my diabetes check and all is good levels are down , weight not too bad only fly is my thyroid is on the blink but not too bad at the mo , :smiling_face_with_halo:
# tokenized: ['@USER', 'Aww', 'hun', 'you', 'really', 'are', 'having', 'a', 'day', 'of', 'it', ',', 'I', "'", 've', 'just', 'been', 'to', 'my', 'diabetes', 'check', 'and', 'all', 'is', 'good', 'levels', 'are', 'down', ',', 'weight', 'not', 'too', 'bad', 'only', 'fly', 'is', 'my', 'thyroid', 'is', 'on', 'the', 'blink', 'but', 'not', 'too', 'bad', 'at', 'the', 'mo', ',', ':', 'smiling_face_with_halo', ':']
# ids: [0, 5, 5586, 6018, 14, 116, 41, 344, 11, 93, 15, 18, 7, 8, 120, 45, 108, 9, 23, 15015, 560, 13, 48, 17, 94, 4138, 41, 181, 7, 1916, 46, 111, 227, 121, 2039, 17, 23, 17300, 39651, 17, 24, 6, 15166, 42, 46, 111, 227, 35, 6, 2191, 7, 4894, 2]
#
# word: smiling_face_with_halo
# word_encoded: [3, 3, 20849]
#
#
#
# sentence: @USER Aww hun you really are having a day of it , I 've just been to my diabetes check and all is good levels are down , weight not too bad only fly is my thyroid is on the blink but not too bad at the mo , :smiling_face_with_halo:
# tokenized: ['@USER', 'Aww', 'hun', 'you', 'really', 'are', 'having', 'a', 'day', 'of', 'it', ',', 'I', "'", 've', 'just', 'been', 'to', 'my', 'diabetes', 'check', 'and', 'all', 'is', 'good', 'levels', 'are', 'down', ',', 'weight', 'not', 'too', 'bad', 'only', 'fly', 'is', 'my', 'thyroid', 'is', 'on', 'the', 'blink', 'but', 'not', 'too', 'bad', 'at', 'the', 'mo', ',', ':', 'smiling_face_with_halo', ':']
# ids: [0, 5, 5586, 6018, 14, 116, 41, 344, 11, 93, 15, 18, 7, 8, 120, 45, 108, 9, 23, 15015, 560, 13, 48, 17, 94, 4138, 41, 181, 7, 1916, 46, 111, 227, 121, 2039, 17, 23, 17300, 39651, 17, 24, 6, 15166, 42, 46, 111, 227, 35, 6, 2191, 7, 4894, 2]
#
# word: :
# word_encoded: [22]
# sentence: He is suffering from diabetes and every year claims lakhs to get treated in Jibdal 's but here he is enjoying Ice cream .
# tokenized: ['He', 'is', 'suffering', 'from', 'diabetes', 'and', 'every', 'year', 'claims', 'lakhs', 'to', 'get', 'treated', 'in', 'Jibdal', "'", 's', 'but', 'here', 'he', 'is', 'enjoying', 'Ice', 'cream', '.']
# ids: [0, 162, 17, 5812, 53, 15015, 13, 234, 189, 3903, 34244, 5983, 9, 51, 4114, 16, 611, 14379, 27789, 20, 42, 137, 58, 17, 3359, 4746, 2074, 4, 2]
#
# word: '
# word_encoded: [69]
#
#
#
# sentence: He is suffering from diabetes and every year claims lakhs to get treated in Jibdal 's but here he is enjoying Ice cream .
# tokenized: ['He', 'is', 'suffering', 'from', 'diabetes', 'and', 'every', 'year', 'claims', 'lakhs', 'to', 'get', 'treated', 'in', 'Jibdal', "'", 's', 'but', 'here', 'he', 'is', 'enjoying', 'Ice', 'cream', '.']
# ids: [0, 162, 17, 5812, 53, 15015, 13, 234, 189, 3903, 34244, 5983, 9, 51, 4114, 16, 611, 14379, 27789, 20, 42, 137, 58, 17, 3359, 4746, 2074, 4, 2]
#
# word: s
# word_encoded: [256]
#
#
#
# sentence: @USER I 'm the one who sent you the diabetic lance AUs I 'm sorry for making you feel feelings
# tokenized: ['@USER', 'I', "'", 'm', 'the', 'one', 'who', 'sent', 'you', 'the', 'diabetic', 'lance', 'AUs', 'I', "'", 'm', 'sorry', 'for', 'making', 'you', 'feel', 'feelings']
# ids: [0, 5, 8, 40, 6, 63, 87, 1168, 14, 6, 49488, 39797, 327, 3005, 8, 40, 462, 19, 382, 14, 174, 1454, 2]
#
# word: '
# word_encoded: [69]
#
#
#
# sentence: @USER I 'm the one who sent you the diabetic lance AUs I 'm sorry for making you feel feelings
# tokenized: ['@USER', 'I', "'", 'm', 'the', 'one', 'who', 'sent', 'you', 'the', 'diabetic', 'lance', 'AUs', 'I', "'", 'm', 'sorry', 'for', 'making', 'you', 'feel', 'feelings']
# ids: [0, 5, 8, 40, 6, 63, 87, 1168, 14, 6, 49488, 39797, 327, 3005, 8, 40, 462, 19, 382, 14, 174, 1454, 2]
#
# word: m
# word_encoded: [504]
#
#
#
# sentence: @USER I 'm the one who sent you the diabetic lance AUs I 'm sorry for making you feel feelings
# tokenized: ['@USER', 'I', "'", 'm', 'the', 'one', 'who', 'sent', 'you', 'the', 'diabetic', 'lance', 'AUs', 'I', "'", 'm', 'sorry', 'for', 'making', 'you', 'feel', 'feelings']
# ids: [0, 5, 8, 40, 6, 63, 87, 1168, 14, 6, 49488, 39797, 327, 3005, 8, 40, 462, 19, 382, 14, 174, 1454, 2]
#
# word: '
# word_encoded: [69]
#
#
#
# sentence: @USER I 'm the one who sent you the diabetic lance AUs I 'm sorry for making you feel feelings
# tokenized: ['@USER', 'I', "'", 'm', 'the', 'one', 'who', 'sent', 'you', 'the', 'diabetic', 'lance', 'AUs', 'I', "'", 'm', 'sorry', 'for', 'making', 'you', 'feel', 'feelings']
# ids: [0, 5, 8, 40, 6, 63, 87, 1168, 14, 6, 49488, 39797, 327, 3005, 8, 40, 462, 19, 382, 14, 174, 1454, 2]
#
# word: m
# word_encoded: [504]
#
#
#
# sentence: Love a discount on SPLENDA :registered: Sweetener because I 'm a diabetic and I bake a lot .
# tokenized: ['Love', 'a', 'discount', 'on', 'SPLENDA', ':', 'registered', ':', 'Sweetener', 'because', 'I', "'", 'm', 'a', 'diabetic', 'and', 'I', 'bake', 'a', 'lot', '.']
# ids: [0, 345, 11, 6964, 24, 381, 4310, 11533, 104, 6825, 15405, 39100, 153, 8, 40, 11, 49488, 13, 8, 11091, 11, 318, 4, 2]
#
# word: :
# word_encoded: [22]
#
#
#
# sentence: Love a discount on SPLENDA :registered: Sweetener because I 'm a diabetic and I bake a lot .
# tokenized: ['Love', 'a', 'discount', 'on', 'SPLENDA', ':', 'registered', ':', 'Sweetener', 'because', 'I', "'", 'm', 'a', 'diabetic', 'and', 'I', 'bake', 'a', 'lot', '.']
# ids: [0, 345, 11, 6964, 24, 381, 4310, 11533, 104, 6825, 15405, 39100, 153, 8, 40, 11, 49488, 13, 8, 11091, 11, 318, 4, 2]
#
# word: registered
# word_encoded: [8237]
#
#
#
# sentence: Love a discount on SPLENDA :registered: Sweetener because I 'm a diabetic and I bake a lot .
# tokenized: ['Love', 'a', 'discount', 'on', 'SPLENDA', ':', 'registered', ':', 'Sweetener', 'because', 'I', "'", 'm', 'a', 'diabetic', 'and', 'I', 'bake', 'a', 'lot', '.']
# ids: [0, 345, 11, 6964, 24, 381, 4310, 11533, 104, 6825, 15405, 39100, 153, 8, 40, 11, 49488, 13, 8, 11091, 11, 318, 4, 2]
#
# word: :
# word_encoded: [22]
#
#
#
# sentence: Love a discount on SPLENDA :registered: Sweetener because I 'm a diabetic and I bake a lot .
# tokenized: ['Love', 'a', 'discount', 'on', 'SPLENDA', ':', 'registered', ':', 'Sweetener', 'because', 'I', "'", 'm', 'a', 'diabetic', 'and', 'I', 'bake', 'a', 'lot', '.']
# ids: [0, 345, 11, 6964, 24, 381, 4310, 11533, 104, 6825, 15405, 39100, 153, 8, 40, 11, 49488, 13, 8, 11091, 11, 318, 4, 2]
#
# word: '
# word_encoded: [69]
#
#
#
# sentence: Love a discount on SPLENDA :registered: Sweetener because I 'm a diabetic and I bake a lot .
# tokenized: ['Love', 'a', 'discount', 'on', 'SPLENDA', ':', 'registered', ':', 'Sweetener', 'because', 'I', "'", 'm', 'a', 'diabetic', 'and', 'I', 'bake', 'a', 'lot', '.']
# ids: [0, 345, 11, 6964, 24, 381, 4310, 11533, 104, 6825, 15405, 39100, 153, 8, 40, 11, 49488, 13, 8, 11091, 11, 318, 4, 2]
#
# word: m
# word_encoded: [504]
#
#
#
# sentence: I need to stop eating kit kats I have diabetes that 's not good for me i hate myself why am I eating such unhealthy shit , ah yes it was because I had nothing else to eat at college today
# tokenized: ['I', 'need', 'to', 'stop', 'eating', 'kit', 'kats', 'I', 'have', 'diabetes', 'that', "'", 's', 'not', 'good', 'for', 'me', 'i', 'hate', 'myself', 'why', 'am', 'I', 'eating', 'such', 'unhealthy', 'shit', ',', 'ah', 'yes', 'it', 'was', 'because', 'I', 'had', 'nothing', 'else', 'to', 'eat', 'at', 'college', 'today']
# ids: [0, 8, 114, 9, 269, 1114, 5361, 409, 5699, 8, 36, 15015, 25, 20, 46, 94, 19, 27, 37, 253, 360, 146, 155, 8, 1114, 367, 16206, 145, 7, 978, 481, 18, 38, 153, 8, 118, 349, 435, 9, 531, 35, 1023, 128, 2]
#
# word: '
# word_encoded: [69]
#
#
#
# sentence: I need to stop eating kit kats I have diabetes that 's not good for me i hate myself why am I eating such unhealthy shit , ah yes it was because I had nothing else to eat at college today
# tokenized: ['I', 'need', 'to', 'stop', 'eating', 'kit', 'kats', 'I', 'have', 'diabetes', 'that', "'", 's', 'not', 'good', 'for', 'me', 'i', 'hate', 'myself', 'why', 'am', 'I', 'eating', 'such', 'unhealthy', 'shit', ',', 'ah', 'yes', 'it', 'was', 'because', 'I', 'had', 'nothing', 'else', 'to', 'eat', 'at', 'college', 'today']
# ids: [0, 8, 114, 9, 269, 1114, 5361, 409, 5699, 8, 36, 15015, 25, 20, 46, 94, 19, 27, 37, 253, 360, 146, 155, 8, 1114, 367, 16206, 145, 7, 978, 481, 18, 38, 153, 8, 118, 349, 435, 9, 531, 35, 1023, 128, 2]
#
# word: s
# word_encoded: [256]
#
#
#
# sentence: nothing worse than being a diabetic man :person_facepalming: :medium_skin_tone: ‍ :male_sign: i 'm CONSTANTLY sick , shit is ridiculous man
# tokenized: ['nothing', 'worse', 'than', 'being', 'a', 'diabetic', 'man', ':p', 'erson_facepalming', ':', ':', 'medium_skin_tone', ':', '\u200d', ':', 'male_sign', ':', 'i', "'", 'm', 'CONSTANTLY', 'sick', ',', 'shit', 'is', 'ridiculous', 'man']
# ids: [0, 349, 1227, 149, 166, 11, 49488, 171, 2541, 1277, 1014, 2555, 37, 40, 5078, 56495, 821, 7, 145, 17, 2963, 171, 2]
#
# word: :p
# word_encoded: [2011]
#
#
#
# sentence: nothing worse than being a diabetic man :person_facepalming: :medium_skin_tone: ‍ :male_sign: i 'm CONSTANTLY sick , shit is ridiculous man
# tokenized: ['nothing', 'worse', 'than', 'being', 'a', 'diabetic', 'man', ':p', 'erson_facepalming', ':', ':', 'medium_skin_tone', ':', '\u200d', ':', 'male_sign', ':', 'i', "'", 'm', 'CONSTANTLY', 'sick', ',', 'shit', 'is', 'ridiculous', 'man']
# ids: [0, 349, 1227, 149, 166, 11, 49488, 171, 2541, 1277, 1014, 2555, 37, 40, 5078, 56495, 821, 7, 145, 17, 2963, 171, 2]
#
# word: erson_facepalming
# word_encoded: [772, 3303, 524, 63828, 5552]
#
#
#
# sentence: nothing worse than being a diabetic man :person_facepalming: :medium_skin_tone: ‍ :male_sign: i 'm CONSTANTLY sick , shit is ridiculous man
# tokenized: ['nothing', 'worse', 'than', 'being', 'a', 'diabetic', 'man', ':p', 'erson_facepalming', ':', ':', 'medium_skin_tone', ':', '\u200d', ':', 'male_sign', ':', 'i', "'", 'm', 'CONSTANTLY', 'sick', ',', 'shit', 'is', 'ridiculous', 'man']
# ids: [0, 349, 1227, 149, 166, 11, 49488, 171, 2541, 1277, 1014, 2555, 37, 40, 5078, 56495, 821, 7, 145, 17, 2963, 171, 2]
#
# word: :
# word_encoded: [22]
#
#
#
# sentence: nothing worse than being a diabetic man :person_facepalming: :medium_skin_tone: ‍ :male_sign: i 'm CONSTANTLY sick , shit is ridiculous man
# tokenized: ['nothing', 'worse', 'than', 'being', 'a', 'diabetic', 'man', ':p', 'erson_facepalming', ':', ':', 'medium_skin_tone', ':', '\u200d', ':', 'male_sign', ':', 'i', "'", 'm', 'CONSTANTLY', 'sick', ',', 'shit', 'is', 'ridiculous', 'man']
# ids: [0, 349, 1227, 149, 166, 11, 49488, 171, 2541, 1277, 1014, 2555, 37, 40, 5078, 56495, 821, 7, 145, 17, 2963, 171, 2]
#
# word: :
# word_encoded: [22]
#
#
#
# sentence: nothing worse than being a diabetic man :person_facepalming: :medium_skin_tone: ‍ :male_sign: i 'm CONSTANTLY sick , shit is ridiculous man
# tokenized: ['nothing', 'worse', 'than', 'being', 'a', 'diabetic', 'man', ':p', 'erson_facepalming', ':', ':', 'medium_skin_tone', ':', '\u200d', ':', 'male_sign', ':', 'i', "'", 'm', 'CONSTANTLY', 'sick', ',', 'shit', 'is', 'ridiculous', 'man']
# ids: [0, 349, 1227, 149, 166, 11, 49488, 171, 2541, 1277, 1014, 2555, 37, 40, 5078, 56495, 821, 7, 145, 17, 2963, 171, 2]
#
# word: medium_skin_tone
# word_encoded: [43586, 3, 6235]
#
#
#
# sentence: nothing worse than being a diabetic man :person_facepalming: :medium_skin_tone: ‍ :male_sign: i 'm CONSTANTLY sick , shit is ridiculous man
# tokenized: ['nothing', 'worse', 'than', 'being', 'a', 'diabetic', 'man', ':p', 'erson_facepalming', ':', ':', 'medium_skin_tone', ':', '\u200d', ':', 'male_sign', ':', 'i', "'", 'm', 'CONSTANTLY', 'sick', ',', 'shit', 'is', 'ridiculous', 'man']
# ids: [0, 349, 1227, 149, 166, 11, 49488, 171, 2541, 1277, 1014, 2555, 37, 40, 5078, 56495, 821, 7, 145, 17, 2963, 171, 2]
#
# word: :
# word_encoded: [22]
#
#
#
# sentence: nothing worse than being a diabetic man :person_facepalming: :medium_skin_tone: ‍ :male_sign: i 'm CONSTANTLY sick , shit is ridiculous man
# tokenized: ['nothing', 'worse', 'than', 'being', 'a', 'diabetic', 'man', ':p', 'erson_facepalming', ':', ':', 'medium_skin_tone', ':', '\u200d', ':', 'male_sign', ':', 'i', "'", 'm', 'CONSTANTLY', 'sick', ',', 'shit', 'is', 'ridiculous', 'man']
# ids: [0, 349, 1227, 149, 166, 11, 49488, 171, 2541, 1277, 1014, 2555, 37, 40, 5078, 56495, 821, 7, 145, 17, 2963, 171, 2]
#
# word: :
# word_encoded: [22]
#
#
#
# sentence: nothing worse than being a diabetic man :person_facepalming: :medium_skin_tone: ‍ :male_sign: i 'm CONSTANTLY sick , shit is ridiculous man
# tokenized: ['nothing', 'worse', 'than', 'being', 'a', 'diabetic', 'man', ':p', 'erson_facepalming', ':', ':', 'medium_skin_tone', ':', '\u200d', ':', 'male_sign', ':', 'i', "'", 'm', 'CONSTANTLY', 'sick', ',', 'shit', 'is', 'ridiculous', 'man']
# ids: [0, 349, 1227, 149, 166, 11, 49488, 171, 2541, 1277, 1014, 2555, 37, 40, 5078, 56495, 821, 7, 145, 17, 2963, 171, 2]
#
# word: male_sign
# word_encoded: [592, 3, 1144]
#
#
#
# sentence: nothing worse than being a diabetic man :person_facepalming: :medium_skin_tone: ‍ :male_sign: i 'm CONSTANTLY sick , shit is ridiculous man
# tokenized: ['nothing', 'worse', 'than', 'being', 'a', 'diabetic', 'man', ':p', 'erson_facepalming', ':', ':', 'medium_skin_tone', ':', '\u200d', ':', 'male_sign', ':', 'i', "'", 'm', 'CONSTANTLY', 'sick', ',', 'shit', 'is', 'ridiculous', 'man']
# ids: [0, 349, 1227, 149, 166, 11, 49488, 171, 2541, 1277, 1014, 2555, 37, 40, 5078, 56495, 821, 7, 145, 17, 2963, 171, 2]
#
# word: :
# word_encoded: [22]
#
#
#
# sentence: nothing worse than being a diabetic man :person_facepalming: :medium_skin_tone: ‍ :male_sign: i 'm CONSTANTLY sick , shit is ridiculous man
# tokenized: ['nothing', 'worse', 'than', 'being', 'a', 'diabetic', 'man', ':p', 'erson_facepalming', ':', ':', 'medium_skin_tone', ':', '\u200d', ':', 'male_sign', ':', 'i', "'", 'm', 'CONSTANTLY', 'sick', ',', 'shit', 'is', 'ridiculous', 'man']
# ids: [0, 349, 1227, 149, 166, 11, 49488, 171, 2541, 1277, 1014, 2555, 37, 40, 5078, 56495, 821, 7, 145, 17, 2963, 171, 2]
#
# word: '
# word_encoded: [69]
#
#
#
# sentence: nothing worse than being a diabetic man :person_facepalming: :medium_skin_tone: ‍ :male_sign: i 'm CONSTANTLY sick , shit is ridiculous man
# tokenized: ['nothing', 'worse', 'than', 'being', 'a', 'diabetic', 'man', ':p', 'erson_facepalming', ':', ':', 'medium_skin_tone', ':', '\u200d', ':', 'male_sign', ':', 'i', "'", 'm', 'CONSTANTLY', 'sick', ',', 'shit', 'is', 'ridiculous', 'man']
# ids: [0, 349, 1227, 149, 166, 11, 49488, 171, 2541, 1277, 1014, 2555, 37, 40, 5078, 56495, 821, 7, 145, 17, 2963, 171, 2]
#
# word: m
# word_encoded: [504]
# sentence: @USER I 'm on 600mg a day and it helps with the nerve pain from diabetes in my feet and the nerve pain from 3 herniated disks in my back .
# tokenized: ['@USER', 'I', "'", 'm', 'on', '600mg', 'a', 'day', 'and', 'it', 'helps', 'with', 'the', 'nerve', 'pain', 'from', 'diabetes', 'in', 'my', 'feet', 'and', 'the', 'nerve', 'pain', 'from', '3', 'herniated', 'disks', 'in', 'my', 'back', '.']
# ids: [0, 5, 8, 40, 24, 13896, 14551, 11, 93, 13, 18, 2820, 30, 6, 9573, 1182, 53, 15015, 16, 23, 1802, 13, 6, 9573, 1182, 53, 163, 3506, 2115, 1269, 1215, 1799, 16, 23, 107, 4, 2]
#
# word: '
# word_encoded: [69]
#
#
#
# sentence: @USER I 'm on 600mg a day and it helps with the nerve pain from diabetes in my feet and the nerve pain from 3 herniated disks in my back .
# tokenized: ['@USER', 'I', "'", 'm', 'on', '600mg', 'a', 'day', 'and', 'it', 'helps', 'with', 'the', 'nerve', 'pain', 'from', 'diabetes', 'in', 'my', 'feet', 'and', 'the', 'nerve', 'pain', 'from', '3', 'herniated', 'disks', 'in', 'my', 'back', '.']
# ids: [0, 5, 8, 40, 24, 13896, 14551, 11, 93, 13, 18, 2820, 30, 6, 9573, 1182, 53, 15015, 16, 23, 1802, 13, 6, 9573, 1182, 53, 163, 3506, 2115, 1269, 1215, 1799, 16, 23, 107, 4, 2]
#
# word: m
# word_encoded: [504]
#
#
#
# sentence: this anesthetic 's pathetic , so is this diabetic waffle and this prosthetic arm keeps crushing my hard taco
# tokenized: ['this', 'anesthetic', "'", 's', 'pathetic', ',', 'so', 'is', 'this', 'diabetic', 'waffle', 'and', 'this', 'prosthetic', 'arm', 'keeps', 'crushing', 'my', 'hard', 'taco']
# ids: [0, 33, 26391, 30754, 20, 4506, 7, 39, 17, 33, 49488, 22930, 13, 33, 2169, 423, 30754, 3162, 1786, 18811, 23, 301, 10357, 2]
#
# word: '
# word_encoded: [69]
#
#
#
# sentence: this anesthetic 's pathetic , so is this diabetic waffle and this prosthetic arm keeps crushing my hard taco
# tokenized: ['this', 'anesthetic', "'", 's', 'pathetic', ',', 'so', 'is', 'this', 'diabetic', 'waffle', 'and', 'this', 'prosthetic', 'arm', 'keeps', 'crushing', 'my', 'hard', 'taco']
# ids: [0, 33, 26391, 30754, 20, 4506, 7, 39, 17, 33, 49488, 22930, 13, 33, 2169, 423, 30754, 3162, 1786, 18811, 23, 301, 10357, 2]
#
# word: s
# word_encoded: [256]
#
#
#
# sentence: @USER @USER I 'm diabetic and super sad it 's not on the sugar free ones as well :sad_but_relieved_face: HTTPURL
# tokenized: ['@USER', '@USER', 'I', "'", 'm', 'diabetic', 'and', 'super', 'sad', 'it', "'", 's', 'not', 'on', 'the', 'sugar', 'free', 'ones', 'as', 'well', ':', 'sad_but_relieved_face', ':', 'HTTPURL']
# ids: [0, 5, 5, 8, 40, 49488, 13, 1068, 573, 18, 20, 46, 24, 6, 4057, 336, 784, 52, 182, 5090, 10, 2]
#
# word: '
# word_encoded: [69]
#
#
#
# sentence: @USER @USER I 'm diabetic and super sad it 's not on the sugar free ones as well :sad_but_relieved_face: HTTPURL
# tokenized: ['@USER', '@USER', 'I', "'", 'm', 'diabetic', 'and', 'super', 'sad', 'it', "'", 's', 'not', 'on', 'the', 'sugar', 'free', 'ones', 'as', 'well', ':', 'sad_but_relieved_face', ':', 'HTTPURL']
# ids: [0, 5, 5, 8, 40, 49488, 13, 1068, 573, 18, 20, 46, 24, 6, 4057, 336, 784, 52, 182, 5090, 10, 2]
#
# word: m
# word_encoded: [504]
#
#
#
# sentence: @USER @USER I 'm diabetic and super sad it 's not on the sugar free ones as well :sad_but_relieved_face: HTTPURL
# tokenized: ['@USER', '@USER', 'I', "'", 'm', 'diabetic', 'and', 'super', 'sad', 'it', "'", 's', 'not', 'on', 'the', 'sugar', 'free', 'ones', 'as', 'well', ':', 'sad_but_relieved_face', ':', 'HTTPURL']
# ids: [0, 5, 5, 8, 40, 49488, 13, 1068, 573, 18, 20, 46, 24, 6, 4057, 336, 784, 52, 182, 5090, 10, 2]
#
# word: '
# word_encoded: [69]
#
#
#
# sentence: @USER @USER I 'm diabetic and super sad it 's not on the sugar free ones as well :sad_but_relieved_face: HTTPURL
# tokenized: ['@USER', '@USER', 'I', "'", 'm', 'diabetic', 'and', 'super', 'sad', 'it', "'", 's', 'not', 'on', 'the', 'sugar', 'free', 'ones', 'as', 'well', ':', 'sad_but_relieved_face', ':', 'HTTPURL']
# ids: [0, 5, 5, 8, 40, 49488, 13, 1068, 573, 18, 20, 46, 24, 6, 4057, 336, 784, 52, 182, 5090, 10, 2]
#
# word: s
# word_encoded: [256]
#
#
#
# sentence: @USER @USER I 'm diabetic and super sad it 's not on the sugar free ones as well :sad_but_relieved_face: HTTPURL
# tokenized: ['@USER', '@USER', 'I', "'", 'm', 'diabetic', 'and', 'super', 'sad', 'it', "'", 's', 'not', 'on', 'the', 'sugar', 'free', 'ones', 'as', 'well', ':', 'sad_but_relieved_face', ':', 'HTTPURL']
# ids: [0, 5, 5, 8, 40, 49488, 13, 1068, 573, 18, 20, 46, 24, 6, 4057, 336, 784, 52, 182, 5090, 10, 2]
#
# word: :
# word_encoded: [22]
#
#
#
# sentence: @USER @USER I 'm diabetic and super sad it 's not on the sugar free ones as well :sad_but_relieved_face: HTTPURL
# tokenized: ['@USER', '@USER', 'I', "'", 'm', 'diabetic', 'and', 'super', 'sad', 'it', "'", 's', 'not', 'on', 'the', 'sugar', 'free', 'ones', 'as', 'well', ':', 'sad_but_relieved_face', ':', 'HTTPURL']
# ids: [0, 5, 5, 8, 40, 49488, 13, 1068, 573, 18, 20, 46, 24, 6, 4057, 336, 784, 52, 182, 5090, 10, 2]
#
# word: sad_but_relieved_face
# word_encoded: [3, 12540, 2426, 17062, 363]
#
#
#
# sentence: @USER @USER I 'm diabetic and super sad it 's not on the sugar free ones as well :sad_but_relieved_face: HTTPURL
# tokenized: ['@USER', '@USER', 'I', "'", 'm', 'diabetic', 'and', 'super', 'sad', 'it', "'", 's', 'not', 'on', 'the', 'sugar', 'free', 'ones', 'as', 'well', ':', 'sad_but_relieved_face', ':', 'HTTPURL']
# ids: [0, 5, 5, 8, 40, 49488, 13, 1068, 573, 18, 20, 46, 24, 6, 4057, 336, 784, 52, 182, 5090, 10, 2]
#
# word: :
# word_encoded: [22]
#
#
#
# sentence: It 's a damn shame she 's giving herself heart disease , type 2 diabetes and a whole bunch of different cancers .
# tokenized: ['It', "'", 's', 'a', 'damn', 'shame', 'she', "'", 's', 'giving', 'herself', 'heart', 'disease', ',', 'type', '2', 'diabetes', 'and', 'a', 'whole', 'bunch', 'of', 'different', 'cancers', '.']
# ids: [0, 76, 20, 11, 500, 2536, 97, 20, 876, 3339, 398, 5110, 7, 1011, 119, 15015, 13, 11, 434, 2297, 15, 589, 47230, 4, 2]
#
# word: '
# word_encoded: [69]
#
#
#
# sentence: It 's a damn shame she 's giving herself heart disease , type 2 diabetes and a whole bunch of different cancers .
# tokenized: ['It', "'", 's', 'a', 'damn', 'shame', 'she', "'", 's', 'giving', 'herself', 'heart', 'disease', ',', 'type', '2', 'diabetes', 'and', 'a', 'whole', 'bunch', 'of', 'different', 'cancers', '.']
# ids: [0, 76, 20, 11, 500, 2536, 97, 20, 876, 3339, 398, 5110, 7, 1011, 119, 15015, 13, 11, 434, 2297, 15, 589, 47230, 4, 2]
#
# word: s
# word_encoded: [256]
#
#
#
# sentence: It 's a damn shame she 's giving herself heart disease , type 2 diabetes and a whole bunch of different cancers .
# tokenized: ['It', "'", 's', 'a', 'damn', 'shame', 'she', "'", 's', 'giving', 'herself', 'heart', 'disease', ',', 'type', '2', 'diabetes', 'and', 'a', 'whole', 'bunch', 'of', 'different', 'cancers', '.']
# ids: [0, 76, 20, 11, 500, 2536, 97, 20, 876, 3339, 398, 5110, 7, 1011, 119, 15015, 13, 11, 434, 2297, 15, 589, 47230, 4, 2]
#
# word: '
# word_encoded: [69]
#
#
#
# sentence: It 's a damn shame she 's giving herself heart disease , type 2 diabetes and a whole bunch of different cancers .
# tokenized: ['It', "'", 's', 'a', 'damn', 'shame', 'she', "'", 's', 'giving', 'herself', 'heart', 'disease', ',', 'type', '2', 'diabetes', 'and', 'a', 'whole', 'bunch', 'of', 'different', 'cancers', '.']
# ids: [0, 76, 20, 11, 500, 2536, 97, 20, 876, 3339, 398, 5110, 7, 1011, 119, 15015, 13, 11, 434, 2297, 15, 589, 47230, 4, 2]
#
# word: s
# word_encoded: [256]
#
#
#
# sentence: Cool I have to do a finger prick / mouth swab to check if my dad 's kidney failure is genetic :) if it is , I 'm gonna be SO raging at him for giving birth to me
# tokenized: ['Cool', 'I', 'have', 'to', 'do', 'a', 'finger', 'prick', '/', 'mouth', 'swab', 'to', 'check', 'if', 'my', 'dad', "'", 's', 'kidney', 'failure', 'is', 'genetic', ':)', 'if', 'it', 'is', ',', 'I', "'", 'm', 'gonna', 'be', 'SO', 'raging', 'at', 'him', 'for', 'giving', 'birth', 'to', 'me']
# ids: [0, 3323, 8, 36, 9, 32, 11, 3709, 11637, 75, 1247, 19985, 475, 9, 560, 65, 23, 688, 20, 21449, 4475, 17, 19892, 150, 65, 18, 17, 7, 8, 40, 194, 31, 519, 21407, 35, 124, 19, 876, 3451, 9, 27, 2]
#
# word: '
# word_encoded: [69]
#
#
#
# sentence: Cool I have to do a finger prick / mouth swab to check if my dad 's kidney failure is genetic :) if it is , I 'm gonna be SO raging at him for giving birth to me
# tokenized: ['Cool', 'I', 'have', 'to', 'do', 'a', 'finger', 'prick', '/', 'mouth', 'swab', 'to', 'check', 'if', 'my', 'dad', "'", 's', 'kidney', 'failure', 'is', 'genetic', ':)', 'if', 'it', 'is', ',', 'I', "'", 'm', 'gonna', 'be', 'SO', 'raging', 'at', 'him', 'for', 'giving', 'birth', 'to', 'me']
# ids: [0, 3323, 8, 36, 9, 32, 11, 3709, 11637, 75, 1247, 19985, 475, 9, 560, 65, 23, 688, 20, 21449, 4475, 17, 19892, 150, 65, 18, 17, 7, 8, 40, 194, 31, 519, 21407, 35, 124, 19, 876, 3451, 9, 27, 2]
#
# word: s
# word_encoded: [256]
#
#
#
# sentence: Cool I have to do a finger prick / mouth swab to check if my dad 's kidney failure is genetic :) if it is , I 'm gonna be SO raging at him for giving birth to me
# tokenized: ['Cool', 'I', 'have', 'to', 'do', 'a', 'finger', 'prick', '/', 'mouth', 'swab', 'to', 'check', 'if', 'my', 'dad', "'", 's', 'kidney', 'failure', 'is', 'genetic', ':)', 'if', 'it', 'is', ',', 'I', "'", 'm', 'gonna', 'be', 'SO', 'raging', 'at', 'him', 'for', 'giving', 'birth', 'to', 'me']
# ids: [0, 3323, 8, 36, 9, 32, 11, 3709, 11637, 75, 1247, 19985, 475, 9, 560, 65, 23, 688, 20, 21449, 4475, 17, 19892, 150, 65, 18, 17, 7, 8, 40, 194, 31, 519, 21407, 35, 124, 19, 876, 3451, 9, 27, 2]
#
# word: '
# word_encoded: [69]
#
#
#
# sentence: Cool I have to do a finger prick / mouth swab to check if my dad 's kidney failure is genetic :) if it is , I 'm gonna be SO raging at him for giving birth to me
# tokenized: ['Cool', 'I', 'have', 'to', 'do', 'a', 'finger', 'prick', '/', 'mouth', 'swab', 'to', 'check', 'if', 'my', 'dad', "'", 's', 'kidney', 'failure', 'is', 'genetic', ':)', 'if', 'it', 'is', ',', 'I', "'", 'm', 'gonna', 'be', 'SO', 'raging', 'at', 'him', 'for', 'giving', 'birth', 'to', 'me']
# ids: [0, 3323, 8, 36, 9, 32, 11, 3709, 11637, 75, 1247, 19985, 475, 9, 560, 65, 23, 688, 20, 21449, 4475, 17, 19892, 150, 65, 18, 17, 7, 8, 40, 194, 31, 519, 21407, 35, 124, 19, 876, 3451, 9, 27, 2]
#
# word: m
# word_encoded: [504]
#
#
#
# sentence: @USER @USER Yes you do I 'm a weirdly shaped from the weight loss thx to diabetes Everyone on this damn planet deserves love support care and worshipping for their natural lives Look deep inside the oneself see what makes you happy then use it to shine no matter what you are made of
# tokenized: ['@USER', '@USER', 'Yes', 'you', 'do', 'I', "'", 'm', 'a', 'weirdly', 'shaped', 'from', 'the', 'weight', 'loss', 'thx', 'to', 'diabetes', 'Everyone', 'on', 'this', 'damn', 'planet', 'deserves', 'love', 'support', 'care', 'and', 'worshipping', 'for', 'their', 'natural', 'lives', 'Look', 'deep', 'inside', 'the', 'oneself', 'see', 'what', 'makes', 'you', 'happy', 'then', 'use', 'it', 'to', 'shine', 'no', 'matter', 'what', 'you', 'are', 'made', 'of']
# ids: [0, 5, 5, 699, 14, 32, 8, 40, 11, 36118, 10197, 53, 6, 1916, 2116, 7684, 9, 15015, 1262, 24, 33, 500, 3615, 2852, 71, 564, 356, 13, 56762, 19, 130, 2642, 1299, 1170, 1567, 1154, 6, 32520, 95, 66, 321, 14, 225, 133, 310, 18, 9, 4854, 80, 704, 66, 14, 41, 214, 15, 2]
#
# word: '
# word_encoded: [69]
#
#
#
# sentence: @USER @USER Yes you do I 'm a weirdly shaped from the weight loss thx to diabetes Everyone on this damn planet deserves love support care and worshipping for their natural lives Look deep inside the oneself see what makes you happy then use it to shine no matter what you are made of
# tokenized: ['@USER', '@USER', 'Yes', 'you', 'do', 'I', "'", 'm', 'a', 'weirdly', 'shaped', 'from', 'the', 'weight', 'loss', 'thx', 'to', 'diabetes', 'Everyone', 'on', 'this', 'damn', 'planet', 'deserves', 'love', 'support', 'care', 'and', 'worshipping', 'for', 'their', 'natural', 'lives', 'Look', 'deep', 'inside', 'the', 'oneself', 'see', 'what', 'makes', 'you', 'happy', 'then', 'use', 'it', 'to', 'shine', 'no', 'matter', 'what', 'you', 'are', 'made', 'of']
# ids: [0, 5, 5, 699, 14, 32, 8, 40, 11, 36118, 10197, 53, 6, 1916, 2116, 7684, 9, 15015, 1262, 24, 33, 500, 3615, 2852, 71, 564, 356, 13, 56762, 19, 130, 2642, 1299, 1170, 1567, 1154, 6, 32520, 95, 66, 321, 14, 225, 133, 310, 18, 9, 4854, 80, 704, 66, 14, 41, 214, 15, 2]
#
# word: m
# word_encoded: [504]
# sentence: I 'd live on bread and water before I 'd let my horrible neighbour die for lack of insulin .
# tokenized: ['I', "'", 'd', 'live', 'on', 'bread', 'and', 'water', 'before', 'I', "'", 'd', 'let', 'my', 'horrible', 'neighbour', 'die', 'for', 'lack', 'of', 'insulin', '.']
# ids: [0, 8, 224, 294, 24, 3878, 13, 791, 213, 8, 224, 197, 23, 2638, 19115, 668, 19, 2717, 15, 46884, 4, 2]
#
# word: '
# word_encoded: [69]
#
#
#
# sentence: I 'd live on bread and water before I 'd let my horrible neighbour die for lack of insulin .
# tokenized: ['I', "'", 'd', 'live', 'on', 'bread', 'and', 'water', 'before', 'I', "'", 'd', 'let', 'my', 'horrible', 'neighbour', 'die', 'for', 'lack', 'of', 'insulin', '.']
# ids: [0, 8, 224, 294, 24, 3878, 13, 791, 213, 8, 224, 197, 23, 2638, 19115, 668, 19, 2717, 15, 46884, 4, 2]
#
# word: d
# word_encoded: [614]
#
#
#
# sentence: I 'd live on bread and water before I 'd let my horrible neighbour die for lack of insulin .
# tokenized: ['I', "'", 'd', 'live', 'on', 'bread', 'and', 'water', 'before', 'I', "'", 'd', 'let', 'my', 'horrible', 'neighbour', 'die', 'for', 'lack', 'of', 'insulin', '.']
# ids: [0, 8, 224, 294, 24, 3878, 13, 791, 213, 8, 224, 197, 23, 2638, 19115, 668, 19, 2717, 15, 46884, 4, 2]
#
# word: '
# word_encoded: [69]
#
#
#
# sentence: I 'd live on bread and water before I 'd let my horrible neighbour die for lack of insulin .
# tokenized: ['I', "'", 'd', 'live', 'on', 'bread', 'and', 'water', 'before', 'I', "'", 'd', 'let', 'my', 'horrible', 'neighbour', 'die', 'for', 'lack', 'of', 'insulin', '.']
# ids: [0, 8, 224, 294, 24, 3878, 13, 791, 213, 8, 224, 197, 23, 2638, 19115, 668, 19, 2717, 15, 46884, 4, 2]
#
# word: d
# word_encoded: [614]
#
#
#
# sentence: I hope to avoid all diabetes related health issues but if I had to choose one I 'd take glockoma .
# tokenized: ['I', 'hope', 'to', 'avoid', 'all', 'diabetes', 'related', 'health', 'issues', 'but', 'if', 'I', 'had', 'to', 'choose', 'one', 'I', "'", 'd', 'take', 'glockoma', '.']
# ids: [0, 8, 240, 9, 3092, 48, 15015, 2857, 1256, 1494, 42, 65, 8, 118, 9, 1698, 63, 8, 224, 169, 630, 14154, 11542, 4, 2]
#
# word: '
# word_encoded: [69]
#
#
#
# sentence: I hope to avoid all diabetes related health issues but if I had to choose one I 'd take glockoma .
# tokenized: ['I', 'hope', 'to', 'avoid', 'all', 'diabetes', 'related', 'health', 'issues', 'but', 'if', 'I', 'had', 'to', 'choose', 'one', 'I', "'", 'd', 'take', 'glockoma', '.']
# ids: [0, 8, 240, 9, 3092, 48, 15015, 2857, 1256, 1494, 42, 65, 8, 118, 9, 1698, 63, 8, 224, 169, 630, 14154, 11542, 4, 2]
#
# word: d
# word_encoded: [614]
#
#
#
# sentence: Hats off to Halle Berry I know ppl are focused on her age alone but she also has diabetes which I 've seen first hand is n't easy w / pregnancy
# tokenized: ['Hats', 'off', 'to', 'Halle', 'Berry', 'I', 'know', 'ppl', 'are', 'focused', 'on', 'her', 'age', 'alone', 'but', 'she', 'also', 'has', 'diabetes', 'which', 'I', "'", 've', 'seen', 'first', 'hand', 'is', "n't", 'easy', 'w', '/', 'pregnancy']
# ids: [0, 25516, 142, 9, 39897, 14574, 8, 68, 762, 41, 5469, 24, 92, 843, 789, 42, 97, 237, 90, 15015, 248, 8, 120, 408, 160, 803, 17, 29, 981, 293, 75, 10869, 2]
#
# word: '
# word_encoded: [69]
#
#
#
# sentence: Hats off to Halle Berry I know ppl are focused on her age alone but she also has diabetes which I 've seen first hand is n't easy w / pregnancy
# tokenized: ['Hats', 'off', 'to', 'Halle', 'Berry', 'I', 'know', 'ppl', 'are', 'focused', 'on', 'her', 'age', 'alone', 'but', 'she', 'also', 'has', 'diabetes', 'which', 'I', "'", 've', 'seen', 'first', 'hand', 'is', "n't", 'easy', 'w', '/', 'pregnancy']
# ids: [0, 25516, 142, 9, 39897, 14574, 8, 68, 762, 41, 5469, 24, 92, 843, 789, 42, 97, 237, 90, 15015, 248, 8, 120, 408, 160, 803, 17, 29, 981, 293, 75, 10869, 2]
#
# word: ve
# word_encoded: [1988]
#
#
#
# sentence: Alzheimer 's and insulin problems later in life are two biggest reasons I stay away from diet soda .
# tokenized: ['Alzheimer', "'", 's', 'and', 'insulin', 'problems', 'later', 'in', 'life', 'are', 'two', 'biggest', 'reasons', 'I', 'stay', 'away', 'from', 'diet', 'soda', '.']
# ids: [0, 24382, 20, 13, 46884, 1191, 606, 16, 138, 41, 255, 1345, 2407, 8, 468, 300, 53, 4549, 11471, 4, 2]
#
# word: '
# word_encoded: [69]
#
#
#
# sentence: Alzheimer 's and insulin problems later in life are two biggest reasons I stay away from diet soda .
# tokenized: ['Alzheimer', "'", 's', 'and', 'insulin', 'problems', 'later', 'in', 'life', 'are', 'two', 'biggest', 'reasons', 'I', 'stay', 'away', 'from', 'diet', 'soda', '.']
# ids: [0, 24382, 20, 13, 46884, 1191, 606, 16, 138, 41, 255, 1345, 2407, 8, 468, 300, 53, 4549, 11471, 4, 2]
#
# word: s
# word_encoded: [256]
#
#
#
# sentence: It 's all joke til your sick at 40 years old with high blood pressure and diabetes ..
# tokenized: ['It', "'", 's', 'all', 'joke', 'til', 'your', 'sick', 'at', '40', 'years', 'old', 'with', 'high', 'blood', 'pressure', 'and', 'diabetes', '..']
# ...
# ids: [0, 49079, 22, 716, 3751, 1656, 44499, 7, 1916, 3124, 8, 40, 45, 116, 6185, 136, 77, 30, 528, 208, 2009, 15, 1256, 1494, 43, 15015, 13, 60109, 11699, 15906, 13, 46884, 11604, 208, 13, 13076, 89, 1916, 149, 8, 56, 4686, 4, 2]
#
# word: '
# word_encoded: [69]
#
#
#
# sentence: cw : body dysphoria , weight gain I 'm just really struggling right now with food ; fear of health issues like diabetes and metabolic syndrome and insulin resistance ; and gaining more weight than I can manage .
# tokenized: ['cw', ':', 'body', 'dysphoria', ',', 'weight', 'gain', 'I', "'", 'm', 'just', 'really', 'struggling', 'right', 'now', 'with', 'food', ';', 'fear', 'of', 'health', 'issues', 'like', 'diabetes', 'and', 'metabolic', 'syndrome', 'and', 'insulin', 'resistance', ';', 'and', 'gaining', 'more', 'weight', 'than', 'I', 'can', 'manage', '.']
# ids: [0, 49079, 22, 716, 3751, 1656, 44499, 7, 1916, 3124, 8, 40, 45, 116, 6185, 136, 77, 30, 528, 208, 2009, 15, 1256, 1494, 43, 15015, 13, 60109, 11699, 15906, 13, 46884, 11604, 208, 13, 13076, 89, 1916, 149, 8, 56, 4686, 4, 2]
#
# word: m
# word_encoded: [504]
#
#
#
# sentence: Mad mfs got AIDS in ATL every time I go to the doctors they wanna take my blood to test for diabetes etc .. FOHWTBS I think they giving ppl dat shit :person_facepalming: :medium_skin_tone: ‍ :female_sign: ️they wo n't get me HTTPURL
# tokenized: ['Mad', 'mfs', 'got', 'AIDS', 'in', 'ATL', 'every', 'time', 'I', 'go', 'to', 'the', 'doctors', 'they', 'wanna', 'take', 'my', 'blood', 'to', 'test', 'for', 'diabetes', 'etc', '..', 'FOHWTBS', 'I', 'think', 'they', 'giving', 'ppl', 'dat', 'shit', ':p', 'erson_facepalming', ':', ':', 'medium_skin_tone', ':', '\u200d', ':', 'female_sign', ':', '️they', 'wo', "n't", 'get', 'me', 'HTTPURL']
# ids: [0, 5713, 7560, 100, 16754, 16, 10212, 234, 78, 8, 82, 9, 6, 5861, 59, 229, 169, 23, 1945, 9, 1156, 19, 15015, 1460, 67, 5316, 544, 17321, 3454, 8, 101, 59, 876, 762, 1851, 145, 2541, 1277, 1014, 1585, 3, 59, 9637, 29, 51, 27, 10, 2]
#
# word: :p
# word_encoded: [2011]
#
#
#
# sentence: Mad mfs got AIDS in ATL every time I go to the doctors they wanna take my blood to test for diabetes etc .. FOHWTBS I think they giving ppl dat shit :person_facepalming: :medium_skin_tone: ‍ :female_sign: ️they wo n't get me HTTPURL
# tokenized: ['Mad', 'mfs', 'got', 'AIDS', 'in', 'ATL', 'every', 'time', 'I', 'go', 'to', 'the', 'doctors', 'they', 'wanna', 'take', 'my', 'blood', 'to', 'test', 'for', 'diabetes', 'etc', '..', 'FOHWTBS', 'I', 'think', 'they', 'giving', 'ppl', 'dat', 'shit', ':p', 'erson_facepalming', ':', ':', 'medium_skin_tone', ':', '\u200d', ':', 'female_sign', ':', '️they', 'wo', "n't", 'get', 'me', 'HTTPURL']
# ids: [0, 5713, 7560, 100, 16754, 16, 10212, 234, 78, 8, 82, 9, 6, 5861, 59, 229, 169, 23, 1945, 9, 1156, 19, 15015, 1460, 67, 5316, 544, 17321, 3454, 8, 101, 59, 876, 762, 1851, 145, 2541, 1277, 1014, 1585, 3, 59, 9637, 29, 51, 27, 10, 2]
#
# word: erson_facepalming
# word_encoded: [772, 3303, 524, 63828, 5552]
#
#
#
# sentence: Mad mfs got AIDS in ATL every time I go to the doctors they wanna take my blood to test for diabetes etc .. FOHWTBS I think they giving ppl dat shit :person_facepalming: :medium_skin_tone: ‍ :female_sign: ️they wo n't get me HTTPURL
# tokenized: ['Mad', 'mfs', 'got', 'AIDS', 'in', 'ATL', 'every', 'time', 'I', 'go', 'to', 'the', 'doctors', 'they', 'wanna', 'take', 'my', 'blood', 'to', 'test', 'for', 'diabetes', 'etc', '..', 'FOHWTBS', 'I', 'think', 'they', 'giving', 'ppl', 'dat', 'shit', ':p', 'erson_facepalming', ':', ':', 'medium_skin_tone', ':', '\u200d', ':', 'female_sign', ':', '️they', 'wo', "n't", 'get', 'me', 'HTTPURL']
# ids: [0, 5713, 7560, 100, 16754, 16, 10212, 234, 78, 8, 82, 9, 6, 5861, 59, 229, 169, 23, 1945, 9, 1156, 19, 15015, 1460, 67, 5316, 544, 17321, 3454, 8, 101, 59, 876, 762, 1851, 145, 2541, 1277, 1014, 1585, 3, 59, 9637, 29, 51, 27, 10, 2]
#
# word: :
# word_encoded: [22]
#
#
#
# sentence: Mad mfs got AIDS in ATL every time I go to the doctors they wanna take my blood to test for diabetes etc .. FOHWTBS I think they giving ppl dat shit :person_facepalming: :medium_skin_tone: ‍ :female_sign: ️they wo n't get me HTTPURL
# tokenized: ['Mad', 'mfs', 'got', 'AIDS', 'in', 'ATL', 'every', 'time', 'I', 'go', 'to', 'the', 'doctors', 'they', 'wanna', 'take', 'my', 'blood', 'to', 'test', 'for', 'diabetes', 'etc', '..', 'FOHWTBS', 'I', 'think', 'they', 'giving', 'ppl', 'dat', 'shit', ':p', 'erson_facepalming', ':', ':', 'medium_skin_tone', ':', '\u200d', ':', 'female_sign', ':', '️they', 'wo', "n't", 'get', 'me', 'HTTPURL']
# ids: [0, 5713, 7560, 100, 16754, 16, 10212, 234, 78, 8, 82, 9, 6, 5861, 59, 229, 169, 23, 1945, 9, 1156, 19, 15015, 1460, 67, 5316, 544, 17321, 3454, 8, 101, 59, 876, 762, 1851, 145, 2541, 1277, 1014, 1585, 3, 59, 9637, 29, 51, 27, 10, 2]
#
# word: :
# word_encoded: [22]
#
#
#
# sentence: Mad mfs got AIDS in ATL every time I go to the doctors they wanna take my blood to test for diabetes etc .. FOHWTBS I think they giving ppl dat shit :person_facepalming: :medium_skin_tone: ‍ :female_sign: ️they wo n't get me HTTPURL
# tokenized: ['Mad', 'mfs', 'got', 'AIDS', 'in', 'ATL', 'every', 'time', 'I', 'go', 'to', 'the', 'doctors', 'they', 'wanna', 'take', 'my', 'blood', 'to', 'test', 'for', 'diabetes', 'etc', '..', 'FOHWTBS', 'I', 'think', 'they', 'giving', 'ppl', 'dat', 'shit', ':p', 'erson_facepalming', ':', ':', 'medium_skin_tone', ':', '\u200d', ':', 'female_sign', ':', '️they', 'wo', "n't", 'get', 'me', 'HTTPURL']
# ids: [0, 5713, 7560, 100, 16754, 16, 10212, 234, 78, 8, 82, 9, 6, 5861, 59, 229, 169, 23, 1945, 9, 1156, 19, 15015, 1460, 67, 5316, 544, 17321, 3454, 8, 101, 59, 876, 762, 1851, 145, 2541, 1277, 1014, 1585, 3, 59, 9637, 29, 51, 27, 10, 2]
#
# word: medium_skin_tone
# word_encoded: [43586, 3, 6235]
#
#
#
# sentence: Mad mfs got AIDS in ATL every time I go to the doctors they wanna take my blood to test for diabetes etc .. FOHWTBS I think they giving ppl dat shit :person_facepalming: :medium_skin_tone: ‍ :female_sign: ️they wo n't get me HTTPURL
# tokenized: ['Mad', 'mfs', 'got', 'AIDS', 'in', 'ATL', 'every', 'time', 'I', 'go', 'to', 'the', 'doctors', 'they', 'wanna', 'take', 'my', 'blood', 'to', 'test', 'for', 'diabetes', 'etc', '..', 'FOHWTBS', 'I', 'think', 'they', 'giving', 'ppl', 'dat', 'shit', ':p', 'erson_facepalming', ':', ':', 'medium_skin_tone', ':', '\u200d', ':', 'female_sign', ':', '️they', 'wo', "n't", 'get', 'me', 'HTTPURL']
# ids: [0, 5713, 7560, 100, 16754, 16, 10212, 234, 78, 8, 82, 9, 6, 5861, 59, 229, 169, 23, 1945, 9, 1156, 19, 15015, 1460, 67, 5316, 544, 17321, 3454, 8, 101, 59, 876, 762, 1851, 145, 2541, 1277, 1014, 1585, 3, 59, 9637, 29, 51, 27, 10, 2]
#
# word: :
# word_encoded: [22]
#
#
#
# sentence: Mad mfs got AIDS in ATL every time I go to the doctors they wanna take my blood to test for diabetes etc .. FOHWTBS I think they giving ppl dat shit :person_facepalming: :medium_skin_tone: ‍ :female_sign: ️they wo n't get me HTTPURL
# tokenized: ['Mad', 'mfs', 'got', 'AIDS', 'in', 'ATL', 'every', 'time', 'I', 'go', 'to', 'the', 'doctors', 'they', 'wanna', 'take', 'my', 'blood', 'to', 'test', 'for', 'diabetes', 'etc', '..', 'FOHWTBS', 'I', 'think', 'they', 'giving', 'ppl', 'dat', 'shit', ':p', 'erson_facepalming', ':', ':', 'medium_skin_tone', ':', '\u200d', ':', 'female_sign', ':', '️they', 'wo', "n't", 'get', 'me', 'HTTPURL']
# ids: [0, 5713, 7560, 100, 16754, 16, 10212, 234, 78, 8, 82, 9, 6, 5861, 59, 229, 169, 23, 1945, 9, 1156, 19, 15015, 1460, 67, 5316, 544, 17321, 3454, 8, 101, 59, 876, 762, 1851, 145, 2541, 1277, 1014, 1585, 3, 59, 9637, 29, 51, 27, 10, 2]
#
# word: :
# word_encoded: [22]
#
#
#
# sentence: Mad mfs got AIDS in ATL every time I go to the doctors they wanna take my blood to test for diabetes etc .. FOHWTBS I think they giving ppl dat shit :person_facepalming: :medium_skin_tone: ‍ :female_sign: ️they wo n't get me HTTPURL
# tokenized: ['Mad', 'mfs', 'got', 'AIDS', 'in', 'ATL', 'every', 'time', 'I', 'go', 'to', 'the', 'doctors', 'they', 'wanna', 'take', 'my', 'blood', 'to', 'test', 'for', 'diabetes', 'etc', '..', 'FOHWTBS', 'I', 'think', 'they', 'giving', 'ppl', 'dat', 'shit', ':p', 'erson_facepalming', ':', ':', 'medium_skin_tone', ':', '\u200d', ':', 'female_sign', ':', '️they', 'wo', "n't", 'get', 'me', 'HTTPURL']
# ids: [0, 5713, 7560, 100, 16754, 16, 10212, 234, 78, 8, 82, 9, 6, 5861, 59, 229, 169, 23, 1945, 9, 1156, 19, 15015, 1460, 67, 5316, 544, 17321, 3454, 8, 101, 59, 876, 762, 1851, 145, 2541, 1277, 1014, 1585, 3, 59, 9637, 29, 51, 27, 10, 2]
#
# word: female_sign
# word_encoded: [18029, 3, 1144]
#
#
#
# sentence: Mad mfs got AIDS in ATL every time I go to the doctors they wanna take my blood to test for diabetes etc .. FOHWTBS I think they giving ppl dat shit :person_facepalming: :medium_skin_tone: ‍ :female_sign: ️they wo n't get me HTTPURL
# tokenized: ['Mad', 'mfs', 'got', 'AIDS', 'in', 'ATL', 'every', 'time', 'I', 'go', 'to', 'the', 'doctors', 'they', 'wanna', 'take', 'my', 'blood', 'to', 'test', 'for', 'diabetes', 'etc', '..', 'FOHWTBS', 'I', 'think', 'they', 'giving', 'ppl', 'dat', 'shit', ':p', 'erson_facepalming', ':', ':', 'medium_skin_tone', ':', '\u200d', ':', 'female_sign', ':', '️they', 'wo', "n't", 'get', 'me', 'HTTPURL']
# ids: [0, 5713, 7560, 100, 16754, 16, 10212, 234, 78, 8, 82, 9, 6, 5861, 59, 229, 169, 23, 1945, 9, 1156, 19, 15015, 1460, 67, 5316, 544, 17321, 3454, 8, 101, 59, 876, 762, 1851, 145, 2541, 1277, 1014, 1585, 3, 59, 9637, 29, 51, 27, 10, 2]
#
# word: :
# word_encoded: [22]
# sentence: i know there 's a lot of misinformation about diabetes out there , so if you 're ever curious , i do n't mind talking about it :smiling_face_with_smiling_eyes:
# tokenized: ['i', 'know', 'there', "'", 's', 'a', 'lot', 'of', 'misinformation', 'about', 'diabetes', 'out', 'there', ',', 'so', 'if', 'you', "'", 're', 'ever', 'curious', ',', 'i', 'do', "n't", 'mind', 'talking', 'about', 'it', ':', 'smiling_face_with_smiling_eyes', ':']
# ids: [0, 37, 68, 99, 20, 11, 318, 15, 33351, 62, 15015, 50, 99, 7, 39, 65, 14, 81, 179, 5002, 7, 37, 32, 29, 410, 401, 62, 18, 518, 2]
#
# word: '
# word_encoded: [69]
#
#
#
# sentence: i know there 's a lot of misinformation about diabetes out there , so if you 're ever curious , i do n't mind talking about it :smiling_face_with_smiling_eyes:
# tokenized: ['i', 'know', 'there', "'", 's', 'a', 'lot', 'of', 'misinformation', 'about', 'diabetes', 'out', 'there', ',', 'so', 'if', 'you', "'", 're', 'ever', 'curious', ',', 'i', 'do', "n't", 'mind', 'talking', 'about', 'it', ':', 'smiling_face_with_smiling_eyes', ':']
# ids: [0, 37, 68, 99, 20, 11, 318, 15, 33351, 62, 15015, 50, 99, 7, 39, 65, 14, 81, 179, 5002, 7, 37, 32, 29, 410, 401, 62, 18, 518, 2]
#
# word: s
# word_encoded: [256]
#
#
#
# sentence: i know there 's a lot of misinformation about diabetes out there , so if you 're ever curious , i do n't mind talking about it :smiling_face_with_smiling_eyes:
# tokenized: ['i', 'know', 'there', "'", 's', 'a', 'lot', 'of', 'misinformation', 'about', 'diabetes', 'out', 'there', ',', 'so', 'if', 'you', "'", 're', 'ever', 'curious', ',', 'i', 'do', "n't", 'mind', 'talking', 'about', 'it', ':', 'smiling_face_with_smiling_eyes', ':']
# ids: [0, 37, 68, 99, 20, 11, 318, 15, 33351, 62, 15015, 50, 99, 7, 39, 65, 14, 81, 179, 5002, 7, 37, 32, 29, 410, 401, 62, 18, 518, 2]
#
# word: '
# word_encoded: [69]
#
#
#
# sentence: i know there 's a lot of misinformation about diabetes out there , so if you 're ever curious , i do n't mind talking about it :smiling_face_with_smiling_eyes:
# tokenized: ['i', 'know', 'there', "'", 's', 'a', 'lot', 'of', 'misinformation', 'about', 'diabetes', 'out', 'there', ',', 'so', 'if', 'you', "'", 're', 'ever', 'curious', ',', 'i', 'do', "n't", 'mind', 'talking', 'about', 'it', ':', 'smiling_face_with_smiling_eyes', ':']
# ids: [0, 37, 68, 99, 20, 11, 318, 15, 33351, 62, 15015, 50, 99, 7, 39, 65, 14, 81, 179, 5002, 7, 37, 32, 29, 410, 401, 62, 18, 518, 2]
#
# word: re
# word_encoded: [1330]
#
#
#
# sentence: i know there 's a lot of misinformation about diabetes out there , so if you 're ever curious , i do n't mind talking about it :smiling_face_with_smiling_eyes:
# tokenized: ['i', 'know', 'there', "'", 's', 'a', 'lot', 'of', 'misinformation', 'about', 'diabetes', 'out', 'there', ',', 'so', 'if', 'you', "'", 're', 'ever', 'curious', ',', 'i', 'do', "n't", 'mind', 'talking', 'about', 'it', ':', 'smiling_face_with_smiling_eyes', ':']
# ids: [0, 37, 68, 99, 20, 11, 318, 15, 33351, 62, 15015, 50, 99, 7, 39, 65, 14, 81, 179, 5002, 7, 37, 32, 29, 410, 401, 62, 18, 518, 2]
#
# word: :
# word_encoded: [22]
#
#
#
# sentence: i know there 's a lot of misinformation about diabetes out there , so if you 're ever curious , i do n't mind talking about it :smiling_face_with_smiling_eyes:
# tokenized: ['i', 'know', 'there', "'", 's', 'a', 'lot', 'of', 'misinformation', 'about', 'diabetes', 'out', 'there', ',', 'so', 'if', 'you', "'", 're', 'ever', 'curious', ',', 'i', 'do', "n't", 'mind', 'talking', 'about', 'it', ':', 'smiling_face_with_smiling_eyes', ':']
# ids: [0, 37, 68, 99, 20, 11, 318, 15, 33351, 62, 15015, 50, 99, 7, 39, 65, 14, 81, 179, 5002, 7, 37, 32, 29, 410, 401, 62, 18, 518, 2]
#
# word: smiling_face_with_smiling_eyes
# word_encoded: [3, 3, 3, 671]
#
#
#
# sentence: i know there 's a lot of misinformation about diabetes out there , so if you 're ever curious , i do n't mind talking about it :smiling_face_with_smiling_eyes:
# tokenized: ['i', 'know', 'there', "'", 's', 'a', 'lot', 'of', 'misinformation', 'about', 'diabetes', 'out', 'there', ',', 'so', 'if', 'you', "'", 're', 'ever', 'curious', ',', 'i', 'do', "n't", 'mind', 'talking', 'about', 'it', ':', 'smiling_face_with_smiling_eyes', ':']
# ids: [0, 37, 68, 99, 20, 11, 318, 15, 33351, 62, 15015, 50, 99, 7, 39, 65, 14, 81, 179, 5002, 7, 37, 32, 29, 410, 401, 62, 18, 518, 2]
#
# word: :
# word_encoded: [22]
#                                                   text  \
# 468  To help change the way the NHS treats #type2di...
# 602  Okay but on the real , I almost lost my life T...
# 388  @USER Mental Health , keep my diabetes in chec...
# 607  I 'm a 58 yr old man , with diabetes and a str...
# 767  Update ( since I made a surprising number of y...
# ..                                                 ...
# 415  @USER Oh I am so sorry :( My father also has m...
# 200  @USER Well its meant to be good for you but I ...
# 710  Mad mfs got AIDS in ATL every time I go to the...
# 361  @USER Bet he would have got more if he was a m...
# 754  i know there 's a lot of misinformation about ...
#
#                                              tokenized  \
# 468  [To, help, change, the, way, the, NHS, treats,...
# 602  [Okay, but, on, the, real, ,, I, almost, lost,...
# 388  [@USER, Mental, Health, ,, keep, my, diabetes,...
# 607  [I, ', m, a, 58, yr, old, man, ,, with, diabet...
# 767  [Update, (, since, I, made, a, surprising, num...
# ..                                                 ...
# 415  [@USER, Oh, I, am, so, sorry, :(, My, father, ...
# 200  [@USER, Well, its, meant, to, be, good, for, y...
# 710  [Mad, mfs, got, AIDS, in, ATL, every, time, I,...
# 361  [@USER, Bet, he, would, have, got, more, if, h...
# 754  [i, know, there, ', s, a, lot, of, misinformat...
#
#                                            predictions
# 468  [O, O, O, O, O, O, I-C, I-C, I-C, O, O, O, O, ...
# 602  [O, O, O, O, O, O, O, O, I-E, I-E, I-E, O, O, ...
# 388  [O, O, O, O, O, O, I-C, O, O, O, O, O, O, O, O...
# 607  [O, O, O, O, O, O, O, O, O, O, I-C, O, O, O, I...
# 767  [O, O, O, O, O, O, O, O, O, O, I-E, O, O, O, O...
# ..                                                 ...
# 415  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 200  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 710  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 361  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 754  [O, O, O, O, O, O, O, O, O, O, I-C, O, O, O, O...
#
# [100 rows x 3 columns]

# %%
cause_effect_DF.to_csv("/home/adrian/Downloads/cause_effect_preds_part_{}.csv".format(i), sep=";")

# %% [markdown]
# ### Read some examples

# %%
aaa = pd.read_csv("/home/adrian/Downloads/cause_effect_preds_part_0.csv", sep=";")
aaa.head()
# Out:
#    Unnamed: 0                                               text  \
# 0         468  To help change the way the NHS treats #type2di...
# 1         602  Okay but on the real , I almost lost my life T...
# 2         388  @USER Mental Health , keep my diabetes in chec...
# 3         607  I 'm a 58 yr old man , with diabetes and a str...
# 4         767  Update ( since I made a surprising number of y...
#
#                                            tokenized  \
# 0  ['To', 'help', 'change', 'the', 'way', 'the', ...
# 1  ['Okay', 'but', 'on', 'the', 'real', ',', 'I',...
# 2  ['@USER', 'Mental', 'Health', ',', 'keep', 'my...
# 3  ['I', "'", 'm', 'a', '58', 'yr', 'old', 'man',...
# 4  ['Update', '(', 'since', 'I', 'made', 'a', 'su...
#
#                                          predictions
# 0  ['O', 'O', 'O', 'O', 'O', 'O', 'I-C', 'I-C', '...
# 1  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-E'...
# 2  ['O', 'O', 'O', 'O', 'O', 'O', 'I-C', 'O', 'O'...
# 3  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...
# 4  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...

# %%
bbb = pd.read_csv("/home/adrian/Downloads/cause_effect_predictions_part_0.csv", sep=";")
bbb.head()

for i,row in bbb[0:50].iterrows():
    print(row["text"])
    print(row["tokenized"])
    print(row["predictions"])
    print()
# Out:
# Hypo in the Boticelli rooms at the @USER and one of the staff members offered me a sweet cause he knew my pain #type1diabetes
# ['Hypo', 'in', 'the', 'Boticelli', 'rooms', 'at', 'the', '@USER', 'and', 'one', 'of', 'the', 'staff', 'members', 'offered', 'me', 'a', 'sweet', 'cause', 'he', 'knew', 'my', 'pain', '#type1diabetes']
# ['I-E', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-C', 'I-C']
#
# Mmm I love bacon and hardly any carbs for breakfast :raising_hands: :light_skin_tone: :smiling_face_with_sunglasses: #breakfastoftheday #diabetes #diabetic ...
# ['Mmm', 'I', 'love', 'bacon', 'and', 'hardly', 'any', 'carbs', 'for', 'breakfast', ':raising_hands:', ':light_skin_tone:', ':smiling_face_with_sunglasses:', '#breakfastoftheday', '#diabetes', '#diabetic', '...']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# @USER "" That does n't mean we should take care of the person who sits at home , eats poorly and gets diabetes .
# ['@USER', '""', 'That', 'does', "n't", 'mean', 'we', 'should', 'take', 'care', 'of', 'the', 'person', 'who', 'sits', 'at', 'home', ',', 'eats', 'poorly', 'and', 'gets', 'diabetes', '.']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-C', 'I-C', 'O', 'O', 'I-C', 'O']
#
# @USER Dear lord that rack is sepeeated by type 1 and type 2 diabetes .
# ['@USER', 'Dear', 'lord', 'that', 'rack', 'is', 'sepeeated', 'by', 'type', '1', 'and', 'type', '2', 'diabetes', '.']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-C', 'I-C', 'I-C', 'I-C', 'I-C', 'I-C', 'O']
#
# He goes into this story about how he beat diabetes and lost 36lbs from being "" on the vinegar ""
# ['He', 'goes', 'into', 'this', 'story', 'about', 'how', 'he', 'beat', 'diabetes', 'and', 'lost', '36lbs', 'from', 'being', '""', 'on', 'the', 'vinegar', '""']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-C', 'O', 'I-E', 'I-E', 'O', 'O', 'I-C', 'I-C', 'I-C', 'I-C', 'I-C']
#
# @USER Having to cut back on carbs , my eye exam found evidence of diabetes damage and I 'm between insurance so no proper doctor yet :unamused_face:
# ['@USER', 'Having', 'to', 'cut', 'back', 'on', 'carbs', ',', 'my', 'eye', 'exam', 'found', 'evidence', 'of', 'diabetes', 'damage', 'and', 'I', "'m", 'between', 'insurance', 'so', 'no', 'proper', 'doctor', 'yet', ':unamused_face:']
# ['O', 'O', 'O', 'I-E', 'I-E', 'I-E', 'I-E', 'O', 'O', 'I-E', 'I-E', 'I-E', 'I-E', 'I-E', 'I-E', 'I-E', 'O', 'O', 'O', 'I-C', 'I-C', 'O', 'O', 'O', 'O', 'O', 'O']
#
# Now I need a whole bottle of wine , the gentleman just told me that his wife has a bad case of diabetes and has had a double leg amputation :loudly_crying_face: :loudly_crying_face:
# ['Now', 'I', 'need', 'a', 'whole', 'bottle', 'of', 'wine', ',', 'the', 'gentleman', 'just', 'told', 'me', 'that', 'his', 'wife', 'has', 'a', 'bad', 'case', 'of', 'diabetes', 'and', 'has', 'had', 'a', 'double', 'leg', 'amputation', ':loudly_crying_face:', ':loudly_crying_face:']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-C', 'O', 'O', 'O', 'O', 'O', 'I-E', 'I-E', 'O', 'O']
#
# Went to the eye doctor today and I still have 20/20 vision and no damage to my eyes from my type 1 diabetes !
# ['Went', 'to', 'the', 'eye', 'doctor', 'today', 'and', 'I', 'still', 'have', '20/20', 'vision', 'and', 'no', 'damage', 'to', 'my', 'eyes', 'from', 'my', 'type', '1', 'diabetes', '!']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-E', 'I-E', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-C', 'I-C', 'I-C', 'O']
#
# En Vogue thank you ever so much for singing the National Athem at my charity event to KO diabetes Love you ladies
# ['En', 'Vogue', 'thank', 'you', 'ever', 'so', 'much', 'for', 'singing', 'the', 'National', 'Athem', 'at', 'my', 'charity', 'event', 'to', 'KO', 'diabetes', 'Love', 'you', 'ladies']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# He said "" oh , you can go at least an hour w / out insulin before getting sick .
# ['He', 'said', '""', 'oh', ',', 'you', 'can', 'go', 'at', 'least', 'an', 'hour', 'w', '/', 'out', 'insulin', 'before', 'getting', 'sick', '.']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-C', 'O', 'O', 'I-E', 'O']
#
# @USER the thing to remember is you breath in co2 + sugar + energy and breathe out o2 + glucose + nitrogen .
# ['@USER', 'the', 'thing', 'to', 'remember', 'is', 'you', 'breath', 'in', 'co2', '+', 'sugar', '+', 'energy', 'and', 'breathe', 'out', 'o2', '+', 'glucose', '+', 'nitrogen', '.']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# @USER Sugar licking lips might produce insulin inside you so I dont think that 's a good idea .
# ['@USER', 'Sugar', 'licking', 'lips', 'might', 'produce', 'insulin', 'inside', 'you', 'so', 'I', 'dont', 'think', 'that', "'s", 'a', 'good', 'idea', '.']
# ['O', 'O', 'O', 'O', 'O', 'I-E', 'I-E', 'I-E', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# @USER I bet something will either explode , cause someone to have diabetes or get shot with some type of torturous nerf dart .
# ['@USER', 'I', 'bet', 'something', 'will', 'either', 'explode', ',', 'cause', 'someone', 'to', 'have', 'diabetes', 'or', 'get', 'shot', 'with', 'some', 'type', 'of', 'torturous', 'nerf', 'dart', '.']
# ['O', 'O', 'O', 'O', 'O', 'O', 'I-E', 'O', 'O', 'O', 'O', 'O', 'I-C', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# That mate is a "" football coach "" for kids going bald at 28 with diabetes from his piss poor diet of spaghetti , butter and cheese .
# ['That', 'mate', 'is', 'a', '""', 'football', 'coach', '""', 'for', 'kids', 'going', 'bald', 'at', '28', 'with', 'diabetes', 'from', 'his', 'piss', 'poor', 'diet', 'of', 'spaghetti', ',', 'butter', 'and', 'cheese', '.']
# ['O', 'O', 'O', 'O', 'O', 'I-E', 'I-E', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-C', 'O', 'O', 'O', 'I-C', 'I-C', 'I-C', 'I-C', 'O', 'O', 'O', 'I-C', 'O']
#
# @USER @USER I 'm in a family of 3 ; one has diabetes , one has MS and one has Aspergers .
# ['@USER', '@USER', 'I', "'m", 'in', 'a', 'family', 'of', '3', ';', 'one', 'has', 'diabetes', ',', 'one', 'has', 'MS', 'and', 'one', 'has', 'Aspergers', '.']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-C', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# I 'd live on bread and water before I 'd let my horrible neighbour die for lack of insulin .
# ['I', "'d", 'live', 'on', 'bread', 'and', 'water', 'before', 'I', "'d", 'let', 'my', 'horrible', 'neighbour', 'die', 'for', 'lack', 'of', 'insulin', '.']
# ['O', 'O', 'I-E', 'I-E', 'I-E', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-E', 'I-E', 'I-E', 'O', 'I-C', 'I-C', 'I-C', 'O']
#
# @USER Like Rae said , ' just cos she 's got diabetes , does n't make her a good person '
# ['@USER', 'Like', 'Rae', 'said', ',', "'", 'just', 'cos', 'she', "'s", 'got', 'diabetes', ',', 'does', "n't", 'make', 'her', 'a', 'good', 'person', "'"]
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-C', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# Hats off to Halle Berry I know ppl are focused on her age alone but she also has diabetes which I 've seen first hand is n't easy w / pregnancy
# ['Hats', 'off', 'to', 'Halle', 'Berry', 'I', 'know', 'ppl', 'are', 'focused', 'on', 'her', 'age', 'alone', 'but', 'she', 'also', 'has', 'diabetes', 'which', 'I', "'ve", 'seen', 'first', 'hand', 'is', "n't", 'easy', 'w', '/', 'pregnancy']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-C', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-C']
#
# Basically i always take pills to regulate my high insuline and i can't eat anything else after that , but i did n't care and ate chocolate
# ['Basically', 'i', 'always', 'take', 'pills', 'to', 'regulate', 'my', 'high', 'insuline', 'and', 'i', "can't", 'eat', 'anything', 'else', 'after', 'that', ',', 'but', 'i', 'did', "n't", 'care', 'and', 'ate', 'chocolate']
# ['O', 'O', 'O', 'O', 'O', 'O', 'I-E', 'I-E', 'I-E', 'I-E', 'O', 'O', 'I-E', 'I-E', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# Ok I understand because insulin is literally 500 $ like chill out we just need this to survive HTTPURL
# ['Ok', 'I', 'understand', 'because', 'insulin', 'is', 'literally', '500', '$', 'like', 'chill', 'out', 'we', 'just', 'need', 'this', 'to', 'survive', 'HTTPURL']
# ['O', 'O', 'O', 'O', 'I-C', 'I-C', 'I-C', 'I-C', 'I-C', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# w / the problems our country is having with obesity / diabetes , it should be considered child abuse for giving your kids shit like pixie stix
# ['w', '/', 'the', 'problems', 'our', 'country', 'is', 'having', 'with', 'obesity', '/', 'diabetes', ',', 'it', 'should', 'be', 'considered', 'child', 'abuse', 'for', 'giving', 'your', 'kids', 'shit', 'like', 'pixie', 'stix']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-C', 'I-C', 'I-C', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# There 's a 99 % chance my mom will be out of a job and without medical care for diabetes
# ['There', "'s", 'a', '99', '%', 'chance', 'my', 'mom', 'will', 'be', 'out', 'of', 'a', 'job', 'and', 'without', 'medical', 'care', 'for', 'diabetes']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-E', 'I-E', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-C']
#
# Polonsky reminds us of top predictors of not doing self monitoring of blood glucose : Avoidance ( because it makes me feel bad ...
# ['Polonsky', 'reminds', 'us', 'of', 'top', 'predictors', 'of', 'not', 'doing', 'self', 'monitoring', 'of', 'blood', 'glucose', ':', 'Avoidance', '(', 'because', 'it', 'makes', 'me', 'feel', 'bad', '...']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-E', 'O', 'I-C', 'I-C', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# @USER @USER @USER Person : "" Doc , I do n't think my advanced diabetes is a huge problem because I feel ok today .
# ['@USER', '@USER', '@USER', 'Person', ':', '""', 'Doc', ',', 'I', 'do', "n't", 'think', 'my', 'advanced', 'diabetes', 'is', 'a', 'huge', 'problem', 'because', 'I', 'feel', 'ok', 'today', '.']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-C', 'I-C', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# Sad news , I score high on diabetic 1 test so doctor wants to take blood & result is in 5th July .
# ['Sad', 'news', ',', 'I', 'score', 'high', 'on', 'diabetic', '1', 'test', 'so', 'doctor', 'wants', 'to', 'take', 'blood', '&', 'result', 'is', 'in', '5th', 'July', '.']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-C', 'I-C', 'I-C', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# Man the only reason Im seriously taking care of myself with this insulin shit is bc I want to give my son a chance !
# ['Man', 'the', 'only', 'reason', 'Im', 'seriously', 'taking', 'care', 'of', 'myself', 'with', 'this', 'insulin', 'shit', 'is', 'bc', 'I', 'want', 'to', 'give', 'my', 'son', 'a', 'chance', '!']
# ['O', 'O', 'O', 'O', 'O', 'O', 'I-E', 'I-E', 'I-E', 'I-E', 'O', 'O', 'I-C', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# I had to get my blood drawn todayyyy ugh they tested me for anemia , thyroid issues , and for diabetes ...
# ['I', 'had', 'to', 'get', 'my', 'blood', 'drawn', 'todayyyy', 'ugh', 'they', 'tested', 'me', 'for', 'anemia', ',', 'thyroid', 'issues', ',', 'and', 'for', 'diabetes', '...']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-C', 'O']
#
# Love my #iPhone it takes awesome pictures of our lovely grandchild :smiling_face_with_heart-eyes: and of course manage my BG #type1 #diabetes HTTPURL
# ['Love', 'my', '#iPhone', 'it', 'takes', 'awesome', 'pictures', 'of', 'our', 'lovely', 'grandchild', ':smiling_face_with_heart-eyes:', 'and', 'of', 'course', 'manage', 'my', 'BG', '#type1', '#diabetes', 'HTTPURL']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-C', 'I-C', 'I-C', 'O']
#
# @USER Sadly needing to cool down so I did n't end up in hospital from diabetes complications again had to take priority .
# ['@USER', 'Sadly', 'needing', 'to', 'cool', 'down', 'so', 'I', 'did', "n't", 'end', 'up', 'in', 'hospital', 'from', 'diabetes', 'complications', 'again', 'had', 'to', 'take', 'priority', '.']
# ['O', 'O', 'O', 'O', 'I-C', 'I-C', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-E', 'O', 'I-C', 'I-C', 'O', 'O', 'O', 'O', 'O', 'O']
#
# @USER thats awful was told at the hospital by diabetic nurses hot temperatures in warm weather / rooms can have an impact on blood sugar readings
# ['@USER', 'thats', 'awful', 'was', 'told', 'at', 'the', 'hospital', 'by', 'diabetic', 'nurses', 'hot', 'temperatures', 'in', 'warm', 'weather', '/', 'rooms', 'can', 'have', 'an', 'impact', 'on', 'blood', 'sugar', 'readings']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-C', 'I-C', 'I-C', 'I-C', 'I-C', 'I-C', 'I-C', 'O', 'O', 'O', 'O', 'O', 'I-E', 'I-E', 'I-E', 'I-E', 'I-E']
#
# I hate when people run around saying that carbs cause diabetes when it 's really excess fat that inhibits the natural production of insulin
# ['I', 'hate', 'when', 'people', 'run', 'around', 'saying', 'that', 'carbs', 'cause', 'diabetes', 'when', 'it', "'s", 'really', 'excess', 'fat', 'that', 'inhibits', 'the', 'natural', 'production', 'of', 'insulin']
# ['O', 'I-E', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-E', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-E', 'I-E', 'I-E']
#
# Every day talking shit about skinny girls :unamused_face: at least my health in good condition and I ain't got diabetes but w / e do ur ting HTTPURL
# ['Every', 'day', 'talking', 'shit', 'about', 'skinny', 'girls', ':unamused_face:', 'at', 'least', 'my', 'health', 'in', 'good', 'condition', 'and', 'I', "ain't", 'got', 'diabetes', 'but', 'w', '/', 'e', 'do', 'ur', 'ting', 'HTTPURL']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-C', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# Ive seen many testimonys of people who is diabetic and just feel alot better when they drink alkalized water
# ['Ive', 'seen', 'many', 'testimonys', 'of', 'people', 'who', 'is', 'diabetic', 'and', 'just', 'feel', 'alot', 'better', 'when', 'they', 'drink', 'alkalized', 'water']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-C', 'O', 'O', 'I-E', 'I-E', 'I-E', 'O', 'O', 'I-C', 'I-C', 'I-C']
#
# Heart disease , diabetes and cancer are # 1 killers in america for a reason HTTPURL
# ['Heart', 'disease', ',', 'diabetes', 'and', 'cancer', 'are', '#', '1', 'killers', 'in', 'america', 'for', 'a', 'reason', 'HTTPURL']
# ['O', 'O', 'O', 'I-C', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# I feel like I 've had autonomic neuropathy since before the diabetes so now I know what to look forward to .
# ['I', 'feel', 'like', 'I', "'ve", 'had', 'autonomic', 'neuropathy', 'since', 'before', 'the', 'diabetes', 'so', 'now', 'I', 'know', 'what', 'to', 'look', 'forward', 'to', '.']
# ['O', 'O', 'O', 'O', 'O', 'O', 'I-E', 'I-E', 'O', 'O', 'O', 'I-C', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# @USER @USER between PCOS and being borderline diabetic I hope it just makes me somewhat normal lol .
# ['@USER', '@USER', 'between', 'PCOS', 'and', 'being', 'borderline', 'diabetic', 'I', 'hope', 'it', 'just', 'makes', 'me', 'somewhat', 'normal', 'lol', '.']
# ['O', 'O', 'O', 'I-C', 'O', 'O', 'I-C', 'I-C', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# Miscarried helping so easy to fall into in #diabetes care #CWDFFL2017 "" I had 2 learn a new language w my teen daughter clear parameters .
# ['Miscarried', 'helping', 'so', 'easy', 'to', 'fall', 'into', 'in', '#diabetes', 'care', '#CWDFFL2017', '""', 'I', 'had', '2', 'learn', 'a', 'new', 'language', 'w', 'my', 'teen', 'daughter', 'clear', 'parameters', '.']
# ['I-E', 'I-E', 'O', 'O', 'O', 'O', 'O', 'O', 'I-C', 'I-C', 'O', 'O', 'O', 'O', 'O', 'I-E', 'I-E', 'I-E', 'I-E', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# He is suffering from diabetes and every year claims lakhs to get treated in Jibdal 's but here he is enjoying Ice cream .
# ['He', 'is', 'suffering', 'from', 'diabetes', 'and', 'every', 'year', 'claims', 'lakhs', 'to', 'get', 'treated', 'in', 'Jibdal', "'s", 'but', 'here', 'he', 'is', 'enjoying', 'Ice', 'cream', '.']
# ['O', 'O', 'I-E', 'O', 'I-C', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-C', 'I-C', 'O']
#
# i 'm watching a movie and there 's a girl who is sick and need insulin and they 're giving her sugar lmaooooooooooo totally the opposite to do
# ['i', "'m", 'watching', 'a', 'movie', 'and', 'there', "'s", 'a', 'girl', 'who', 'is', 'sick', 'and', 'need', 'insulin', 'and', 'they', "'re", 'giving', 'her', 'sugar', 'lmaooooooooooo', 'totally', 'the', 'opposite', 'to', 'do']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-C', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# @USER my kids have type 2 diabetes , and it 's because of bad parenting , by mark olsen
# ['@USER', 'my', 'kids', 'have', 'type', '2', 'diabetes', ',', 'and', 'it', "'s", 'because', 'of', 'bad', 'parenting', ',', 'by', 'mark', 'olsen']
# ['O', 'O', 'O', 'O', 'I-E', 'I-E', 'I-E', 'O', 'O', 'O', 'O', 'O', 'O', 'I-C', 'I-C', 'O', 'O', 'O', 'O']
#
# @USER I have diabetes know how you feel could be hundreds of things that are preexisting when u sign up for a new plan
# ['@USER', 'I', 'have', 'diabetes', 'know', 'how', 'you', 'feel', 'could', 'be', 'hundreds', 'of', 'things', 'that', 'are', 'preexisting', 'when', 'u', 'sign', 'up', 'for', 'a', 'new', 'plan']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# A5 ) I hope my boy is a confident 20yr old , living his life , not held back by diabetes , head held high , unashamed , proud to be himself #OzDOC
# ['A5', ')', 'I', 'hope', 'my', 'boy', 'is', 'a', 'confident', '20yr', 'old', ',', 'living', 'his', 'life', ',', 'not', 'held', 'back', 'by', 'diabetes', ',', 'head', 'held', 'high', ',', 'unashamed', ',', 'proud', 'to', 'be', 'himself', '#OzDOC']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-C', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# Er'eyone having antihistamine injections at kappa made me feel soo comfortable doing my insulin :syringe:
# ["Er'eyone", 'having', 'antihistamine', 'injections', 'at', 'kappa', 'made', 'me', 'feel', 'soo', 'comfortable', 'doing', 'my', 'insulin', ':syringe:']
# ['O', 'O', 'I-E', 'I-E', 'O', 'O', 'O', 'O', 'I-E', 'I-E', 'I-E', 'I-E', 'I-E', 'I-E', 'I-E']
#
# Had to do my glucose test n get a big ass shot in my arm .
# ['Had', 'to', 'do', 'my', 'glucose', 'test', 'n', 'get', 'a', 'big', 'ass', 'shot', 'in', 'my', 'arm', '.']
# ['O', 'O', 'O', 'O', 'I-C', 'I-C', 'O', 'O', 'O', 'O', 'O', 'I-E', 'I-E', 'I-E', 'I-E', 'O']
#
# After some thought , I agree that blood glucose management should be my focus .
# ['After', 'some', 'thought', ',', 'I', 'agree', 'that', 'blood', 'glucose', 'management', 'should', 'be', 'my', 'focus', '.']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-E', 'I-E', 'I-E', 'I-E', 'I-E', 'I-E', 'I-E', 'O']
#
# I 'm just going to assume that other owners with diabetic pets get to experience this too .
# ['I', "'m", 'just', 'going', 'to', 'assume', 'that', 'other', 'owners', 'with', 'diabetic', 'pets', 'get', 'to', 'experience', 'this', 'too', '.']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-C', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# @USER As a diabetic let me just point out that not eating any or some of the bun makes a cheeseburger a filling cheap and fairly healthy meal .
# ['@USER', 'As', 'a', 'diabetic', 'let', 'me', 'just', 'point', 'out', 'that', 'not', 'eating', 'any', 'or', 'some', 'of', 'the', 'bun', 'makes', 'a', 'cheeseburger', 'a', 'filling', 'cheap', 'and', 'fairly', 'healthy', 'meal', '.']
# ['O', 'O', 'O', 'I-C', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# @USER thats why cops dont carry epipens , nitro , or insulin but carry narcan .
# ['@USER', 'thats', 'why', 'cops', 'dont', 'carry', 'epipens', ',', 'nitro', ',', 'or', 'insulin', 'but', 'carry', 'narcan', '.']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# My doctor just told me she think I got diabetes and I feel like I got diagnosed with cancer or something :loudly_crying_face:
# ['My', 'doctor', 'just', 'told', 'me', 'she', 'think', 'I', 'got', 'diabetes', 'and', 'I', 'feel', 'like', 'I', 'got', 'diagnosed', 'with', 'cancer', 'or', 'something', ':loudly_crying_face:']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'I-C', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
# #dianeabbott yet again inspires as a potential Home Sec , what is it now a migraine , diabetes ...
# ['#dianeabbott', 'yet', 'again', 'inspires', 'as', 'a', 'potential', 'Home', 'Sec', ',', 'what', 'is', 'it', 'now', 'a', 'migraine', ',', 'diabetes', '...']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']

# %%
for tokens, predicts in zip(df_causal.tokenized, predictions):
    print("\n")
    for token, predic in zip(tokens, predicts):
        print(token, predic)
# Out:
# @USER O
# I O
# could O
# really O
# use O
# help O
# my O
# mom O
# has O
# Parkinsons O
# disease O
# and O
# dementia O
# and O
# diabetes I-C
# she O
# just O
# suffered O
# a O
# long O
# term O
# stroke O
# and O
# my O
# grandma O
# has O
# Lamonia O
# bad O
# i O
# can't I-C
# afford I-C
# thier I-C
# medicine I-C
# we O
# do O
# n't O
# have O
# no O
# food O
# either O
# please O
# anything O
# helps O
# on O
# behalf O
# of O
# them O
# anything O
# helps O
# $ O
# IIKINGGPOPPII O
#
#
# So O
# now O
# that O
# my O
# grandpa O
# has O
# diabetes I-C
# we O
# are O
# buying O
# him O
# all O
# his O
# medications O
# & O
# I O
# ' O
# m O
# just O
# so O
# in O
# shock O
# and O
# disappointed O
# how O
# much O
# it O
# costs O
# . O
#
#
# @USER O
# @USER O
# He O
# could O
# also O
# slip O
# into O
# diabetic I-C
# ketoacidosis I-C
# which O
# brings O
# on O
# tremors O
# and O
# even O
# rage O
# also O
# potentially O
# death O
# . O
#
#
# I O
# hate I-E
# hormones I-E
# : O
# face_with_steam_from_nose O
# : O
# #pms O
# #type1diabetes O
# #hormones O
# #justgoaway O
# HTTPURL O
#
#
# Turns O
# out O
# he O
# had O
# COPD O
# , O
# that O
# plus O
# his O
# diabetes I-C
# caused O
# him O
# to O
# have O
# a O
# cardiac I-E
# arrest I-E
# . O
#
#
# Woke O
# up O
# with O
# dry I-E
# mouth I-E
# earlier O
# so O
# I O
# ' O
# ll O
# be O
# worrying I-E
# myself I-E
# fucking I-E
# sick I-E
# that O
# I O
# have O
# diabetes I-C
# for O
# the O
# next O
# week O
# or O
# so O
# . O
#
#
# I O
# AM O
# ABSOLUTELY O
# FUCKING O
# FUMING O
# , O
# my O
# mum O
# is O
# 65 O
# next O
# month O
# , O
# has O
# diabetes I-C
# and O
# works O
# as O
# a O
# medical O
# secretary O
# at O
# a O
# GP O
# surgery O
# , O
# she O
# has O
# finally O
# made O
# the O
# decision O
# to O
# self O
# isolate O
# , O
# has O
# told O
# her O
# manager O
# she O
# will O
# work O
# from O
# home O
# , O
# and O
# THIS O
# BITCH O
# is O
# not O
# making O
# any O
# moves O
# to O
# help O
# her O
# cont O
# ... O
#
#
# @USER O
# @USER O
# My O
# son O
# was O
# diagnosed O
# with O
# type I-C
# 1 I-C
# diabetes I-C
# 2 O
# years O
# ago O
# at O
# age O
# 2 O
# and O
# now O
# my O
# oldest O
# ( O
# 11 O
# years O
# old O
# ) O
# was O
# diagnosed O
# recently O
# with O
# type O
# 1 O
# as O
# well O
# ! O
#
#
# nobody O
# said O
# “ O
# just O
# have O
# normal I-E
# blood I-E
# sugar I-E
# ” O
# when O
# your O
# ass O
# had O
# diabetes I-C
# in O
# hannah O
# montana O
# HTTPURL O
#
#
# @USER O
# What O
# a O
# way O
# to O
# help O
# people O
# who O
# depend I-C
# on I-C
# insulin I-C
# to O
# live O
# , O
# especially O
# during O
# a O
# pandemic O
# . O
#
#
# My O
# Grandpa O
# ( O
# who O
# has O
# Alzheimer O
# ' O
# s O
# ): O
# I O
# do O
# n't O
# have O
# diabetes O
# Gram O
# : O
# yes O
# you O
# do O
# . O
#
#
# got O
# my O
# glucose I-C
# test I-C
# results I-C
# back O
# but O
# i O
# have O
# no O
# fucking O
# idea O
# what O
# they O
# mean O
# : O
# zany_face O
# : O
# i O
# ' O
# ll O
# anxiously O
# wait O
# for O
# my O
# doctor O
# to O
# say O
# something O
# lol O
#
#
# I O
# would O
# love O
# to O
# be O
# an O
# organ O
# donor O
# but O
# I O
# was O
# advised O
# not O
# to O
# because O
# I O
# ' O
# m O
# a O
# diabetic I-C
# and O
# it O
# takes O
# a O
# serious O
# toll O
# on O
# all O
# of O
# my O
# working O
# organs I-E
#
#
# But O
# nah O
# nah O
# fr O
# fr O
# al O
# sick O
# lol O
# .. O
# diabetes I-C
# a O
# disease O
# something O
# .. O
# he O
# ' O
# s O
# so O
# skinnyyyy O
# and O
# frail O
#
#
# @USER O
# My O
# children O
# would O
# they O
# love O
# it O
# but O
# dad O
# is O
# diabetic I-C
# so O
# we O
# rarely O
# get O
# it O
# be O
# lovely O
# for O
# them O
# one O
# likes O
# white O
# the O
# other O
# likes O
# ... O
#
#
# @USER O
# I O
# also O
# have O
# the O
# beetus O
# and O
# that O
# shake O
# is O
# literally O
# 3 O
# 4 O
# days O
# of O
# insulin O
# for O
# me O
#
#
# Your O
# life O
# to O
# laughing O
# to O
# enjoy O
# completely O
# happy O
# even O
# if O
# you O
# have O
# diabetes I-C
# Ensure O
# Diabetes O
# Care O
#
#
# @USER O
# Medicare O
# is O
# driving O
# up I-E
# costs I-E
# and O
# why O
# are O
# you O
# discriminating O
# open O
# against O
# people O
# with O
# type I-C
# 1 I-C
# diabetes I-C
# . O
#
#
# @USER O
# @USER O
# @USER O
# @USER O
# I O
# have O
# type I-C
# 1 I-C
# diabetes I-C
# and O
# I O
# can O
# say O
# that O
# you O
# ' O
# re O
# exaggerating O
# , O
# stop O
# getting O
# sensitive O
# over O
# every O
# letter O
# . O
#
#
# @USER O
# @USER O
# @USER O
# @USER O
# @USER O
# Do O
# n't O
# get O
# excited I-C
# and O
# let O
# your O
# diabetes I-C
# get O
# the O
# best O
# of O
# you O
# big O
# man O
#
#
# i O
# have O
# to O
# go O
# to O
# the O
# diabetes I-C
# doctor I-C
# , O
# he O
# ' O
# s O
# not O
# going O
# to O
# be O
# happy O
# with O
# me O
# especially O
# since O
# i O
# ' O
# ve O
# have O
# n't O
# even O
# attempted O
# to O
# get O
# my O
# sugar I-C
# down I-C
# 1 O
# bit O
# . O
#
#
# @USER O
# lactic O
# fermentation O
# where O
# the O
# cells O
# in O
# my O
# hands I-E
# do I-E
# n't I-E
# have I-E
# enough I-E
# oxygen I-E
# so O
# they O
# break I-C
# down I-C
# glucose I-C
# for O
# cellular I-E
# energy I-E
# , O
# ATP O
# :p O
# erson_getting_massage O
# : O
# ‍ O
# : O
# female_sign O
# : O
# :p O
# erson_getting_massage O
# : O
# ‍ O
# : O
# female_sign O
# : O
#
#
# Literally O
# halfway O
# into O
# injecting O
# my O
# insulin I-C
# and O
# I O
# get O
# the O
# sharpest I-E
# shooting I-E
# pain I-E
# through O
# my O
# thigh O
# because O
# of O
# where O
# I O
# stabbed I-C
# but O
# out O
# of O
# instinct O
# I O
# pressed O
# on O
# to O
# finish O
# the O
# dose O
# and O
# ughhhhhh O
# that O
# huuuuuuuurt O
#
#
# @USER O
# As O
# for O
# diabetes I-C
# , O
# it O
# has O
# something O
# to O
# do O
# with O
# one O
# person O
# losing O
# or O
# missing O
# something O
# or O
# a O
# chance O
# that O
# he O
# could O
# win O
# , O
# longing O
# for O
# things O
# that O
# should O
# have O
# been O
# , O
# but O
# dint O
# , O
# in O
# turn O
# it O
# creates O
# sorrow O
# inside O
# him O
# taking O
# away O
# all O
# the O
# sweetness O
# from O
# his O
# life O
# . O
#
#
# @USER O
# I O
# mean O
# , O
# too O
# much O
# glucose O
# is O
# bad O
# for O
# your O
# body O
# as O
# any O
# high O
# quantities O
# of O
# a O
# single O
# nutrient O
# . O
#
#
# At O
# this O
# stage O
# of O
# my O
# diabetes I-C
# ✻ O
# journey O
# ✻ O
# .. O
# I O
# ' O
# m O
# redrafting O
# the O
# précis O
# of O
# my O
# daily O
# round O
# .. O
# I O
# wince O
# at O
# my O
# early O
# idealism O
# and O
# enthusiasm O
# . O
#
#
# @USER O
# @USER O
# .. O
# take O
# it O
# when O
# they O
# are O
# supposed O
# to O
# because O
# they O
# can't I-C
# afford I-C
# enough I-C
# insulin I-C
# to O
# make O
# it O
# the O
# whole O
# month O
# . O
#
#
# she O
# has O
# type I-C
# 1 I-C
# diabetes I-C
# and O
# she O
# was O
# very O
# sick I-E
# yesterday O
# and O
# then O
# this O
# morning O
# she O
# was O
# literally O
# almost O
# comatose O
# so O
# I O
# had O
# to O
# drive O
# her O
# to O
# the O
# emergency O
# room O
# . O
#
#
# @USER O
# I O
# hope O
# so O
# Abbey O
# do O
# n't O
# want O
# to O
# bore O
# you O
# with O
# my O
# own O
# horror O
# stories O
# or O
# those O
# of O
# my O
# diabetic I-C
# friends O
# re O
# advice O
# it O
# needs O
# to O
# change O
#
#
# My O
# son O
# never O
# this O
# active O
# in O
# the O
# middle O
# of O
# the O
# day O
# , O
# I O
# take O
# that O
# glucose I-C
# test I-C
# now O
# it O
# feel O
# like O
# he O
# bouncing O
# off O
# my O
# stomach O
# walls O
# : O
# upside O
# down_face O
# : O
#
#
# @USER O
# @USER O
# @USER O
# im O
# eagerly O
# waiting O
# for O
# diabetes I-C
# to O
# take I-E
# your I-E
# feet I-E
# too O
# , O
# ill O
# get O
# to O
# it O
# when O
# i O
# get O
# to O
# it O
# , O
# snowflake O
#
#
# I O
# never O
# really O
# post O
# clips O
# but O
# this O
# one O
# is O
# mad O
# funny O
# cause O
# both O
# these O
# kids O
# were O
# in O
# game O
# chat O
# calling O
# me O
# a O
# diabetic O
# fuck O
# . O
#
#
# @USER O
# If O
# you O
# ' O
# re O
# not I-C
# insulin I-C
# resistant I-C
# I O
# do O
# n't O
# think O
# majority O
# of O
# people O
# need O
# to O
# worry O
# about O
# those O
# things O
# . O
#
#
# @USER O
# @USER O
# Well O
# in O
# my O
# primary O
# care O
# trust O
# it O
# ' O
# s O
# 55,000 O
# diabetics I-C
# Not O
# all O
# are O
# insulin I-C
# dependant I-C
# currently O
# but O
# ofcourse O
# that O
# can O
# change O
# with O
# no O
# warning O
# . O
#
#
# @USER O
# Well O
# let O
# me O
# tell O
# you O
# something O
# about O
# diets O
# my O
# mom O
# and O
# dad O
# are O
# dead I-E
# because O
# of O
# diabetes I-C
# I O
# have O
# a O
# twin O
# brother O
# who O
# has O
# diabetes I-C
# . O
#
#
# You O
# bitches O
# with O
# celiulte O
# and O
# back O
# fat O
# at O
# 20 O
# kill O
# me O
# and O
# yourself O
# like O
# bitch O
# do O
# n't O
# worry I-E
# about I-E
# me I-E
# worry I-E
# about O
# not O
# getting O
# diabetes I-C
# fat I-C
# ass O
# . O
#
#
# That O
# ' O
# s O
# like O
# saying O
# , O
# “ O
# I O
# do O
# n't O
# understand O
# how O
# you O
# can O
# have O
# diabetes I-C
# when O
# you O
# have O
# such O
# a O
# great O
# life O
# . O
#
#
# I O
# just O
# want O
# you O
# guys O
# to O
# understand O
# it O
# literally O
# takes O
# LESS O
# THAN O
# $ O
# 10 O
# to O
# make O
# a O
# vial O
# of O
# insulin O
# and O
# prices O
# are O
# marked I-C
# up I-C
# to O
# $ O
# 100 O
# $ O
# 300 O
# . O
#
#
# I O
# just O
# got O
# an O
# email O
# saying O
# my O
# new I-E
# blood I-E
# glucose I-E
# meter I-E
# has O
# been O
# shipped O
# and O
# I O
# got O
# ... O
#
#
# Today O
# is O
# the O
# first O
# day O
# in O
# 10 O
# years O
# that O
# I O
# have O
# gone I-C
# without I-C
# my I-C
# insulin I-C
# pump I-C
# , O
# & O
# it O
# ' O
# s O
# sad O
# to O
# know O
# that O
# the O
# US O
# Healthcare O
# system O
# is O
# HORRIBLE O
# . O
#
#
# As O
# the O
# wife O
# to O
# a O
# Type I-C
# 1 I-C
# diabetic I-C
# and O
# as O
# a O
# mom O
# who O
# had O
# gestational I-C
# diabetes I-C
# , O
# it O
# pains O
# me O
# to O
# know O
# that O
# a O
# disease O
# that O
# can O
# be O
# managed O
# so O
# well O
# with O
# good O
# outcome O
# , O
# has O
# these O
# horrific O
# costs I-E
# for I-E
# medication I-E
# . O
#
#
# Girl O
# , O
# 10 O
# , O
# with O
# Type I-E
# 1 I-E
# diabetes I-E
# dies I-E
# after O
# blood I-E
# sugar I-E
# dropped I-E
# during O
# sleepover O
# HTTPURL O
#
#
# Learned O
# today O
# that O
# processed I-C
# meat I-C
# and O
# dairy O
# are O
# extremely O
# terrible O
# for O
# u O
# and O
# causes O
# cancer O
# and O
# diabetes I-E
# ... O
#
#
# As O
# someone O
# whose O
# grandfather O
# suffered O
# from O
# diabetes I-C
# , O
# I O
# would O
# n't O
# wish O
# the O
# disease O
# on O
# anybody O
# and O
# sincerely O
# wish O
# Nathan O
# Bedford O
# Forrest O
# well O
# and O
# hope O
# he O
# has O
# a O
# speedy O
# recovery O
# . O
#
#
# @USER O
# Having O
# required I-E
# insulin I-E
# since O
# I O
# was O
# 3 O
# , O
# 63 O
# years O
# , O
# my O
# pure O
# disdain O
# for O
# Big O
# Pharma O
# and O
# the O
# Rethuglican O
# Party O
# alliance O
# grows O
# each O
# day O
# . O
#
#
# My O
# daughter O
# is O
# type I-C
# 1 I-C
# diabetic I-C
# and O
# has O
# had O
# excellent O
# NHS O
# care O
# all O
# her O
# lufe O
# . O
#
#
# As O
# somebody O
# who O
# recently O
# lost O
# his O
# job O
# , O
# and O
# has O
# a O
# loved O
# one O
# with O
# diabetes I-C
# , O
# people O
# like O
# @USER O
# look O
# nice O
# to O
# badger O
# but O
# do O
# n't O
# do O
# it O
# . O
#
#
# Last O
# night O
# , O
# my O
# fiancee O
# had O
# to O
# go O
# to O
# the O
# ER O
# to O
# get O
# a O
# tiny O
# vial O
# of O
# insulin O
# because O
# her O
# regular O
# provider O
# suspended O
# her O
# account O
# over O
# a O
# $ O
# 37 O
# balance O
# she O
# was O
# n't O
# even O
# notified O
# of O
# . O
#
#
# I O
# know O
# a O
# large O
# community O
# of O
# people O
# with O
# diabetes O
# bc O
# of O
# the O
# camp O
# for O
# kids O
# with O
# diabetes O
# that O
# I O
# ' O
# m O
# involved O
# in O
# . O
#
#
# But O
# it O
# ' O
# s O
# upset O
# #diabetes I-C
# , O
# caused O
# pain I-E
# , O
# my O
# heart O
# is O
# going O
# berserk O
# ( O
# aortic O
# valve O
# ) O
# and O
# I O
# ' O
# m O
# covered O
# in O
# bruises O
# #MDS O
# . O
#
#
# @USER O
# Normally O
# I O
# ' O
# d O
# be O
# judgy O
# as O
# hell O
# , O
# but O
# if O
# he O
# ' O
# s O
# a O
# diabetic I-C
# , O
# he O
# might O
# have O
# dangerously O
# low I-E
# blood I-E
# sugar I-E
# . O
#
#
# I O
# could O
# understand O
# if O
# it O
# was O
# narcotics I-C
# meds I-C
# but O
# it O
# ' O
# s O
# fucking O
# diabetes I-C
# and O
# blood O
# pressure O
# which O
# is O
# going O
# as O
# I O
# type O
# cause O
# I O
# ' O
# ve O
# already O
# Ubered O
# to O
# the O
# other O
# side O
# of O
# the O
# city O
# for O
# fuck O
# sakes O
# ! O
#
#
# @USER O
# It O
# is O
# a O
# death I-E
# sentence I-E
# to O
# be O
# in O
# the O
# United O
# States O
# and O
# have O
# diabetes I-C
# or O
# multiple O
# scerlosis O
# . O
#
#
# This O
# morning O
# I O
# had O
# a O
# text O
# from O
# the O
# #nhs O
# for O
# a O
# diabetic I-E
# eye I-E
# screening I-E
# appt I-E
# on O
# Friday O
# . O
#
#
# They O
# plotted O
# on O
# the O
# obese I-C
# , O
# diabetic I-C
# , O
# ppl O
# with O
# asthma O
# , O
# etc O
# & O
# that O
# just O
# makes O
# me O
# sick I-E
#
#
# @USER O
# I O
# have O
# had O
# type I-C
# 1 I-C
# diabetes I-C
# for O
# 23 O
# years O
# and O
# the O
# complications O
# were O
# already O
# peeking O
# their O
# head O
# in O
# the O
# door O
# . O
#
#
# His O
# sugar I-C
# has O
# been O
# high O
# and O
# need O
# insulin I-C
# to I-C
# bring I-C
# it I-C
# down I-C
# but O
# do O
# n't O
# have O
# anyone O
# to O
# help O
# us O
# . O
#
#
# There O
# are O
# millions O
# of O
# people O
# with O
# issues O
# like O
# high I-C
# blood I-C
# pressure I-C
# , O
# diabetes I-C
# , O
# and O
# other O
# treatable O
# things O
# that O
# do O
# n't O
# get O
# care O
# bc O
# they O
# do O
# n't O
# have O
# access O
# . O
#
#
# I O
# hope O
# Nick O
# Jonas O
# does O
# n't O
# get O
# the O
# tubing O
# from O
# his O
# insulin I-C
# pump I-C
# caught O
# when O
# he O
# spins O
# around O
# his O
# spinning O
# chair O
# on O
# The O
# Voice O
# . O
#
#
# As O
# a O
# diabetic I-C
# , O
# and O
# 41 O
# years O
# old O
# , O
# J O
# still O
# consider O
# myself O
# to O
# be O
# relatively O
# low I-E
# risk I-E
# . O
#
#
# Jerry O
# took O
# today O
# off O
# so O
# he O
# could O
# drive O
# me O
# to O
# my O
# 3hr I-C
# glucose I-C
# test I-C
# . O
#
#
# @USER O
# It O
# would O
# help O
# if O
# your O
# employees O
# understood O
# that O
# giving O
# non O
# diet I-C
# drinks I-C
# to O
# a O
# diabetic I-C
# , O
# is O
# a O
# serious O
# problem O
# . O
#
#
# @USER O
# As O
# a O
# mom O
# of O
# #T1D I-C
# it O
# ' O
# s O
# shocking O
# how O
# uneducated O
# folks O
# are O
# and O
# more O
# shocking O
# that O
# there O
# is O
# n't O
# #Insulin4all O
# Educate O
# all O
# #insulinequalslife O
#
#
# ( O
# complications O
# of O
# diabetes I-C
# he O
# did O
# not O
# take O
# care O
# of O
# himself O
# ) O
# One O
# additional O
# painful O
# thing O
# is O
# just O
# going O
# about O
# your O
# life O
# / O
# activities O
# and O
# having O
# that O
# sharp O
# plastic O
# poke O
# sneak O
# up O
# on O
# you O
# , O
# out O
# of O
# nowhere O
# . O
#
#
# I O
# had O
# to O
# say O
# it O
# to O
# someone O
# again O
# today O
# : O
# “ O
# #gout O
# is O
# the O
# easy O
# part O
# – O
# it O
# ' O
# s O
# the O
# diabetes I-C
# and O
# heart I-E
# attacks I-E
# you O
# need O
# to O
# worry O
# about O
# ” O
# . O
#
#
# He O
# passed I-E
# away I-E
# in O
# 2014 O
# because O
# he O
# did I-C
# n't I-C
# make I-C
# enough I-C
# money I-C
# to I-C
# purchase I-C
# his I-C
# insulin I-C
# & O
# he O
# hated O
# asking O
# people O
# for O
# money O
# . O
#
#
# This O
# is O
# sad O
# case O
# , O
# diabetes I-C
# can O
# go O
# from O
# bad O
# toe O
# to O
# leg I-E
# amputation I-E
# quicker O
# than O
# anyone O
# . O
#
#
# @USER O
# I O
# honestly O
# hate I-E
# when O
# I O
# tell O
# ppl O
# I O
# ' O
# m O
# diabetic I-C
# then O
# they O
# start O
# educating O
# me O
# as O
# if O
# i O
# did O
# n't O
# have O
# diabetes I-C
# since O
# I O
# was O
# 12 O
# lol O
#
#
# I O
# am O
# living O
# with O
# , O
# #cancer I-E
# , I-E
# #MS I-E
# , I-E
# #RA I-E
# , I-E
# #Fibromyalgia I-E
# , I-E
# #diabetes I-E
# , O
# & O
# #COPD O
# . O
#
#
# “ O
# stabbing O
# pains O
# ” O
# aka O
# diabetic I-C
# neuropathy I-C
# , O
# he O
# will O
# most O
# likely I-E
# never I-E
# feel I-E
# the I-E
# same I-E
# way I-E
# in O
# his O
# hands O
# again O
# ! O
#
#
# I O
# do O
# n't O
# think O
# I O
# ' O
# m O
# a O
# bad O
# person O
# , O
# but O
# I O
# did O
# pee O
# in O
# a O
# diabetic I-C
# guys O
# bird O
# bath O
# once O
# . O
#
#
# He O
# died I-E
# in O
# his O
# sleep O
# , O
# coroner O
# reported O
# " O
# " O
# due O
# to O
# complications I-C
# with I-C
# diabetes I-C
# . O
#
#
# @USER O
# @USER O
# @USER O
# It O
# saddens O
# me O
# to O
# think O
# there O
# are O
# diabetics I-C
# rationing I-C
# their I-C
# insulin I-C
# , O
# forgoing O
# meals O
# as O
# a O
# form O
# of O
# blood I-E
# sugar I-E
# management I-E
# and O
# being O
# made O
# to O
# feel I-E
# guilt I-E
# over O
# their O
# condition O
# . O
#
#
# I O
# was O
# prediabetic O
# all O
# through O
# high O
# school O
# all O
# through O
# the O
# Navy O
# and O
# during O
# my O
# pregnancies O
# with O
# all O
# 4 O
# of O
# my O
# children O
# . O
#
#
# @USER O
# @USER O
# Great O
# idea O
# my O
# elderly O
# , O
# diabetic I-C
# , O
# Parkinson O
# ' O
# s O
# suffering O
# mother O
# in O
# law O
# who O
# lives O
# next O
# door O
# to O
# me O
# is O
# already O
# panicking O
# about O
# what O
# will O
# happen O
# if O
# Mark O
# & O
# I O
# have O
# to O
# self O
# isolate O
# and O
# can't O
# get O
# them O
# supplies O
# . O
#
#
# @USER O
# nah O
# im O
# nkt O
# risking O
# it O
# n O
# my O
# dad O
# comes O
# back O
# tonigjt O
# n O
# he O
# ' O
# ll O
# prolly O
# hug O
# me O
# and O
# hes O
# heavily O
# diabetic I-C
# n O
# not O
# caring O
# abt O
# this O
# shi O
# at O
# all O
# so O
# I O
# HAVE O
# TO O
# CARE O
# FOR O
# THEM O
# BY O
# NOT O
# GETTING O
# IT O
#
#
# @USER O
# @USER O
# I O
# was O
# 9 O
# when O
# you O
# were O
# diagnosed O
# and O
# had O
# been O
# living O
# with O
# type I-C
# 1 I-C
# diabetes I-C
# for O
# 6 O
# years O
# already O
# . O
#
#
# I O
# was O
# watching O
# cheeni O
# Kum O
# and O
# my O
# gf O
# left O
# me O
# saying O
# I O
# am O
# not O
# fit O
# for O
# her O
# I O
# ll O
# make O
# her O
# diabetic I-E
# #funny O
# #sarcasm O
# now O
# I O
# have O
# look O
# for O
# a O
# older O
# woman O
# to O
# understand O
# my O
# sarcasm O
#
#
# It O
# ' O
# s O
# either O
# because O
# I O
# ' O
# m O
# diabetic I-C
# or O
# because O
# I O
# drink O
# a O
# gallon O
# of O
# unsweetened O
# brewed O
# iced O
# tea O
# a O
# day O
# , O
# or O
# a O
# combination O
# of O
# both O
# . O
#
#
# I O
# wish O
# I O
# could O
# remember O
# to O
# look O
# after O
# myself O
# properly O
# I O
# ' O
# m O
# honestly O
# surprised O
# with O
# such I-C
# bad I-C
# mh I-C
# and O
# diabetes I-C
# control I-C
# I O
# ' O
# m O
# still O
# going O
# strong O
#
#
# @USER O
# You O
# do O
# n't O
# have O
# to O
# worry O
# about O
# losing O
# to O
# a O
# diabetic I-C
# if O
# they O
# can't O
# even O
# show O
# up O
# bc O
# have O
# to O
# put O
# all O
# their O
# energy O
# into O
# getting O
# insulin I-C
# so O
# they O
# do O
# n't O
# die I-E
# . O
#
#
# the O
# ONE O
# day O
# I O
# wanted O
# a O
# stress I-E
# free I-E
# day I-E
# : O
# loudly_crying_face O
# : O
# chasing O
# shoplifters O
# , O
# helping O
# a O
# diabetic O
# lady O
# who O
# ' O
# d O
# collapsed O
# from O
# smoking O
# crack O
# n O
# then O
# caught O
# up O
# in O
# a O
# fight O
# in O
# McDonald I-C
# ' O
# s O
# : O
# loudly_crying_face O
# : O
# u O
# can't O
# make O
# this O
# shit O
# up O
# but O
# BEXLEYHEATH O
# till O
# I O
# die O
# luv O
# : O
# star O
# struck O
# : O
#
#
# @USER O
# I O
# ' O
# m O
# not O
# immuno O
# compromised O
# but O
# I O
# ' O
# m O
# obese I-C
# , O
# diabetic I-C
# , O
# with O
# a O
# history O
# upper O
# respiratory O
# issues O
# and O
# the O
# third O
# case O
# in O
# Michigan O
# is O
# in O
# my O
# county O
# . O
#
#
# Because O
# it O
# all O
# gets O
# broken O
# down O
# into O
# glucose O
# :p O
# erson_facepalming O
# : O
# ‍ O
# : O
# male_sign O
# : O
# lol O
#
#
# “ O
# I O
# ' O
# m O
# My O
# NaNa O
# ' O
# s O
# “ O
# sweetie O
# ” O
# , O
# : O
# lollipop O
# : O
# : O
# candy O
# : O
# : O
# chocolate_bar O
# : O
# Ironically O
# she O
# got O
# diabetes I-C
# .. O
# : O
# syringe O
# : O
# : O
# microbe O
# : O
# I O
# hate I-E
# to O
# see O
# her O
# in O
# pain O
# , O
# : O
# face_with_head O
# bandage O
# : O
# : O
# face_with_thermometer O
# : O
# But O
# I O
# know O
# she O
# dying O
# to O
# see O
# me O
# . O
#
#
# @USER O
# You O
# beyond O
# delusional O
# to O
# even O
# think O
# it O
# ' O
# s O
# diabetes O
# other O
# than O
# seeing O
# the O
# good O
# side O
# . O
#
#
# @USER O
# Being O
# a O
# diabetic I-C
# for O
# 30 O
# years O
# now O
# , O
# the O
# woman O
# in O
# cincy O
# saying O
# she O
# needed I-E
# her I-E
# insulin I-E
# cause O
# her O
# blood I-C
# sugar I-C
# was I-C
# dropping I-C
# was I-C
# n't I-C
# diabetic I-C
# . O
#
#
# I O
# ' O
# m O
# still O
# mad O
# the O
# oompaloompa O
# man O
# said O
# insulin I-C
# is I-C
# cheaper I-C
# than O
# water O
# . O
#
#
# @USER O
# @USER O
# @USER O
# Actually O
# there O
# is O
# no O
# sugar O
# in O
# gfuel O
# but O
# I O
# already O
# have O
# diabetes I-C
# , O
# this O
# is O
# sad O
# Alexa O
# , O
# play O
# all O
# the O
# bitches O
# that O
# played O
# me O
#
#
# told O
# him O
# my O
# symptoms O
# , O
# he O
# whipped O
# out O
# his O
# phone O
# , O
# now O
# i O
# have O
# an O
# xray O
# for O
# cancer O
# N O
# a O
# blood I-E
# test I-E
# for O
# diabetes I-C
# ! O
#
#
# 2020 O
# Stacey O
# has O
# an O
# insulin I-E
# pump I-E
# she O
# just O
# bedazzled O
# it O
# , O
# it O
# ' O
# s O
# very O
# good O
#
#
# diabetes I-C
# is O
# a O
# big O
# issue O
# w O
# SW O
# diets O
# , O
# and O
# it O
# cleans I-E
# your I-E
# blood I-E
# so O
# quickly O
# that O
# anyone O
# I O
# give O
# it O
# to O
# is O
# hooked O
# . O
#
#
# So O
# because O
# of O
# my O
# type I-C
# 1 I-C
# diabetes I-C
# I O
# ' O
# ve O
# to O
# socially I-E
# distance I-E
# as O
# much O
# as O
# possible O
# for O
# twelve O
# weeks O
# from O
# this O
# weekend O
# . O
#
#
# i O
# ' O
# m O
# not O
# supposed O
# to O
# eat O
# because O
# i O
# ' O
# m O
# taking O
# a O
# glucose I-C
# test I-C
# tomorrow O
# & O
# i O
# fkn O
# hate I-E
# it O
# : O
# face_with_rolling_eyes O
# : O
#
#
# @USER O
# So O
# I O
# asked O
# my O
# mom O
# the O
# same O
# question O
# because O
# in O
# our O
# family I-C
# we O
# have O
# a O
# very O
# active O
# " O
# " O
# history O
# of O
# diabetes I-C
# . O
#
#
# @USER O
# It O
# seriously O
# takes O
# a O
# lot O
# of O
# nerve O
# to O
# blatantly O
# not O
# take O
# care O
# of O
# your O
# diabetes I-C
# and O
# then O
# throw O
# a O
# never O
# ending O
# pity O
# party O
# for O
# yourself O
# when O
# you O
# ' O
# re O
# supposed O
# to O
# be O
# announcing O
# baseball O
# . O
#
#
# @USER O
# @USER O
# I O
# ' O
# m O
# in O
# constant I-E
# worry I-E
# over O
# how O
# I O
# ' O
# ll O
# get I-C
# insulin I-C
# and O
# test I-E
# strips I-E
# . O
#
#
# Obese I-C
# Mexican I-C
# families I-C
# be O
# like O
# : O
# “ O
# It O
# ' O
# s O
# too O
# bad O
# we O
# all O
# get O
# diabetes I-C
# / O
# arthritis O
# / O
# high I-C
# blood I-C
# pressure I-C
# . O
#
#
# " O
# " O
# I O
# wanna O
# help O
# people O
# and O
# impact I-E
# the I-E
# world I-E
# " O
# " O
# Not O
# gonna O
# happen O
# with O
# liver I-C
# failure I-C
# or O
# diabetes I-C
# before O
# you O
# ' O
# re O
# 40 O
# . O
#
#
# This O
# is O
# a O
# good O
# reminder O
# to O
# make I-E
# myself I-E
# work I-E
# on O
# my O
# booklette O
# about O
# insulin O
# boring O
# but O
# life O
# saving O
# . O

# %% [markdown]
# ## Check performances

# %%
##### DATA TO LOAD ######
from ast import literal_eval

dataPath = "data/cause_effect_sentences_with_IO_tags.csv"

data = pd.read_csv(dataPath, sep=";", converters={"tokenized":literal_eval, "bio_tags":literal_eval})
data = data[(data["Cause"].notnull()) & (data["Effect"].notnull())].sample(n=200)

print(data.shape)

data.head()
# Out:
# (200, 7)
#                                                sentence Intent  \
# 1201  I forgot to change my pump this morning and I ...    NaN
# 2007  I got prescribed contrave by my doctor and its...  mC;mE
# 2331  @USER I ' m sure those who can't afford their ...    NaN
# 1394  I look at it like this , all that sugar leads ...     mE
# 2284  She is 8 she went blind last summer bc of diab...    NaN
#
#                            Cause                                  Effect  \
# 1201    forgot to change my pump                        high blood sugar
# 2007          contrave;metformin  increased my metabolism;shed 20 pounds
# 2331  can't afford their insulin                               ration it
# 1394                       sugar          diabetes;obesity;dental issues
# 2284                    diabetes                                   blind
#
#       Causal association                                          tokenized  \
# 1201                 1.0  [I, forgot, to, change, my, pump, this, mornin...
# 2007                 1.0  [I, got, prescribed, contrave, by, my, doctor,...
# 2331                 1.0  [@USER, I, ', m, sure, those, who, can't, affo...
# 1394                 1.0  [I, look, at, it, like, this, ,, all, that, su...
# 2284                 1.0  [She, is, 8, she, went, blind, last, summer, b...
#
#                                                bio_tags
# 1201  [O, I-C, I-C, I-C, I-C, I-C, O, O, O, O, O, O,...
# 2007  [O, O, O, I-C, O, O, O, O, O, O, O, O, O, I-C,...
# 2331  [O, O, O, O, O, O, O, I-C, I-C, I-C, I-C, O, O...
# 1394  [O, O, O, O, O, O, O, O, O, I-C, O, O, I-E, O,...
# 2284  [O, O, O, O, O, I-E, O, O, O, O, I-C, O, O, O,...

# %%
X_data = [sent2features(sentence, tokenized) for sentence, tokenized in zip(data.sentence.values.tolist(), data.tokenized.values.tolist())]

# %%
cause_effect_model = joblib.load("./model-causal-span/bertEmbeddings_simpleCRF.pkl")
predictions = cause_effect_model.predict(X_data)

# %%
for tokens, true_labels, predicts in zip(data.tokenized, data.bio_tags, predictions):
    print("\n")
    for token, true_label, predic in zip(tokens, true_labels, predicts):
        print(token, "true:", true_label, "predic:", predic)
# Out:
# I true: O predic: O
# forgot true: I-C predic: O
# to true: I-C predic: O
# change true: I-C predic: O
# my true: I-C predic: O
# pump true: I-C predic: O
# this true: O predic: O
# morning true: O predic: O
# and true: O predic: O
# I true: O predic: O
# did true: O predic: O
# n't true: O predic: O
# grab true: O predic: O
# any true: O predic: O
# insulin true: O predic: O
# so true: O predic: O
# now true: O predic: O
# I true: O predic: O
# have true: O predic: O
# 10 true: O predic: O
# units true: O predic: O
# to true: O predic: O
# get true: O predic: O
# me true: O predic: O
# through true: O predic: O
# the true: O predic: O
# day true: O predic: O
# when true: O predic: O
# I true: O predic: O
# usually true: O predic: O
# go true: O predic: O
# through true: O predic: O
# like true: O predic: O
# 50 true: O predic: O
# so true: O predic: O
# I true: O predic: O
# 'm true: O predic: O
# going true: O predic: O
# to true: O predic: O
# have true: O predic: O
# high true: I-E predic: I-E
# blood true: I-E predic: I-E
# sugar true: I-E predic: I-E
# all true: O predic: O
# day true: O predic: O
# I true: O predic: O
# 'm true: O predic: O
# so true: O predic: O
# dumb true: O predic: O
#
#
# I true: O predic: O
# got true: O predic: O
# prescribed true: O predic: O
# contrave true: I-C predic: O
# by true: O predic: O
# my true: O predic: O
# doctor true: O predic: O
# and true: O predic: O
# its true: O predic: O
# like true: O predic: O
# a true: O predic: O
# pre true: O predic: I-C
# diabetic true: O predic: I-C
# metformin true: I-C predic: I-C
# and true: O predic: O
# its true: O predic: O
# increased true: I-E predic: O
# my true: I-E predic: O
# metabolism true: I-E predic: O
# tenfold true: O predic: O
# and true: O predic: O
# ive true: O predic: O
# shed true: I-E predic: I-E
# 20 true: I-E predic: I-E
# pounds true: I-E predic: I-E
# in true: O predic: O
# a true: O predic: O
# month true: O predic: O
# . true: O predic: O
#
#
# @USER true: O predic: O
# I true: O predic: O
# ' true: O predic: O
# m true: O predic: O
# sure true: O predic: O
# those true: O predic: O
# who true: O predic: O
# can't true: I-C predic: I-C
# afford true: I-C predic: I-C
# their true: I-C predic: I-C
# insulin true: I-C predic: I-C
# now true: O predic: O
# and true: O predic: O
# now true: O predic: O
# have true: O predic: O
# to true: O predic: O
# ration true: I-E predic: O
# it true: I-E predic: O
# because true: O predic: O
# of true: O predic: O
# your true: O predic: O
# stupid true: O predic: O
# ass true: O predic: O
# temper true: O predic: O
# tantrum true: O predic: O
# are true: O predic: O
# singing true: O predic: O
# a true: O predic: O
# different true: O predic: O
# tune true: O predic: O
# you true: O predic: O
# asshole true: O predic: O
# ! true: O predic: O
#
#
# I true: O predic: O
# look true: O predic: O
# at true: O predic: O
# it true: O predic: O
# like true: O predic: O
# this true: O predic: O
# , true: O predic: O
# all true: O predic: O
# that true: O predic: O
# sugar true: I-C predic: I-C
# leads true: O predic: O
# to true: O predic: O
# diabetes true: I-E predic: I-C
# , true: O predic: O
# obesity true: I-E predic: I-E
# , true: O predic: O
# dental true: I-E predic: O
# issues true: I-E predic: O
# neither true: O predic: O
# are true: O predic: O
# great true: O predic: O
# , true: O predic: O
# I true: O predic: O
# 'm true: O predic: O
# just true: O predic: O
# glad true: O predic: O
# I true: O predic: O
# 've true: O predic: O
# been true: O predic: O
# relatively true: O predic: O
# healthy true: O predic: O
# :crossed_fingers: true: O predic: O
# :medium_skin_tone: true: O predic: O
#
#
# She true: O predic: O
# is true: O predic: O
# 8 true: O predic: O
# she true: O predic: O
# went true: O predic: O
# blind true: I-E predic: I-E
# last true: O predic: O
# summer true: O predic: O
# bc true: O predic: O
# of true: O predic: O
# diabetes true: I-C predic: I-C
# n true: O predic: O
# she true: O predic: O
# has true: O predic: O
# Cushings true: O predic: O
# disease true: O predic: O
# but true: O predic: O
# she true: O predic: O
# is true: O predic: O
# still true: O predic: O
# very true: O predic: O
# happy true: O predic: O
#
#
# USER true: O predic: O
# A1 true: O predic: O
# I true: O predic: O
# have true: O predic: O
# a true: O predic: O
# lot true: O predic: O
# of true: O predic: O
# friends true: O predic: O
# who true: O predic: O
# are true: O predic: O
# obese true: I-C predic: I-C
# and true: O predic: O
# most true: O predic: O
# of true: O predic: O
# them true: O predic: O
# have true: O predic: O
# Diabetes true: I-E predic: I-C
# . true: O predic: O
#
#
# Shin true: O predic: O
# splints true: O predic: O
# :check_mark_button: true: O predic: O
# Forgot true: I-C predic: I-C
# insulin true: I-C predic: I-C
# :check_mark_button: true: O predic: O
# Walked true: O predic: O
# into true: O predic: O
# 3 true: O predic: O
# people true: O predic: O
# already true: O predic: O
# :check_mark_button: true: O predic: O
# All true: O predic: O
# in true: O predic: O
# a true: O predic: O
# hard true: I-E predic: O
# mornings true: I-E predic: I-C
# work true: O predic: I-C
#
#
# @USER true: O predic: O
# He true: O predic: O
# was true: O predic: O
# on true: O predic: O
# tv true: O predic: O
# being true: O predic: O
# all true: O predic: O
# muscly true: O predic: O
# and true: O predic: O
# I true: O predic: O
# had true: O predic: O
# just true: O predic: O
# eaten true: I-C predic: O
# a true: I-C predic: O
# maxibon true: I-C predic: O
# so true: O predic: O
# I true: O predic: O
# was true: O predic: O
# in true: O predic: O
# a true: O predic: O
# diabetic true: I-E predic: I-C
# coma true: I-E predic: I-C
# when true: O predic: O
# I true: O predic: O
# wrote true: O predic: O
# this true: O predic: O
# tweet true: O predic: O
# HTTPURL true: O predic: O
#
#
# @USER true: O predic: O
# Just true: O predic: O
# because true: O predic: O
# some true: O predic: O
# people true: O predic: O
# need true: O predic: O
# insulin true: I-C predic: I-C
# to true: O predic: O
# stay true: I-E predic: O
# alive true: I-E predic: O
# , true: O predic: O
# that true: O predic: O
# does true: O predic: O
# n't true: O predic: O
# make true: O predic: O
# instant true: O predic: O
# and true: O predic: O
# easy true: O predic: O
# access true: O predic: O
# to true: O predic: O
# insulin true: O predic: O
# a true: O predic: O
# human true: O predic: O
# right true: O predic: O
# , true: O predic: O
# that true: O predic: O
# all true: O predic: O
# people true: O predic: O
# on true: O predic: O
# earth true: O predic: O
# should true: O predic: O
# have true: O predic: O
# . true: O predic: O
#
#
# USER true: O predic: O
# I true: O predic: O
# called true: O predic: O
# the true: O predic: O
# Texas true: O predic: O
# Dept true: O predic: O
# of true: O predic: O
# Health true: O predic: O
# , true: O predic: O
# and true: O predic: O
# asked true: O predic: O
# if true: O predic: O
# any true: O predic: O
# of true: O predic: O
# these true: O predic: O
# kids true: O predic: O
# are true: O predic: O
# diabetic true: I-C predic: I-C
# , true: O predic: O
# if true: O predic: O
# someone true: O predic: O
# is true: O predic: O
# sitting true: O predic: O
# up true: O predic: O
# with true: O predic: O
# them true: O predic: O
# at true: O predic: O
# 3am true: O predic: O
# when true: O predic: O
# they true: O predic: O
# have true: O predic: O
# blood true: I-E predic: I-E
# sugar true: I-E predic: I-E
# lows true: I-E predic: I-E
# , true: O predic: O
# to true: O predic: O
# avoid true: O predic: I-E
# coma true: O predic: I-E
# / true: O predic: I-E
# death true: O predic: I-E
# , true: O predic: O
# and true: O predic: O
# asked true: O predic: O
# if true: O predic: O
# parents true: O predic: O
# given true: O predic: O
# dly true: O predic: O
# blood true: O predic: O
# sugar true: O predic: O
# updates true: O predic: O
# . true: O predic: O
#
#
# One true: O predic: O
# thing true: O predic: O
# that true: O predic: O
# baffles true: O predic: O
# me true: O predic: O
# on true: O predic: O
# dera true: O predic: O
# controversy true: O predic: O
# , true: O predic: O
# #Ramraheemsingh true: O predic: O
# was true: O predic: O
# suffering true: I-E predic: I-E
# from true: O predic: O
# hypertension true: I-C predic: I-C
# , true: O predic: O
# acute true: O predic: O
# diabetes true: I-C predic: I-C
# & true: O predic: O
# back true: I-C predic: I-C
# ache true: I-C predic: I-C
# . true: O predic: O
#
#
# Glad true: I-E predic: O
# to true: O predic: O
# see true: O predic: O
# insulin true: I-C predic: I-C
# prices true: I-C predic: I-C
# have true: I-C predic: I-C
# come true: I-C predic: I-C
# down true: I-C predic: I-C
# . true: O predic: O
#
#
# It true: O predic: O
# was true: O predic: O
# announced true: O predic: O
# Diabetes true: I-C predic: I-C
# was true: O predic: O
# the true: O predic: O
# major true: O predic: O
# underlying true: O predic: O
# health true: O predic: O
# conditions true: O predic: O
# that true: O predic: O
# killed true: I-E predic: O
# people true: O predic: O
# with true: O predic: O
# Covid true: O predic: O
# . true: O predic: O
#
#
# @USER true: O predic: O
# I true: O predic: O
# am true: O predic: O
# at true: O predic: O
# high true: I-E predic: O
# risk true: I-E predic: O
# as true: O predic: O
# well true: O predic: O
# because true: O predic: O
# I true: O predic: O
# am true: O predic: O
# diabetic true: I-C predic: I-C
# with true: O predic: O
# 15 true: O predic: O
# % true: O predic: O
# lung true: O predic: O
# damage true: O predic: O
# . true: O predic: O
#
#
# USER true: O predic: O
# Those true: O predic: O
# numbers true: O predic: O
# look true: O predic: O
# good true: O predic: O
# but true: O predic: O
# I true: O predic: O
# would true: O predic: O
# see true: I-E predic: I-E
# a true: I-E predic: I-E
# doctor true: I-E predic: I-E
# to true: O predic: O
# find true: O predic: O
# out true: O predic: O
# why true: O predic: O
# the true: O predic: O
# glucose true: I-C predic: I-C
# level true: I-C predic: I-C
# is true: I-C predic: O
# going true: I-C predic: O
# up true: I-C predic: O
# . true: O predic: O
#
#
# @USER true: O predic: O
# This true: O predic: O
# should true: O predic: O
# work true: O predic: O
# as true: O predic: O
# well true: O predic: O
# as true: O predic: O
# taking true: O predic: I-E
# half true: I-E predic: I-E
# your true: I-E predic: I-E
# insulin true: I-E predic: I-E
# because true: O predic: O
# it true: O predic: O
# ' true: O predic: O
# s true: O predic: O
# so true: O predic: O
# expensive true: I-C predic: O
# . true: O predic: O
#
#
# @USER true: O predic: O
# Hard true: O predic: O
# to true: O predic: O
# believe true: O predic: O
# that true: O predic: O
# guy true: O predic: O
# died true: I-E predic: I-E
# of true: O predic: O
# a true: O predic: O
# heart true: I-C predic: I-C
# attack true: I-C predic: I-C
# and true: O predic: O
# untreated true: O predic: O
# diabetes true: I-C predic: I-C
# ... true: O predic: O
#
#
# A true: O predic: O
# better true: O predic: O
# headline true: O predic: O
# might true: O predic: O
# be true: O predic: O
# " true: O predic: O
# Americans true: O predic: O
# are true: O predic: O
# dying true: I-E predic: I-E
# thanks true: O predic: O
# to true: O predic: O
# insulin true: I-C predic: I-C
# price true: I-C predic: I-C
# gouging true: I-C predic: I-C
# " true: O predic: O
# #insulin4all true: O predic: O
#
#
# USER true: O predic: O
# USER true: O predic: O
# I true: O predic: O
# lost true: I-E predic: I-E
# my true: I-E predic: O
# mom true: I-E predic: O
# in true: O predic: O
# a true: O predic: O
# car true: O predic: O
# accident true: O predic: O
# caused true: O predic: O
# by true: O predic: O
# her true: O predic: O
# diabetes true: I-C predic: I-C
# . true: O predic: O
#
#
# after true: O predic: O
# my true: O predic: O
# birthday true: O predic: O
# I true: O predic: O
# lost true: I-E predic: I-E
# my true: I-E predic: O
# father true: I-E predic: O
# from true: O predic: O
# complications true: O predic: I-C
# to true: O predic: O
# a true: O predic: O
# TBI true: I-C predic: O
# and true: O predic: O
# diabetes true: I-C predic: I-C
# . true: O predic: O
#
#
# USER true: O predic: O
# People true: O predic: O
# die true: I-E predic: I-E
# in true: O predic: O
# the true: O predic: O
# USA true: O predic: O
# because true: O predic: O
# they true: O predic: O
# can't true: I-C predic: I-C
# get true: I-C predic: I-C
# insulin true: I-C predic: I-C
# . true: O predic: O
#
#
# I true: O predic: O
# really true: O predic: O
# wish true: O predic: O
# Diabetes true: I-C predic: I-C
# Type true: I-C predic: I-C
# 1 true: I-C predic: I-C
# insulin true: I-C predic: I-C
# and true: I-C predic: I-C
# equipment true: I-C predic: I-C
# was true: I-C predic: I-C
# less true: I-C predic: I-C
# pricey true: I-C predic: I-C
# , true: O predic: O
# im true: O predic: O
# worried true: I-E predic: I-E
# for true: O predic: O
# my true: O predic: O
# sister true: O predic: O
# x true: O predic: O
# ( true: O predic: O
#
#
# @USER true: O predic: O
# I true: O predic: O
# wish true: O predic: O
# I true: O predic: O
# could true: O predic: O
# help true: O predic: O
# but true: O predic: O
# really true: O predic: O
# struggling true: I-E predic: I-E
# with true: O predic: O
# having true: O predic: O
# a true: O predic: O
# 16yr true: O predic: O
# old true: O predic: O
# just true: O predic: O
# diagnosed true: O predic: O
# with true: O predic: O
# type true: I-C predic: I-C
# 1 true: I-C predic: I-C
# diabetes true: I-C predic: I-C
# and true: O predic: O
# I true: O predic: O
# am true: O predic: O
# trying true: O predic: O
# to true: O predic: O
# get true: O predic: O
# my true: O predic: O
# car true: O predic: O
# back true: O predic: O
# after true: O predic: O
# getting true: O predic: O
# it true: O predic: O
# repo true: O predic: O
#
#
# @USER true: O predic: O
# @USER true: O predic: O
# @USER true: O predic: O
# Wait true: O predic: O
# I true: O predic: O
# thought true: O predic: O
# George true: O predic: O
# Floyd true: O predic: O
# ' true: O predic: O
# s true: O predic: O
# death true: I-E predic: O
# was true: O predic: O
# because true: O predic: O
# of true: O predic: O
# high true: I-C predic: I-C
# cost true: I-C predic: I-C
# insulin true: I-C predic: I-C
# : true: O predic: O
# thinking_face true: O predic: O
# : true: O predic: O
#
#
# the true: O predic: O
# gestational true: I-E predic: I-C
# diabetes true: I-E predic: I-C
# diet true: I-E predic: I-C
# .. true: O predic: O
# : true: O predic: O
# upside true: O predic: O
# down_face true: O predic: O
# : true: O predic: O
# only true: O predic: O
# reason true: O predic: O
# I true: O predic: O
# ' true: O predic: O
# m true: O predic: O
# doing true: O predic: O
# it true: O predic: O
# is true: O predic: O
# bc true: O predic: O
# I true: O predic: O
# get true: O predic: O
# a true: O predic: O
# baby true: I-C predic: O
# @USER true: O predic: O
# the true: O predic: O
# end true: O predic: O
# of true: O predic: O
# it true: O predic: O
# : true: O predic: O
# hugging_face true: O predic: O
# : true: O predic: O
# HTTPURL true: O predic: O
#
#
# USER true: O predic: O
# I true: O predic: O
# have true: O predic: O
# vision true: I-E predic: I-E
# problems true: I-E predic: I-E
# due true: O predic: O
# to true: O predic: O
# diabetes true: I-C predic: I-C
# . true: O predic: O
#
#
# USER true: O predic: O
# USER true: O predic: O
# I true: O predic: O
# find true: O predic: O
# tracking true: I-E predic: I-E
# my true: I-E predic: I-E
# Blood true: I-E predic: I-E
# ketones true: I-E predic: I-E
# and true: I-E predic: O
# Glucose true: I-E predic: O
# helps true: O predic: O
# When true: O predic: O
# I true: O predic: O
# know true: O predic: O
# I true: O predic: O
# 'm true: O predic: O
# in true: I-C predic: O
# Ketosis true: I-C predic: I-C
# and true: O predic: O
# that true: O predic: O
# cheating true: I-C predic: I-C
# on true: I-C predic: I-C
# carbs true: I-C predic: I-C
# will true: O predic: O
# cause true: O predic: O
# me true: O predic: O
# to true: O predic: O
# feel true: I-E predic: I-E
# lousy true: I-E predic: I-E
# for true: O predic: O
# 2 true: O predic: O
# weeks true: O predic: O
# it true: O predic: O
# 's true: O predic: O
# much true: O predic: O
# easier true: O predic: O
# to true: O predic: O
# pass true: O predic: O
# the true: O predic: O
# carbs true: O predic: O
# up true: O predic: O
#
#
# USER true: O predic: O
# USER true: O predic: O
# USER true: O predic: O
# Now true: O predic: O
# I true: O predic: O
# 'm true: O predic: O
# going true: O predic: O
# to true: O predic: O
# go true: O predic: O
# treat true: O predic: O
# the true: O predic: O
# diabetic true: I-C predic: I-C
# low true: I-E predic: I-C
# I true: O predic: O
# 'm true: O predic: O
# having true: O predic: O
# , true: O predic: O
# feed true: O predic: O
# my true: O predic: O
# puppy true: O predic: O
# some true: O predic: O
# peanut true: O predic: O
# butter true: O predic: O
# rice true: O predic: O
# cakes true: O predic: O
# , true: O predic: O
# and true: O predic: O
# go true: O predic: O
# to true: O predic: O
# sleep true: O predic: O
# . true: O predic: O
#
#
# 18 true: O predic: O
# years true: O predic: O
# ago true: O predic: O
# today true: O predic: O
# my true: O predic: O
# life true: I-E predic: I-E
# changed true: I-E predic: I-E
# fundamentally true: O predic: O
# when true: O predic: O
# I true: O predic: O
# was true: O predic: O
# diagnosed true: O predic: O
# with true: O predic: O
# type true: I-C predic: I-C
# 1 true: I-C predic: I-C
# diabetes true: I-C predic: I-C
# . true: O predic: O
#
#
# Lack true: I-E predic: I-E
# of true: I-E predic: I-E
# oxygen true: I-E predic: I-E
# due true: O predic: O
# to true: O predic: O
# a true: O predic: O
# weak true: I-C predic: I-C
# heart true: I-C predic: I-C
# & true: O predic: O
# diabetes true: I-C predic: I-C
# going true: O predic: O
# through true: O predic: O
# his true: O predic: O
# body true: O predic: O
# and true: O predic: O
# his true: O predic: O
# doctors true: O predic: O
# refusing true: O predic: O
# to true: O predic: O
# help true: O predic: O
# my true: O predic: O
# dad true: O predic: O
# regarding true: O predic: O
# giving true: O predic: O
# my true: O predic: O
# dad true: O predic: O
# a true: O predic: O
# : true: O predic: O
# ox true: O predic: O
# : true: O predic: O
# oxygen true: O predic: O
# tank true: O predic: O
# . true: O predic: O
#
#
# USER true: O predic: O
# USER true: O predic: O
# I true: O predic: O
# 'll true: O predic: O
# have true: O predic: O
# the true: O predic: O
# last true: O predic: O
# laugh true: O predic: O
# when true: O predic: O
# they true: O predic: O
# cut true: I-E predic: I-E
# your true: I-E predic: I-E
# foot true: I-E predic: I-E
# off true: I-E predic: I-E
# due true: O predic: O
# to true: O predic: O
# your true: O predic: O
# self true: O predic: O
# induced true: O predic: O
# diabetes true: I-C predic: I-C
# . true: O predic: O
#
#
# Decades true: O predic: O
# of true: O predic: O
# food true: I-E predic: I-E
# addiction true: I-E predic: I-E
# because true: O predic: O
# of true: O predic: O
# PTSD true: I-C predic: I-C
# really true: O predic: O
# fucked true: O predic: I-E
# my true: O predic: I-E
# life true: O predic: I-E
# and true: O predic: I-E
# health true: O predic: I-E
# . true: O predic: O
#
#
# USER true: O predic: O
# USER true: O predic: O
# They true: O predic: O
# do true: O predic: O
# not true: O predic: O
# work true: O predic: O
# or true: O predic: O
# help true: O predic: O
# as true: O predic: O
# we true: O predic: O
# have true: O predic: O
# insurance true: I-C predic: I-C
# and true: O predic: O
# can true: O predic: O
# still true: O predic: O
# not true: I-E predic: O
# afford true: I-E predic: I-C
# the true: I-E predic: I-C
# insulin true: I-E predic: I-C
# . true: O predic: O
#
#
# I true: O predic: O
# have true: O predic: O
# to true: O predic: O
# take true: O predic: O
# this true: O predic: O
# stupid true: O predic: O
# glucose true: I-C predic: I-C
# test true: I-C predic: I-C
# tomorrow true: O predic: O
# so true: O predic: O
# I true: O predic: O
# have true: O predic: O
# to true: O predic: O
# fast true: I-E predic: I-E
# for true: O predic: O
# 12 true: O predic: O
# hours true: O predic: O
# . true: O predic: O
#
#
# soooo true: O predic: O
# I true: O predic: O
# ' true: O predic: O
# m true: O predic: O
# a true: O predic: O
# hypochondriac true: O predic: O
# but true: O predic: O
# I true: O predic: O
# feel true: O predic: O
# like true: O predic: O
# I true: O predic: O
# might true: O predic: O
# have true: O predic: O
# diabetes true: I-C predic: I-C
# and true: O predic: O
# I true: O predic: O
# ' true: O predic: O
# m true: O predic: O
# really true: O predic: O
# scared true: I-E predic: I-E
# ): true: O predic: O
#
#
# My true: O predic: O
# glucose true: I-C predic: I-C
# is true: I-C predic: I-C
# abnormal true: I-C predic: I-C
# ( true: O predic: I-C
# way true: O predic: I-C
# to true: O predic: I-C
# high true: O predic: I-C
# ) true: O predic: O
# & true: O predic: O
# I true: O predic: O
# have true: O predic: O
# anemia true: I-E predic: O
# again true: O predic: O
# :/ true: O predic: O
# uhhh true: O predic: O
# back true: O predic: O
# to true: O predic: O
# the true: O predic: O
# doctor true: O predic: O
# I true: O predic: O
# go true: O predic: O
#
#
# USER true: O predic: O
# My true: O predic: O
# childhood true: O predic: O
# min true: O predic: O
# pin true: O predic: O
# got true: O predic: O
# diabetes true: I-C predic: I-C
# and true: O predic: O
# now true: O predic: O
# he true: O predic: O
# 's true: O predic: O
# blind true: I-E predic: I-E
# :loudly_crying_face: true: O predic: O
# :loudly_crying_face: true: O predic: O
# :loudly_crying_face: true: O predic: O
#
#
# 10 true: O predic: O
# years true: O predic: O
# ago true: O predic: O
# I true: O predic: O
# decided true: O predic: O
# I true: O predic: O
# wanted true: O predic: O
# to true: O predic: O
# become true: I-E predic: O
# a true: I-E predic: O
# Pediatric true: I-E predic: O
# Endocrinologist true: I-E predic: O
# because true: O predic: O
# of true: O predic: O
# this true: O predic: O
# diagnosis true: I-C predic: O
# . true: O predic: O
#
#
# @USER true: O predic: O
# My true: O predic: O
# new true: I-C predic: O
# health true: I-C predic: O
# insurance true: I-C predic: O
# would true: O predic: O
# n't true: I-E predic: I-E
# cover true: I-E predic: I-E
# my true: I-E predic: I-E
# non true: I-E predic: I-E
# insulin true: I-E predic: I-E
# diabetes true: I-E predic: I-E
# injection true: I-E predic: I-E
# med true: I-E predic: I-E
# , true: O predic: O
# even true: O predic: O
# though true: O predic: O
# I true: O predic: O
# ' true: O predic: O
# d true: O predic: O
# been true: O predic: O
# taking true: O predic: O
# it true: O predic: O
# for true: O predic: O
# a true: O predic: O
# year true: O predic: O
# with true: O predic: O
# great true: O predic: O
# results true: O predic: O
# , true: O predic: O
# and true: O predic: O
# I true: O predic: O
# had true: O predic: O
# to true: O predic: O
# switch true: O predic: O
# doctors true: O predic: O
# . true: O predic: O
#
#
# @USER true: O predic: O
# Finally true: O predic: O
# got true: O predic: O
# my true: O predic: O
# isolation true: I-E predic: O
# note true: O predic: O
# due true: O predic: O
# to true: O predic: O
# my true: O predic: O
# diabetes true: I-C predic: I-C
# so true: O predic: O
# I true: O predic: O
# can true: O predic: O
# stay true: O predic: I-E
# home true: O predic: I-E
# until true: O predic: O
# all true: O predic: O
# this true: O predic: O
# is true: O predic: O
# over true: O predic: O
# now true: O predic: O
# . true: O predic: O
#
#
# Fasting true: I-E predic: O
# for true: O predic: O
# a true: O predic: O
# glucose true: I-C predic: I-C
# test true: I-C predic: I-C
# and true: O predic: O
# I true: O predic: O
# 'm true: O predic: O
# so true: O predic: O
# hangry true: I-E predic: I-E
# . true: O predic: O
#
#
# In true: O predic: O
# her true: O predic: O
# case true: O predic: O
# , true: O predic: O
# as true: O predic: O
# a true: O predic: O
# diabetic true: O predic: I-C
# , true: O predic: O
# she true: O predic: O
# has true: O predic: O
# insulin true: I-C predic: I-E
# but true: I-C predic: O
# w true: I-C predic: O
# / true: I-C predic: O
# o true: I-C predic: I-C
# food true: I-C predic: I-C
# can true: O predic: O
# hv true: O predic: O
# detrimental true: I-E predic: I-E
# effects true: I-E predic: I-E
#
#
# I true: O predic: O
# was true: O predic: O
# moved true: O predic: O
# when true: O predic: O
# the true: O predic: O
# young true: O predic: O
# lady true: O predic: O
# on true: O predic: O
# the true: O predic: O
# left true: O predic: O
# spoke true: O predic: O
# about true: O predic: O
# how true: O predic: O
# difficult true: I-E predic: I-E
# living true: I-E predic: I-E
# with true: O predic: O
# #T1D true: I-C predic: I-C
# is true: O predic: O
# . true: O predic: O
#
#
# It true: O predic: O
# 's true: O predic: O
# world true: O predic: O
# diabetes true: O predic: O
# day true: O predic: O
# , true: O predic: O
# so true: O predic: O
# , true: O predic: O
# being true: O predic: O
# the true: O predic: O
# diabetic true: I-C predic: I-C
# that true: O predic: O
# i true: O predic: O
# am true: O predic: O
# , true: O predic: O
# it true: O predic: O
# 's true: O predic: O
# all true: O predic: O
# about true: O predic: O
# me true: O predic: O
# and true: O predic: O
# my true: O predic: O
# insulin true: I-E predic: I-C
# pump true: I-E predic: I-C
# today true: O predic: O
#
#
# If true: O predic: O
# you true: O predic: O
# drink true: I-C predic: I-C
# wine true: I-C predic: I-C
# in true: O predic: O
# the true: O predic: O
# evening true: O predic: O
# or true: O predic: O
# eat true: I-C predic: I-C
# carbs true: I-C predic: I-C
# after true: O predic: O
# 7 true: O predic: O
# or true: O predic: O
# 8 true: O predic: O
# your true: O predic: O
# pancreas true: I-E predic: O
# may true: I-E predic: O
# be true: I-E predic: O
# working true: I-E predic: O
# overtime true: O predic: O
# at true: O predic: O
# 3 true: O predic: O
# a true: O predic: O
# . true: O predic: O
#
#
# USER true: O predic: O
# for true: O predic: O
# my true: O predic: O
# uncle true: O predic: O
# who true: O predic: O
# died true: I-E predic: I-E
# of true: O predic: O
# renal true: I-C predic: I-C
# failure true: I-C predic: I-C
# .. true: O predic: O
# he true: O predic: O
# was true: O predic: O
# given true: O predic: O
# 24 true: O predic: O
# tablets true: O predic: O
# per true: O predic: O
# day true: O predic: O
# plus true: O predic: O
# insulin true: O predic: O
# taking true: O predic: O
# biopsy true: O predic: O
# of true: O predic: O
# kidney true: O predic: O
# even true: O predic: O
# when true: O predic: O
# problem true: O predic: O
# was true: O predic: O
# in true: O predic: O
# small true: O predic: O
# stage true: O predic: O
# would true: O predic: O
# have true: O predic: O
# solved true: O predic: O
# his true: O predic: O
# problem true: O predic: O
# other true: O predic: O
# doctors true: O predic: O
# said true: O predic: O
# Actually true: O predic: O
# its true: O predic: O
# those true: O predic: O
# tablets true: O predic: O
# which true: O predic: O
# killed true: O predic: O
# him true: O predic: O
# sooner true: O predic: O
# . true: O predic: O
#
#
# Being true: O predic: O
# diabetic true: I-C predic: I-C
# is true: O predic: I-C
# expensive true: I-E predic: I-C
# ! true: O predic: O
#
#
# But true: O predic: O
# it true: O predic: O
# does true: O predic: O
# n't true: O predic: O
# help true: O predic: O
# the true: O predic: O
# Type true: I-C predic: I-C
# 1 true: I-C predic: I-C
# diabetic true: I-C predic: I-C
# you true: O predic: O
# denied true: I-C predic: O
# care true: I-C predic: O
# to true: O predic: O
# until true: O predic: O
# he true: O predic: O
# “ true: O predic: O
# played true: O predic: O
# ball true: O predic: O
# ” true: O predic: O
# sending true: O predic: O
# him true: O predic: O
# to true: O predic: O
# the true: O predic: O
# ER true: O predic: I-E
# for true: O predic: O
# nearly true: O predic: O
# going true: O predic: O
# into true: O predic: O
# DKA true: I-E predic: I-E
# . true: O predic: O
#
#
# Growing true: I-C predic: O
# up true: I-C predic: O
# with true: I-C predic: O
# a true: I-C predic: O
# Type true: I-C predic: I-C
# 1 true: I-C predic: I-C
# Diabetic true: I-C predic: I-C
# mom true: O predic: O
# made true: O predic: O
# me true: O predic: O
# realize true: O predic: O
# from true: O predic: O
# a true: O predic: O
# young true: O predic: O
# age true: O predic: O
# just true: O predic: O
# how true: O predic: O
# fucked true: I-E predic: I-E
# health true: I-E predic: I-E
# insurance true: I-E predic: I-E
# in true: I-E predic: O
# the true: I-E predic: O
# US true: I-E predic: O
# is true: O predic: O
#
#
# Hey true: O predic: O
# ok true: O predic: O
# so true: O predic: O
# un true: O predic: O
# ( true: O predic: O
# fortunately true: O predic: O
# ) true: O predic: O
# I true: O predic: O
# 'm true: O predic: O
# probably true: O predic: O
# dying true: I-E predic: I-E
# soon true: O predic: O
# or true: O predic: O
# going true: I-E predic: O
# blind true: I-E predic: I-E
# because true: O predic: O
# of true: O predic: O
# diabetes true: I-C predic: I-C
# and true: O predic: O
# I true: O predic: O
# just true: O predic: O
# wanna true: O predic: O
# put true: O predic: O
# out true: O predic: O
# that true: O predic: O
# if true: O predic: O
# I true: O predic: O
# do true: O predic: O
# die true: O predic: I-E
# I true: O predic: O
# need true: O predic: O
# everyone true: O predic: O
# who true: O predic: O
# attends true: O predic: O
# to true: O predic: O
# watch true: O predic: O
# the true: O predic: O
# first true: O predic: O
# livestream true: O predic: O
# of true: O predic: O
# the true: O predic: O
# dreamsmp true: O predic: O
# OR true: O predic: O
# get true: O predic: O
# technoblade true: O predic: O
# to true: O predic: O
# say true: O predic: O
# “ true: O predic: O
# rip true: O predic: O
# to true: O predic: O
# that true: O predic: O
# bitch true: O predic: O
# ” true: O predic: O
# and true: O predic: O
# play true: O predic: O
# it true: O predic: O
# . true: O predic: O
#
#
# @USER true: O predic: O
# @USER true: O predic: O
# @USER true: O predic: O
# Yes true: O predic: O
# full true: O predic: O
# steam true: O predic: O
# ahead true: O predic: O
# to true: O predic: O
# diabetes true: I-C predic: I-C
# unless true: O predic: O
# mommy true: O predic: O
# ' true: O predic: O
# s true: O predic: O
# life true: I-E predic: I-E
# style true: I-E predic: I-E
# changes true: I-E predic: I-E
# ! true: O predic: O
#
#
# A true: O predic: O
# shot true: I-C predic: I-C
# of true: I-C predic: I-C
# insulin true: I-C predic: I-C
# will true: O predic: O
# save true: I-E predic: I-E
# her true: I-E predic: I-E
# life true: I-E predic: I-E
# . true: O predic: O
#
#
# i true: O predic: O
# do true: O predic: O
# n't true: O predic: O
# want true: O predic: O
# people true: O predic: O
# with true: O predic: O
# diabetes true: O predic: I-E
# dying true: I-E predic: I-E
# because true: O predic: O
# they true: O predic: O
# can't true: I-C predic: I-C
# afford true: I-C predic: I-C
# insulin true: I-C predic: I-C
# is true: O predic: O
# that true: O predic: O
# too true: O predic: O
# much true: O predic: O
# to true: O predic: O
# ask true: O predic: O
# for true: O predic: O
#
#
# ( true: O predic: O
# my true: O predic: O
# diabetes true: I-C predic: I-C
# is true: O predic: I-C
# stress true: I-E predic: I-C
# related true: O predic: O
# and true: O predic: O
# my true: O predic: O
# blood true: O predic: I-E
# sugars true: O predic: I-E
# have true: O predic: O
# been true: O predic: O
# at true: O predic: O
# near true: O predic: O
# normal true: O predic: O
# levels true: O predic: O
# ) true: O predic: O
#
#
# Need true: O predic: O
# some true: O predic: O
# help true: O predic: O
# our true: O predic: O
# oldest true: O predic: O
# pug true: O predic: O
# was true: O predic: O
# diagnosed true: O predic: O
# with true: O predic: O
# diabetes true: I-C predic: I-C
# which true: O predic: O
# has true: O predic: O
# progressed true: O predic: O
# rapidly true: O predic: O
# , true: O predic: O
# she true: O predic: O
# has true: O predic: O
# developed true: O predic: O
# cataracts true: I-E predic: O
# last true: O predic: O
# week true: O predic: O
# and true: O predic: O
# how true: O predic: O
# now true: O predic: O
# gone true: O predic: O
# blind true: I-E predic: I-E
# . true: O predic: O
#
#
# I true: O predic: O
# have true: O predic: O
# never true: O predic: O
# been true: O predic: O
# more true: O predic: O
# than true: O predic: O
# a true: O predic: O
# little true: O predic: I-C
# overweight true: I-C predic: I-C
# and true: O predic: O
# was true: O predic: O
# in true: O predic: O
# the true: O predic: O
# BMI true: O predic: O
# normal true: O predic: O
# range true: O predic: O
# when true: O predic: O
# I true: O predic: O
# developed true: O predic: O
# diabetes true: I-E predic: I-C
# . true: O predic: O
#
#
# I true: O predic: O
# 'm true: O predic: O
# halfway true: O predic: O
# to true: O predic: O
# my true: O predic: O
# goal true: O predic: O
# of true: O predic: O
# getting true: O predic: O
# a true: O predic: O
# new true: O predic: I-C
# insulin true: I-C predic: I-C
# pump true: I-C predic: I-C
# and true: O predic: O
# this true: O predic: O
# would true: O predic: O
# help true: I-E predic: O
# me true: O predic: O
# out true: O predic: O
# a true: O predic: O
# bunch true: O predic: O
# :pleading_face: true: O predic: O
# #DiabetesAwarenessMonth true: O predic: O
#
#
# My true: O predic: O
# husband true: O predic: O
# has true: O predic: O
# neuropathy true: I-E predic: I-E
# from true: O predic: O
# diabetes true: I-C predic: I-C
# . true: O predic: O
#
#
# My true: O predic: O
# daughter true: O predic: O
# has true: O predic: O
# type true: I-C predic: I-C
# 1 true: I-C predic: I-C
# diabetes true: I-C predic: I-C
# and true: O predic: O
# requires true: I-E predic: I-E
# insulin true: I-E predic: I-E
# to true: O predic: I-E
# stay true: O predic: I-E
# alive true: O predic: I-E
# . true: O predic: O
#
#
# USER true: O predic: O
# He true: O predic: O
# got true: I-E predic: I-C
# really true: I-E predic: I-C
# dramatic true: I-E predic: I-C
# about true: O predic: I-C
# his true: O predic: I-C
# diabetes true: I-C predic: I-C
# so true: O predic: O
# . true: O predic: O
#
#
# @USER true: O predic: O
# when true: O predic: O
# my true: O predic: O
# sister true: O predic: O
# ' true: O predic: O
# s true: O predic: O
# lung true: O predic: I-C
# transplant true: O predic: I-C
# meds true: I-C predic: I-C
# turned true: O predic: O
# her true: O predic: O
# into true: O predic: O
# a true: O predic: O
# Type true: I-E predic: I-C
# I true: I-E predic: I-C
# diabetic true: I-E predic: I-C
# , true: O predic: O
# she true: O predic: O
# found true: O predic: O
# eating true: I-C predic: I-C
# vegan true: I-C predic: I-C
# helped true: O predic: O
# keep true: I-E predic: O
# her true: I-E predic: O
# numbers true: I-E predic: O
# in true: I-E predic: O
# balance true: I-E predic: O
# . true: O predic: O
#
#
# My true: O predic: O
# mother true: O predic: O
# : true: O predic: O
# I true: O predic: O
# ' true: O predic: O
# m true: O predic: O
# positive true: O predic: O
# when true: O predic: O
# you true: O predic: O
# get true: O predic: O
# older true: O predic: O
# you true: O predic: O
# ' true: O predic: O
# re true: O predic: O
# going true: O predic: O
# to true: O predic: O
# get true: O predic: O
# diabetes true: I-E predic: I-E
# from true: O predic: O
# what true: O predic: O
# you true: O predic: O
# eat true: I-C predic: O
# . true: O predic: O
#
#
# Making true: O predic: O
# an true: O predic: O
# emergency true: O predic: O
# trip true: O predic: O
# to true: O predic: O
# Mosgiel true: O predic: O
# to true: O predic: O
# get true: O predic: O
# some true: O predic: O
# insulin true: I-E predic: O
# off true: O predic: O
# a true: O predic: O
# stranger true: O predic: O
# Suspect true: O predic: O
# I true: O predic: O
# have true: O predic: O
# a true: O predic: O
# dodgy true: O predic: O
# batch true: O predic: O
# & true: O predic: O
# urgent true: O predic: O
# pharmacy true: O predic: O
# have true: O predic: O
# the true: O predic: O
# same true: O predic: O
# batch true: O predic: O
# as true: O predic: O
# me true: O predic: O
# Have true: O predic: O
# done true: O predic: O
# everything true: O predic: O
# possible true: O predic: O
# to true: O predic: O
# bring true: I-C predic: O
# BGL true: I-C predic: I-C
# down true: I-C predic: I-C
# new true: O predic: O
# everything true: O predic: O
# over true: O predic: O
# last true: O predic: O
# 24h true: O predic: O
# without true: O predic: O
# success true: O predic: O
# TG true: O predic: O
# I true: O predic: O
# ' true: O predic: O
# m true: O predic: O
# not true: O predic: O
# susceptible true: O predic: O
# to true: O predic: O
# ketones true: O predic: I-C
# #T1D true: O predic: I-C
#
#
# USER true: O predic: O
# Your true: O predic: O
# father true: O predic: O
# had true: O predic: O
# a true: O predic: O
# diabetic true: I-C predic: I-E
# shock true: I-E predic: I-E
#
#
# Started true: O predic: O
# cutting true: I-C predic: I-C
# down true: I-C predic: I-C
# on true: I-C predic: I-C
# carbs true: I-C predic: I-C
# and true: O predic: O
# my true: O predic: O
# blood true: I-E predic: I-E
# sugars true: I-E predic: I-E
# have true: I-E predic: I-E
# come true: I-E predic: I-E
# down true: I-E predic: I-E
# alot true: O predic: O
# so true: O predic: O
# has true: O predic: O
# the true: O predic: O
# amount true: O predic: O
# of true: O predic: O
# insulin true: O predic: O
# I true: O predic: O
# have true: O predic: O
# to true: O predic: O
# take true: O predic: O
# per true: O predic: O
# meal true: O predic: O
# . true: O predic: O
#
#
# I true: O predic: O
# search true: O predic: O
# so true: O predic: O
# long true: O predic: O
# for true: O predic: O
# a true: O predic: O
# ffp true: O predic: O
# 3 true: O predic: O
# mask true: O predic: O
# for true: O predic: O
# my true: O predic: O
# type true: I-C predic: I-C
# 1 true: I-C predic: I-C
# diabetic true: I-C predic: I-C
# brother true: O predic: O
# who true: O predic: O
# is true: O predic: O
# at true: O predic: O
# high true: I-E predic: I-E
# risk true: I-E predic: I-E
# from true: I-E predic: O
# the true: I-E predic: O
# virus true: I-E predic: O
# and true: O predic: O
# was true: O predic: O
# only true: O predic: O
# able true: O predic: O
# to true: O predic: O
# find true: O predic: O
# one true: O predic: O
# ( true: O predic: O
# thankfully true: O predic: O
# ) true: O predic: O
# but true: O predic: O
# gosh true: O predic: O
# I true: O predic: O
# can true: O predic: O
# not true: O predic: O
# believe true: O predic: O
# people true: O predic: O
# are true: O predic: O
# buying true: O predic: O
# them true: O predic: O
# just true: O predic: O
# to true: O predic: O
# sell true: O predic: O
# them true: O predic: O
# for true: O predic: O
# a true: O predic: O
# higher true: O predic: O
# price true: O predic: O
# how true: O predic: O
# selfish true: O predic: O
# do true: O predic: O
# you true: O predic: O
# have true: O predic: O
# to true: O predic: O
# be true: O predic: O
# to true: O predic: O
# do true: O predic: O
# that true: O predic: O
#
#
# Ca true: I-E predic: O
# n't true: I-E predic: O
# get true: I-E predic: O
# to true: I-E predic: O
# sleep true: I-E predic: O
# because true: O predic: O
# my true: O predic: O
# blood true: I-C predic: I-C
# sugars true: I-C predic: I-C
# were true: I-C predic: I-C
# low true: I-C predic: I-C
# so true: O predic: O
# I true: O predic: O
# had true: O predic: O
# some true: O predic: O
# sweets true: I-E predic: I-C
# and true: O predic: O
# now true: O predic: O
# they true: O predic: O
# ' true: O predic: O
# re true: O predic: O
# too true: O predic: O
# high true: O predic: O
# : true: O predic: O
# loudly_crying_face true: O predic: O
# : true: O predic: O
# #T1D true: I-C predic: I-C
# #Diabetes true: I-C predic: I-C
#
#
# USER true: O predic: O
# USER true: O predic: O
# I true: O predic: O
# know true: O predic: O
# someone true: O predic: O
# who true: O predic: O
# did true: O predic: O
# this true: O predic: O
# , true: O predic: O
# who true: O predic: O
# racked true: O predic: O
# up true: O predic: O
# medical true: O predic: O
# bills true: O predic: O
# and true: O predic: O
# then true: O predic: O
# died true: I-E predic: I-E
# of true: O predic: O
# diabetes true: I-C predic: I-C
# ( true: O predic: O
# from true: O predic: O
# poor true: I-C predic: I-C
# diet true: I-C predic: I-C
# ) true: O predic: O
# , true: O predic: O
# and true: O predic: O
# then true: O predic: O
# his true: O predic: O
# widow true: O predic: O
# blew true: O predic: O
# all true: O predic: O
# the true: O predic: O
# money true: O predic: O
# on true: O predic: O
# paying true: O predic: O
# said true: O predic: O
# debt true: O predic: O
# ( true: O predic: O
# idk true: O predic: O
# why true: O predic: O
# tho true: O predic: O
# something true: O predic: O
# something true: O predic: O
# moral true: O predic: O
# obligation true: O predic: O
# ) true: O predic: O
# . true: O predic: O
#
#
# @USER true: O predic: O
# @USER true: O predic: O
# @USER true: O predic: O
# I true: O predic: O
# had true: O predic: O
# a true: O predic: O
# uncle true: O predic: O
# addicted true: O predic: O
# to true: O predic: O
# Pepsi true: O predic: O
# cola true: O predic: O
# , true: O predic: O
# he true: O predic: O
# drank true: O predic: O
# a true: O predic: O
# case true: O predic: O
# a true: O predic: O
# day true: O predic: O
# , true: O predic: O
# til true: O predic: O
# diabetes true: I-C predic: I-C
# took true: I-E predic: I-E
# 1 true: I-E predic: I-E
# of true: I-E predic: I-E
# his true: I-E predic: I-E
# legs true: I-E predic: I-E
# , true: O predic: O
# and true: O predic: O
# the true: O predic: O
# other true: O predic: O
# ... true: O predic: O
#
#
# What true: O predic: O
# a true: O predic: O
# twit true: O predic: O
# all true: O predic: O
# of true: O predic: O
# sudden true: O predic: O
# the true: O predic: O
# guy true: O predic: O
# who true: O predic: O
# looted true: O predic: O
# Medicare true: O predic: O
# is true: O predic: O
# dumbfounded true: I-E predic: O
# by true: O predic: O
# cost true: I-C predic: O
# of true: I-C predic: O
# insulin true: I-C predic: O
# notice true: O predic: O
# how true: O predic: O
# Republicans true: O predic: O
# never true: O predic: O
# answer true: O predic: O
# the true: O predic: O
# question true: O predic: O
# but true: O predic: O
# come true: O predic: O
# up true: O predic: O
# with true: O predic: O
# a true: O predic: O
# new true: O predic: O
# talking true: O predic: O
# point true: O predic: O
# cost true: O predic: O
# of true: O predic: O
# medical true: O predic: O
# care true: O predic: O
# did true: O predic: O
# this true: O predic: O
# guy true: O predic: O
# just true: O predic: O
# get true: O predic: O
# thrown true: O predic: O
# off true: O predic: O
# back true: O predic: O
# of true: O predic: O
# truck true: O predic: O
#
#
# Heard true: O predic: O
# an true: O predic: O
# obese true: O predic: O
# woman true: O predic: O
# say true: O predic: O
# her true: O predic: O
# diabetes true: I-C predic: I-C
# medication true: I-C predic: I-C
# gives true: O predic: O
# her true: O predic: O
# a true: O predic: O
# sweet true: I-E predic: I-E
# tooth true: I-E predic: I-E
#
#
# after true: O predic: O
# two true: O predic: O
# years true: O predic: O
# of true: O predic: O
# learning true: O predic: O
# medicine true: O predic: O
# my true: O predic: O
# biggest true: O predic: O
# fears true: I-E predic: O
# are true: O predic: O
# developing true: I-C predic: I-C
# diabetes true: I-C predic: I-C
# or true: O predic: O
# getting true: O predic: O
# compartment true: O predic: O
# syndrome true: O predic: O
#
#
# i true: O predic: O
# got true: O predic: O
# this true: O predic: O
# 10 true: O predic: O
# year true: O predic: O
# diabetes true: I-C predic: O
# medal true: O predic: O
# in true: O predic: O
# the true: O predic: O
# mail true: O predic: O
# for true: O predic: O
# my true: O predic: O
# 10 true: O predic: O
# year true: O predic: O
# diaversary true: O predic: O
# today true: O predic: O
# so true: O predic: O
# a true: O predic: O
# big true: O predic: O
# congratulations true: O predic: O
# to true: O predic: O
# me true: O predic: O
# for true: O predic: O
# living true: O predic: O
# with true: O predic: O
# a true: O predic: O
# nonworking true: I-E predic: I-E
# pancreas true: I-E predic: I-E
# for true: O predic: O
# half true: O predic: O
# my true: O predic: O
# life true: O predic: O
# :p true: O predic: O
# artying_face true: O predic: O
# : true: O predic: O
# :p true: O predic: O
# artying_face true: O predic: O
# : true: O predic: O
# HTTPURL true: O predic: O
#
#
# ive true: O predic: O
# seen true: O predic: O
# storys true: O predic: O
# of true: O predic: O
# people true: O predic: O
# dying true: I-E predic: I-E
# because true: O predic: O
# they true: O predic: O
# cant true: I-C predic: I-C
# afford true: I-C predic: I-C
# it true: O predic: O
# and true: O predic: O
# without true: O predic: O
# insurance true: O predic: O
# its true: O predic: O
# so true: O predic: O
# much true: O predic: O
# more true: O predic: O
# expensive true: O predic: I-E
#
#
# You true: O predic: O
# ' true: O predic: O
# re true: O predic: O
# a true: O predic: O
# fucking true: O predic: O
# sociopath true: O predic: O
# if true: O predic: O
# fellow true: O predic: O
# human true: O predic: O
# beings true: O predic: O
# dying true: I-E predic: I-E
# bc true: O predic: O
# they true: O predic: O
# can't true: I-C predic: I-C
# afford true: I-C predic: I-C
# insulin true: I-C predic: I-C
# does true: O predic: O
# n't true: O predic: O
# rile true: O predic: O
# up true: O predic: O
# emotion true: O predic: O
# . true: O predic: O
#
#
# My true: O predic: O
# #CGM true: I-C predic: I-E
# sensor true: O predic: I-E
# in true: O predic: I-E
# my true: O predic: I-E
# arm true: O predic: I-E
# is true: O predic: I-E
# itching true: I-E predic: I-E
# like true: O predic: O
# crazy true: O predic: O
# ( true: O predic: O
# it true: O predic: O
# ' true: O predic: O
# s true: O predic: O
# almost true: O predic: O
# time true: O predic: O
# to true: O predic: O
# change true: O predic: O
# it true: O predic: O
# so true: O predic: O
# I true: O predic: O
# bet true: O predic: O
# the true: O predic: O
# skin true: O predic: O
# is true: O predic: O
# irritated true: O predic: O
# ) true: O predic: O
# and true: O predic: O
# I true: O predic: O
# just true: O predic: O
# want true: O predic: O
# to true: O predic: O
# rip true: O predic: O
# it true: O predic: O
# outttt true: O predic: O
#
#
# Now true: O predic: O
# we true: O predic: O
# just true: O predic: O
# need true: O predic: O
# to true: O predic: O
# try true: O predic: O
# to true: O predic: O
# get true: O predic: O
# his true: O predic: O
# insulin true: I-C predic: I-C
# regulated true: I-C predic: I-C
# and true: O predic: O
# hopefully true: O predic: O
# the true: O predic: O
# seizures true: I-E predic: I-E
# stop true: I-E predic: I-E
#
#
# @USER true: O predic: O
# @USER true: O predic: O
# @USER true: O predic: O
# If true: O predic: O
# I true: O predic: O
# died true: I-E predic: I-E
# due true: O predic: O
# to true: O predic: O
# corona true: I-C predic: O
# because true: O predic: O
# I true: O predic: O
# overweight true: I-C predic: I-C
# or true: O predic: O
# had true: O predic: O
# diabetes true: I-C predic: I-C
# or true: O predic: O
# smoked true: O predic: O
# I true: O predic: O
# would true: O predic: O
# think true: O predic: O
# the true: O predic: O
# discussion true: O predic: O
# is true: O predic: O
# beneficial true: O predic: O
# as true: O predic: O
# it true: O predic: O
# may true: O predic: O
# prevent true: O predic: O
# more true: O predic: O
# deaths true: O predic: O
# . true: O predic: O
#
#
# @USER true: O predic: O
# after true: O predic: O
# my true: O predic: O
# mom true: O predic: O
# legs true: I-E predic: I-E
# were true: I-E predic: I-E
# cut true: I-E predic: I-E
# off true: I-E predic: I-E
# because true: O predic: O
# of true: O predic: O
# diabetes true: I-C predic: I-C
# , true: O predic: O
# she true: O predic: O
# was true: O predic: O
# always true: O predic: O
# crying true: I-E predic: I-E
# but true: O predic: O
# because true: O predic: O
# of true: O predic: O
# you true: O predic: O
# jakezyrus true: O predic: O
# and true: O predic: O
# your true: O predic: O
# amazing true: O predic: O
# voice true: O predic: O
# she true: O predic: O
# ' true: O predic: O
# s true: O predic: O
# still true: O predic: O
# fighting true: O predic: O
# . true: O predic: O
#
#
# USER true: O predic: O
# USER true: O predic: O
# The true: O predic: O
# trouble true: O predic: O
# is true: O predic: O
# , true: O predic: O
# there true: O predic: O
# are true: O predic: O
# people true: O predic: O
# who true: O predic: O
# can true: O predic: O
# gain true: I-E predic: I-E
# weight true: I-E predic: I-E
# because true: O predic: O
# of true: O predic: O
# insulin true: I-C predic: I-C
# resistance true: I-C predic: I-C
# / true: O predic: O
# metabolic true: O predic: O
# syndrome true: O predic: O
# who true: O predic: O
# eat true: O predic: O
# what true: O predic: O
# is true: O predic: O
# regarded true: O predic: O
# as true: O predic: O
# a true: O predic: O
# healthy true: O predic: I-C
# diet true: O predic: I-C
# . true: O predic: O
#
#
# USER true: O predic: O
# Diabetic true: I-C predic: I-C
# brain true: O predic: I-E
# fog true: O predic: I-E
# its true: O predic: O
# real true: O predic: O
# he true: O predic: O
# needs true: O predic: O
# to true: O predic: O
# lose true: I-E predic: I-E
# a true: I-E predic: I-E
# lot true: I-E predic: I-E
# f true: I-E predic: I-E
# weight true: I-E predic: I-E
# . true: O predic: O
#
#
# Feel true: O predic: O
# well true: O predic: O
# bad true: O predic: O
# that true: O predic: O
# a true: O predic: O
# diabetic true: I-C predic: I-C
# woman true: O predic: O
# on true: O predic: O
# the true: O predic: O
# bus true: O predic: O
# felt true: O predic: O
# the true: O predic: O
# need true: O predic: O
# to true: O predic: O
# explain true: O predic: O
# to true: O predic: O
# me true: O predic: O
# that true: O predic: O
# she true: O predic: O
# ' true: O predic: O
# s true: O predic: O
# not true: O predic: O
# a true: O predic: O
# junkie true: O predic: O
# and true: O predic: O
# just true: O predic: O
# taking true: I-E predic: O
# her true: I-E predic: O
# blood true: I-E predic: O
# : true: O predic: O
# face_with_tears_of_joy true: O predic: O
# : true: O predic: O
# : true: O predic: O
# weary_face true: O predic: O
# : true: O predic: O
#
#
# Less true: I-C predic: I-C
# diabetes true: I-C predic: I-C
# means true: O predic: O
# less true: I-E predic: O
# COVID true: I-E predic: I-E
# ...
# in true: O predic: O
# a true: O predic: O
# high true: I-E predic: I-E
# risk true: I-E predic: I-E
# category true: O predic: I-E
# because true: O predic: O
# I true: O predic: O
# 'm true: O predic: O
# diabetic true: I-C predic: I-C
# & true: O predic: O
# asthmatic true: O predic: O
# but true: O predic: O
# I true: O predic: O
# 'm true: O predic: O
# not true: O predic: O
# worried true: O predic: I-E
# . true: O predic: O
#
#
# People true: O predic: O
# are true: O predic: O
# literally true: O predic: O
# dying true: I-E predic: I-E
# because true: O predic: O
# they true: O predic: O
# can't true: I-C predic: I-C
# diabetes true: I-C predic: I-C
# medicine true: I-C predic: I-C
# . true: O predic: O
#
#
# USER true: O predic: O
# USER true: O predic: O
# I true: O predic: O
# shall true: O predic: O
# try true: O predic: O
# to true: O predic: O
# solve true: O predic: O
# them true: O predic: O
# issues true: O predic: O
# with true: O predic: O
# love true: O predic: O
# :clapping_hands: true: O predic: O
# :light_skin_tone: true: O predic: O
# & true: O predic: O
# food true: O predic: O
# :pregnant_woman: true: O predic: O
# :light_skin_tone: true: O predic: O
# Healthy true: I-E predic: O
# food true: I-E predic: O
# * true: O predic: O
# because true: O predic: O
# diabetes true: I-C predic: I-C
# :relieved_face: true: O predic: O
#
#
# Finally true: O predic: O
# got true: O predic: I-C
# my true: O predic: I-C
# insulin true: I-C predic: I-C
# I true: O predic: O
# went true: O predic: O
# one true: O predic: O
# day true: O predic: O
# without true: O predic: O
# and true: O predic: O
# I true: O predic: O
# 'm true: O predic: O
# a true: O predic: O
# total true: O predic: O
# grouch true: I-E predic: I-E
# ! true: O predic: O
#
#
# Becoming true: O predic: O
# more true: O predic: O
# & true: O predic: O
# more true: O predic: O
# comfy true: I-E predic: O
# with true: O predic: O
# my true: O predic: O
# insulin true: I-C predic: I-C
# pump true: I-C predic: I-C
# being true: O predic: O
# visible true: O predic: O
# ! true: O predic: O
#
#
# I true: O predic: O
# ' true: O predic: O
# m true: O predic: O
# already true: O predic: O
# feeling true: O predic: O
# shit true: O predic: O
# enough true: O predic: O
# tonight true: O predic: O
# OF true: O predic: O
# COURSE true: O predic: O
# my true: O predic: O
# diabetes true: I-C predic: I-C
# makes true: O predic: O
# it true: O predic: O
# worse true: O predic: O
# and true: O predic: O
# keeps true: I-E predic: O
# me true: I-E predic: O
# up true: I-E predic: O
# for true: O predic: O
# 2 true: O predic: O
# and true: O predic: O
# a true: O predic: O
# half true: O predic: O
# hours true: O predic: O
#
#
# Must true: O predic: O
# read true: O predic: O
# I true: O predic: O
# Had true: O predic: O
# to true: O predic: O
# Bury true: I-E predic: I-E
# My true: O predic: O
# 26 true: O predic: O
# Year true: O predic: O
# Old true: O predic: O
# Son true: O predic: O
# Because true: O predic: O
# He true: O predic: O
# Could true: I-C predic: I-C
# n't true: I-C predic: I-C
# Afford true: I-C predic: I-C
# Insulin true: I-C predic: I-C
# HTTPURL true: O predic: O
# via true: O predic: O
# USER true: O predic: O
#
#
# I true: O predic: O
# was true: O predic: O
# diagnosed true: O predic: O
# with true: O predic: O
# type true: I-C predic: I-C
# 1 true: I-C predic: I-C
# diabetes true: I-C predic: I-C
# and true: O predic: O
# asked true: O predic: O
# for true: O predic: O
# Time true: O predic: O
# Of true: O predic: O
# My true: O predic: O
# Self true: O predic: O
# employment true: O predic: O
# as true: O predic: O
# this true: O predic: O
# nearly true: I-E predic: O
# killed true: I-E predic: O
# me true: I-E predic: O
# . true: O predic: O
#
#
# I true: O predic: O
# have true: O predic: O
# Type true: I-C predic: I-C
# 1 true: I-C predic: I-C
# diabetes true: I-C predic: I-C
# and true: O predic: O
# my true: O predic: O
# immune true: I-E predic: I-E
# system true: I-E predic: I-E
# can't true: I-E predic: I-E
# fight true: I-E predic: I-E
# COVID true: I-E predic: I-E
# and true: O predic: O
# I true: O predic: O
# work true: O predic: O
# in true: O predic: O
# Assisted true: O predic: O
# Living true: O predic: O
# where true: O predic: O
# your true: O predic: O
# elders true: O predic: O
# are true: O predic: O
# scared true: O predic: I-E
# and true: O predic: O
# lonely true: O predic: O
# and true: O predic: O
# I true: O predic: O
# 'm true: O predic: O
# trying true: O predic: O
# to true: O predic: O
# keep true: O predic: O
# them true: O predic: O
# alive true: O predic: I-E
# from true: O predic: O
# a true: O predic: O
# holes true: O predic: O
# like true: O predic: O
# you true: O predic: O
# . true: O predic: O
#
#
# USER true: O predic: O
# This true: O predic: O
# is true: O predic: O
# almost true: O predic: O
# as true: O predic: O
# funny true: O predic: O
# as true: O predic: O
# people true: O predic: O
# dying true: I-E predic: I-E
# after true: O predic: O
# rationing true: I-C predic: I-C
# insulin true: I-C predic: I-C
#
#
# USER true: O predic: O
# My true: O predic: O
# father true: O predic: O
# had true: O predic: O
# knee true: O predic: O
# surgery true: O predic: O
# and true: O predic: O
# had true: O predic: O
# to true: O predic: O
# stay true: I-E predic: I-E
# overnight true: I-E predic: I-E
# because true: O predic: O
# of true: O predic: O
# his true: O predic: O
# diabetes true: I-C predic: I-C
# and true: O predic: O
# the true: O predic: O
# overall true: O predic: O
# bill true: O predic: O
# was true: O predic: O
# 45k true: O predic: O
# . true: O predic: O
#
#
# Of true: O predic: O
# course true: O predic: O
# I true: O predic: O
# started true: O predic: O
# to true: O predic: O
# panic true: O predic: I-E
# cause true: O predic: O
# no true: O predic: O
# one true: O predic: O
# in true: O predic: O
# my true: O predic: O
# family true: O predic: O
# have true: O predic: O
# diabetes true: O predic: I-C
# NO true: O predic: O
# ONE true: O predic: O
# and true: O predic: O
# almost true: O predic: O
# every true: O predic: O
# person true: O predic: O
# that true: O predic: O
# has true: O predic: O
# diabetes true: I-E predic: I-C
# has true: O predic: O
# it true: O predic: O
# cause true: O predic: O
# of true: O predic: O
# their true: O predic: O
# genes true: I-C predic: I-C
# . true: O predic: O
#
#
# Always true: O predic: O
# and true: O predic: O
# the true: O predic: O
# heat true: I-C predic: I-C
# ( true: O predic: O
# sometimes true: O predic: O
# ) true: O predic: O
# makes true: O predic: O
# my true: O predic: O
# bloods true: I-E predic: I-E
# drop true: I-E predic: I-E
# rapidly true: I-E predic: I-E
# : true: O predic: O
# thinking_face true: O predic: O
# : true: O predic: O
# #T1D true: I-C predic: I-C
# #Heatwave true: I-C predic: I-C
# HTTPURL true: O predic: O
#
#
# So true: O predic: O
# , true: O predic: O
# I true: O predic: O
# get true: O predic: O
# it true: O predic: O
# , true: O predic: O
# but true: O predic: O
# I true: O predic: O
# ' true: O predic: O
# m true: O predic: O
# really true: O predic: O
# getting true: I-E predic: I-E
# sick true: I-E predic: I-E
# of true: O predic: I-E
# diet true: I-C predic: I-E
# discussions true: I-C predic: I-E
# when true: O predic: O
# it true: O predic: O
# comes true: O predic: O
# to true: O predic: O
# #diabetes true: O predic: O
# . true: O predic: O
#
#
# Seven true: O predic: O
# years true: O predic: O
# of true: O predic: O
# diabetic true: I-C predic: O
# hell true: O predic: O
# and true: O predic: O
# it true: O predic: O
# still true: O predic: O
# makes true: O predic: O
# me true: O predic: O
# want true: I-E predic: O
# to true: I-E predic: O
# die true: I-E predic: I-E
# In true: O predic: O
# nights true: O predic: O
# like true: O predic: O
# this true: O predic: O
# I true: O predic: O
# really true: O predic: O
# want true: O predic: O
# my true: O predic: O
# old true: O predic: O
# life true: O predic: O
# back true: O predic: O
# Without true: O predic: O
# all true: O predic: O
# that true: O predic: O
# shit true: O predic: O
# Just true: O predic: O
# normal true: O predic: O
# and true: O predic: O
# not true: O predic: O
# getting true: O predic: O
# told true: O predic: O
# that true: O predic: O
# I true: O predic: O
# maybe true: O predic: O
# can't true: O predic: O
# have true: O predic: O
# children true: O predic: O
# later true: O predic: O
# or true: O predic: O
# go true: O predic: O
# blind true: O predic: I-E
# if true: O predic: O
# I true: O predic: O
# do true: O predic: O
# n't true: O predic: O
# handle true: O predic: O
# my true: O predic: O
# situation true: O predic: O
# better true: O predic: O
#
#
# @USER true: O predic: O
# I true: O predic: O
# could true: O predic: O
# use true: O predic: O
# some true: O predic: O
# help true: O predic: O
# I true: O predic: O
# am true: O predic: O
# a true: O predic: O
# diabetic true: I-C predic: I-C
# and true: O predic: O
# I true: O predic: O
# am true: O predic: O
# insulin true: I-E predic: I-E
# dependent true: I-E predic: I-E
# and true: O predic: O
# even true: O predic: O
# with true: O predic: O
# my true: O predic: O
# health true: O predic: O
# insurance true: O predic: O
# I true: O predic: O
# can't true: O predic: I-E
# afford true: O predic: I-E
# my true: O predic: I-E
# insulin true: O predic: I-E
# . true: O predic: O
#
#
# USER true: O predic: O
# USER true: O predic: O
# My true: O predic: O
# child true: O predic: O
# has true: O predic: O
# Type true: I-C predic: I-C
# 1 true: I-C predic: I-C
# diabetes true: I-C predic: I-C
# , true: O predic: O
# it true: O predic: O
# can true: O predic: O
# cost true: I-E predic: I-E
# up true: O predic: I-E
# to true: O predic: I-E
# $ true: O predic: I-E
# 1k true: O predic: I-E
# a true: O predic: O
# month true: O predic: O
# for true: O predic: O
# prescriptions true: O predic: O
# , true: O predic: O
# it true: O predic: O
# 's true: O predic: O
# terrifying true: O predic: O
# ! true: O predic: O
#
#
# @USER true: O predic: O
# Eat true: O predic: O
# at true: O predic: O
# 11 true: O predic: O
# and true: O predic: O
# 5 true: O predic: O
# mainly true: O predic: O
# protein true: O predic: O
# and true: O predic: O
# veggies true: O predic: O
# These true: O predic: O
# are true: O predic: O
# the true: O predic: O
# times true: O predic: O
# where true: O predic: O
# the true: O predic: O
# insulin true: I-C predic: I-C
# drops true: I-C predic: I-C
# in true: O predic: O
# the true: O predic: O
# body true: O predic: O
# and true: O predic: O
# you true: O predic: O
# feel true: I-E predic: I-E
# hungry true: I-E predic: I-E
# Mainly true: O predic: O
# eat true: O predic: O
# when true: O predic: O
# hungry true: O predic: O
# and true: O predic: O
# drink true: O predic: O
# when true: O predic: O
# thirsty true: O predic: O
# Cut true: O predic: O
# the true: O predic: O
# sugar true: O predic: O
# to true: O predic: O
# zero true: O predic: O
# if true: O predic: O
# possible true: O predic: O
# It true: O predic: O
# ' true: O predic: O
# s true: O predic: O
# working true: O predic: O
# for true: O predic: O
# me true: O predic: O
# hope true: O predic: O
# it true: O predic: O
# will true: O predic: O
# work true: O predic: O
# for true: O predic: O
# you true: O predic: O
#
#
# Time true: O predic: O
# to true: O predic: O
# see true: O predic: O
# the true: O predic: O
# doctor true: O predic: O
# about true: O predic: O
# this true: O predic: O
# one true: O predic: O
# because true: O predic: O
# the true: O predic: O
# sensor true: I-C predic: O
# I true: O predic: O
# wore true: O predic: O
# that true: O predic: O
# goes true: O predic: O
# with true: O predic: O
# my true: O predic: O
# pump true: O predic: I-C
# was true: O predic: O
# incredibly true: O predic: O
# painful true: I-E predic: O
# and true: O predic: O
# didnt true: O predic: O
# work true: O predic: O
# for true: O predic: O
# me true: O predic: O
# . true: O predic: O
#
#
# My true: O predic: O
# son true: O predic: O
# needs true: O predic: O
# his true: O predic: O
# medical true: I-E predic: I-E
# care true: I-E predic: I-E
# deduction true: I-E predic: I-E
# as true: O predic: O
# he true: O predic: O
# has true: O predic: O
# Type true: I-C predic: I-C
# 1 true: I-C predic: I-C
# diabetes true: I-C predic: I-C
# . true: O predic: O
#
#
# It true: O predic: O
# eliminates true: O predic: O
# a true: O predic: O
# ton true: O predic: O
# of true: O predic: O
# carbs true: O predic: O
# and true: O predic: O
# reduces true: I-C predic: I-C
# insulin true: I-C predic: I-C
# , true: O predic: O
# which true: O predic: O
# in true: O predic: O
# turn true: O predic: O
# reduces true: I-E predic: I-E
# hunger true: I-E predic: I-E
# . true: O predic: O
#
#
# @USER true: O predic: O
# able true: O predic: O
# to true: O predic: O
# make true: O predic: I-E
# enough true: O predic: I-E
# money true: I-C predic: I-E
# to true: O predic: I-E
# pay true: I-E predic: I-E
# for true: I-E predic: I-E
# my true: I-E predic: I-E
# insulin true: I-E predic: I-E
# and true: O predic: O
# keep true: O predic: O
# food true: I-C predic: O
# in true: O predic: O
# the true: O predic: O
# house true: O predic: O
# because true: O predic: O
# i true: O predic: O
# need true: O predic: O
# food true: O predic: O
# and true: O predic: O
# insulin true: O predic: I-E
# to true: O predic: I-E
# regulate true: I-E predic: I-E
# my true: I-E predic: I-E
# blood true: I-E predic: I-E
# sugar true: I-E predic: I-E
# to true: O predic: O
# stay true: I-E predic: O
# healthy true: I-E predic: O
# . true: O predic: O
#
#
# Dying true: I-E predic: I-E
# from true: O predic: O
# lack true: I-C predic: I-C
# of true: I-C predic: I-C
# insulin true: I-C predic: I-C
# is true: O predic: O
# torture true: O predic: O
# , true: O predic: O
# excruciatingly true: O predic: I-E
# painful true: O predic: I-E
# . true: O predic: O
#
#
# USER true: O predic: O
# Plz true: O predic: O
# sister true: O predic: O
# I true: O predic: O
# m true: O predic: O
# not true: O predic: O
# in true: O predic: O
# my true: O predic: O
# home true: O predic: O
# and true: O predic: O
# will true: O predic: O
# go true: O predic: O
# to true: O predic: O
# exam true: O predic: O
# center true: O predic: O
# with true: O predic: O
# uncle true: O predic: O
# who true: O predic: O
# is true: O predic: O
# diabetic true: I-C predic: I-C
# please true: O predic: O
# mam true: O predic: O
# I true: O predic: O
# do true: O predic: O
# n't true: O predic: O
# want true: O predic: O
# to true: O predic: O
# risk true: I-E predic: O
# their true: I-E predic: O
# lives true: I-E predic: O
# pls true: O predic: O
# support true: O predic: O
# us true: O predic: O
#
#
# USER true: O predic: O
# USER true: O predic: O
# And true: O predic: O
# keto true: I-C predic: I-C
# is true: O predic: O
# terrible true: I-E predic: O
# as true: O predic: O
# well true: O predic: O
# but true: O predic: O
# that true: O predic: O
# 's true: O predic: O
# a true: O predic: O
# different true: O predic: O
# story true: O predic: O
# . true: O predic: O
#
#
# USER true: O predic: O
# $ true: O predic: O
# NicholasxDrew true: O predic: O
# my true: O predic: O
# fiance true: O predic: O
# USER true: O predic: O
# is true: O predic: O
# a true: O predic: O
# T1 true: I-C predic: I-C
# diabetic true: I-C predic: I-C
# that true: O predic: O
# could true: O predic: O
# use true: O predic: O
# any true: O predic: O
# amount true: O predic: O
# tremendously true: O predic: O
# she true: O predic: O
# struggles true: I-E predic: I-E
# monthly true: O predic: O
# if true: O predic: O
# not true: O predic: O
# bi true: O predic: O
# weekly true: O predic: O
# to true: O predic: O
# come true: O predic: O
# up true: O predic: O
# with true: O predic: O
# the true: O predic: O
# funds true: O predic: O
# for true: O predic: O
# her true: O predic: O
# insulin true: O predic: O
# that true: O predic: O
# she true: O predic: O
# unfortunately true: O predic: O
# will true: O predic: O
# be true: O predic: O
# stuck true: O predic: O
# struggling true: O predic: I-E
# w true: O predic: O
# for true: O predic: O
# the true: O predic: O
# rest true: O predic: O
# of true: O predic: O
# her true: O predic: O
# days true: O predic: O
# . true: O predic: O
#
#
# My true: O predic: O
# friend true: O predic: O
# has true: O predic: O
# been true: O predic: O
# diabetic true: I-C predic: I-C
# 4 true: O predic: O
# years true: O predic: O
# more true: O predic: O
# than true: O predic: O
# me true: O predic: O
# and true: O predic: O
# she true: O predic: O
# ' true: O predic: O
# s true: O predic: O
# had true: O predic: O
# multiple true: O predic: O
# eye true: I-E predic: I-E
# injections true: I-E predic: I-E
# & true: O predic: I-E
# surgeries true: I-E predic: I-E
# + true: O predic: O
# has true: O predic: O
# kidney true: I-E predic: I-E
# failure true: I-E predic: I-E
# & true: O predic: O
# needs true: O predic: O
# dialysis true: I-E predic: I-E
# multiple true: O predic: O
# times true: O predic: O
# a true: O predic: O
# week true: O predic: O
# . true: O predic: O
